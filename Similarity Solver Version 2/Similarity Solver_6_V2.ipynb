# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
g = 9.807  # Acceleration due to gravity in m/s^2
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.8e5 
Power1 = 1032.9
H1 = P1/rho1/g; Q1 = M1/rho1

#D2 = 50e-3; rho2 = 1286; mu2 = 33.82e-3
D2 = 50e-3; N2 = 7000

# Define lower and upper bounds
lb = [1100, 1e-3, 0, 2.0e5, 0.1e-3]  # Lower bounds
ub = [1300, 35e-3, 10000, 4.25e5, 1e-3]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    rho2, mu2, Power2, P2 ,Q2 = x
    
    # Specific speed equation residual
    #F1 = (N1 * np.sqrt(Q1) / (P1/(rho1*g))**(3/4)) - (N2 * np.sqrt(Q2) / (P2/(rho2*g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( Q1 / (N1 * D1**3)) - (Q2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( g*P1/(rho1*g) / (N1**2 * D1**2)) - ( g*P2/(rho2*g) / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (rho1 * N1 * D1**2 / mu1) - (rho2 * N2 * D2**2 / mu2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( Power1 / ( rho1 * N1**3 * D1**5) ) - ( Power2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1, 1, 1e-3, 1]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([1200, 30e-3, 800, 3e5, 0.3e-3])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 0.154843
# basinhopping step 1: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 1.35525e-14
# found new global minimum on step 1 with function value 1.35525e-14
# basinhopping step 2: f 1.35525e-14 trial_f 2.20073e+12 accepted 0  lowest_f 1.35525e-14
# basinhopping step 3: f 1.35525e-14 trial_f 2.83013e+12 accepted 0  lowest_f 1.35525e-14
# basinhopping step 4: f 1.35525e-14 trial_f 2.67694e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 5: f 1.35525e-14 trial_f 9.63523e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 6: f 1.35525e-14 trial_f 3.51351e+12 accepted 0  lowest_f 1.35525e-14
# basinhopping step 7: f 1.35525e-14 trial_f 9.91791e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 8: f 1.35525e-14 trial_f 1.08912e+12 accepted 0  lowest_f 1.35525e-14
# basinhopping step 9: f 0.0228682 trial_f 0.0228682 accepted 1  lowest_f 1.35525e-14
# basinhopping step 10: f 4.21282e-22 trial_f 4.21282e-22 accepted 1  lowest_f 4.21282e-22
# found new global minimum on step 10 with function value 4.21282e-22
# basinhopping step 11: f 4.21282e-22 trial_f 0.856204 accepted 0  lowest_f 4.21282e-22
# basinhopping step 12: f 4.21282e-22 trial_f 6.68152e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 13: f 4.21282e-22 trial_f 2.47445e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 14: f 4.21282e-22 trial_f 4.2442e+10 accepted 0  lowest_f 4.21282e-22
# basinhopping step 15: f 4.21282e-22 trial_f 1.85046e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 16: f 4.21282e-22 trial_f 1.41453e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 17: f 4.21282e-22 trial_f 4.90659e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 18: f 4.21282e-22 trial_f 6.44791e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 19: f 4.21282e-22 trial_f 2.08199e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 20: f 4.03872e-09 trial_f 4.03872e-09 accepted 1  lowest_f 4.21282e-22
# basinhopping step 21: f 4.03872e-09 trial_f 6.40425e+11 accepted 0  lowest_f 4.21282e-22
# basinhopping step 22: f 4.03872e-09 trial_f 1.55509e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 23: f 4.03872e-09 trial_f 1.75712e+11 accepted 0  lowest_f 4.21282e-22
# basinhopping step 24: f 4.03872e-09 trial_f 2.61195 accepted 0  lowest_f 4.21282e-22
# basinhopping step 25: f 4.03872e-09 trial_f 3.28635e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 26: f 4.03872e-09 trial_f 2.25601e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 27: f 0.00270233 trial_f 0.00270233 accepted 1  lowest_f 4.21282e-22
# basinhopping step 28: f 0.00270233 trial_f 1.02317e+12 accepted 0  lowest_f 4.21282e-22
# basinhopping step 29: f 0.00270233 trial_f 6.92066e+11 accepted 0  lowest_f 4.21282e-22
# basinhopping step 30: f 0.00270233 trial_f 4.90536e+11 accepted 0  lowest_f 4.21282e-22
# basinhopping step 31: f 0.00270233 trial_f 3.33374e+11 accepted 0  lowest_f 4.21282e-22
# basinhopping step 32: f 0.00270233 trial_f 6.10684e+10 accepted 0  lowest_f 4.21282e-22
# basinhopping step 33: f 1.42711e-09 trial_f 1.42711e-09 accepted 1  lowest_f 4.21282e-22
# basinhopping step 34: f 0.0174803 trial_f 0.0174803 accepted 1  lowest_f 4.21282e-22
# basinhopping step 35: f 2.97645e-39 trial_f 2.97645e-39 accepted 1  lowest_f 2.97645e-39
# found new global minimum on step 35 with function value 2.97645e-39
# basinhopping step 36: f 2.97645e-39 trial_f 3.0584e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 37: f 2.97645e-39 trial_f 4.49062e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 38: f 2.97645e-39 trial_f 1.11809e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 39: f 2.97645e-39 trial_f 1.35268e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 40: f 2.97645e-39 trial_f 1.89981 accepted 0  lowest_f 2.97645e-39
# basinhopping step 41: f 2.97645e-39 trial_f 1.01785e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 42: f 0.0100494 trial_f 0.0100494 accepted 1  lowest_f 2.97645e-39
# basinhopping step 43: f 0.0100494 trial_f 3.77806e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 44: f 0.0100494 trial_f 1.74044e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 45: f 0.0100494 trial_f 1.52673e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 46: f 0.0100494 trial_f 1.37047e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 47: f 0.0100494 trial_f 5.39793e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 48: f 0.0100494 trial_f 1.15555e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 49: f 0.0100494 trial_f 1.8788e+12 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.180000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 50: f 0.0100494 trial_f 1.33351 accepted 0  lowest_f 2.97645e-39
# basinhopping step 51: f 0.0100494 trial_f 1.41463e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 52: f 0.0100494 trial_f 2.4136e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 53: f 0.0100494 trial_f 8.21848e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 54: f 3.91668e-12 trial_f 3.91668e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 55: f 3.91668e-12 trial_f 8.6274e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 56: f 3.91668e-12 trial_f 1.04943e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 57: f 3.91668e-12 trial_f 5.82432e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 58: f 3.91668e-12 trial_f 8.03402e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 59: f 4.01211e-09 trial_f 4.01211e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 60: f 4.01211e-09 trial_f 2.46908e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 61: f 4.01211e-09 trial_f 1.87949e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 62: f 4.01211e-09 trial_f 3.95009e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 63: f 4.01211e-09 trial_f 1.09876e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 64: f 4.01211e-09 trial_f 6.8792e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 65: f 4.01211e-09 trial_f 2.01867 accepted 0  lowest_f 2.97645e-39
# basinhopping step 66: f 4.01211e-09 trial_f 1.02262e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 67: f 4.01211e-09 trial_f 2.3501e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 68: f 4.01211e-09 trial_f 1.91237e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 69: f 4.01211e-09 trial_f 1291.65 accepted 0  lowest_f 2.97645e-39
# basinhopping step 70: f 4.01211e-09 trial_f 703.143 accepted 0  lowest_f 2.97645e-39
# basinhopping step 71: f 4.01211e-09 trial_f 625.823 accepted 0  lowest_f 2.97645e-39
# basinhopping step 72: f 4.01211e-09 trial_f 2.06628e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 73: f 4.01211e-09 trial_f 305.082 accepted 0  lowest_f 2.97645e-39
# basinhopping step 74: f 4.01211e-09 trial_f 1816.06 accepted 0  lowest_f 2.97645e-39
# basinhopping step 75: f 0.0688377 trial_f 0.0688377 accepted 1  lowest_f 2.97645e-39
# basinhopping step 76: f 0.0688377 trial_f 38566.7 accepted 0  lowest_f 2.97645e-39
# basinhopping step 77: f 0.0688377 trial_f 1.96177e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 78: f 0.0688377 trial_f 6.82559e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 79: f 0.0688377 trial_f 1.25055e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 80: f 0.0688377 trial_f 1.14356e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 81: f 0.0688377 trial_f 1.04827e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 82: f 0.00497983 trial_f 0.00497983 accepted 1  lowest_f 2.97645e-39
# basinhopping step 83: f 0.00497983 trial_f 3.10071e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 84: f 0.00497983 trial_f 3.5197e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 85: f 0.00497983 trial_f 1.40599e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 86: f 0.00497983 trial_f 1.79163e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 87: f 0.00497983 trial_f 2.97039e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 88: f 0.00497983 trial_f 6.05523e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 89: f 0.00497983 trial_f 1.53945e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 90: f 0.00497983 trial_f 1.77201e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 91: f 1.27915e-09 trial_f 1.27915e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 92: f 1.27915e-09 trial_f 1.39512e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 93: f 1.27915e-09 trial_f 3.94125e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 94: f 1.27915e-09 trial_f 3.09623e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 95: f 1.27915e-09 trial_f 5.60566e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 96: f 1.27915e-09 trial_f 2.09385e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 97: f 1.27915e-09 trial_f 1.57254e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 98: f 0.0524186 trial_f 0.0524186 accepted 1  lowest_f 2.97645e-39
# basinhopping step 99: f 0.0524186 trial_f 1.411e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.150000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 100: f 0.000118447 trial_f 0.000118447 accepted 1  lowest_f 2.97645e-39
# basinhopping step 101: f 0.000118447 trial_f 3.81903 accepted 0  lowest_f 2.97645e-39
# basinhopping step 102: f 0.000118447 trial_f 1.01066e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 103: f 0.000118447 trial_f 2.50661e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 104: f 0.000118447 trial_f 6.06779e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 105: f 0.000118447 trial_f 1.86604e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 106: f 0.000118447 trial_f 7.37382e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 107: f 0.000118447 trial_f 6.24639e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 108: f 0.000118447 trial_f 1.30698e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 109: f 0.000118447 trial_f 4.35972e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 110: f 0.000118447 trial_f 4.67895e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 111: f 0.000118447 trial_f 3.71548e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 112: f 0.000118447 trial_f 2.62394e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 113: f 0.000118447 trial_f 3.76685e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 114: f 0.000118447 trial_f 8.86264e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 115: f 0.000118447 trial_f 690.004 accepted 0  lowest_f 2.97645e-39
# basinhopping step 116: f 4.03908e-09 trial_f 4.03908e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 117: f 0.00049921 trial_f 0.00049921 accepted 1  lowest_f 2.97645e-39
# basinhopping step 118: f 0.00049921 trial_f 5.99081e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 119: f 0.00049921 trial_f 1.20688e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 120: f 0.00049921 trial_f 2.21119e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 121: f 0.00049921 trial_f 4.56803e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 122: f 0.00049921 trial_f 1.99435e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 123: f 0.00049921 trial_f 2.67595e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 124: f 0.00049921 trial_f 3.86847e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 125: f 0.00049921 trial_f 7.32292e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 126: f 0.00049921 trial_f 3.05458e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 127: f 0.00049921 trial_f 3.01681e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 128: f 0.00049921 trial_f 4.08017e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 129: f 0.00049921 trial_f 1.94445e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 130: f 0.00049921 trial_f 4.0855e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 131: f 0.00049921 trial_f 18.072 accepted 0  lowest_f 2.97645e-39
# basinhopping step 132: f 0.00049921 trial_f 3.59388e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 133: f 0.00049921 trial_f 1.01488e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 134: f 0.00049921 trial_f 2.72064e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 135: f 0.00049921 trial_f 9.42903e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 136: f 0.00049921 trial_f 4.51374e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 137: f 0.00049921 trial_f 3.40667e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 138: f 7.25013e-35 trial_f 7.25013e-35 accepted 1  lowest_f 2.97645e-39
# basinhopping step 139: f 7.25013e-35 trial_f 5.47195e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 140: f 7.25013e-35 trial_f 4.4673e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 141: f 7.25013e-35 trial_f 1.91616e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 142: f 7.25013e-35 trial_f 2272.45 accepted 0  lowest_f 2.97645e-39
# basinhopping step 143: f 7.25013e-35 trial_f 1.72906e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 144: f 7.25013e-35 trial_f 5.16259e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 145: f 7.25013e-35 trial_f 1.5078e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 146: f 7.25013e-35 trial_f 5.81169e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 147: f 7.25013e-35 trial_f 6.46194e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 148: f 7.25013e-35 trial_f 1.75072e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 149: f 7.25013e-35 trial_f 3.51264e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.126667 target 0.500000 new stepsize 0.729 old stepsize 0.81
# basinhopping step 150: f 7.25013e-35 trial_f 2.67414e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 151: f 7.25013e-35 trial_f 1.59889e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 152: f 7.25013e-35 trial_f 1.91912e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 153: f 7.25013e-35 trial_f 1.66534e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 154: f 7.25013e-35 trial_f 1.51145e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 155: f 7.25013e-35 trial_f 7.59324e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 156: f 7.25013e-35 trial_f 5.05635e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 157: f 7.25013e-35 trial_f 5.13908e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 158: f 7.25013e-35 trial_f 4.68722e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 159: f 7.25013e-35 trial_f 5.47947e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 160: f 7.25013e-35 trial_f 4.51626e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 161: f 7.25013e-35 trial_f 5.91188e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 162: f 7.25013e-35 trial_f 1.95768e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 163: f 0.000467976 trial_f 0.000467976 accepted 1  lowest_f 2.97645e-39
# basinhopping step 164: f 0.000467976 trial_f 1.17719e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 165: f 0.000467976 trial_f 1.02237e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 166: f 0.0138874 trial_f 0.0138874 accepted 1  lowest_f 2.97645e-39
# basinhopping step 167: f 0.0138874 trial_f 8.3886e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 168: f 0.0138874 trial_f 4.56868e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 169: f 0.0138874 trial_f 3.97375e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 170: f 0.0138874 trial_f 9.68383 accepted 0  lowest_f 2.97645e-39
# basinhopping step 171: f 0.0138874 trial_f 46.8602 accepted 0  lowest_f 2.97645e-39
# basinhopping step 172: f 0.0138874 trial_f 1.21057e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 173: f 0.0138874 trial_f 3.70863e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 174: f 0.0138874 trial_f 8.80384e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 175: f 0.0138874 trial_f 1.1792e+12 accepted 0  lowest_f 2.97645e-39
# warning: basinhopping: local minimization failure
# basinhopping step 176: f 0.0138874 trial_f 2.71578e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 177: f 0.0138874 trial_f 3.4716e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 178: f 6.60474e-05 trial_f 6.60474e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 179: f 6.60474e-05 trial_f 3.31524e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 180: f 1.21982e-13 trial_f 1.21982e-13 accepted 1  lowest_f 2.97645e-39
# basinhopping step 181: f 0.000935655 trial_f 0.000935655 accepted 1  lowest_f 2.97645e-39
# basinhopping step 182: f 0.000935655 trial_f 2.23696e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 183: f 0.000935655 trial_f 6.41571e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 184: f 0.000935655 trial_f 2.42785e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 185: f 0.000935655 trial_f 4.40606e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 186: f 0.000935655 trial_f 1.86062e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 187: f 0.000935655 trial_f 2.27009e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 188: f 0.000935655 trial_f 1.856e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 189: f 0.000935655 trial_f 6.6934e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 190: f 0.000935655 trial_f 8.03012e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 191: f 0.000935655 trial_f 5.08996e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 192: f 0.000935655 trial_f 2.43432e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 193: f 0.000935655 trial_f 4.92963e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 194: f 0.000935655 trial_f 1.55918e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 195: f 0.000935655 trial_f 1.68517e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 196: f 0.000935655 trial_f 2.72239e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 197: f 0.000935655 trial_f 1.32321e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 198: f 0.000935655 trial_f 1.61095e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 199: f 0.000859725 trial_f 0.000859725 accepted 1  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.125000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 200: f 0.000859725 trial_f 7.24998e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 201: f 0.000859725 trial_f 3.13472e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 202: f 3.04932e-12 trial_f 3.04932e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 203: f 3.04932e-12 trial_f 17.8962 accepted 0  lowest_f 2.97645e-39
# basinhopping step 204: f 1.476e-31 trial_f 1.476e-31 accepted 1  lowest_f 2.97645e-39
# basinhopping step 205: f 1.476e-31 trial_f 2.22951e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 206: f 1.35357e-09 trial_f 1.35357e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 207: f 1.35357e-09 trial_f 9.59174e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 208: f 1.35357e-09 trial_f 1.13202e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 209: f 0.00462977 trial_f 0.00462977 accepted 1  lowest_f 2.97645e-39
# basinhopping step 210: f 0.00462977 trial_f 894.661 accepted 0  lowest_f 2.97645e-39
# basinhopping step 211: f 0.00462977 trial_f 3.05802e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 212: f 0.00462977 trial_f 3.79225e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 213: f 0.000443882 trial_f 0.000443882 accepted 1  lowest_f 2.97645e-39
# basinhopping step 214: f 0.000443882 trial_f 2.25492e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 215: f 0.000443882 trial_f 2.22133e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 216: f 5.72066e-05 trial_f 5.72066e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 217: f 5.72066e-05 trial_f 9.38951e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 218: f 5.72066e-05 trial_f 2.17311e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 219: f 5.72066e-05 trial_f 1.208e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 220: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 221: f 1.35525e-14 trial_f 1.90338e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 222: f 9.89693e-31 trial_f 9.89693e-31 accepted 1  lowest_f 2.97645e-39
# basinhopping step 223: f 9.89693e-31 trial_f 1.35909e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 224: f 9.89693e-31 trial_f 2.25773e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 225: f 9.89693e-31 trial_f 3.31814e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 226: f 9.89693e-31 trial_f 1.23061e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 227: f 9.89693e-31 trial_f 1.52538e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 228: f 9.89693e-31 trial_f 5.13986e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 229: f 9.89693e-31 trial_f 3.99401e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 230: f 0.0421987 trial_f 0.0421987 accepted 1  lowest_f 2.97645e-39
# basinhopping step 231: f 0.0421987 trial_f 2.53587e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 232: f 0.0294107 trial_f 0.0294107 accepted 1  lowest_f 2.97645e-39
# basinhopping step 233: f 0.0294107 trial_f 1.17887e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 234: f 0.0294107 trial_f 2.24305e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 235: f 0.0294107 trial_f 1.95341e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 236: f 0.0294107 trial_f 4.4599e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 237: f 0.0294107 trial_f 1.73485e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 238: f 0.0294107 trial_f 1.27395e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 239: f 0.168734 trial_f 0.168734 accepted 1  lowest_f 2.97645e-39
# basinhopping step 240: f 0.168734 trial_f 4.39429e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 241: f 0.168734 trial_f 2.65767e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 242: f 0.168734 trial_f 1.21403e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 243: f 0.168734 trial_f 1.05125e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 244: f 0.168734 trial_f 5.21976e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 245: f 0.168734 trial_f 6.24357e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 246: f 0.19762 trial_f 0.19762 accepted 1  lowest_f 2.97645e-39
# basinhopping step 247: f 0.19762 trial_f 6.62562e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 248: f 0.19762 trial_f 3.62111e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 249: f 0.19762 trial_f 1.13687e+12 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.148000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 250: f 0.19762 trial_f 8.51956e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 251: f 0.0316529 trial_f 0.0316529 accepted 1  lowest_f 2.97645e-39
# basinhopping step 252: f 5.4226e-14 trial_f 5.4226e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 253: f 5.4226e-14 trial_f 1.00875e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 254: f 4.01487e-09 trial_f 4.01487e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 255: f 4.89281e-12 trial_f 4.89281e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 256: f 4.89281e-12 trial_f 2.57701e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 257: f 4.89281e-12 trial_f 1.72375e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 258: f 4.89281e-12 trial_f 5.95082e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 259: f 4.89281e-12 trial_f 2.56632e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 260: f 0.221806 trial_f 0.221806 accepted 1  lowest_f 2.97645e-39
# basinhopping step 261: f 2.47844 trial_f 2.47844 accepted 1  lowest_f 2.97645e-39
# basinhopping step 262: f 2.47844 trial_f 1.54478e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 263: f 2.47844 trial_f 2.29842e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 264: f 2.47844 trial_f 4.08669e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 265: f 2.47844 trial_f 7.28758e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 266: f 2.47844 trial_f 6.42275e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 267: f 2.47844 trial_f 6.35824e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 268: f 2.47844 trial_f 9.52497e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 269: f 2.47844 trial_f 4.87038e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 270: f 2.47844 trial_f 5.27924e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 271: f 2.47844 trial_f 1.72716e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 272: f 2.47844 trial_f 3.96934e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 273: f 2.47844 trial_f 2.12849e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 274: f 2.47844 trial_f 2.45278e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 275: f 2.47844 trial_f 479.128 accepted 0  lowest_f 2.97645e-39
# basinhopping step 276: f 2.47844 trial_f 2.01988e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 277: f 2.47844 trial_f 2.13426e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 278: f 2.47844 trial_f 1.96178e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 279: f 2.47844 trial_f 4.59992e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 280: f 2.47844 trial_f 1.21465e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 281: f 2.47844 trial_f 9.10607e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 282: f 2.47844 trial_f 6.63734e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 283: f 2.47844 trial_f 9.4956e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 284: f 2.47844 trial_f 5.4599e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 285: f 2.47844 trial_f 3.06403e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 286: f 2.47844 trial_f 2.79948e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 287: f 2.47844 trial_f 8.58395e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 288: f 2.47844 trial_f 1.35331e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 289: f 2.47844 trial_f 1.49958e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 290: f 2.47844 trial_f 1.3197e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 291: f 2.47844 trial_f 20.5151 accepted 0  lowest_f 2.97645e-39
# basinhopping step 292: f 2.47844 trial_f 2.20657e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 293: f 0.345538 trial_f 0.345538 accepted 1  lowest_f 2.97645e-39
# basinhopping step 294: f 0.345538 trial_f 1.24129e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 295: f 0.345538 trial_f 2.12417e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 296: f 0.345538 trial_f 4.72604e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 297: f 0.345538 trial_f 1.69261e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 298: f 0.00123849 trial_f 0.00123849 accepted 1  lowest_f 2.97645e-39
# basinhopping step 299: f 0.00123849 trial_f 2.05519e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.150000 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 300: f 0.101578 trial_f 0.101578 accepted 1  lowest_f 2.97645e-39
# basinhopping step 301: f 0.101578 trial_f 1.01412e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 302: f 0.101578 trial_f 1.22227e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 303: f 4.30614e-09 trial_f 4.30614e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 304: f 4.30614e-09 trial_f 4.21351e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 305: f 4.30614e-09 trial_f 2.06957e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 306: f 0.000214212 trial_f 0.000214212 accepted 1  lowest_f 2.97645e-39
# basinhopping step 307: f 0.000214212 trial_f 7.47136e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 308: f 0.000214212 trial_f 1.05106e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 309: f 0.0722308 trial_f 0.0722308 accepted 1  lowest_f 2.97645e-39
# basinhopping step 310: f 0.0722308 trial_f 9.30409e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 311: f 0.0722308 trial_f 3.88299e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 312: f 0.0722308 trial_f 9.65704e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 313: f 0.0722308 trial_f 7.94179e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 314: f 0.0722308 trial_f 2.17352e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 315: f 0.0722308 trial_f 2.35843e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 316: f 0.0722308 trial_f 4.4394 accepted 0  lowest_f 2.97645e-39
# basinhopping step 317: f 8.27795e-05 trial_f 8.27795e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 318: f 8.27795e-05 trial_f 2.76437e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 319: f 8.27795e-05 trial_f 1626.32 accepted 0  lowest_f 2.97645e-39
# basinhopping step 320: f 8.27795e-05 trial_f 4.98222e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 321: f 8.27795e-05 trial_f 2423.03 accepted 0  lowest_f 2.97645e-39
# basinhopping step 322: f 0.0231731 trial_f 0.0231731 accepted 1  lowest_f 2.97645e-39
# basinhopping step 323: f 0.0231731 trial_f 1.28677e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 324: f 0.00117427 trial_f 0.00117427 accepted 1  lowest_f 2.97645e-39
# basinhopping step 325: f 0.00117427 trial_f 3.9045e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 326: f 0.00117427 trial_f 6.03896 accepted 0  lowest_f 2.97645e-39
# basinhopping step 327: f 1.35628e-14 trial_f 1.35628e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 328: f 0.00103956 trial_f 0.00103956 accepted 1  lowest_f 2.97645e-39
# basinhopping step 329: f 0.00103956 trial_f 8.01795e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 330: f 9.84592e-05 trial_f 9.84592e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 331: f 9.84592e-05 trial_f 4.61594e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 332: f 9.84592e-05 trial_f 5.12801e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 333: f 9.84592e-05 trial_f 2.46133e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 334: f 9.84592e-05 trial_f 3.65235e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 335: f 9.84592e-05 trial_f 3238.03 accepted 0  lowest_f 2.97645e-39
# basinhopping step 336: f 9.84592e-05 trial_f 9.72336e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 337: f 9.84592e-05 trial_f 1.90736e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 338: f 4.56974e-28 trial_f 4.56974e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 339: f 4.56974e-28 trial_f 6.89273e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 340: f 4.56974e-28 trial_f 2.75953e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 341: f 8.75961e-30 trial_f 8.75961e-30 accepted 1  lowest_f 2.97645e-39
# basinhopping step 342: f 0.000223414 trial_f 0.000223414 accepted 1  lowest_f 2.97645e-39
# basinhopping step 343: f 0.000223414 trial_f 2.24362e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 344: f 0.000223414 trial_f 5.0527e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 345: f 0.000223414 trial_f 2.20431e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 346: f 0.000223414 trial_f 1494.09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 347: f 0.000223414 trial_f 2818.57 accepted 0  lowest_f 2.97645e-39
# basinhopping step 348: f 5.42141e-14 trial_f 5.42141e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 349: f 0.0987291 trial_f 0.0987291 accepted 1  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.171429 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 350: f 0.0987291 trial_f 7.19336e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 351: f 0.0987291 trial_f 1.1498e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 352: f 0.0987291 trial_f 7.95973e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 353: f 0.0987291 trial_f 2.77382e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 354: f 0.0987291 trial_f 4.6042e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 355: f 0.0987291 trial_f 1.57167e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 356: f 0.0987291 trial_f 0.598219 accepted 0  lowest_f 2.97645e-39
# basinhopping step 357: f 0.0987291 trial_f 1.49652e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 358: f 0.0987291 trial_f 3.88774e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 359: f 0.0987291 trial_f 1.24392e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 360: f 0.0987291 trial_f 2.80442e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 361: f 0.0987291 trial_f 2.53559 accepted 0  lowest_f 2.97645e-39
# basinhopping step 362: f 0.0987291 trial_f 4.40467e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 363: f 0.0987291 trial_f 17.7101 accepted 0  lowest_f 2.97645e-39
# basinhopping step 364: f 0.0987291 trial_f 18.1126 accepted 0  lowest_f 2.97645e-39
# basinhopping step 365: f 0.0987291 trial_f 2.47599e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 366: f 0.0987291 trial_f 4.19799e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 367: f 0.0987291 trial_f 7.25939e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 368: f 0.0987291 trial_f 7.05701e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 369: f 0.0987291 trial_f 5.35793e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 370: f 0.0987291 trial_f 5.82136e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 371: f 0.0067076 trial_f 0.0067076 accepted 1  lowest_f 2.97645e-39
# basinhopping step 372: f 0.0067076 trial_f 1.03464e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 373: f 0.0067076 trial_f 1.3283e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 374: f 0.0067076 trial_f 3.18319e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 375: f 0.0067076 trial_f 0.0575717 accepted 0  lowest_f 2.97645e-39
# basinhopping step 376: f 0.0067076 trial_f 1.75455e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 377: f 0.0067076 trial_f 6.2763e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 378: f 0.0067076 trial_f 5.24376e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 379: f 0.0067076 trial_f 17.856 accepted 0  lowest_f 2.97645e-39
# basinhopping step 380: f 0.0067076 trial_f 9.30759 accepted 0  lowest_f 2.97645e-39
# basinhopping step 381: f 0.0067076 trial_f 1.20703e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 382: f 0.0067076 trial_f 1.12702e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 383: f 0.0067076 trial_f 3.55834e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 384: f 0.0067076 trial_f 1.11563e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 385: f 0.0067076 trial_f 1.03447e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 386: f 0.0067076 trial_f 1.00727e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 387: f 5.97678e-12 trial_f 5.97678e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 388: f 0.000358109 trial_f 0.000358109 accepted 1  lowest_f 2.97645e-39
# basinhopping step 389: f 0.000358109 trial_f 7.0637e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 390: f 0.000358109 trial_f 18.1272 accepted 0  lowest_f 2.97645e-39
# basinhopping step 391: f 0.000358109 trial_f 6.88271e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 392: f 0.000358109 trial_f 17.7987 accepted 0  lowest_f 2.97645e-39
# basinhopping step 393: f 0.000358109 trial_f 9.33259e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 394: f 0.000358109 trial_f 5.76445e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 395: f 0.000358109 trial_f 4.64182e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 396: f 0.000358109 trial_f 1.10101e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 397: f 0.000358109 trial_f 2.49053e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 398: f 0.000358109 trial_f 8.82386e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 399: f 0.000358109 trial_f 1.84069e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.157500 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 400: f 0.000358109 trial_f 6.66543e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 401: f 0.000358109 trial_f 1.75272e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 402: f 0.000358109 trial_f 3.52456e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 403: f 0.000358109 trial_f 17.9691 accepted 0  lowest_f 2.97645e-39
# basinhopping step 404: f 0.000358109 trial_f 6.36957e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 405: f 1.50412e-27 trial_f 1.50412e-27 accepted 1  lowest_f 2.97645e-39
# basinhopping step 406: f 4.01478e-09 trial_f 4.01478e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 407: f 4.01478e-09 trial_f 6.4703e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 408: f 0.00418793 trial_f 0.00418793 accepted 1  lowest_f 2.97645e-39
# basinhopping step 409: f 0.00115323 trial_f 0.00115323 accepted 1  lowest_f 2.97645e-39
# basinhopping step 410: f 0.00115323 trial_f 8.38013e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 411: f 0.00115323 trial_f 2.77885e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 412: f 0.00115323 trial_f 1.1566e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 413: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 414: f 1.35525e-14 trial_f 4.27158e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 415: f 1.35525e-14 trial_f 1.13809e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 416: f 1.35525e-14 trial_f 1.36509e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 417: f 0.00274094 trial_f 0.00274094 accepted 1  lowest_f 2.97645e-39
# basinhopping step 418: f 0.0356477 trial_f 0.0356477 accepted 1  lowest_f 2.97645e-39
# basinhopping step 419: f 0.0356477 trial_f 3.67066e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 420: f 0.0356477 trial_f 2.51294e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 421: f 0.0356477 trial_f 2.0226e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 422: f 0.0356477 trial_f 4.49211e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 423: f 0.0356477 trial_f 2.82618e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 424: f 0.0356477 trial_f 3.3296e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 425: f 4.29508e-09 trial_f 4.29508e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 426: f 4.29508e-09 trial_f 1.1259e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 427: f 4.29508e-09 trial_f 28.932 accepted 0  lowest_f 2.97645e-39
# basinhopping step 428: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 429: f 1.35525e-14 trial_f 3.76969e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 430: f 1.35525e-14 trial_f 4.30222e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 431: f 1.35525e-14 trial_f 1.40667e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 432: f 1.35525e-14 trial_f 3.04136e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 433: f 1.35525e-14 trial_f 2.14294e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 434: f 1.35525e-14 trial_f 9.95425e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 435: f 1.35525e-14 trial_f 7.82302e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 436: f 1.35525e-14 trial_f 6.06631e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 437: f 1.35525e-14 trial_f 3388.31 accepted 0  lowest_f 2.97645e-39
# basinhopping step 438: f 1.35525e-14 trial_f 7.11805e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 439: f 1.35525e-14 trial_f 5.40569e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 440: f 1.35525e-14 trial_f 1.16787e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 441: f 4.80035e-05 trial_f 4.80035e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 442: f 4.80035e-05 trial_f 8.6382e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 443: f 4.80035e-05 trial_f 538.482 accepted 0  lowest_f 2.97645e-39
# basinhopping step 444: f 4.80035e-05 trial_f 4.17476e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 445: f 4.80035e-05 trial_f 1.95654e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 446: f 4.80035e-05 trial_f 2.00202e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 447: f 4.80035e-05 trial_f 2.83388e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 448: f 4.80035e-05 trial_f 5.80186e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 449: f 0.000150403 trial_f 0.000150403 accepted 1  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.164444 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 450: f 0.000150403 trial_f 612.59 accepted 0  lowest_f 2.97645e-39
# basinhopping step 451: f 5.13024e-05 trial_f 5.13024e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 452: f 5.13024e-05 trial_f 5.46868e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 453: f 5.13024e-05 trial_f 7.85904e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 454: f 5.13024e-05 trial_f 1.06477e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 455: f 7.57357e-05 trial_f 7.57357e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 456: f 7.57357e-05 trial_f 1.51561e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 457: f 7.57357e-05 trial_f 6.80988e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 458: f 3.04954e-12 trial_f 3.04954e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 459: f 0.000401096 trial_f 0.000401096 accepted 1  lowest_f 2.97645e-39
# basinhopping step 460: f 0.000401096 trial_f 4.23583e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 461: f 0.000401096 trial_f 4.77792e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 462: f 0.000401096 trial_f 2.82258e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 463: f 0.000401096 trial_f 1.01504e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 464: f 0.000401096 trial_f 1.01204e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 465: f 0.000401096 trial_f 4.28147e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 466: f 0.000401096 trial_f 6.50269e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 467: f 0.000401096 trial_f 9.55519e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 468: f 0.000401096 trial_f 1.00918e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 469: f 0.000401096 trial_f 1.25406e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 470: f 0.000401096 trial_f 6.5758e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 471: f 0.000401096 trial_f 9.67599e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 472: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 473: f 0.000896748 trial_f 0.000896748 accepted 1  lowest_f 2.97645e-39
# basinhopping step 474: f 0.000896748 trial_f 1.40095e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 475: f 0.000896748 trial_f 1.90565e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 476: f 0.000896748 trial_f 5.01918e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 477: f 0.000896748 trial_f 4.39544e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 478: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 479: f 1.35525e-14 trial_f 6.89528e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 480: f 1.35525e-14 trial_f 5.28226e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 481: f 2.47849e-28 trial_f 2.47849e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 482: f 2.47849e-28 trial_f 1.5319e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 483: f 2.47849e-28 trial_f 5.26217e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 484: f 2.47849e-28 trial_f 9.16226e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 485: f 2.47849e-28 trial_f 5.33302e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 486: f 2.47849e-28 trial_f 2.20276e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 487: f 2.47849e-28 trial_f 1.45253e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 488: f 2.47849e-28 trial_f 1.00046e+12 accepted 0  lowest_f 2.97645e-39
# basinhopping step 489: f 7.40012e-05 trial_f 7.40012e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 490: f 7.40012e-05 trial_f 17.9905 accepted 0  lowest_f 2.97645e-39
# basinhopping step 491: f 7.40012e-05 trial_f 9.19229e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 492: f 7.40012e-05 trial_f 2.65912e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 493: f 7.40012e-05 trial_f 2.75091e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 494: f 9.4871e-28 trial_f 9.4871e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 495: f 9.4871e-28 trial_f 8.88367e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 496: f 9.4871e-28 trial_f 2.20016e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 497: f 5.97675e-12 trial_f 5.97675e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 498: f 1.42213e-09 trial_f 1.42213e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 499: f 1.42213e-09 trial_f 2.00676e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.172000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 500: f 4.2953e-09 trial_f 4.2953e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 501: f 4.2953e-09 trial_f 7.63776e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 502: f 4.2953e-09 trial_f 2.54741e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 503: f 5.42246e-14 trial_f 5.42246e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 504: f 5.42246e-14 trial_f 9.77101e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 505: f 5.42246e-14 trial_f 4.02866e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 506: f 5.42246e-14 trial_f 7.97752e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 507: f 5.42246e-14 trial_f 2.82186e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 508: f 5.42246e-14 trial_f 1.9645e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 509: f 5.42246e-14 trial_f 1.79254e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 510: f 3.48581e-31 trial_f 3.48581e-31 accepted 1  lowest_f 2.97645e-39
# basinhopping step 511: f 3.48581e-31 trial_f 2.07917e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 512: f 3.48581e-31 trial_f 3.49914e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 513: f 0.0866531 trial_f 0.0866531 accepted 1  lowest_f 2.97645e-39
# basinhopping step 514: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 515: f 1.35525e-14 trial_f 8.46851e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 516: f 0.0452831 trial_f 0.0452831 accepted 1  lowest_f 2.97645e-39
# basinhopping step 517: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 518: f 1.35525e-14 trial_f 4.42031e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 519: f 1.55178e-05 trial_f 1.55178e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 520: f 1.55178e-05 trial_f 2.80112e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 521: f 1.55178e-05 trial_f 2.06905e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 522: f 1.55178e-05 trial_f 3.1612e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 523: f 1.55178e-05 trial_f 6.25811e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 524: f 0.0149356 trial_f 0.0149356 accepted 1  lowest_f 2.97645e-39
# basinhopping step 525: f 0.0149356 trial_f 1.65177e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 526: f 0.0149356 trial_f 0.400898 accepted 0  lowest_f 2.97645e-39
# basinhopping step 527: f 0.0149356 trial_f 8.02253e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 528: f 0.0149356 trial_f 8.21996e+11 accepted 0  lowest_f 2.97645e-39
# ...
# basinhopping step 826: f 0.000478567 trial_f 0.000478567 accepted 1  lowest_f 2.97645e-39
# basinhopping step 827: f 3.73878e-28 trial_f 3.73878e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 828: f 3.73878e-28 trial_f 2.71724e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 829: f 4.0112e-09 trial_f 4.0112e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 830: f 4.0112e-09 trial_f 1.71001e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 831: f 4.0112e-09 trial_f 2.74923e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 832: f 4.0112e-09 trial_f 5.46419 accepted 0  lowest_f 2.97645e-39
# basinhopping step 833: f 0.255235 trial_f 0.255235 accepted 1  lowest_f 2.97645e-39
# basinhopping step 834: f 0.255235 trial_f 3.0933e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 835: f 0.255235 trial_f 1.22034e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 836: f 0.255235 trial_f 2.38266e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 837: f 0.255235 trial_f 3.50172e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 838: f 0.107548 trial_f 0.107548 accepted 1  lowest_f 2.97645e-39
# basinhopping step 839: f 0.107548 trial_f 1.13415e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 840: f 0.107548 trial_f 7.30394e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 841: f 0.107548 trial_f 2.71224 accepted 0  lowest_f 2.97645e-39
# basinhopping step 842: f 0.107548 trial_f 2.34594e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 843: f 7.16945e-12 trial_f 7.16945e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 844: f 7.16945e-12 trial_f 5.06247e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 845: f 7.16945e-12 trial_f 1.22131e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 846: f 7.16945e-12 trial_f 8.86466e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 847: f 7.16945e-12 trial_f 2.25258e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 848: f 7.16945e-12 trial_f 0.762692 accepted 0  lowest_f 2.97645e-39
# basinhopping step 849: f 7.16945e-12 trial_f 3.48403e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.208235 target 0.500000 new stepsize 0.166772 old stepsize 0.185302
# basinhopping step 850: f 3.91675e-12 trial_f 3.91675e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 851: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 852: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 853: f 8.24897e-28 trial_f 8.24897e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 854: f 0.00175921 trial_f 0.00175921 accepted 1  lowest_f 2.97645e-39
# basinhopping step 855: f 0.00175921 trial_f 2.07e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 856: f 0.00175921 trial_f 0.798694 accepted 0  lowest_f 2.97645e-39
# basinhopping step 857: f 0.00175921 trial_f 3.57353e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 858: f 0.00175921 trial_f 2.06448e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 859: f 5.42101e-14 trial_f 5.42101e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 860: f 5.42101e-14 trial_f 2.20821e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 861: f 5.42101e-14 trial_f 4.08056e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 862: f 0.701045 trial_f 0.701045 accepted 1  lowest_f 2.97645e-39
# basinhopping step 863: f 0.701045 trial_f 0.986999 accepted 0  lowest_f 2.97645e-39
# basinhopping step 864: f 0.701045 trial_f 1.68571e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 865: f 0.000598697 trial_f 0.000598697 accepted 1  lowest_f 2.97645e-39
# basinhopping step 866: f 1.42434e-31 trial_f 1.42434e-31 accepted 1  lowest_f 2.97645e-39
# basinhopping step 867: f 4.01031e-09 trial_f 4.01031e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 868: f 4.39164e-12 trial_f 4.39164e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 869: f 0.000134978 trial_f 0.000134978 accepted 1  lowest_f 2.97645e-39
# basinhopping step 870: f 4.82061e-28 trial_f 4.82061e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 871: f 4.82061e-28 trial_f 5.23044e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 872: f 4.82061e-28 trial_f 3.98528e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 873: f 7.16945e-12 trial_f 7.16945e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 874: f 4.00993e-09 trial_f 4.00993e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 875: f 4.00993e-09 trial_f 2.98188e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 876: f 4.00993e-09 trial_f 4.24863e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 877: f 4.00993e-09 trial_f 2.73069e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 878: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 879: f 1.35525e-14 trial_f 5.24064e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 880: f 1.35525e-14 trial_f 3.22694e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 881: f 5.97689e-12 trial_f 5.97689e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 882: f 5.97689e-12 trial_f 4.7286e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 883: f 5.97689e-12 trial_f 4.77904e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 884: f 5.97689e-12 trial_f 12627 accepted 0  lowest_f 2.97645e-39
# basinhopping step 885: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 886: f 1.24078e-17 trial_f 1.24078e-17 accepted 1  lowest_f 2.97645e-39
# basinhopping step 887: f 1.24078e-17 trial_f 3.27507e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 888: f 1.24078e-17 trial_f 2.74652e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 889: f 6.17284e-28 trial_f 6.17284e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 890: f 6.17284e-28 trial_f 2.15732e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 891: f 6.17284e-28 trial_f 3.17849e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 892: f 6.17284e-28 trial_f 2.71062e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 893: f 6.17284e-28 trial_f 2.13272e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 894: f 5.9768e-12 trial_f 5.9768e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 895: f 5.9768e-12 trial_f 3.2719e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 896: f 5.9768e-12 trial_f 4.8504e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 897: f 5.9768e-12 trial_f 1.06003e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 898: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 899: f 1.35525e-14 trial_f 7.30175e+10 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.221111 target 0.500000 new stepsize 0.150095 old stepsize 0.166772
# basinhopping step 900: f 1.35525e-14 trial_f 2.79566e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 901: f 5.64525e-28 trial_f 5.64525e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 902: f 4.87893e-13 trial_f 4.87893e-13 accepted 1  lowest_f 2.97645e-39
# basinhopping step 903: f 4.87893e-13 trial_f 3.02384e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 904: f 7.16929e-12 trial_f 7.16929e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 905: f 1.66981e-10 trial_f 1.66981e-10 accepted 1  lowest_f 2.97645e-39
# basinhopping step 906: f 1.35609e-14 trial_f 1.35609e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 907: f 1.35609e-14 trial_f 18.0195 accepted 0  lowest_f 2.97645e-39
# basinhopping step 908: f 5.97666e-12 trial_f 5.97666e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 909: f 2.83419e-28 trial_f 2.83419e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 910: f 2.83419e-28 trial_f 2.8305e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 911: f 2.83419e-28 trial_f 2.34663e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 912: f 2.83419e-28 trial_f 2.27597e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 913: f 2.83419e-28 trial_f 2.42211e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 914: f 5.42103e-12 trial_f 5.42103e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 915: f 2.61773e-28 trial_f 2.61773e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 916: f 2.61773e-28 trial_f 2.97512e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 917: f 0.130859 trial_f 0.130859 accepted 1  lowest_f 2.97645e-39
# basinhopping step 918: f 0.130859 trial_f 9.82076e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 919: f 0.130859 trial_f 510.239 accepted 0  lowest_f 2.97645e-39
# basinhopping step 920: f 0.130859 trial_f 4.83486e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 921: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 922: f 1.35637e-14 trial_f 1.35637e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 923: f 1.35637e-14 trial_f 3.21065e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 924: f 0.00583324 trial_f 0.00583324 accepted 1  lowest_f 2.97645e-39
# basinhopping step 925: f 7.94664e-28 trial_f 7.94664e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 926: f 7.94664e-28 trial_f 2.54177e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 927: f 7.94664e-28 trial_f 3.65431e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 928: f 7.94664e-28 trial_f 2.91937e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 929: f 7.94664e-28 trial_f 1.96869e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 930: f 7.94664e-28 trial_f 3.58894e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 931: f 7.94664e-28 trial_f 3.43293e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 932: f 5.42101e-14 trial_f 5.42101e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 933: f 3.04939e-12 trial_f 3.04939e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 934: f 0.000154071 trial_f 0.000154071 accepted 1  lowest_f 2.97645e-39
# basinhopping step 935: f 0.000154071 trial_f 0.980451 accepted 0  lowest_f 2.97645e-39
# basinhopping step 936: f 0.000154071 trial_f 3.4068e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 937: f 0.000154071 trial_f 5.73681e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 938: f 1.3574e-14 trial_f 1.3574e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 939: f 1.3574e-14 trial_f 7.97939e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 940: f 1.3574e-14 trial_f 2.72526e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 941: f 1.3574e-14 trial_f 4.15851e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 942: f 3.95251e-28 trial_f 3.95251e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 943: f 3.95251e-28 trial_f 1.62381e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 944: f 6.7413e-28 trial_f 6.7413e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 945: f 6.7413e-28 trial_f 17.8428 accepted 0  lowest_f 2.97645e-39
# basinhopping step 946: f 6.7413e-28 trial_f 2.84508e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 947: f 6.7413e-28 trial_f 6.58115e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 948: f 1.59713e-14 trial_f 1.59713e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 949: f 1.10033e-31 trial_f 1.10033e-31 accepted 1  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.232632 target 0.500000 new stepsize 0.135085 old stepsize 0.150095
# basinhopping step 950: f 1.10033e-31 trial_f 2.92245e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 951: f 1.10033e-31 trial_f 1.86265e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 952: f 4.01431e-09 trial_f 4.01431e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 953: f 4.29508e-09 trial_f 4.29508e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 954: f 4.29508e-09 trial_f 3.56484e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 955: f 4.29508e-09 trial_f 1.1828e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 956: f 4.29508e-09 trial_f 3.08865e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 957: f 3.29446e-05 trial_f 3.29446e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 958: f 1.6563e-05 trial_f 1.6563e-05 accepted 1  lowest_f 2.97645e-39
# basinhopping step 959: f 1.6563e-05 trial_f 4.74288e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 960: f 1.6563e-05 trial_f 4.30016e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 961: f 1.6563e-05 trial_f 2.16692e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 962: f 1.6563e-05 trial_f 2.09736e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 963: f 1.6563e-05 trial_f 2.02033e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 964: f 1.6563e-05 trial_f 4.74374e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 965: f 1.6563e-05 trial_f 2.76166e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 966: f 1.6563e-05 trial_f 3.99747e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 967: f 1.6563e-05 trial_f 606759 accepted 0  lowest_f 2.97645e-39
# basinhopping step 968: f 1.6563e-05 trial_f 1.8208e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 969: f 1.6563e-05 trial_f 1058.53 accepted 0  lowest_f 2.97645e-39
# basinhopping step 970: f 1.6563e-05 trial_f 17.9138 accepted 0  lowest_f 2.97645e-39
# basinhopping step 971: f 1.6563e-05 trial_f 1.80832e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 972: f 1.6563e-05 trial_f 5.14847e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 973: f 1.6563e-05 trial_f 18.0468 accepted 0  lowest_f 2.97645e-39
# basinhopping step 974: f 4.29509e-09 trial_f 4.29509e-09 accepted 1  lowest_f 2.97645e-39
# basinhopping step 975: f 1.06041e-27 trial_f 1.06041e-27 accepted 1  lowest_f 2.97645e-39
# basinhopping step 976: f 1.06041e-27 trial_f 1.1258e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 977: f 1.06041e-27 trial_f 8.89138e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 978: f 1.06041e-27 trial_f 2.42362e+08 accepted 0  lowest_f 2.97645e-39
# basinhopping step 979: f 1.06041e-27 trial_f 1.04138e+10 accepted 0  lowest_f 2.97645e-39
# basinhopping step 980: f 3.39085e-28 trial_f 3.39085e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 981: f 3.39085e-28 trial_f 2.83619e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 982: f 3.39085e-28 trial_f 2.51489e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 983: f 3.39085e-28 trial_f 2.24825 accepted 0  lowest_f 2.97645e-39
# basinhopping step 984: f 3.39085e-28 trial_f 2.38786e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 985: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 986: f 1.35525e-14 trial_f 17.8909 accepted 0  lowest_f 2.97645e-39
# basinhopping step 987: f 1.35525e-14 trial_f 4.11755e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 988: f 1.35525e-14 trial_f 2.27239e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 989: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.97645e-39
# basinhopping step 990: f 1.35525e-14 trial_f 1.74925e+11 accepted 0  lowest_f 2.97645e-39
# basinhopping step 991: f 1.35525e-14 trial_f 3.14415 accepted 0  lowest_f 2.97645e-39
# basinhopping step 992: f 5.44306e-28 trial_f 5.44306e-28 accepted 1  lowest_f 2.97645e-39
# basinhopping step 993: f 1.81547e-30 trial_f 1.81547e-30 accepted 1  lowest_f 2.97645e-39
# basinhopping step 994: f 1.81547e-30 trial_f 1.27685e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 995: f 6.55945e-12 trial_f 6.55945e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 996: f 6.55945e-12 trial_f 3.52213e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 997: f 6.55972e-12 trial_f 6.55972e-12 accepted 1  lowest_f 2.97645e-39
# basinhopping step 998: f 6.55972e-12 trial_f 1.84268e+09 accepted 0  lowest_f 2.97645e-39
# basinhopping step 999: f 6.55972e-12 trial_f 2.51555e+11 accepted 0  lowest_f 2.97645e-39
# adaptive stepsize: acceptance rate 0.234000 target 0.500000 new stepsize 0.121577 old stepsize 0.135085
# basinhopping step 1000: f 0.167412 trial_f 0.167412 accepted 1  lowest_f 2.97645e-39

# %%
rho2, mu2, Power2, P2, Q2 = result.x[0], result.x[1], result.x[2], result.x[3], result.x[4]

M2 = Q2*rho2
H2 = P2/rho2/g
specific_speed_1 = N1*np.sqrt(Q1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(Q2)/(P2/(rho2*g))**(3/4)
print(f"Ns_1 = {specific_speed_1:.4f}, Ns_2 = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = Power1/ ( rho1 * N1**3 * D1**5)
power_coeff_2 = Power2/ ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff_1 = (P1*Q1)/Power1
pump_eff_2 = (P2*Q2)/Power2
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Power1/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Power1/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Efficiency = {pump_eff_1*100:.3f} %\n"
      f"Prototype's Electrical Power = {Power1/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Dynamic Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Kinematic Viscosity is {mu2*10**6/rho2:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Power2/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Power2/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Efficiency = {pump_eff_2*100:.3f} %\n"
      f"Model's Electrical Power = {Power2/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns_1 = 13.4047, Ns_2 = 13.4047, Matching = 99.99999999999999 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.0003126379284978666, Matching = 99.99999999999999 %
# Head Coefficient Prototype = 0.0014186931209146892, Model = 0.0014186931209146892, Matching = 100.0 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8462, Matching = 100.0 %
# Power Coefficient Prototype = 0.00000078, Model = 0.00000078, Matching = 99.9999999999992 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.800 Bar
# Prototype's Pressure Head is 70.884 m HAN+H2O2
# Prototype's Pressure Head is 70.884 m Testing Fluid
# Prototype's Pressure Head is 110.125 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 590.886 W
# Prototype's Shaft Power = 1043.333 W
# Prototype's Shaft Torque = 0.712 N-m
# Prototype's Efficiency = 57.206 %
# Prototype's Electrical Power = 1227.451 W
#
#
# Model's Shaft Speed is 7000.000 RPM
# Model's Impeller Diameter is 50.000 mm
# Model's Mass Flow Rate is 0.356 Kg/s
# Model's Pressure Across Pump is 2.259 Bar
# Model's Pressure Head is 14.827 m HAN+H2O2
# Model's Pressure Head is 17.721 m Testing Fluid
# Model's Pressure Head is 23.035 m Water
# Model's Volumetric Flow Rate is 0.2736 L/s
# Model's Fluid's Dynamic Viscosity is 27.1921 mPa-s
# Model's Fluid's Kinematic Viscosity is 20.9192 mPa-s
# Model's Fluid's Density is 1299.8681 kg/m^3
# Model's Hydraulic Power = 61.798 W
# Model's Shaft Power = 109.117 W
# Model's Shaft Torque = 0.149 N-m
# Model's Efficiency = 57.206 %
# Model's Electrical Power = 128.373 W
