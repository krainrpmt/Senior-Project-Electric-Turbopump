# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
g = 9.807  # Acceleration due to gravity in m/s^2
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.8e5 
Power1 = 1032.9
H1 = P1/rho1/g; Q1 = M1/rho1

#D2 = 50e-3; rho2 = 1286; mu2 = 33.82e-3
D2 = 50e-3; N2 = 7000

# Define lower and upper bounds
lb = [900, 1e-3, 0, 1e5, 0.1e-3]  # Lower bounds
ub = [1400, 35e-3, 10000, 4.25e5, 1e-3]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    rho2, mu2, Power2, P2 ,Q2 = x
    
    # Specific speed equation residual
    #F1 = (N1 * np.sqrt(Q1) / (P1/(rho1*g))**(3/4)) - (N2 * np.sqrt(Q2) / (P2/(rho2*g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( Q1 / (N1 * D1**3)) - (Q2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( g*P1/(rho1*g) / (N1**2 * D1**2)) - ( g*P2/(rho2*g) / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (rho1 * N1 * D1**2 / mu1) - (rho2 * N2 * D2**2 / mu2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( Power1 / ( rho1 * N1**3 * D1**5) ) - ( Power2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1, 1, 1e-3, 1]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([1200, 30e-3, 800, 3e5, 0.3e-3])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 2.01894e-05
# basinhopping step 1: f 0.0274796 trial_f 0.0274796 accepted 1  lowest_f 2.01894e-05
# basinhopping step 2: f 0.0274796 trial_f 1.71757e+12 accepted 0  lowest_f 2.01894e-05
# basinhopping step 3: f 0.0274796 trial_f 18.9329 accepted 0  lowest_f 2.01894e-05
# basinhopping step 4: f 0.0274796 trial_f 107.796 accepted 0  lowest_f 2.01894e-05
# basinhopping step 5: f 0.0274796 trial_f 2.86423e+11 accepted 0  lowest_f 2.01894e-05
# basinhopping step 6: f 1.71898e-09 trial_f 1.71898e-09 accepted 1  lowest_f 1.71898e-09
# found new global minimum on step 6 with function value 1.71898e-09
# basinhopping step 7: f 1.71898e-09 trial_f 4.96852e+10 accepted 0  lowest_f 1.71898e-09
# basinhopping step 8: f 1.71898e-09 trial_f 1.60565e+12 accepted 0  lowest_f 1.71898e-09
# basinhopping step 9: f 1.71898e-09 trial_f 7.96558e+10 accepted 0  lowest_f 1.71898e-09
# basinhopping step 10: f 1.71898e-09 trial_f 3.2431e+10 accepted 0  lowest_f 1.71898e-09
# basinhopping step 11: f 1.71898e-09 trial_f 5.37975e+11 accepted 0  lowest_f 1.71898e-09
# basinhopping step 12: f 1.71898e-09 trial_f 1.04852e+11 accepted 0  lowest_f 1.71898e-09
# basinhopping step 13: f 1.71898e-09 trial_f 1.38771e+12 accepted 0  lowest_f 1.71898e-09
# basinhopping step 14: f 1.71898e-09 trial_f 1.62384e+12 accepted 0  lowest_f 1.71898e-09
# basinhopping step 15: f 1.71898e-09 trial_f 54.5105 accepted 0  lowest_f 1.71898e-09
# basinhopping step 16: f 1.71898e-09 trial_f 3.02319e+12 accepted 0  lowest_f 1.71898e-09
# basinhopping step 17: f 1.71898e-09 trial_f 5.43708 accepted 0  lowest_f 1.71898e-09
# basinhopping step 18: f 7.02563e-11 trial_f 7.02563e-11 accepted 1  lowest_f 7.02563e-11
# found new global minimum on step 18 with function value 7.02563e-11
# basinhopping step 19: f 7.02563e-11 trial_f 7.50885e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 20: f 7.02563e-11 trial_f 3.0208e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 21: f 7.02563e-11 trial_f 12.3176 accepted 0  lowest_f 7.02563e-11
# basinhopping step 22: f 0.0245128 trial_f 0.0245128 accepted 1  lowest_f 7.02563e-11
# basinhopping step 23: f 0.0245128 trial_f 7.72518e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 24: f 0.0245128 trial_f 6.14965e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 25: f 0.0245128 trial_f 2.70139e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 26: f 0.0245128 trial_f 1.47101e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 27: f 0.0245128 trial_f 2.28837e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 28: f 0.0245128 trial_f 5.45419e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 29: f 0.0245128 trial_f 7.08878e+11 accepted 0  lowest_f 7.02563e-11
# basinhopping step 30: f 0.0245128 trial_f 7.43834e+11 accepted 0  lowest_f 7.02563e-11
# basinhopping step 31: f 0.0245128 trial_f 3.36616 accepted 0  lowest_f 7.02563e-11
# basinhopping step 32: f 0.0245128 trial_f 9.34828e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 33: f 0.0245128 trial_f 2.48858e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 34: f 0.0245128 trial_f 3.97333e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 35: f 0.0245128 trial_f 3.94901e+10 accepted 0  lowest_f 7.02563e-11
# basinhopping step 36: f 0.0245128 trial_f 1.97186e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 37: f 0.0245128 trial_f 31.1091 accepted 0  lowest_f 7.02563e-11
# basinhopping step 38: f 0.0245128 trial_f 7.74205e+11 accepted 0  lowest_f 7.02563e-11
# basinhopping step 39: f 1.04951e-10 trial_f 1.04951e-10 accepted 1  lowest_f 7.02563e-11
# basinhopping step 40: f 1.04951e-10 trial_f 1.78744e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 41: f 2.63621e-08 trial_f 2.63621e-08 accepted 1  lowest_f 7.02563e-11
# basinhopping step 42: f 2.63621e-08 trial_f 2.77557e+11 accepted 0  lowest_f 7.02563e-11
# basinhopping step 43: f 2.63621e-08 trial_f 7.16861e+11 accepted 0  lowest_f 7.02563e-11
# basinhopping step 44: f 0.00734416 trial_f 0.00734416 accepted 1  lowest_f 7.02563e-11
# basinhopping step 45: f 0.0280004 trial_f 0.0280004 accepted 1  lowest_f 7.02563e-11
# basinhopping step 46: f 0.0280004 trial_f 0.394638 accepted 0  lowest_f 7.02563e-11
# basinhopping step 47: f 0.0280004 trial_f 1.65083e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 48: f 0.0280004 trial_f 28.0879 accepted 0  lowest_f 7.02563e-11
# basinhopping step 49: f 0.0280004 trial_f 0.916956 accepted 0  lowest_f 7.02563e-11
# adaptive stepsize: acceptance rate 0.160000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 50: f 0.0681991 trial_f 0.0681991 accepted 1  lowest_f 7.02563e-11
# basinhopping step 51: f 0.0681991 trial_f 1.26062e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 52: f 0.0344234 trial_f 0.0344234 accepted 1  lowest_f 7.02563e-11
# basinhopping step 53: f 0.0344234 trial_f 3.74694e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 54: f 0.0344234 trial_f 4.97722e+12 accepted 0  lowest_f 7.02563e-11
# basinhopping step 55: f 0.0344234 trial_f 2.40031e+11 accepted 0  lowest_f 7.02563e-11
# basinhopping step 56: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 1.35525e-14
# found new global minimum on step 56 with function value 1.35525e-14
# basinhopping step 57: f 1.35525e-14 trial_f 625.82 accepted 0  lowest_f 1.35525e-14
# basinhopping step 58: f 1.35525e-14 trial_f 400.151 accepted 0  lowest_f 1.35525e-14
# basinhopping step 59: f 1.35525e-14 trial_f 2.04334 accepted 0  lowest_f 1.35525e-14
# basinhopping step 60: f 1.35525e-14 trial_f 3.27118e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 61: f 1.35525e-14 trial_f 7.53407e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 62: f 1.35525e-14 trial_f 69.5112 accepted 0  lowest_f 1.35525e-14
# basinhopping step 63: f 1.35525e-14 trial_f 5.01589 accepted 0  lowest_f 1.35525e-14
# basinhopping step 64: f 1.35525e-14 trial_f 619.486 accepted 0  lowest_f 1.35525e-14
# basinhopping step 65: f 1.35525e-14 trial_f 636.995 accepted 0  lowest_f 1.35525e-14
# basinhopping step 66: f 1.35525e-14 trial_f 2.10758e+08 accepted 0  lowest_f 1.35525e-14
# basinhopping step 67: f 0.0671877 trial_f 0.0671877 accepted 1  lowest_f 1.35525e-14
# basinhopping step 68: f 0.0671877 trial_f 4.17878e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 69: f 0.0671877 trial_f 15.2424 accepted 0  lowest_f 1.35525e-14
# basinhopping step 70: f 0.153345 trial_f 0.153345 accepted 1  lowest_f 1.35525e-14
# basinhopping step 71: f 0.207301 trial_f 0.207301 accepted 1  lowest_f 1.35525e-14
# basinhopping step 72: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 1.35525e-14
# basinhopping step 73: f 8.33546e-05 trial_f 8.33546e-05 accepted 1  lowest_f 1.35525e-14
# basinhopping step 74: f 8.33546e-05 trial_f 6.28578e+10 accepted 0  lowest_f 1.35525e-14
# basinhopping step 75: f 2.39067e-11 trial_f 2.39067e-11 accepted 1  lowest_f 1.35525e-14
# basinhopping step 76: f 2.39067e-11 trial_f 1.35157e+12 accepted 0  lowest_f 1.35525e-14
# basinhopping step 77: f 5.79265e-08 trial_f 5.79265e-08 accepted 1  lowest_f 1.35525e-14
# basinhopping step 78: f 5.79265e-08 trial_f 5.58366e+11 accepted 0  lowest_f 1.35525e-14
# warning: basinhopping: local minimization failure
# basinhopping step 79: f 5.79265e-08 trial_f 6.6434e+09 accepted 0  lowest_f 1.35525e-14
# basinhopping step 80: f 5.79265e-08 trial_f 6.98725e+11 accepted 0  lowest_f 1.35525e-14
# basinhopping step 81: f 5.79265e-08 trial_f 210.006 accepted 0  lowest_f 1.35525e-14
# basinhopping step 82: f 5.79265e-08 trial_f 372.77 accepted 0  lowest_f 1.35525e-14
# basinhopping step 83: f 0.0087884 trial_f 0.0087884 accepted 1  lowest_f 1.35525e-14
# basinhopping step 84: f 0.0087884 trial_f 1.16797e+12 accepted 0  lowest_f 1.35525e-14
# basinhopping step 85: f 8.05349e-27 trial_f 8.05349e-27 accepted 1  lowest_f 8.05349e-27
# found new global minimum on step 85 with function value 8.05349e-27
# basinhopping step 86: f 0.00157848 trial_f 0.00157848 accepted 1  lowest_f 8.05349e-27
# basinhopping step 87: f 0.00157848 trial_f 9.09426e+11 accepted 0  lowest_f 8.05349e-27
# basinhopping step 88: f 0.00961243 trial_f 0.00961243 accepted 1  lowest_f 8.05349e-27
# basinhopping step 89: f 0.00961243 trial_f 1.95331e+12 accepted 0  lowest_f 8.05349e-27
# basinhopping step 90: f 9.8798e-12 trial_f 9.8798e-12 accepted 1  lowest_f 8.05349e-27
# basinhopping step 91: f 9.8798e-12 trial_f 95.2442 accepted 0  lowest_f 8.05349e-27
# basinhopping step 92: f 9.8798e-12 trial_f 132.806 accepted 0  lowest_f 8.05349e-27
# basinhopping step 93: f 2.87209e-30 trial_f 2.87209e-30 accepted 1  lowest_f 2.87209e-30
# found new global minimum on step 93 with function value 2.87209e-30
# basinhopping step 94: f 0.00792589 trial_f 0.00792589 accepted 1  lowest_f 2.87209e-30
# basinhopping step 95: f 0.00792589 trial_f 1.6894e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 96: f 0.00792589 trial_f 7.64757e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 97: f 0.000302647 trial_f 0.000302647 accepted 1  lowest_f 2.87209e-30
# basinhopping step 98: f 0.000302647 trial_f 8.55259e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 99: f 3.80693e-11 trial_f 3.80693e-11 accepted 1  lowest_f 2.87209e-30
# adaptive stepsize: acceptance rate 0.270000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 100: f 3.80693e-11 trial_f 211.861 accepted 0  lowest_f 2.87209e-30
# basinhopping step 101: f 1.1712 trial_f 1.1712 accepted 1  lowest_f 2.87209e-30
# basinhopping step 102: f 1.1712 trial_f 1.55817e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 103: f 0.00610225 trial_f 0.00610225 accepted 1  lowest_f 2.87209e-30
# basinhopping step 104: f 0.00610225 trial_f 4.0689e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 105: f 0.00610225 trial_f 3.95665 accepted 0  lowest_f 2.87209e-30
# basinhopping step 106: f 0.00610225 trial_f 1.35552e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 107: f 0.00610225 trial_f 1.88805e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 108: f 0.00610225 trial_f 1.32512e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 109: f 0.00610225 trial_f 4.40716e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 110: f 0.00610225 trial_f 7.81732e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 111: f 0.00610225 trial_f 6.67917e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 112: f 0.00610225 trial_f 1.06645 accepted 0  lowest_f 2.87209e-30
# basinhopping step 113: f 0.00610225 trial_f 5.60066e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 114: f 0.00610225 trial_f 1.70349e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 115: f 0.00610225 trial_f 6.70027e+09 accepted 0  lowest_f 2.87209e-30
# basinhopping step 116: f 0.00610225 trial_f 5.24448e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 117: f 0.00610225 trial_f 6.02703e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 118: f 0.00610225 trial_f 9.0292e+09 accepted 0  lowest_f 2.87209e-30
# basinhopping step 119: f 0.00610225 trial_f 3.67504 accepted 0  lowest_f 2.87209e-30
# basinhopping step 120: f 0.00610225 trial_f 1.0199e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 121: f 1.35617e-14 trial_f 1.35617e-14 accepted 1  lowest_f 2.87209e-30
# basinhopping step 122: f 1.35617e-14 trial_f 1.25746e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 123: f 1.35617e-14 trial_f 216.957 accepted 0  lowest_f 2.87209e-30
# basinhopping step 124: f 1.35617e-14 trial_f 159.47 accepted 0  lowest_f 2.87209e-30
# basinhopping step 125: f 1.35617e-14 trial_f 3.17802e+08 accepted 0  lowest_f 2.87209e-30
# basinhopping step 126: f 1.35617e-14 trial_f 0.598442 accepted 0  lowest_f 2.87209e-30
# basinhopping step 127: f 0.00530223 trial_f 0.00530223 accepted 1  lowest_f 2.87209e-30
# basinhopping step 128: f 0.00530223 trial_f 0.459345 accepted 0  lowest_f 2.87209e-30
# basinhopping step 129: f 0.00530223 trial_f 6.53345e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 130: f 0.00530223 trial_f 3.48691e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 131: f 0.00530223 trial_f 5.30068e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 132: f 0.00530223 trial_f 1.8326e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 133: f 0.00530223 trial_f 2.82923e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 134: f 0.00530223 trial_f 2.63536e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 135: f 0.00530223 trial_f 5.38816e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 136: f 0.00530223 trial_f 2.03073e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 137: f 0.00530223 trial_f 2.27954e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 138: f 0.00530223 trial_f 3.49465e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 139: f 0.00530223 trial_f 8.56864e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 140: f 0.00530223 trial_f 5.23226 accepted 0  lowest_f 2.87209e-30
# basinhopping step 141: f 0.00530223 trial_f 4.09333e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 142: f 0.00530223 trial_f 1.58376e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 143: f 0.00530223 trial_f 1.41676e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 144: f 0.00530223 trial_f 1.64497e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 145: f 0.00530223 trial_f 1.52283e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 146: f 0.00530223 trial_f 2.27482e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 147: f 0.00530223 trial_f 3.88222e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 148: f 0.00530223 trial_f 2.12727e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 149: f 0.00530223 trial_f 5.69604e+10 accepted 0  lowest_f 2.87209e-30
# adaptive stepsize: acceptance rate 0.206667 target 0.500000 new stepsize 0.729 old stepsize 0.81
# basinhopping step 150: f 0.00530223 trial_f 1.66632e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 151: f 0.00530223 trial_f 1.61917e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 152: f 0.00530223 trial_f 9.50621e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 153: f 0.00530223 trial_f 6.05106 accepted 0  lowest_f 2.87209e-30
# basinhopping step 154: f 0.00530223 trial_f 3.49852e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 155: f 0.00530223 trial_f 2.13368e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 156: f 3.38814e-11 trial_f 3.38814e-11 accepted 1  lowest_f 2.87209e-30
# basinhopping step 157: f 3.38814e-11 trial_f 126.004 accepted 0  lowest_f 2.87209e-30
# basinhopping step 158: f 3.38814e-11 trial_f 2.26481e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 159: f 3.38814e-11 trial_f 111.544 accepted 0  lowest_f 2.87209e-30
# basinhopping step 160: f 3.38814e-11 trial_f 7.80211e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 161: f 3.38814e-11 trial_f 0.0902741 accepted 0  lowest_f 2.87209e-30
# basinhopping step 162: f 3.38814e-11 trial_f 53.5912 accepted 0  lowest_f 2.87209e-30
# basinhopping step 163: f 3.38814e-11 trial_f 12.8564 accepted 0  lowest_f 2.87209e-30
# basinhopping step 164: f 3.38814e-11 trial_f 3.99954e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 165: f 9.32273e-15 trial_f 9.32273e-15 accepted 1  lowest_f 2.87209e-30
# basinhopping step 166: f 9.32273e-15 trial_f 31.8341 accepted 0  lowest_f 2.87209e-30
# basinhopping step 167: f 1.28273e-05 trial_f 1.28273e-05 accepted 1  lowest_f 2.87209e-30
# basinhopping step 168: f 1.28273e-05 trial_f 595.721 accepted 0  lowest_f 2.87209e-30
# basinhopping step 169: f 4.5591e-11 trial_f 4.5591e-11 accepted 1  lowest_f 2.87209e-30
# basinhopping step 170: f 4.5591e-11 trial_f 7.57747e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 171: f 4.5591e-11 trial_f 2.68582e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 172: f 4.5591e-11 trial_f 2.28613e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 173: f 4.5591e-11 trial_f 3.18319e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 174: f 4.5591e-11 trial_f 81.3489 accepted 0  lowest_f 2.87209e-30
# basinhopping step 175: f 4.5591e-11 trial_f 4.06762e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 176: f 1.41679e-09 trial_f 1.41679e-09 accepted 1  lowest_f 2.87209e-30
# basinhopping step 177: f 1.41679e-09 trial_f 5.30103e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 178: f 0.0413762 trial_f 0.0413762 accepted 1  lowest_f 2.87209e-30
# basinhopping step 179: f 0.0413762 trial_f 1.57664e+11 accepted 0  lowest_f 2.87209e-30
# basinhopping step 180: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 2.87209e-30
# basinhopping step 181: f 1.35525e-14 trial_f 94.1652 accepted 0  lowest_f 2.87209e-30
# basinhopping step 182: f 1.35525e-14 trial_f 1.5824e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 183: f 1.35525e-14 trial_f 13.4821 accepted 0  lowest_f 2.87209e-30
# basinhopping step 184: f 1.35525e-14 trial_f 2.75568 accepted 0  lowest_f 2.87209e-30
# basinhopping step 185: f 1.35525e-14 trial_f 7.39441 accepted 0  lowest_f 2.87209e-30
# basinhopping step 186: f 5.88931e-08 trial_f 5.88931e-08 accepted 1  lowest_f 2.87209e-30
# basinhopping step 187: f 0.133679 trial_f 0.133679 accepted 1  lowest_f 2.87209e-30
# basinhopping step 188: f 0.124316 trial_f 0.124316 accepted 1  lowest_f 2.87209e-30
# basinhopping step 189: f 0.124316 trial_f 5.06717 accepted 0  lowest_f 2.87209e-30
# basinhopping step 190: f 0.124316 trial_f 4.83038e+10 accepted 0  lowest_f 2.87209e-30
# basinhopping step 191: f 0.124316 trial_f 4.03089e+12 accepted 0  lowest_f 2.87209e-30
# basinhopping step 192: f 1.86408e-34 trial_f 1.86408e-34 accepted 1  lowest_f 1.86408e-34
# found new global minimum on step 192 with function value 1.86408e-34
# basinhopping step 193: f 1.86408e-34 trial_f 2.57652e+12 accepted 0  lowest_f 1.86408e-34
# basinhopping step 194: f 1.86408e-34 trial_f 9.47624e+08 accepted 0  lowest_f 1.86408e-34
# basinhopping step 195: f 7.80627e-12 trial_f 7.80627e-12 accepted 1  lowest_f 1.86408e-34
# basinhopping step 196: f 7.80627e-12 trial_f 25.6779 accepted 0  lowest_f 1.86408e-34
# basinhopping step 197: f 7.80627e-12 trial_f 24.7705 accepted 0  lowest_f 1.86408e-34
# basinhopping step 198: f 7.80627e-12 trial_f 1.11411e+11 accepted 0  lowest_f 1.86408e-34
# basinhopping step 199: f 7.80627e-12 trial_f 35.9675 accepted 0  lowest_f 1.86408e-34
# adaptive stepsize: acceptance rate 0.215000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 200: f 9.41614e-31 trial_f 9.41614e-31 accepted 1  lowest_f 1.86408e-34
# basinhopping step 201: f 9.41614e-31 trial_f 354.576 accepted 0  lowest_f 1.86408e-34
# basinhopping step 202: f 9.41614e-31 trial_f 89.7935 accepted 0  lowest_f 1.86408e-34
# basinhopping step 203: f 9.41614e-31 trial_f 100.051 accepted 0  lowest_f 1.86408e-34
# basinhopping step 204: f 9.41614e-31 trial_f 4.23183e+10 accepted 0  lowest_f 1.86408e-34
# basinhopping step 205: f 9.41614e-31 trial_f 39.3671 accepted 0  lowest_f 1.86408e-34
# basinhopping step 206: f 9.41614e-31 trial_f 7.0486e+11 accepted 0  lowest_f 1.86408e-34
# basinhopping step 207: f 9.41614e-31 trial_f 95.4077 accepted 0  lowest_f 1.86408e-34
# basinhopping step 208: f 9.41614e-31 trial_f 37.0665 accepted 0  lowest_f 1.86408e-34
# basinhopping step 209: f 9.41614e-31 trial_f 3.18785e+10 accepted 0  lowest_f 1.86408e-34
# basinhopping step 210: f 9.41614e-31 trial_f 83.067 accepted 0  lowest_f 1.86408e-34
# basinhopping step 211: f 9.41614e-31 trial_f 6.08521e+10 accepted 0  lowest_f 1.86408e-34
# basinhopping step 212: f 5.97904e-38 trial_f 5.97904e-38 accepted 1  lowest_f 5.97904e-38
# found new global minimum on step 212 with function value 5.97904e-38
# basinhopping step 213: f 5.97904e-38 trial_f 205.885 accepted 0  lowest_f 5.97904e-38
# basinhopping step 214: f 5.97904e-38 trial_f 1.2567e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 215: f 5.97904e-38 trial_f 173.812 accepted 0  lowest_f 5.97904e-38
# basinhopping step 216: f 7.60095e-07 trial_f 7.60095e-07 accepted 1  lowest_f 5.97904e-38
# basinhopping step 217: f 7.60095e-07 trial_f 5.51073 accepted 0  lowest_f 5.97904e-38
# basinhopping step 218: f 7.60095e-07 trial_f 4.04157e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 219: f 0.070681 trial_f 0.070681 accepted 1  lowest_f 5.97904e-38
# basinhopping step 220: f 0.070681 trial_f 5.21365 accepted 0  lowest_f 5.97904e-38
# basinhopping step 221: f 0.070681 trial_f 1.33713e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 222: f 0.070681 trial_f 6.21388e+09 accepted 0  lowest_f 5.97904e-38
# basinhopping step 223: f 0.070681 trial_f 4.38347e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 224: f 1.35785e-14 trial_f 1.35785e-14 accepted 1  lowest_f 5.97904e-38
# basinhopping step 225: f 1.35785e-14 trial_f 203.856 accepted 0  lowest_f 5.97904e-38
# basinhopping step 226: f 1.35785e-14 trial_f 2.31604e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 227: f 1.35785e-14 trial_f 1.87474e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 228: f 1.35785e-14 trial_f 5.05951e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 229: f 1.35785e-14 trial_f 110.349 accepted 0  lowest_f 5.97904e-38
# basinhopping step 230: f 1.35785e-14 trial_f 24.6524 accepted 0  lowest_f 5.97904e-38
# basinhopping step 231: f 4.66051e-37 trial_f 4.66051e-37 accepted 1  lowest_f 5.97904e-38
# basinhopping step 232: f 4.66051e-37 trial_f 4.36244e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 233: f 4.66051e-37 trial_f 3.4294e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 234: f 4.66051e-37 trial_f 2.37144e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 235: f 4.66051e-37 trial_f 2.16942e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 236: f 4.66051e-37 trial_f 1.45089e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 237: f 4.66051e-37 trial_f 3.16819 accepted 0  lowest_f 5.97904e-38
# basinhopping step 238: f 0.0509739 trial_f 0.0509739 accepted 1  lowest_f 5.97904e-38
# basinhopping step 239: f 0.0509739 trial_f 1.88099e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 240: f 0.0509739 trial_f 230.997 accepted 0  lowest_f 5.97904e-38
# basinhopping step 241: f 0.0509739 trial_f 2.27342e+09 accepted 0  lowest_f 5.97904e-38
# basinhopping step 242: f 0.0509739 trial_f 88.5001 accepted 0  lowest_f 5.97904e-38
# basinhopping step 243: f 0.0509739 trial_f 8.55996e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 244: f 0.0509739 trial_f 21.7557 accepted 0  lowest_f 5.97904e-38
# basinhopping step 245: f 0.0509739 trial_f 2.16743 accepted 0  lowest_f 5.97904e-38
# basinhopping step 246: f 0.0509739 trial_f 12.6285 accepted 0  lowest_f 5.97904e-38
# basinhopping step 247: f 0.0509739 trial_f 1.61098e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 248: f 0.0509739 trial_f 422.558 accepted 0  lowest_f 5.97904e-38
# basinhopping step 249: f 0.0509739 trial_f 4.13624e+11 accepted 0  lowest_f 5.97904e-38
# adaptive stepsize: acceptance rate 0.200000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 250: f 0.0509739 trial_f 73.003 accepted 0  lowest_f 5.97904e-38
# basinhopping step 251: f 0.0509739 trial_f 2.05997e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 252: f 6.10638e-08 trial_f 6.10638e-08 accepted 1  lowest_f 5.97904e-38
# basinhopping step 253: f 6.10638e-08 trial_f 3.97113e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 254: f 0.00797079 trial_f 0.00797079 accepted 1  lowest_f 5.97904e-38
# basinhopping step 255: f 0.128397 trial_f 0.128397 accepted 1  lowest_f 5.97904e-38
# basinhopping step 256: f 0.128397 trial_f 6.64797e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 257: f 0.000226707 trial_f 0.000226707 accepted 1  lowest_f 5.97904e-38
# basinhopping step 258: f 0.0162757 trial_f 0.0162757 accepted 1  lowest_f 5.97904e-38
# basinhopping step 259: f 0.0162757 trial_f 9.13158e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 260: f 0.0162757 trial_f 1.59887e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 261: f 0.0162757 trial_f 1.59458e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 262: f 0.0162757 trial_f 1.36408e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 263: f 0.0162757 trial_f 1.99876e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 264: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 5.97904e-38
# basinhopping step 265: f 1.35525e-14 trial_f 107.938 accepted 0  lowest_f 5.97904e-38
# basinhopping step 266: f 1.35525e-14 trial_f 497.621 accepted 0  lowest_f 5.97904e-38
# basinhopping step 267: f 1.35525e-14 trial_f 56.961 accepted 0  lowest_f 5.97904e-38
# basinhopping step 268: f 1.97109e-28 trial_f 1.97109e-28 accepted 1  lowest_f 5.97904e-38
# basinhopping step 269: f 2.74439e-11 trial_f 2.74439e-11 accepted 1  lowest_f 5.97904e-38
# basinhopping step 270: f 0.00542047 trial_f 0.00542047 accepted 1  lowest_f 5.97904e-38
# basinhopping step 271: f 0.00542047 trial_f 3.63803e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 272: f 0.00542047 trial_f 1.17402 accepted 0  lowest_f 5.97904e-38
# basinhopping step 273: f 0.00542047 trial_f 140.767 accepted 0  lowest_f 5.97904e-38
# basinhopping step 274: f 0.00542047 trial_f 103.423 accepted 0  lowest_f 5.97904e-38
# basinhopping step 275: f 0.00542047 trial_f 6.42894e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 276: f 0.00542047 trial_f 2.34063e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 277: f 0.00542047 trial_f 1.77571e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 278: f 4.25009e-11 trial_f 4.25009e-11 accepted 1  lowest_f 5.97904e-38
# basinhopping step 279: f 4.25009e-11 trial_f 113.005 accepted 0  lowest_f 5.97904e-38
# basinhopping step 280: f 0.00818041 trial_f 0.00818041 accepted 1  lowest_f 5.97904e-38
# basinhopping step 281: f 0.00818041 trial_f 1.212e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 282: f 0.00818041 trial_f 2.3216e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 283: f 0.00818041 trial_f 2.31039e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 284: f 0.00818041 trial_f 2.15708e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 285: f 0.00818041 trial_f 2.65213e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 286: f 0.00818041 trial_f 1.27757e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 287: f 0.00818041 trial_f 2.57565e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 288: f 0.00818041 trial_f 4.51124e+09 accepted 0  lowest_f 5.97904e-38
# basinhopping step 289: f 0.00818041 trial_f 9.42348e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 290: f 0.00818041 trial_f 4.54225e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 291: f 0.00818041 trial_f 1.11108e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 292: f 0.00818041 trial_f 81.1626 accepted 0  lowest_f 5.97904e-38
# basinhopping step 293: f 0.00818041 trial_f 4.71904e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 294: f 0.00818041 trial_f 1.29434e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 295: f 0.00818041 trial_f 83.0831 accepted 0  lowest_f 5.97904e-38
# basinhopping step 296: f 0.00102692 trial_f 0.00102692 accepted 1  lowest_f 5.97904e-38
# basinhopping step 297: f 0.00102692 trial_f 2.06068e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 298: f 0.00102692 trial_f 93.6883 accepted 0  lowest_f 5.97904e-38
# basinhopping step 299: f 0.00102692 trial_f 1.61455e+11 accepted 0  lowest_f 5.97904e-38
# adaptive stepsize: acceptance rate 0.206667 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 300: f 0.00102692 trial_f 12.846 accepted 0  lowest_f 5.97904e-38
# basinhopping step 301: f 5.52893e-32 trial_f 5.52893e-32 accepted 1  lowest_f 5.97904e-38
# basinhopping step 302: f 5.52893e-32 trial_f 1.29317e+12 accepted 0  lowest_f 5.97904e-38
# basinhopping step 303: f 5.52893e-32 trial_f 3.57421e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 304: f 5.52893e-32 trial_f 1.64426e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 305: f 5.52893e-32 trial_f 1.92248e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 306: f 5.52893e-32 trial_f 1.76684e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 307: f 5.52893e-32 trial_f 4.85687e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 308: f 7.77539e-27 trial_f 7.77539e-27 accepted 1  lowest_f 5.97904e-38
# basinhopping step 309: f 7.77539e-27 trial_f 12.7871 accepted 0  lowest_f 5.97904e-38
# basinhopping step 310: f 7.77539e-27 trial_f 11.7268 accepted 0  lowest_f 5.97904e-38
# basinhopping step 311: f 7.77539e-27 trial_f 1.97481e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 312: f 7.77539e-27 trial_f 2.81334e+11 accepted 0  lowest_f 5.97904e-38
# basinhopping step 313: f 7.77539e-27 trial_f 8.19758e+10 accepted 0  lowest_f 5.97904e-38
# basinhopping step 314: f 4.70198e-38 trial_f 4.70198e-38 accepted 1  lowest_f 4.70198e-38
# found new global minimum on step 314 with function value 4.70198e-38
# basinhopping step 315: f 4.70198e-38 trial_f 6.40804e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 316: f 4.70198e-38 trial_f 4.17503e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 317: f 4.70198e-38 trial_f 0.433281 accepted 0  lowest_f 4.70198e-38
# basinhopping step 318: f 4.70198e-38 trial_f 5.99976e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 319: f 1.13765e-05 trial_f 1.13765e-05 accepted 1  lowest_f 4.70198e-38
# basinhopping step 320: f 0.00950465 trial_f 0.00950465 accepted 1  lowest_f 4.70198e-38
# basinhopping step 321: f 0.00950465 trial_f 2.57761e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 322: f 0.00295509 trial_f 0.00295509 accepted 1  lowest_f 4.70198e-38
# basinhopping step 323: f 0.00295509 trial_f 1.66081e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 324: f 0.00295509 trial_f 2.38792e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 325: f 3.80694e-11 trial_f 3.80694e-11 accepted 1  lowest_f 4.70198e-38
# basinhopping step 326: f 3.80694e-11 trial_f 1.08701e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 327: f 3.80694e-11 trial_f 128.313 accepted 0  lowest_f 4.70198e-38
# basinhopping step 328: f 3.80694e-11 trial_f 5.98156 accepted 0  lowest_f 4.70198e-38
# basinhopping step 329: f 3.80694e-11 trial_f 45.468 accepted 0  lowest_f 4.70198e-38
# basinhopping step 330: f 3.80694e-11 trial_f 1.48499e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 331: f 3.80694e-11 trial_f 27.1694 accepted 0  lowest_f 4.70198e-38
# basinhopping step 332: f 7.42137e-11 trial_f 7.42137e-11 accepted 1  lowest_f 4.70198e-38
# basinhopping step 333: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 334: f 1.35525e-14 trial_f 91.3668 accepted 0  lowest_f 4.70198e-38
# basinhopping step 335: f 5.42101e-14 trial_f 5.42101e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 336: f 5.42101e-14 trial_f 1.25757e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 337: f 4.99617e-38 trial_f 4.99617e-38 accepted 1  lowest_f 4.70198e-38
# basinhopping step 338: f 4.99617e-38 trial_f 56.0937 accepted 0  lowest_f 4.70198e-38
# basinhopping step 339: f 4.99617e-38 trial_f 1.62249e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 340: f 4.99617e-38 trial_f 2.69827e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 341: f 7.54928e-05 trial_f 7.54928e-05 accepted 1  lowest_f 4.70198e-38
# basinhopping step 342: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 343: f 5.81024e-29 trial_f 5.81024e-29 accepted 1  lowest_f 4.70198e-38
# basinhopping step 344: f 5.81024e-29 trial_f 1.27006e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 345: f 5.81024e-29 trial_f 1.31138e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 346: f 5.81024e-29 trial_f 109.681 accepted 0  lowest_f 4.70198e-38
# basinhopping step 347: f 0.0116474 trial_f 0.0116474 accepted 1  lowest_f 4.70198e-38
# basinhopping step 348: f 0.0116474 trial_f 2.72268e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 349: f 0.0116474 trial_f 93.0915 accepted 0  lowest_f 4.70198e-38
# adaptive stepsize: acceptance rate 0.220000 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 350: f 0.0116474 trial_f 3.70844e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 351: f 0.0116474 trial_f 8.23464e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 352: f 0.0116474 trial_f 1.2381e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 353: f 0.0116474 trial_f 4.74762e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 354: f 0.0116474 trial_f 4.77318e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 355: f 0.0116474 trial_f 8.03824 accepted 0  lowest_f 4.70198e-38
# basinhopping step 356: f 6.929e-28 trial_f 6.929e-28 accepted 1  lowest_f 4.70198e-38
# basinhopping step 357: f 5.42101e-14 trial_f 5.42101e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 358: f 5.42101e-14 trial_f 3.08976e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 359: f 5.42101e-14 trial_f 3.99201e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 360: f 5.81082e-07 trial_f 5.81082e-07 accepted 1  lowest_f 4.70198e-38
# basinhopping step 361: f 5.81082e-07 trial_f 101.001 accepted 0  lowest_f 4.70198e-38
# basinhopping step 362: f 5.81082e-07 trial_f 0.0894032 accepted 0  lowest_f 4.70198e-38
# basinhopping step 363: f 5.81082e-07 trial_f 1.76398e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 364: f 1.55887e-24 trial_f 1.55887e-24 accepted 1  lowest_f 4.70198e-38
# basinhopping step 365: f 8.67373e-11 trial_f 8.67373e-11 accepted 1  lowest_f 4.70198e-38
# basinhopping step 366: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 367: f 1.35525e-14 trial_f 3.26281e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 368: f 1.35525e-14 trial_f 8.92628e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 369: f 1.35525e-14 trial_f 1.6984e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 370: f 1.35525e-14 trial_f 1.15195e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 371: f 1.35525e-14 trial_f 5.81969e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 372: f 1.35525e-14 trial_f 1.10012e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 373: f 0.0394853 trial_f 0.0394853 accepted 1  lowest_f 4.70198e-38
# basinhopping step 374: f 4.21631e-27 trial_f 4.21631e-27 accepted 1  lowest_f 4.70198e-38
# basinhopping step 375: f 8.41591e-27 trial_f 8.41591e-27 accepted 1  lowest_f 4.70198e-38
# basinhopping step 376: f 8.41591e-27 trial_f 145.602 accepted 0  lowest_f 4.70198e-38
# basinhopping step 377: f 8.41591e-27 trial_f 52.3175 accepted 0  lowest_f 4.70198e-38
# basinhopping step 378: f 8.41591e-27 trial_f 4.911e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 379: f 8.41591e-27 trial_f 3.6935e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 380: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 381: f 1.35525e-14 trial_f 1.04475e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 382: f 1.35525e-14 trial_f 1.30214e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 383: f 1.35525e-14 trial_f 4.67459e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 384: f 1.35525e-14 trial_f 2.41348e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 385: f 1.32828e-10 trial_f 1.32828e-10 accepted 1  lowest_f 4.70198e-38
# basinhopping step 386: f 3.4596e-33 trial_f 3.4596e-33 accepted 1  lowest_f 4.70198e-38
# basinhopping step 387: f 1.33556e-27 trial_f 1.33556e-27 accepted 1  lowest_f 4.70198e-38
# basinhopping step 388: f 1.33556e-27 trial_f 7.90965e+08 accepted 0  lowest_f 4.70198e-38
# basinhopping step 389: f 1.33556e-27 trial_f 79.344 accepted 0  lowest_f 4.70198e-38
# basinhopping step 390: f 1.33556e-27 trial_f 33.9048 accepted 0  lowest_f 4.70198e-38
# basinhopping step 391: f 1.33556e-27 trial_f 144.711 accepted 0  lowest_f 4.70198e-38
# basinhopping step 392: f 1.33556e-27 trial_f 12.2978 accepted 0  lowest_f 4.70198e-38
# basinhopping step 393: f 1.33556e-27 trial_f 1.83378e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 394: f 1.33556e-27 trial_f 3.58462e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 395: f 1.33556e-27 trial_f 2.87195e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 396: f 6.21254e-11 trial_f 6.21254e-11 accepted 1  lowest_f 4.70198e-38
# basinhopping step 397: f 6.21254e-11 trial_f 2.15242e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 398: f 6.21254e-11 trial_f 198.711 accepted 0  lowest_f 4.70198e-38
# basinhopping step 399: f 6.21254e-11 trial_f 6.88755e+10 accepted 0  lowest_f 4.70198e-38
# adaptive stepsize: acceptance rate 0.227500 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 400: f 6.21254e-11 trial_f 4.10094e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 401: f 6.21254e-11 trial_f 1.2682e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 402: f 6.21254e-11 trial_f 2.59239e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 403: f 6.21254e-11 trial_f 1.31261e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 404: f 6.21254e-11 trial_f 5.09914 accepted 0  lowest_f 4.70198e-38
# basinhopping step 405: f 6.21254e-11 trial_f 8.68454e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 406: f 6.21254e-11 trial_f 3.58137e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 407: f 6.21254e-11 trial_f 1.31893e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 408: f 6.21254e-11 trial_f 2.66334e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 409: f 6.21254e-11 trial_f 2.72048e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 410: f 2.27818e-11 trial_f 2.27818e-11 accepted 1  lowest_f 4.70198e-38
# basinhopping step 411: f 0.000190154 trial_f 0.000190154 accepted 1  lowest_f 4.70198e-38
# basinhopping step 412: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 413: f 1.35525e-14 trial_f 6.59606e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 414: f 0.00337071 trial_f 0.00337071 accepted 1  lowest_f 4.70198e-38
# basinhopping step 415: f 0.00337071 trial_f 1.6186e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 416: f 0.00337071 trial_f 1.91643e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 417: f 0.00337071 trial_f 9.21354e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 418: f 0.00337071 trial_f 4.48857e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 419: f 0.00337071 trial_f 5.20095 accepted 0  lowest_f 4.70198e-38
# basinhopping step 420: f 0.000119964 trial_f 0.000119964 accepted 1  lowest_f 4.70198e-38
# basinhopping step 421: f 0.000119964 trial_f 253.273 accepted 0  lowest_f 4.70198e-38
# basinhopping step 422: f 0.0156782 trial_f 0.0156782 accepted 1  lowest_f 4.70198e-38
# basinhopping step 423: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 424: f 6.02321e-08 trial_f 6.02321e-08 accepted 1  lowest_f 4.70198e-38
# basinhopping step 425: f 6.02321e-08 trial_f 4.13123e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 426: f 6.02321e-08 trial_f 5.09152e+09 accepted 0  lowest_f 4.70198e-38
# basinhopping step 427: f 6.02321e-08 trial_f 101.164 accepted 0  lowest_f 4.70198e-38
# basinhopping step 428: f 7.9326e-22 trial_f 7.9326e-22 accepted 1  lowest_f 4.70198e-38
# basinhopping step 429: f 7.9326e-22 trial_f 1.37652e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 430: f 7.9326e-22 trial_f 112.504 accepted 0  lowest_f 4.70198e-38
# basinhopping step 431: f 7.9326e-22 trial_f 3.79463e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 432: f 7.9326e-22 trial_f 4.89515 accepted 0  lowest_f 4.70198e-38
# basinhopping step 433: f 2.95353e-14 trial_f 2.95353e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 434: f 2.95353e-14 trial_f 6.22255 accepted 0  lowest_f 4.70198e-38
# basinhopping step 435: f 2.95353e-14 trial_f 5.3888e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 436: f 2.95353e-14 trial_f 92.7681 accepted 0  lowest_f 4.70198e-38
# basinhopping step 437: f 1.40262e-07 trial_f 1.40262e-07 accepted 1  lowest_f 4.70198e-38
# basinhopping step 438: f 1.40262e-07 trial_f 4.21251e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 439: f 1.40262e-07 trial_f 5.28087 accepted 0  lowest_f 4.70198e-38
# basinhopping step 440: f 5.42101e-14 trial_f 5.42101e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 441: f 5.42101e-14 trial_f 1.21066e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 442: f 0.421151 trial_f 0.421151 accepted 1  lowest_f 4.70198e-38
# basinhopping step 443: f 0.421151 trial_f 5.75588 accepted 0  lowest_f 4.70198e-38
# basinhopping step 444: f 0.421151 trial_f 2.90259e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 445: f 4.21658e-08 trial_f 4.21658e-08 accepted 1  lowest_f 4.70198e-38
# basinhopping step 446: f 4.21658e-08 trial_f 5.86865e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 447: f 4.21658e-08 trial_f 116.715 accepted 0  lowest_f 4.70198e-38
# basinhopping step 448: f 4.21658e-08 trial_f 2.13341e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 449: f 4.21658e-08 trial_f 4.99088e+11 accepted 0  lowest_f 4.70198e-38
# adaptive stepsize: acceptance rate 0.233333 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 450: f 4.21658e-08 trial_f 41.3602 accepted 0  lowest_f 4.70198e-38
# basinhopping step 451: f 4.21658e-08 trial_f 7.14681 accepted 0  lowest_f 4.70198e-38
# basinhopping step 452: f 4.21658e-08 trial_f 195.569 accepted 0  lowest_f 4.70198e-38
# basinhopping step 453: f 4.21658e-08 trial_f 3.9064e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 454: f 0.152091 trial_f 0.152091 accepted 1  lowest_f 4.70198e-38
# basinhopping step 455: f 1.66647e-07 trial_f 1.66647e-07 accepted 1  lowest_f 4.70198e-38
# basinhopping step 456: f 1.66647e-07 trial_f 5.98441 accepted 0  lowest_f 4.70198e-38
# basinhopping step 457: f 1.66647e-07 trial_f 216.257 accepted 0  lowest_f 4.70198e-38
# basinhopping step 458: f 1.66647e-07 trial_f 210.896 accepted 0  lowest_f 4.70198e-38
# basinhopping step 459: f 1.66647e-07 trial_f 23.0764 accepted 0  lowest_f 4.70198e-38
# basinhopping step 460: f 5.97667e-12 trial_f 5.97667e-12 accepted 1  lowest_f 4.70198e-38
# basinhopping step 461: f 5.97667e-12 trial_f 17.7632 accepted 0  lowest_f 4.70198e-38
# basinhopping step 462: f 5.97667e-12 trial_f 152.269 accepted 0  lowest_f 4.70198e-38
# basinhopping step 463: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 464: f 1.35525e-14 trial_f 3.21417e+08 accepted 0  lowest_f 4.70198e-38
# basinhopping step 465: f 1.35525e-14 trial_f 41.8501 accepted 0  lowest_f 4.70198e-38
# basinhopping step 466: f 1.35525e-14 trial_f 6.39611 accepted 0  lowest_f 4.70198e-38
# basinhopping step 467: f 1.35525e-14 trial_f 74.9328 accepted 0  lowest_f 4.70198e-38
# basinhopping step 468: f 0.00374477 trial_f 0.00374477 accepted 1  lowest_f 4.70198e-38
# basinhopping step 469: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 470: f 1.35525e-14 trial_f 2.05476e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 471: f 1.35525e-14 trial_f 2.72946e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 472: f 1.35525e-14 trial_f 1.40617e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 473: f 1.35525e-14 trial_f 92.1907 accepted 0  lowest_f 4.70198e-38
# basinhopping step 474: f 1.35525e-14 trial_f 2.82362e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 475: f 1.35525e-14 trial_f 3.20873e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 476: f 1.35525e-14 trial_f 1.29194e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 477: f 6.08373e-11 trial_f 6.08373e-11 accepted 1  lowest_f 4.70198e-38
# basinhopping step 478: f 6.08373e-11 trial_f 72.4174 accepted 0  lowest_f 4.70198e-38
# basinhopping step 479: f 6.08373e-11 trial_f 5.98617e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 480: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 481: f 1.35525e-14 trial_f 3.18659e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 482: f 1.35525e-14 trial_f 4.20204e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 483: f 1.35525e-14 trial_f 2.12549e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 484: f 1.35525e-14 trial_f 5.05211e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 485: f 1.35525e-14 trial_f 1.37577e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 486: f 1.35525e-14 trial_f 4.623e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 487: f 1.35525e-14 trial_f 0.537782 accepted 0  lowest_f 4.70198e-38
# basinhopping step 488: f 3.88198e-27 trial_f 3.88198e-27 accepted 1  lowest_f 4.70198e-38
# basinhopping step 489: f 3.41601e-33 trial_f 3.41601e-33 accepted 1  lowest_f 4.70198e-38
# basinhopping step 490: f 3.41601e-33 trial_f 99.408 accepted 0  lowest_f 4.70198e-38
# basinhopping step 491: f 3.41601e-33 trial_f 113.534 accepted 0  lowest_f 4.70198e-38
# basinhopping step 492: f 3.41601e-33 trial_f 1.81883e+09 accepted 0  lowest_f 4.70198e-38
# basinhopping step 493: f 3.41601e-33 trial_f 37.3464 accepted 0  lowest_f 4.70198e-38
# basinhopping step 494: f 8.67362e-13 trial_f 8.67362e-13 accepted 1  lowest_f 4.70198e-38
# warning: basinhopping: local minimization failure
# basinhopping step 495: f 8.67362e-13 trial_f 5.48245e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 496: f 8.67362e-13 trial_f 3.91323e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 497: f 8.67362e-13 trial_f 1.34305e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 498: f 1.35525e-10 trial_f 1.35525e-10 accepted 1  lowest_f 4.70198e-38
# basinhopping step 499: f 3.41883e-12 trial_f 3.41883e-12 accepted 1  lowest_f 4.70198e-38
# adaptive stepsize: acceptance rate 0.236000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 500: f 3.41883e-12 trial_f 2.92831e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 501: f 0.0498895 trial_f 0.0498895 accepted 1  lowest_f 4.70198e-38
# basinhopping step 502: f 1.08556e-26 trial_f 1.08556e-26 accepted 1  lowest_f 4.70198e-38
# basinhopping step 503: f 2.38497e-09 trial_f 2.38497e-09 accepted 1  lowest_f 4.70198e-38
# basinhopping step 504: f 2.38497e-09 trial_f 122.442 accepted 0  lowest_f 4.70198e-38
# basinhopping step 505: f 2.38497e-09 trial_f 115.112 accepted 0  lowest_f 4.70198e-38
# basinhopping step 506: f 2.38497e-09 trial_f 1.56655e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 507: f 2.38497e-09 trial_f 1.92661e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 508: f 2.38497e-09 trial_f 9.53769 accepted 0  lowest_f 4.70198e-38
# basinhopping step 509: f 5.42101e-14 trial_f 5.42101e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 510: f 5.42101e-14 trial_f 1.0104e+12 accepted 0  lowest_f 4.70198e-38
# basinhopping step 511: f 1.35526e-14 trial_f 1.35526e-14 accepted 1  lowest_f 4.70198e-38
# basinhopping step 512: f 1.35526e-14 trial_f 13.4033 accepted 0  lowest_f 4.70198e-38
# basinhopping step 513: f 1.35526e-14 trial_f 2.06034e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 514: f 1.35526e-14 trial_f 2.06109e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 515: f 0.000381228 trial_f 0.000381228 accepted 1  lowest_f 4.70198e-38
# basinhopping step 516: f 4.46396e-21 trial_f 4.46396e-21 accepted 1  lowest_f 4.70198e-38
# basinhopping step 517: f 4.46396e-21 trial_f 1.21876e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 518: f 4.46396e-21 trial_f 7.72202e+11 accepted 0  lowest_f 4.70198e-38
# basinhopping step 519: f 4.46396e-21 trial_f 0.470625 accepted 0  lowest_f 4.70198e-38
# basinhopping step 520: f 1.90493e-27 trial_f 1.90493e-27 accepted 1  lowest_f 4.70198e-38
# basinhopping step 521: f 2.56307e-27 trial_f 2.56307e-27 accepted 1  lowest_f 4.70198e-38
# basinhopping step 522: f 2.56307e-27 trial_f 52.8971 accepted 0  lowest_f 4.70198e-38
# basinhopping step 523: f 2.56307e-27 trial_f 17.1807 accepted 0  lowest_f 4.70198e-38
# basinhopping step 524: f 2.56307e-27 trial_f 2.06053e+10 accepted 0  lowest_f 4.70198e-38
# basinhopping step 525: f 1.66776e-20 trial_f 1.66776e-20 accepted 1  lowest_f 4.70198e-38
# basinhopping step 526: f 1.66776e-20 trial_f 1.07378e+12 accepted 0  lowest_f 4.70198e-38
# ...
# basinhopping step 827: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 828: f 9.11273e-11 trial_f 9.11273e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 829: f 9.11273e-11 trial_f 2.06034e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 830: f 1.66639e-15 trial_f 1.66639e-15 accepted 1  lowest_f 3.59192e-40
# basinhopping step 831: f 1.66639e-15 trial_f 46.8738 accepted 0  lowest_f 3.59192e-40
# basinhopping step 832: f 1.66639e-15 trial_f 3.81911e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 833: f 1.66639e-15 trial_f 2.02784e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 834: f 1.66639e-15 trial_f 2.02223e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 835: f 1.66639e-15 trial_f 3.05739e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 836: f 1.66639e-15 trial_f 3.32573e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 837: f 1.71938e-27 trial_f 1.71938e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 838: f 5.42163e-14 trial_f 5.42163e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 839: f 1.35671e-14 trial_f 1.35671e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 840: f 1.35671e-14 trial_f 1.94077 accepted 0  lowest_f 3.59192e-40
# basinhopping step 841: f 4.81334e-37 trial_f 4.81334e-37 accepted 1  lowest_f 3.59192e-40
# basinhopping step 842: f 4.81334e-37 trial_f 1.52099e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 843: f 4.81334e-37 trial_f 2.65389e+10 accepted 0  lowest_f 3.59192e-40
# warning: basinhopping: local minimization failure
# basinhopping step 844: f 4.81334e-37 trial_f 5.21193e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 845: f 0.524144 trial_f 0.524144 accepted 1  lowest_f 3.59192e-40
# basinhopping step 846: f 0.524144 trial_f 1.93096e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 847: f 4.82275e-27 trial_f 4.82275e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 848: f 4.82275e-27 trial_f 2.06742e+08 accepted 0  lowest_f 3.59192e-40
# basinhopping step 849: f 4.82275e-27 trial_f 1.22557e+11 accepted 0  lowest_f 3.59192e-40
# adaptive stepsize: acceptance rate 0.302353 target 0.500000 new stepsize 0.166772 old stepsize 0.185302
# basinhopping step 850: f 4.82275e-27 trial_f 12.0699 accepted 0  lowest_f 3.59192e-40
# basinhopping step 851: f 1.22231e-33 trial_f 1.22231e-33 accepted 1  lowest_f 3.59192e-40
# basinhopping step 852: f 1.22231e-33 trial_f 7.12977e+08 accepted 0  lowest_f 3.59192e-40
# basinhopping step 853: f 1.22231e-33 trial_f 9.09162e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 854: f 3.38813e-11 trial_f 3.38813e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 855: f 3.38813e-11 trial_f 4.59481e+09 accepted 0  lowest_f 3.59192e-40
# basinhopping step 856: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 857: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 858: f 1.35525e-14 trial_f 1.89625 accepted 0  lowest_f 3.59192e-40
# basinhopping step 859: f 1.35525e-14 trial_f 1.19344e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 860: f 1.35525e-14 trial_f 4.24433e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 861: f 1.35525e-14 trial_f 1.2914e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 862: f 1.35525e-14 trial_f 0.831816 accepted 0  lowest_f 3.59192e-40
# basinhopping step 863: f 1.35525e-14 trial_f 2.57681e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 864: f 1.35525e-14 trial_f 2.729e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 865: f 1.35525e-14 trial_f 8.12038e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 866: f 0.0151013 trial_f 0.0151013 accepted 1  lowest_f 3.59192e-40
# basinhopping step 867: f 0.0151013 trial_f 1.74507e+09 accepted 0  lowest_f 3.59192e-40
# basinhopping step 868: f 3.78241e-27 trial_f 3.78241e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 869: f 2.16841e-13 trial_f 2.16841e-13 accepted 1  lowest_f 3.59192e-40
# basinhopping step 870: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 871: f 1.35525e-14 trial_f 2.06033e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 872: f 1.35525e-14 trial_f 3.08308 accepted 0  lowest_f 3.59192e-40
# basinhopping step 873: f 1.35525e-14 trial_f 0.852674 accepted 0  lowest_f 3.59192e-40
# basinhopping step 874: f 1.35525e-14 trial_f 2.06012e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 875: f 2.34881e-12 trial_f 2.34881e-12 accepted 1  lowest_f 3.59192e-40
# basinhopping step 876: f 4.50234e-18 trial_f 4.50234e-18 accepted 1  lowest_f 3.59192e-40
# basinhopping step 877: f 6.33452e-12 trial_f 6.33452e-12 accepted 1  lowest_f 3.59192e-40
# basinhopping step 878: f 6.33452e-12 trial_f 7.47619e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 879: f 6.33452e-12 trial_f 2.52114e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 880: f 6.33452e-12 trial_f 7.2208e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 881: f 4.64534e-11 trial_f 4.64534e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 882: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 883: f 1.35525e-14 trial_f 5.83617 accepted 0  lowest_f 3.59192e-40
# basinhopping step 884: f 1.35525e-14 trial_f 6.91151e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 885: f 1.35525e-14 trial_f 9.4498e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 886: f 1.35525e-14 trial_f 1.12904e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 887: f 1.35525e-14 trial_f 9.03067e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 888: f 1.35525e-14 trial_f 1.99277 accepted 0  lowest_f 3.59192e-40
# basinhopping step 889: f 1.35525e-14 trial_f 1.53113e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 890: f 1.35525e-14 trial_f 1.25148 accepted 0  lowest_f 3.59192e-40
# basinhopping step 891: f 1.35525e-14 trial_f 4.44732e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 892: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 893: f 1.35525e-14 trial_f 23.3695 accepted 0  lowest_f 3.59192e-40
# basinhopping step 894: f 9.12951e-10 trial_f 9.12951e-10 accepted 1  lowest_f 3.59192e-40
# basinhopping step 895: f 1.21061e-27 trial_f 1.21061e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 896: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 897: f 8.24537e-11 trial_f 8.24537e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 898: f 5.87785e-38 trial_f 5.87785e-38 accepted 1  lowest_f 3.59192e-40
# basinhopping step 899: f 5.87785e-38 trial_f 1.76846e+11 accepted 0  lowest_f 3.59192e-40
# adaptive stepsize: acceptance rate 0.306667 target 0.500000 new stepsize 0.150095 old stepsize 0.166772
# basinhopping step 900: f 0.511456 trial_f 0.511456 accepted 1  lowest_f 3.59192e-40
# basinhopping step 901: f 3.53042e-28 trial_f 3.53042e-28 accepted 1  lowest_f 3.59192e-40
# basinhopping step 902: f 1.62863e-27 trial_f 1.62863e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 903: f 8.49586e-20 trial_f 8.49586e-20 accepted 1  lowest_f 3.59192e-40
# basinhopping step 904: f 8.49586e-20 trial_f 2.40836e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 905: f 0.330423 trial_f 0.330423 accepted 1  lowest_f 3.59192e-40
# basinhopping step 906: f 0.0158934 trial_f 0.0158934 accepted 1  lowest_f 3.59192e-40
# basinhopping step 907: f 0.0158934 trial_f 1.36758e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 908: f 4.71764e-11 trial_f 4.71764e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 909: f 3.03873e-30 trial_f 3.03873e-30 accepted 1  lowest_f 3.59192e-40
# basinhopping step 910: f 3.03873e-30 trial_f 3.49206e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 911: f 1.28233e-11 trial_f 1.28233e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 912: f 4.52453e-37 trial_f 4.52453e-37 accepted 1  lowest_f 3.59192e-40
# basinhopping step 913: f 0.000640748 trial_f 0.000640748 accepted 1  lowest_f 3.59192e-40
# basinhopping step 914: f 0.000640748 trial_f 2.06081e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 915: f 5.72913e-22 trial_f 5.72913e-22 accepted 1  lowest_f 3.59192e-40
# basinhopping step 916: f 4.87892e-11 trial_f 4.87892e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 917: f 2.39718e-12 trial_f 2.39718e-12 accepted 1  lowest_f 3.59192e-40
# basinhopping step 918: f 9.11284e-11 trial_f 9.11284e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 919: f 0.0646047 trial_f 0.0646047 accepted 1  lowest_f 3.59192e-40
# basinhopping step 920: f 0.0646047 trial_f 4.71102 accepted 0  lowest_f 3.59192e-40
# basinhopping step 921: f 0.0646047 trial_f 1.32157 accepted 0  lowest_f 3.59192e-40
# basinhopping step 922: f 0.0646047 trial_f 1.48936 accepted 0  lowest_f 3.59192e-40
# basinhopping step 923: f 8.56575e-05 trial_f 8.56575e-05 accepted 1  lowest_f 3.59192e-40
# basinhopping step 924: f 6.34471e-28 trial_f 6.34471e-28 accepted 1  lowest_f 3.59192e-40
# basinhopping step 925: f 6.34471e-28 trial_f 1.38529e+09 accepted 0  lowest_f 3.59192e-40
# basinhopping step 926: f 6.34471e-28 trial_f 2.06059e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 927: f 0.00386231 trial_f 0.00386231 accepted 1  lowest_f 3.59192e-40
# basinhopping step 928: f 0.00386231 trial_f 9.26847e+08 accepted 0  lowest_f 3.59192e-40
# basinhopping step 929: f 0.00386231 trial_f 7.90956 accepted 0  lowest_f 3.59192e-40
# basinhopping step 930: f 8.23941e-27 trial_f 8.23941e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 931: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 932: f 1.35525e-14 trial_f 5.33477e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 933: f 1.35525e-14 trial_f 3.52269e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 934: f 1.36045e-14 trial_f 1.36045e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 935: f 3.25608e-18 trial_f 3.25608e-18 accepted 1  lowest_f 3.59192e-40
# basinhopping step 936: f 3.25608e-18 trial_f 1.14404e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 937: f 3.25608e-18 trial_f 3.00093 accepted 0  lowest_f 3.59192e-40
# basinhopping step 938: f 3.25608e-18 trial_f 5.71982e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 939: f 3.25608e-18 trial_f 8.3345e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 940: f 8.02337e-27 trial_f 8.02337e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 941: f 8.02337e-27 trial_f 6.33764 accepted 0  lowest_f 3.59192e-40
# basinhopping step 942: f 8.02337e-27 trial_f 0.269627 accepted 0  lowest_f 3.59192e-40
# basinhopping step 943: f 1.35525e-14 trial_f 1.35525e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 944: f 0.114003 trial_f 0.114003 accepted 1  lowest_f 3.59192e-40
# basinhopping step 945: f 0.114003 trial_f 6.12638e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 946: f 0.114003 trial_f 2.12052e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 947: f 7.96652e-28 trial_f 7.96652e-28 accepted 1  lowest_f 3.59192e-40
# basinhopping step 948: f 9.12159e-11 trial_f 9.12159e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 949: f 9.12159e-11 trial_f 8.58006e+10 accepted 0  lowest_f 3.59192e-40
# adaptive stepsize: acceptance rate 0.320000 target 0.500000 new stepsize 0.135085 old stepsize 0.150095
# basinhopping step 950: f 9.12159e-11 trial_f 2.13544e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 951: f 9.12159e-11 trial_f 2.72215e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 952: f 4.55908e-11 trial_f 4.55908e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 953: f 4.55908e-11 trial_f 7.75746 accepted 0  lowest_f 3.59192e-40
# basinhopping step 954: f 0.108679 trial_f 0.108679 accepted 1  lowest_f 3.59192e-40
# basinhopping step 955: f 0.0106133 trial_f 0.0106133 accepted 1  lowest_f 3.59192e-40
# basinhopping step 956: f 0.0106133 trial_f 1.10266e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 957: f 0.0106133 trial_f 1.1517e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 958: f 0.0106133 trial_f 2.48202e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 959: f 0.0272809 trial_f 0.0272809 accepted 1  lowest_f 3.59192e-40
# basinhopping step 960: f 6.72085e-28 trial_f 6.72085e-28 accepted 1  lowest_f 3.59192e-40
# basinhopping step 961: f 1.47587e-14 trial_f 1.47587e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 962: f 6.5161e-07 trial_f 6.5161e-07 accepted 1  lowest_f 3.59192e-40
# basinhopping step 963: f 1.35533e-14 trial_f 1.35533e-14 accepted 1  lowest_f 3.59192e-40
# basinhopping step 964: f 1.35533e-14 trial_f 202.378 accepted 0  lowest_f 3.59192e-40
# basinhopping step 965: f 0.601749 trial_f 0.601749 accepted 1  lowest_f 3.59192e-40
# basinhopping step 966: f 4.07823e-27 trial_f 4.07823e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 967: f 4.07823e-27 trial_f 3.39636 accepted 0  lowest_f 3.59192e-40
# basinhopping step 968: f 4.07823e-27 trial_f 2.06e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 969: f 1.61255e-35 trial_f 1.61255e-35 accepted 1  lowest_f 3.59192e-40
# basinhopping step 970: f 0.268215 trial_f 0.268215 accepted 1  lowest_f 3.59192e-40
# basinhopping step 971: f 0.246046 trial_f 0.246046 accepted 1  lowest_f 3.59192e-40
# basinhopping step 972: f 0.246046 trial_f 8.16674e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 973: f 0.246046 trial_f 7.68527 accepted 0  lowest_f 3.59192e-40
# basinhopping step 974: f 6.41501e-07 trial_f 6.41501e-07 accepted 1  lowest_f 3.59192e-40
# basinhopping step 975: f 7.09963e-27 trial_f 7.09963e-27 accepted 1  lowest_f 3.59192e-40
# basinhopping step 976: f 5.01901e-05 trial_f 5.01901e-05 accepted 1  lowest_f 3.59192e-40
# basinhopping step 977: f 5.01901e-05 trial_f 7.00706e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 978: f 5.01901e-05 trial_f 3.91758e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 979: f 5.01901e-05 trial_f 1.72349e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 980: f 7.02564e-11 trial_f 7.02564e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 981: f 6.96749e-20 trial_f 6.96749e-20 accepted 1  lowest_f 3.59192e-40
# basinhopping step 982: f 6.96749e-20 trial_f 6.80803e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 983: f 6.96749e-20 trial_f 6.23897e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 984: f 6.96749e-20 trial_f 2.19667 accepted 0  lowest_f 3.59192e-40
# basinhopping step 985: f 4.55912e-11 trial_f 4.55912e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 986: f 4.55912e-11 trial_f 2.06057e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 987: f 8.67376e-11 trial_f 8.67376e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 988: f 8.67376e-11 trial_f 2.06101e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 989: f 5.72598e-11 trial_f 5.72598e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 990: f 0.859499 trial_f 0.859499 accepted 1  lowest_f 3.59192e-40
# basinhopping step 991: f 0.859499 trial_f 2.05998e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 992: f 0.859499 trial_f 7.15234 accepted 0  lowest_f 3.59192e-40
# basinhopping step 993: f 0.0571514 trial_f 0.0571514 accepted 1  lowest_f 3.59192e-40
# basinhopping step 994: f 8.24536e-11 trial_f 8.24536e-11 accepted 1  lowest_f 3.59192e-40
# basinhopping step 995: f 1.88824e-17 trial_f 1.88824e-17 accepted 1  lowest_f 3.59192e-40
# basinhopping step 996: f 1.88824e-17 trial_f 1.58607e+11 accepted 0  lowest_f 3.59192e-40
# basinhopping step 997: f 1.88824e-17 trial_f 3.7672e+10 accepted 0  lowest_f 3.59192e-40
# warning: basinhopping: local minimization failure
# basinhopping step 998: f 1.88824e-17 trial_f 5.01414e+10 accepted 0  lowest_f 3.59192e-40
# basinhopping step 999: f 1.88824e-17 trial_f 4.44536e+10 accepted 0  lowest_f 3.59192e-40
# adaptive stepsize: acceptance rate 0.329000 target 0.500000 new stepsize 0.121577 old stepsize 0.135085
# basinhopping step 1000: f 1.88824e-17 trial_f 8.51078e+08 accepted 0  lowest_f 3.59192e-40

# %%
rho2, mu2, Power2, P2, Q2 = result.x[0], result.x[1], result.x[2], result.x[3], result.x[4]

M2 = Q2*rho2
H2 = P2/rho2/g
specific_speed_1 = N1*np.sqrt(Q1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(Q2)/(P2/(rho2*g))**(3/4)
print(f"Ns_1 = {specific_speed_1:.4f}, Ns_2 = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = Power1/ ( rho1 * N1**3 * D1**5)
power_coeff_2 = Power2/ ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff_1 = (P1*Q1)/Power1
pump_eff_2 = (P2*Q2)/Power2
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Power1/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Power1/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Efficiency = {pump_eff_1*100:.3f} %\n"
      f"Prototype's Electrical Power = {Power1/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Dynamic Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Kinematic Viscosity is {mu2*10**6/rho2:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Power2/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Power2/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Efficiency = {pump_eff_2*100:.3f} %\n"
      f"Model's Electrical Power = {Power2/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns_1 = 13.4047, Ns_2 = 13.4047, Matching = 99.99999999999999 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031263792849786664, Matching = 100.0 %
# Head Coefficient Prototype = 0.0014186931209146892, Model = 0.0014186931209146892, Matching = 100.0 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8462, Matching = 100.0 %
# Power Coefficient Prototype = 0.00000078, Model = 0.00000078, Matching = 99.99999999999756 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.800 Bar
# Prototype's Pressure Head is 70.884 m HAN+H2O2
# Prototype's Pressure Head is 70.884 m Testing Fluid
# Prototype's Pressure Head is 110.125 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 590.886 W
# Prototype's Shaft Power = 1043.333 W
# Prototype's Shaft Torque = 0.712 N-m
# Prototype's Efficiency = 57.206 %
# Prototype's Electrical Power = 1227.451 W
#
#
# Model's Shaft Speed is 7000.000 RPM
# Model's Impeller Diameter is 50.000 mm
# Model's Mass Flow Rate is 0.383 Kg/s
# Model's Pressure Across Pump is 2.433 Bar
# Model's Pressure Head is 15.969 m HAN+H2O2
# Model's Pressure Head is 17.721 m Testing Fluid
# Model's Pressure Head is 24.809 m Water
# Model's Volumetric Flow Rate is 0.2736 L/s
# Model's Fluid's Dynamic Viscosity is 29.2868 mPa-s
# Model's Fluid's Kinematic Viscosity is 20.9192 mPa-s
# Model's Fluid's Density is 1399.9998 kg/m^3
# Model's Hydraulic Power = 66.558 W
# Model's Shaft Power = 117.523 W
# Model's Shaft Torque = 0.160 N-m
# Model's Efficiency = 57.206 %
# Model's Electrical Power = 138.262 W
