# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.4e5
#rho2 = 1000; mu2 = 10e-3
D2 = 50e-3; rho2 = 1281; mu2 = 29.28e-3 #59% Sucrose W/W at 30 C
g = 9.807  # Acceleration due to gravity in m/s^2

Q1 = M1/rho1

# Define lower and upper bounds for mu, rho, m_dot, pressure rise
lb = [2000, 0.3, 2e5]  # Lower bounds
ub = [8000, 0.85, 3e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    N2, M2, P2 = x
    
    # Specific speed equation residual
    F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( M1/rho1 / (N1 * D1**3)) - (M2/rho2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( P1/rho1 / (N1**2 * D1**2)) - ( P2/rho2 / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (M1/mu1 / D1) - (M2/mu2 / D2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( P1 * M1/rho1 / ( rho1 * N1**3 * D1**5) ) - ( P2 * M2/rho2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F1, F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1.0, 1.0e-3, 1.0e-3, 1, 1.0e3]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([8000, 0.4, 2e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 6.65009e-05
# basinhopping step 1: f 8.38776e-05 trial_f 8.38776e-05 accepted 1  lowest_f 6.65009e-05
# basinhopping step 2: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 6.65009e-05
# basinhopping step 3: f 2.66012e-16 trial_f 2.66012e-16 accepted 1  lowest_f 2.66012e-16
# found new global minimum on step 3 with function value 2.66012e-16
# basinhopping step 4: f 1.08961e-15 trial_f 1.08961e-15 accepted 1  lowest_f 2.66012e-16
# warning: basinhopping: local minimization failure
# basinhopping step 5: f 1.08961e-15 trial_f 1.90224e-11 accepted 0  lowest_f 2.66012e-16
# basinhopping step 6: f 7.10493e-15 trial_f 7.10493e-15 accepted 1  lowest_f 2.66012e-16
# basinhopping step 7: f 6.32345e-15 trial_f 6.32345e-15 accepted 1  lowest_f 2.66012e-16
# basinhopping step 8: f 6.67886e-17 trial_f 6.67886e-17 accepted 1  lowest_f 6.67886e-17
# found new global minimum on step 8 with function value 6.67886e-17
# basinhopping step 9: f 9.76546e-14 trial_f 9.76546e-14 accepted 1  lowest_f 6.67886e-17
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 9.76546e-14 trial_f 1.4868e-11 accepted 0  lowest_f 6.67886e-17
# C:\Users\Krai\AppData\Local\Temp\ipykernel_47004\1226903114.py:23: RuntimeWarning: invalid value encountered in sqrt
#   F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 9.76546e-14 trial_f 3.39618e-17 accepted 0  lowest_f 6.67886e-17
# basinhopping step 12: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 6.67886e-17
# basinhopping step 13: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 6.67886e-17
# basinhopping step 14: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 6.67886e-17
# basinhopping step 15: f 1.71681e-25 trial_f 1.71681e-25 accepted 1  lowest_f 1.71681e-25
# found new global minimum on step 15 with function value 1.71681e-25
# basinhopping step 16: f 2.20351e-16 trial_f 2.20351e-16 accepted 1  lowest_f 1.71681e-25
# basinhopping step 17: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.71681e-25
# basinhopping step 18: f 6.08343e-17 trial_f 6.08343e-17 accepted 1  lowest_f 1.71681e-25
# basinhopping step 19: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.71681e-25
# basinhopping step 20: f 2.06793e-13 trial_f 2.06793e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 21: f 1.92084e-13 trial_f 1.92084e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 22: f 4.7626e-13 trial_f 4.7626e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 23: f 1.59029e-13 trial_f 1.59029e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 24: f 1.97152e-13 trial_f 1.97152e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 25: f 1.94178e-13 trial_f 1.94178e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 26: f 6.41875e-14 trial_f 6.41875e-14 accepted 1  lowest_f 1.71681e-25
# basinhopping step 27: f 8.38723e-05 trial_f 8.38723e-05 accepted 1  lowest_f 1.71681e-25
# basinhopping step 28: f 1.85074e-13 trial_f 1.85074e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 29: f 6.58509e-16 trial_f 6.58509e-16 accepted 1  lowest_f 1.71681e-25
# basinhopping step 30: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.71681e-25
# basinhopping step 31: f 1.82927e-13 trial_f 1.82927e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 32: f 1.85403e-13 trial_f 1.85403e-13 accepted 1  lowest_f 1.71681e-25
# basinhopping step 33: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.71681e-25
# basinhopping step 34: f 9.59196e-16 trial_f 9.59196e-16 accepted 1  lowest_f 1.71681e-25
# basinhopping step 35: f 1.11296e-27 trial_f 1.11296e-27 accepted 1  lowest_f 1.11296e-27
# found new global minimum on step 35 with function value 1.11296e-27
# basinhopping step 36: f 5.68696e-16 trial_f 5.68696e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 37: f 1.40072e-14 trial_f 1.40072e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 38: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 39: f 2.04143e-18 trial_f 2.04143e-18 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 40: f 2.04143e-18 trial_f 1.04788e-14 accepted 0  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 2.04143e-18 trial_f 1.37438e-11 accepted 0  lowest_f 1.11296e-27
# basinhopping step 42: f 1.13206e-15 trial_f 1.13206e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 43: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 44: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 45: f 8.6971e-18 trial_f 8.6971e-18 accepted 1  lowest_f 1.11296e-27
# basinhopping step 46: f 4.62038e-16 trial_f 4.62038e-16 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 47: f 4.62038e-16 trial_f 3.39717e-17 accepted 0  lowest_f 1.11296e-27
# basinhopping step 48: f 7.26068e-17 trial_f 7.26068e-17 accepted 1  lowest_f 1.11296e-27
# basinhopping step 49: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.860000 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 50: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 51: f 5.41855e-15 trial_f 5.41855e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 52: f 9.74582e-16 trial_f 9.74582e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 53: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 54: f 1.64244e-13 trial_f 1.64244e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 55: f 1.90075e-13 trial_f 1.90075e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 56: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 57: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 58: f 1.61631e-13 trial_f 1.61631e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 59: f 3.53938e-16 trial_f 3.53938e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 60: f 6.38692e-16 trial_f 6.38692e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 61: f 9.92045e-14 trial_f 9.92045e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 62: f 5.84711e-13 trial_f 5.84711e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 63: f 1.92255e-13 trial_f 1.92255e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 64: f 1.84403e-13 trial_f 1.84403e-13 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 65: f 1.84403e-13 trial_f 1.99813e-11 accepted 0  lowest_f 1.11296e-27
# basinhopping step 66: f 5.64265e-13 trial_f 5.64265e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 67: f 6.08156e-19 trial_f 6.08156e-19 accepted 1  lowest_f 1.11296e-27
# basinhopping step 68: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 69: f 1.07657e-13 trial_f 1.07657e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 70: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 71: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 72: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 73: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 74: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 75: f 6.25976e-16 trial_f 6.25976e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 76: f 1.81201e-13 trial_f 1.81201e-13 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 77: f 1.81201e-13 trial_f 1.20845e-05 accepted 0  lowest_f 1.11296e-27
# basinhopping step 78: f 8.38776e-05 trial_f 8.38776e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step
accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 247: f 1.80505e-13 trial_f 4.75301e-17 accepted 0  lowest_f 1.11296e-27
# basinhopping step 248: f 7.80438e-17 trial_f 7.80438e-17 accepted 1  lowest_f 1.11296e-27
# basinhopping step 249: f 5.68764e-16 trial_f 5.68764e-16 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.932000 target 0.500000 new stepsize 1.69351 old stepsize 1.52416
# basinhopping step 250: f 2.00943e-13 trial_f 2.00943e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 251: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 252: f 1.14725e-13 trial_f 1.14725e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 253: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 254: f 1.62237e-13 trial_f 1.62237e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 255: f 1.86157e-13 trial_f 1.86157e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 256: f 8.28615e-27 trial_f 8.28615e-27 accepted 1  lowest_f 1.11296e-27
# basinhopping step 257: f 1.63166e-13 trial_f 1.63166e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 258: f 1.59869e-13 trial_f 1.59869e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 259: f 1.81654e-13 trial_f 1.81654e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 260: f 1.68349e-13 trial_f 1.68349e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 261: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 262: f 8.63928e-16 trial_f 8.63928e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 263: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 264: f 1.61821e-13 trial_f 1.61821e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 265: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 266: f 1.80464e-13 trial_f 1.80464e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 267: f 6.49198e-14 trial_f 6.49198e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 268: f 5.33477e-16 trial_f 5.33477e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 269: f 4.1656e-13 trial_f 4.1656e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 270: f 3.91703e-13 trial_f 3.91703e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 271: f 8.38722e-05 trial_f 8.38722e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 272: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 273: f 1.79988e-13 trial_f 1.79988e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 274: f 1.79358e-13 trial_f 1.79358e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 275: f 5.75583e-14 trial_f 5.75583e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 276: f 1.5913e-13 trial_f 1.5913e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 277: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 278: f 5.28603e-16 trial_f 5.28603e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 279: f 8.9291e-18 trial_f 8.9291e-18 accepted 1  lowest_f 1.11296e-27
# basinhopping step 280: f 1.98413e-13 trial_f 1.98413e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 281: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 282: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 283: f 3.38537e-16 trial_f 3.38537e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 284: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 285: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 286: f 1.85074e-13 trial_f 1.85074e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 287: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 288: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 289: f 1.80074e-13 trial_f 1.80074e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 290: f 4.6665e-20 trial_f 4.6665e-20 accepted 1  lowest_f 1.11296e-27
# basinhopping step 291: f 1.61045e-13 trial_f 1.61045e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 292: f 1.69807e-14 trial_f 1.69807e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 293: f 1.97155e-16 trial_f 1.97155e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 294: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 295: f 8.82864e-15 trial_f 8.82864e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 296: f 8.8454e-18 trial_f 8.8454e-18 accepted 1  lowest_f 1.11296e-27
# basinhopping step 297: f 1.74998e-24 trial_f 1.74998e-24 accepted 1  lowest_f 1.11296e-27
# basinhopping step 298: f 8.38776e-05 trial_f 8.38776e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 299: f 3.37071e-15 trial_f 3.37071e-15 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.943333 target 0.500000 new stepsize 1.88168 old stepsize 1.69351
# basinhopping step 300: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 301: f 5.60655e-16 trial_f 5.60655e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 302: f 1.56736e-13 trial_f 1.56736e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 303: f 8.25868e-18 trial_f 8.25868e-18 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 304: f 8.25868e-18 trial_f 1.16819e-05 accepted 0  lowest_f 1.11296e-27
# basinhopping step 305: f 2.4216e-15 trial_f 2.4216e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step
-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 425: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 426: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 427: f 9.05375e-18 trial_f 9.05375e-18 accepted 1  lowest_f 1.11296e-27
# basinhopping step 428: f 5.62701e-14 trial_f 5.62701e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 429: f 1.69388e-15 trial_f 1.69388e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 430: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 431: f 1.71161e-16 trial_f 1.71161e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 432: f 1.97671e-13 trial_f 1.97671e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 433: f 1.29092e-15 trial_f 1.29092e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 434: f 4.03979e-17 trial_f 4.03979e-17 accepted 1  lowest_f 1.11296e-27
# basinhopping step 435: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 436: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 437: f 1.84449e-13 trial_f 1.84449e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 438: f 1.91032e-14 trial_f 1.91032e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 439: f 1.39431e-14 trial_f 1.39431e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 440: f 8.38723e-05 trial_f 8.38723e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 441: f 1.42198e-17 trial_f 1.42198e-17 accepted 1  lowest_f 1.11296e-27
# basinhopping step 442: f 2.61977e-13 trial_f 2.61977e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 443: f 5.33928e-15 trial_f 5.33928e-15 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 444: f 5.33928e-15 trial_f 1.38154e-05 accepted 0  lowest_f 1.11296e-27
# basinhopping step 445: f 3.58208e-15 trial_f 3.58208e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 446: f 9.70722e-14 trial_f 9.70722e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 447: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 448: f 2.76124e-15 trial_f 2.76124e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 449: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.948889 target 0.500000 new stepsize 2.58117 old stepsize 2.32306
# basinhopping step 450: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 451: f 9.45638e-18 trial_f 9.45638e-18 accepted 1  lowest_f 1.11296e-27
# basinhopping step 452: f 6.8153e-19 trial_f 6.8153e-19 accepted 1  lowest_f 1.11296e-27
# basinhopping step 453: f 8.38723e-05 trial_f 8.38723e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 454: f 1.62224e-13 trial_f 1.62224e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 455: f 1.35643e-13 trial_f 1.35643e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 456: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 457: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 458: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 459: f 7.97535e-14 trial_f 7.97535e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 460: f 5.68065e-16 trial_f 5.68065e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 461: f 4.32404e-16 trial_f 4.32404e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 462: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 463: f 8.38726e-05 trial_f 8.38726e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 464: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 465: f 2.91959e-16 trial_f 2.91959e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 466: f 1.80756e-13 trial_f 1.80756e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 467: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 468: f 8.38778e-05 trial_f 3.00015e-16 accepted 0  lowest_f 1.11296e-27
# basinhopping step 469: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 470: f 7.94326e-17 trial_f 7.94326e-17 accepted 1  lowest_f 1.11296e-27
# basinhopping step 471: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 472: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 473: f 3.28343e-15 trial_f 3.28343e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 474: f 8.76252e-15 trial_f 8.76252e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 475: f 1.56255e-16 trial_f 1.56255e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 476: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 477: f 9.43404e-14 trial_f 9.43404e-14 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 478: f 9.43404e-14 trial_f 1.50882e-05 accepted 0  lowest_f 1.11296e-27
# basinhopping step 479: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 480: f 8.38778e-05 trial_f 4.50788e-17 accepted 0  lowest_f 1.11296e-27
# basinhopping step 481: f 1.54283e-16 trial_f 1.54283e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 482: f 1.85212e-13 trial_f 1.85212e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 483: f 1.06796e-15 trial_f 1.06796e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 484: f 1.94483e-13 trial_f 1.94483e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 485: f 4.91644e-13 trial_f 4.91644e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 486: f 9.44083e-15 trial_f 9.44083e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 487: f 8.38776e-05 trial_f 8.38776e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 488: f 1.84685e-13 trial_f 1.84685e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 489: f 1.30281e-17 trial_f 1.30281e-17 accepted 1  lowest_f 1.11296e-27
# basinhopping step 490: f 4.45696e-14 trial_f 4.45696e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 491: f 8.74289e-16 trial_f 8.74289e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 492: f 1.96524e-13 trial_f 1.96524e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 493: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 494: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 495: f 1.84794e-13 trial_f 1.84794e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 496: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 497: f 5.68813e-14 trial_f 5.68813e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 498: f 8.38723e-05 trial_f 8.38723e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 499: f 1.96267e-14 trial_f 1.96267e-14 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.948000 target 0.500000 new stepsize 2.86797 old stepsize 2.58117
# basinhopping step 500: f 9.23232e-14 trial_f 9.23232e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 501: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 502: f 3.70765e-14 trial_f 3.70765e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 503: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 504: f 8.09617e-18 trial_f 8.09617e-18 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# ...
# basinhopping step 833: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 834: f 2.17345e-13 trial_f 2.17345e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 835: f 1.2933e-16 trial_f 1.2933e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 836: f 5.89615e-16 trial_f 5.89615e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 837: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 838: f 8.38725e-05 trial_f 8.38725e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 839: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 840: f 5.44587e-15 trial_f 5.44587e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 841: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 842: f 2.17179e-13 trial_f 2.17179e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 843: f 1.82259e-13 trial_f 1.82259e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 844: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 845: f 1.42916e-15 trial_f 1.42916e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 846: f 1.79072e-13 trial_f 1.79072e-13 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 847: f 1.79072e-13 trial_f 1.28455e-14 accepted 0  lowest_f 1.11296e-27
# basinhopping step 848: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 849: f 4.32709e-14 trial_f 4.32709e-14 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.943529 target 0.500000 new stepsize 5.99622 old stepsize 5.3966
# basinhopping step 850: f 8.47638e-24 trial_f 8.47638e-24 accepted 1  lowest_f 1.11296e-27
# basinhopping step 851: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 852: f 8.38779e-05 trial_f 1.27694e-14 accepted 0  lowest_f 1.11296e-27
# basinhopping step 853: f 8.38725e-05 trial_f 8.38725e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 854: f 8.38725e-05 trial_f 1.24236e-14 accepted 0  lowest_f 1.11296e-27
# basinhopping step 855: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 856: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 857: f 2.17069e-13 trial_f 2.17069e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 858: f 2.17305e-13 trial_f 2.17305e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 859: f 3.44003e-15 trial_f 3.44003e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 860: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 861: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 862: f 7.68698e-15 trial_f 7.68698e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 863: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 864: f 8.38725e-05 trial_f 8.38725e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 865: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 866: f 8.38727e-05 trial_f 8.38727e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 867: f 5.92727e-16 trial_f 5.92727e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 868: f 1.60567e-16 trial_f 1.60567e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step
-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 940: f 1.8041e-13 trial_f 1.8041e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 941: f 2.16975e-13 trial_f 2.16975e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 942: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 943: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 944: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 945: f 2.16965e-13 trial_f 2.16965e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 946: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 947: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 948: f 2.93649e-15 trial_f 2.93649e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 949: f 8.38777e-05 trial_f 8.38777e-05 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.945263 target 0.500000 new stepsize 7.40274 old stepsize 6.66246
# basinhopping step 950: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 951: f 8.3878e-05 trial_f 4.85659e-15 accepted 0  lowest_f 1.11296e-27
# basinhopping step 952: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 953: f 2.94348e-15 trial_f 2.94348e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 954: f 2.16971e-13 trial_f 2.16971e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 955: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 956: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 957: f 6.47073e-14 trial_f 6.47073e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 958: f 4.28299e-14 trial_f 4.28299e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 959: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 960: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 961: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 962: f 1.76919e-15 trial_f 1.76919e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 963: f 9.24145e-14 trial_f 9.24145e-14 accepted 1  lowest_f 1.11296e-27
# basinhopping step 964: f 1.28623e-16 trial_f 1.28623e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 965: f 8.38722e-05 trial_f 8.38722e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 966: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 967: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 968: f 8.38778e-05 trial_f 1.27662e-14 accepted 0  lowest_f 1.11296e-27
# basinhopping step 969: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 970: f 2.17137e-13 trial_f 2.17137e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 971: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 972: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 973: f 8.38725e-05 trial_f 8.38725e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 974: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 975: f 3.77806e-15 trial_f 3.77806e-15 accepted 1  lowest_f 1.11296e-27
# basinhopping step 976: f 8.38724e-05 trial_f 8.38724e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 977: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 978: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 979: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 980: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 981: f 2.17e-13 trial_f 2.17e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 982: f 2.16966e-13 trial_f 2.16966e-13 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 983: f 2.16966e-13 trial_f 1.24559e-14 accepted 0  lowest_f 1.11296e-27
# basinhopping step 984: f 2.1735e-13 trial_f 2.1735e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 985: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 986: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 987: f 2.16978e-13 trial_f 2.16978e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 988: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 989: f 8.38726e-05 trial_f 8.38726e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 990: f 5.38606e-16 trial_f 5.38606e-16 accepted 1  lowest_f 1.11296e-27
# basinhopping step 991: f 2.17339e-13 trial_f 2.17339e-13 accepted 1  lowest_f 1.11296e-27
# basinhopping step 992: f 8.38778e-05 trial_f 8.38778e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 993: f 8.3878e-05 trial_f 8.3878e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 994: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 995: f 8.38725e-05 trial_f 8.38725e-05 accepted 1  lowest_f 1.11296e-27
# basinhopping step 996: f 8.38782e-05 trial_f 8.38782e-05 accepted 1  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 997: f 8.38782e-05 trial_f 1.23461e-14 accepted 0  lowest_f 1.11296e-27
# warning: basinhopping: local minimization failure
# basinhopping step 998: f 8.38782e-05 trial_f 5.66584e-15 accepted 0  lowest_f 1.11296e-27
# basinhopping step 999: f 8.38781e-05 trial_f 8.38781e-05 accepted 1  lowest_f 1.11296e-27
# adaptive stepsize: acceptance rate 0.943000 target 0.500000 new stepsize 8.22526 old stepsize 7.40274
# basinhopping step 1000: f 8.38779e-05 trial_f 8.38779e-05 accepted 1  lowest_f 1.11296e-27

# %%
N2, M2, P2 = result.x[0], result.x[1], result.x[2]
Q2 = M2/rho2
specific_speed_1 = N1*np.sqrt(M1/rho1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(M2/rho2)/(P2/(rho2*g))**(3/4)
print(f"Ns = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = P1 * M1 / rho1 / ( rho1 * N1**3 * D1**5)
power_coeff_2 = P2 * M2 / rho2 / ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff = 0.50
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Q1*P1/pump_eff/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Q1*P1/pump_eff/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Electrical Power = {Q1*P1/pump_eff/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Dynamic Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Kinematic Viscosity is {mu2*10**6/rho2:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Q2*P2/pump_eff/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Q2*P2/pump_eff/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Electrical Power = {Q2*P2/pump_eff/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns = 13.7895, Matching = 99.99999999999997 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031263792849787716, Matching = 99.99999999999663 %
# Head Coefficient Prototype = 0.001366148931251182, Model = 0.0013661489312512135, Matching = 99.9999999999977 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8462, Matching = 99.99999999999662 %
# Power Coefficient Prototype = 0.00000043, Model = 0.00000043, Matching = 99.99999999999434 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.400 Bar
# Prototype's Pressure Head is 68.259 m HAN+H2O2
# Prototype's Pressure Head is 68.259 m Testing Fluid
# Prototype's Pressure Head is 106.047 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 569.001 W
# Prototype's Shaft Power = 1149.497 W
# Prototype's Shaft Torque = 0.784 N-m
# Prototype's Electrical Power = 1352.349 W
#
#
# Model's Shaft Speed is 7648.492 RPM
# Model's Impeller Diameter is 50.000 mm
# Model's Mass Flow Rate is 0.383 Kg/s
# Model's Pressure Across Pump is 2.559 Bar
# Model's Pressure Head is 16.798 m HAN+H2O2
# Model's Pressure Head is 20.373 m Testing Fluid
# Model's Pressure Head is 26.098 m Water
# Model's Volumetric Flow Rate is 0.2989 L/s
# Model's Fluid's Dynamic Viscosity is 29.2800 mPa-s
# Model's Fluid's Kinematic Viscosity is 22.8571 mPa-s
# Model's Fluid's Density is 1281.0000 kg/m^3
# Model's Hydraulic Power = 76.501 W
# Model's Shaft Power = 154.547 W
# Model's Shaft Torque = 0.193 N-m
# Model's Electrical Power = 181.820 W
