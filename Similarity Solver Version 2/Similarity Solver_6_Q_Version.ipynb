# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
g = 9.807  # Acceleration due to gravity in m/s^2
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.8e5 
Power1 = 1032.9
H1 = P1/rho1/g; Q1 = M1/rho1

#D2 = 50e-3; rho2 = 1286; mu2 = 33.82e-3
D2 = 50e-3; N2 = 7000; Q2 = 0.278e-3

# Define lower and upper bounds
lb = [500, 1e-3, 0, 0e5]  # Lower bounds
ub = [10000, 100e-3, 10000, 10e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    rho2, mu2, Power2, P2 = x
    
    # Specific speed equation residual
    #F1 = (N1 * np.sqrt(Q1) / (P1/(rho1*g))**(3/4)) - (N2 * np.sqrt(Q2) / (P2/(rho2*g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( Q1 / (N1 * D1**3)) - (Q2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( g*P1/(rho1*g) / (N1**2 * D1**2)) - ( g*P2/(rho2*g) / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (rho1 * N1 * D1**2 / mu1) - (rho2 * N2 * D2**2 / mu2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( Power1 / ( rho1 * N1**3 * D1**5) ) - ( Power2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1, 1, 1e-3, 1]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([1200, 30e-3, 800, 3e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 2.5783e-11
# basinhopping step 1: f 2.5783e-11 trial_f 19.7243 accepted 0  lowest_f 2.5783e-11
# basinhopping step 2: f 2.57718e-11 trial_f 2.57718e-11 accepted 1  lowest_f 2.57718e-11
# found new global minimum on step 2 with function value 2.57718e-11
# basinhopping step 3: f 2.57718e-11 trial_f 8.54689e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 4: f 2.57718e-11 trial_f 1.71881e+13 accepted 0  lowest_f 2.57718e-11
# warning: basinhopping: local minimization failure
# basinhopping step 5: f 2.57718e-11 trial_f 7.60274e+09 accepted 0  lowest_f 2.57718e-11
# basinhopping step 6: f 2.57718e-11 trial_f 3.08415e+08 accepted 0  lowest_f 2.57718e-11
# basinhopping step 7: f 2.57718e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 8: f 2.57718e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 9: f 2.57718e-11 trial_f 4.55796e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 10: f 2.57718e-11 trial_f 1.633e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 11: f 2.57718e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 12: f 2.57718e-11 trial_f 5.2464e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 13: f 2.57718e-11 trial_f 2.91744e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 14: f 2.57718e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 15: f 2.57718e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 16: f 2.57718e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 17: f 2.57718e-11 trial_f 3.54361e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 18: f 1.16249e-08 trial_f 1.16249e-08 accepted 1  lowest_f 2.57718e-11
# basinhopping step 19: f 1.16249e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 20: f 1.16249e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 21: f 1.16249e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 22: f 2.5783e-11 trial_f 2.5783e-11 accepted 1  lowest_f 2.57718e-11
# basinhopping step 23: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 24: f 2.5783e-11 trial_f 3.60876e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 25: f 2.5783e-11 trial_f 1.34816e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 26: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 27: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 28: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 29: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 30: f 2.5783e-11 trial_f 1.63651 accepted 0  lowest_f 2.57718e-11
# basinhopping step 31: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 32: f 2.5783e-11 trial_f 8.09605e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 33: f 2.5783e-11 trial_f 9.44558e+11 accepted 0  lowest_f 2.57718e-11
# basinhopping step 34: f 2.5783e-11 trial_f 2.51802e+08 accepted 0  lowest_f 2.57718e-11
# basinhopping step 35: f 2.5783e-11 trial_f 8.07278e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 36: f 2.5783e-11 trial_f 5.09758e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 37: f 2.5783e-11 trial_f 1.56179e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 38: f 2.5783e-11 trial_f 1.45296e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 39: f 2.5783e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 40: f 2.5783e-11 trial_f 7.96335e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 41: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 42: f 8.76184e-06 trial_f 8.76184e-06 accepted 1  lowest_f 2.57718e-11
# basinhopping step 43: f 8.76184e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 44: f 8.76184e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 45: f 2.5783e-11 trial_f 2.5783e-11 accepted 1  lowest_f 2.57718e-11
# basinhopping step 46: f 2.5783e-11 trial_f 2.93441e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 47: f 2.5783e-11 trial_f 6.85701e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 48: f 2.5783e-11 trial_f 1.56674e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 49: f 2.5783e-11 trial_f 8.5465e+12 accepted 0  lowest_f 2.57718e-11
# adaptive stepsize: acceptance rate 0.100000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 50: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 51: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 52: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 53: f 2.5783e-11 trial_f 4.21225e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 54: f 2.5783e-11 trial_f 2.62502e+08 accepted 0  lowest_f 2.57718e-11
# basinhopping step 55: f 2.5783e-11 trial_f 8.54674e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 56: f 2.5783e-11 trial_f 1.63301e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 57: f 2.5783e-11 trial_f 2.60051e+13 accepted 0  lowest_f 2.57718e-11
# basinhopping step 58: f 2.58236e-11 trial_f 2.58236e-11 accepted 1  lowest_f 2.57718e-11
# basinhopping step 59: f 2.58236e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 60: f 2.58236e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 61: f 2.58236e-11 trial_f 1080.7 accepted 0  lowest_f 2.57718e-11
# basinhopping step 62: f 2.58236e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 63: f 2.58236e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 64: f 2.58236e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57718e-11
# basinhopping step 65: f 3.17461e-11 trial_f 3.17461e-11 accepted 1  lowest_f 2.57718e-11
# basinhopping step 66: f 3.17461e-11 trial_f 6.42097e+12 accepted 0  lowest_f 2.57718e-11
# basinhopping step 67: f 3.38853e-09 trial_f 3.38853e-09 accepted 1  lowest_f 2.57718e-11
# basinhopping step 68: f 5.55129e-08 trial_f 5.55129e-08 accepted 1  lowest_f 2.57718e-11
# basinhopping step 69: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# found new global minimum on step 69 with function value 2.57694e-11
# basinhopping step 70: f 2.57694e-11 trial_f 6.47598e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 71: f 2.57694e-11 trial_f 2.66785e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 72: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 73: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 74: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 75: f 2.57694e-11 trial_f 8.54625e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 76: f 2.57694e-11 trial_f 1.05657e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 77: f 2.57694e-11 trial_f 2.6778e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 78: f 2.57694e-11 trial_f 3.04801e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 79: f 9.70894e-06 trial_f 9.70894e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 80: f 9.70894e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 81: f 2.1929e-10 trial_f 2.1929e-10 accepted 1  lowest_f 2.57694e-11
# basinhopping step 82: f 0.0653682 trial_f 0.0653682 accepted 1  lowest_f 2.57694e-11
# basinhopping step 83: f 2.74093e-11 trial_f 2.74093e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 84: f 2.58526e-11 trial_f 2.58526e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 85: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 86: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 87: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 88: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 89: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 90: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 91: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 92: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 93: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 94: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 95: f 2.58526e-11 trial_f 4.16064e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 96: f 2.58526e-11 trial_f 5.9204e+16 accepted 0  lowest_f 2.57694e-11
# basinhopping step 97: f 2.58526e-11 trial_f 3.88693e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 98: f 2.58526e-11 trial_f 2.90131e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 99: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.150000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 100: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 101: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 102: f 2.58526e-11 trial_f 5.49071e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 103: f 2.58526e-11 trial_f 6.51142e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 104: f 2.58526e-11 trial_f 1.42502e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 105: f 2.58526e-11 trial_f 7.52297e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 106: f 2.58526e-11 trial_f 9.11324e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 107: f 2.58526e-11 trial_f 4.68867e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 108: f 2.58526e-11 trial_f 1.70694e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 109: f 2.58526e-11 trial_f 1.63298e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 110: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 111: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 112: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 113: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 114: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 115: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 116: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 117: f 2.58526e-11 trial_f 3.98072e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 118: f 2.58526e-11 trial_f 4.06359e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 119: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 120: f 2.58526e-11 trial_f 1.0453e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 121: f 2.58526e-11 trial_f 4.73008e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 122: f 2.58526e-11 trial_f 5.75703e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 123: f 2.58526e-11 trial_f 2.6139e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 124: f 2.58526e-11 trial_f 4.23216e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 125: f 2.58526e-11 trial_f 1.30612e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 126: f 2.58526e-11 trial_f 9.40441e+11 accepted 0  lowest_f 2.57694e-11
# basinhopping step 127: f 2.58526e-11 trial_f 2.03673e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 128: f 2.58526e-11 trial_f 5.38873e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 129: f 2.58526e-11 trial_f 1.15692e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 130: f 2.58526e-11 trial_f 1.4225e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 131: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 132: f 2.58526e-11 trial_f 1.73441e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 133: f 2.58526e-11 trial_f 3.94536e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 134: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 135: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 136: f 2.58526e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 137: f 0.00313866 trial_f 0.00313866 accepted 1  lowest_f 2.57694e-11
# basinhopping step 138: f 0.00313866 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 139: f 0.00313866 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 140: f 0.313369 trial_f 0.313369 accepted 1  lowest_f 2.57694e-11
# basinhopping step 141: f 0.313369 trial_f 1.05399e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 142: f 0.313369 trial_f 8.10457e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 143: f 0.313369 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 144: f 9.35173e-06 trial_f 9.35173e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 145: f 4.76933e-10 trial_f 4.76933e-10 accepted 1  lowest_f 2.57694e-11
# basinhopping step 146: f 4.76933e-10 trial_f 8.46284e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 147: f 4.76933e-10 trial_f 2.07708e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 148: f 4.76933e-10 trial_f 2.67277e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 149: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.126667 target 0.500000 new stepsize 0.729 old stepsize 0.81
# basinhopping step 150: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 151: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 152: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 153: f 4.76933e-10 trial_f 1.26105e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 154: f 4.76933e-10 trial_f 6.92903e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 155: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 156: f 4.76933e-10 trial_f 2.63008e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 157: f 4.76933e-10 trial_f 4.60829e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 158: f 4.76933e-10 trial_f 3.67435e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 159: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 160: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 161: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 162: f 4.76933e-10 trial_f 4.73018e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 163: f 4.76933e-10 trial_f 4.48204e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 164: f 4.76933e-10 trial_f 8.54686e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 165: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 166: f 4.76933e-10 trial_f 5.66407e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 167: f 4.76933e-10 trial_f 1.25697e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 168: f 4.76933e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 169: f 1.37139e-08 trial_f 1.37139e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 170: f 2.59791e-11 trial_f 2.59791e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 171: f 2.59791e-11 trial_f 8.29704e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 172: f 2.57712e-11 trial_f 2.57712e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 173: f 2.57712e-11 trial_f 2.58821e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 174: f 2.57712e-11 trial_f 5.24802e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 175: f 2.59257e-08 trial_f 2.59257e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 176: f 3.33313e-11 trial_f 3.33313e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 177: f 3.33313e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 178: f 3.33313e-11 trial_f 5.13669e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 179: f 3.33313e-11 trial_f 1.72212e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 180: f 1.26284 trial_f 1.26284 accepted 1  lowest_f 2.57694e-11
# basinhopping step 181: f 1.26284 trial_f 19.5617 accepted 0  lowest_f 2.57694e-11
# basinhopping step 182: f 2.62573e-11 trial_f 2.62573e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 183: f 2.62573e-11 trial_f 8.19934e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 184: f 2.62573e-11 trial_f 1.63315e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 185: f 2.62573e-11 trial_f 1.30145e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 186: f 2.62573e-11 trial_f 1.5897e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 187: f 2.62573e-11 trial_f 8.1385e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 188: f 2.62573e-11 trial_f 4.25287e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 189: f 2.62573e-11 trial_f 2.40632e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 190: f 2.62573e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 191: f 2.62573e-11 trial_f 3.93498e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 192: f 2.62573e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 193: f 2.62573e-11 trial_f 2.77778e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 194: f 2.62573e-11 trial_f 6.46199e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 195: f 2.57846e-11 trial_f 2.57846e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 196: f 2.57846e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 197: f 5.2018e-09 trial_f 5.2018e-09 accepted 1  lowest_f 2.57694e-11
# basinhopping step 198: f 5.2018e-09 trial_f 1.11992e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 199: f 5.2018e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.140000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 200: f 5.2018e-09 trial_f 2.93438e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 201: f 5.2018e-09 trial_f 8.54688e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 202: f 5.2018e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 203: f 5.2018e-09 trial_f 2.03859e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 204: f 5.2018e-09 trial_f 5.48152e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 205: f 5.2018e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 206: f 5.2018e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 207: f 5.2018e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 208: f 5.2018e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 209: f 0.0170025 trial_f 0.0170025 accepted 1  lowest_f 2.57694e-11
# basinhopping step 210: f 0.0170025 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 211: f 0.0170025 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 212: f 2.62591e-11 trial_f 2.62591e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 213: f 2.62591e-11 trial_f 2.93427e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 214: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 215: f 2.62591e-11 trial_f 2.84707e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 216: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 217: f 2.62591e-11 trial_f 2.75323e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 218: f 2.62591e-11 trial_f 3.97817e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 219: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 220: f 2.62591e-11 trial_f 2.79154e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 221: f 2.62591e-11 trial_f 1.85057e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 222: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 223: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 224: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 225: f 2.62591e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 226: f 2.62591e-11 trial_f 2.8757e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 227: f 5.51448e-06 trial_f 5.51448e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 228: f 5.51448e-06 trial_f 6.10381e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 229: f 0.0477049 trial_f 0.0477049 accepted 1  lowest_f 2.57694e-11
# basinhopping step 230: f 0.0477049 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 231: f 2.58272e-11 trial_f 2.58272e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 232: f 2.58272e-11 trial_f 1.88416e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 233: f 2.58272e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 234: f 0.0197133 trial_f 0.0197133 accepted 1  lowest_f 2.57694e-11
# basinhopping step 235: f 0.0197133 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 236: f 0.0197133 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 237: f 0.0197133 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 238: f 0.0197133 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 239: f 2.58914e-11 trial_f 2.58914e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 240: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 241: f 2.58914e-11 trial_f 1.84959e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 242: f 2.58914e-11 trial_f 1.00293e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 243: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 244: f 2.58914e-11 trial_f 1.28505e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 245: f 2.58914e-11 trial_f 1.61065e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 246: f 2.58914e-11 trial_f 3.15957e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 247: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 248: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 249: f 2.58914e-11 trial_f 5.53175e+12 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.140000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 250: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 251: f 2.58914e-11 trial_f 3.87069e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 252: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 253: f 2.58914e-11 trial_f 2.03859e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 254: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 255: f 2.58914e-11 trial_f 6.84386e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 256: f 2.58914e-11 trial_f 1.56667e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 257: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 258: f 2.58914e-11 trial_f 4.7301e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 259: f 2.58914e-11 trial_f 2.40702e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 260: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 261: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 262: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 263: f 2.58914e-11 trial_f 3.78509e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 264: f 2.58914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 265: f 2.58914e-11 trial_f 4.81004e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 266: f 2.58914e-11 trial_f 1.22156e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 267: f 0.0874618 trial_f 0.0874618 accepted 1  lowest_f 2.57694e-11
# basinhopping step 268: f 0.0874618 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 269: f 1.02862e-08 trial_f 1.02862e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 270: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 271: f 1.02862e-08 trial_f 2.61327e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 272: f 1.02862e-08 trial_f 4.28769e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 273: f 1.02862e-08 trial_f 3.88039e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 274: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 275: f 1.02862e-08 trial_f 1.35104 accepted 0  lowest_f 2.57694e-11
# basinhopping step 276: f 1.02862e-08 trial_f 7.2175e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 277: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 278: f 1.02862e-08 trial_f 2.93405e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 279: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 280: f 1.02862e-08 trial_f 7.20519e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 281: f 1.02862e-08 trial_f 8.22188e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 282: f 1.02862e-08 trial_f 8.20181e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 283: f 1.02862e-08 trial_f 4.25757e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 284: f 1.02862e-08 trial_f 7.26489e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 285: f 1.02862e-08 trial_f 7.63213e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 286: f 1.02862e-08 trial_f 1.25221e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 287: f 1.02862e-08 trial_f 2.51489e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 288: f 1.02862e-08 trial_f 8.54577e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 289: f 1.02862e-08 trial_f 7.64761e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 290: f 1.02862e-08 trial_f 2.51298e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 291: f 1.02862e-08 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 292: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 293: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 294: f 1.02862e-08 trial_f 3.11304e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 295: f 1.02862e-08 trial_f 1.21129e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 296: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 297: f 1.02862e-08 trial_f 4.62475e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 298: f 1.02862e-08 trial_f 2.53231e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 299: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.123333 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 300: f 1.02862e-08 trial_f 3.8415e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 301: f 1.02862e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 302: f 0.0225525 trial_f 0.0225525 accepted 1  lowest_f 2.57694e-11
# basinhopping step 303: f 0.0225525 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 304: f 0.0225525 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 305: f 7.4849e-11 trial_f 7.4849e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 306: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 307: f 7.4849e-11 trial_f 3.63038e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 308: f 7.4849e-11 trial_f 3.50353e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 309: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 310: f 7.4849e-11 trial_f 3.9849e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 311: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 312: f 7.4849e-11 trial_f 9.96501e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 313: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 314: f 7.4849e-11 trial_f 1.38968e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 315: f 7.4849e-11 trial_f 1.26357e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 316: f 7.4849e-11 trial_f 2.98856e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 317: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 318: f 7.4849e-11 trial_f 8.48274e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 319: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 320: f 7.4849e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 321: f 7.4849e-11 trial_f 6.57379e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 322: f 7.4849e-11 trial_f 2.70678e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 323: f 7.4849e-11 trial_f 8.02602e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 324: f 7.4849e-11 trial_f 6.87296e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 325: f 7.4849e-11 trial_f 1.64267e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 326: f 2.577e-11 trial_f 2.577e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 327: f 2.577e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 328: f 2.577e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 329: f 2.577e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 330: f 2.577e-11 trial_f 0.551381 accepted 0  lowest_f 2.57694e-11
# basinhopping step 331: f 2.57775e-11 trial_f 2.57775e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 332: f 8.04456e-06 trial_f 8.04456e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 333: f 8.04456e-06 trial_f 14.9834 accepted 0  lowest_f 2.57694e-11
# basinhopping step 334: f 8.04456e-06 trial_f 6.46802e+09 accepted 0  lowest_f 2.57694e-11
# basinhopping step 335: f 8.04456e-06 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 336: f 4.69401e-10 trial_f 4.69401e-10 accepted 1  lowest_f 2.57694e-11
# basinhopping step 337: f 4.69401e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 338: f 4.69401e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 339: f 4.69401e-10 trial_f 2.83603e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 340: f 4.69401e-10 trial_f 9.8152e+10 accepted 0  lowest_f 2.57694e-11
# basinhopping step 341: f 4.69401e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 342: f 4.69401e-10 trial_f 8.5464e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 343: f 4.69401e-10 trial_f 4.72985e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 344: f 6.70852e-06 trial_f 6.70852e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 345: f 6.70852e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 346: f 2.5783e-11 trial_f 2.5783e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 347: f 2.5783e-11 trial_f 2.93434e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 348: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 349: f 2.5783e-11 trial_f 1.36833e+12 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.128571 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 350: f 2.5783e-11 trial_f 8.54627e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 351: f 2.5783e-11 trial_f 2.93437e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 352: f 2.5783e-11 trial_f 8.54633e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 353: f 7.53325e-06 trial_f 7.53325e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 354: f 7.53325e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 355: f 7.53325e-06 trial_f 5.88431e+16 accepted 0  lowest_f 2.57694e-11
# basinhopping step 356: f 7.53325e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 357: f 7.53325e-06 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 358: f 4.9922e-11 trial_f 4.9922e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 359: f 4.9922e-11 trial_f 4.73021e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 360: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# found new global minimum on step 360 with function value 2.57694e-11
# basinhopping step 361: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 362: f 2.57694e-11 trial_f 224.165 accepted 0  lowest_f 2.57694e-11
# basinhopping step 363: f 3.24273e-11 trial_f 3.24273e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 364: f 3.24273e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 365: f 3.24273e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 366: f 3.24273e-11 trial_f 5.39786e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 367: f 3.24273e-11 trial_f 1.49016e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 368: f 3.24273e-11 trial_f 3.33586e+09 accepted 0  lowest_f 2.57694e-11
# basinhopping step 369: f 3.24273e-11 trial_f 1.17801e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 370: f 3.24273e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 371: f 3.24273e-11 trial_f 1.59402e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 372: f 3.24273e-11 trial_f 4.37285e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 373: f 1.71959e-08 trial_f 1.71959e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 374: f 1.71959e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 375: f 1.71959e-08 trial_f 1.204e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 376: f 2.5914e-11 trial_f 2.5914e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 377: f 2.5914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 378: f 2.5914e-11 trial_f 1.56671e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 379: f 2.5914e-11 trial_f 1.98778e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 380: f 2.5914e-11 trial_f 2.48487e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 381: f 2.5914e-11 trial_f 5.94546e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 382: f 2.5914e-11 trial_f 1.48493e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 383: f 2.5914e-11 trial_f 1.15243e+13 accepted 0  lowest_f 2.57694e-11
# basinhopping step 384: f 2.5914e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 385: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 386: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 387: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 388: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 389: f 2.57694e-11 trial_f 3.11054e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 390: f 0.325028 trial_f 0.325028 accepted 1  lowest_f 2.57694e-11
# basinhopping step 391: f 2.35483e-05 trial_f 2.35483e-05 accepted 1  lowest_f 2.57694e-11
# basinhopping step 392: f 2.35483e-05 trial_f 1.79842e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 393: f 2.35483e-05 trial_f 2.97967e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 394: f 2.35483e-05 trial_f 8.54655e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 395: f 2.35483e-05 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 396: f 2.35483e-05 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 397: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 398: f 2.57694e-11 trial_f 6.35788e+10 accepted 0  lowest_f 2.57694e-11
# basinhopping step 399: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.140000 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 400: f 2.57694e-11 trial_f 126.109 accepted 0  lowest_f 2.57694e-11
# basinhopping step 401: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 402: f 2.57694e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 403: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 404: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 405: f 2.57694e-11 trial_f 152.845 accepted 0  lowest_f 2.57694e-11
# basinhopping step 406: f 2.57694e-11 trial_f 7.00424e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 407: f 2.57694e-11 trial_f 90.6442 accepted 0  lowest_f 2.57694e-11
# basinhopping step 408: f 2.57694e-11 trial_f 224.366 accepted 0  lowest_f 2.57694e-11
# basinhopping step 409: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 410: f 2.57694e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 411: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 412: f 2.57694e-11 trial_f 85.2235 accepted 0  lowest_f 2.57694e-11
# basinhopping step 413: f 2.57694e-11 trial_f 93.0073 accepted 0  lowest_f 2.57694e-11
# basinhopping step 414: f 2.57694e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 415: f 2.57694e-11 trial_f 3.95755e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 416: f 2.57694e-11 trial_f 3.14768e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 417: f 5.60494e-11 trial_f 5.60494e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 418: f 5.60494e-11 trial_f 4.73021e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 419: f 5.60494e-11 trial_f 2.73239e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 420: f 5.60494e-11 trial_f 1.7041e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 421: f 5.60494e-11 trial_f 1.35909 accepted 0  lowest_f 2.57694e-11
# basinhopping step 422: f 5.60494e-11 trial_f 1.07841e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 423: f 5.60494e-11 trial_f 4.02469e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 424: f 5.60494e-11 trial_f 1.82262e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 425: f 5.60494e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 426: f 5.60494e-11 trial_f 5.63172e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 427: f 5.60494e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 428: f 5.60494e-11 trial_f 2.49739e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 429: f 4.58132e-08 trial_f 4.58132e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 430: f 4.58132e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 431: f 4.58132e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 432: f 4.58132e-08 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 433: f 2.66666e-11 trial_f 2.66666e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 434: f 2.66666e-11 trial_f 2.65306e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 435: f 2.66666e-11 trial_f 2.93435e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 436: f 2.66666e-11 trial_f 2.98372e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 437: f 8.49376e-06 trial_f 8.49376e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 438: f 8.49376e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 439: f 8.49376e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 440: f 0.000801535 trial_f 0.000801535 accepted 1  lowest_f 2.57694e-11
# basinhopping step 441: f 0.000801535 trial_f 1.56662e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 442: f 0.000223361 trial_f 0.000223361 accepted 1  lowest_f 2.57694e-11
# basinhopping step 443: f 9.5916e-05 trial_f 9.5916e-05 accepted 1  lowest_f 2.57694e-11
# basinhopping step 444: f 9.5916e-05 trial_f 4.2394e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 445: f 2.62573e-11 trial_f 2.62573e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 446: f 2.57695e-11 trial_f 2.57695e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 447: f 2.57695e-11 trial_f 6.94643e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 448: f 2.57695e-11 trial_f 2.93447e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 449: f 8.09085e-06 trial_f 8.09085e-06 accepted 1  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.146667 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 450: f 8.09085e-06 trial_f 1.20706 accepted 0  lowest_f 2.57694e-11
# basinhopping step 451: f 8.09085e-06 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 452: f 8.09085e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 453: f 8.09085e-06 trial_f 1.22986e+10 accepted 0  lowest_f 2.57694e-11
# basinhopping step 454: f 4.79463e-10 trial_f 4.79463e-10 accepted 1  lowest_f 2.57694e-11
# basinhopping step 455: f 5.59239e-06 trial_f 5.59239e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 456: f 5.59239e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 457: f 8.39847e-09 trial_f 8.39847e-09 accepted 1  lowest_f 2.57694e-11
# basinhopping step 458: f 8.39847e-09 trial_f 2.03873e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 459: f 8.39847e-09 trial_f 1.56664e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 460: f 8.39847e-09 trial_f 2.93441e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 461: f 8.39847e-09 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 462: f 0.0724779 trial_f 0.0724779 accepted 1  lowest_f 2.57694e-11
# basinhopping step 463: f 2.57842e-11 trial_f 2.57842e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 464: f 2.57842e-11 trial_f 1.113e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 465: f 3.49316e-11 trial_f 3.49316e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 466: f 3.49316e-11 trial_f 1.55177e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 467: f 3.49316e-11 trial_f 2.48007e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 468: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 469: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 470: f 3.49316e-11 trial_f 1.5724e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 471: f 3.49316e-11 trial_f 1.48162e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 472: f 3.49316e-11 trial_f 5.00207e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 473: f 3.49316e-11 trial_f 2.77285e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 474: f 3.49316e-11 trial_f 4.22817e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 475: f 3.49316e-11 trial_f 3.52637e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 476: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 477: f 3.49316e-11 trial_f 6.64001e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 478: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 479: f 3.49316e-11 trial_f 4.47341e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 480: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 481: f 3.49316e-11 trial_f 2.04288e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 482: f 3.49316e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 483: f 3.49316e-11 trial_f 2.46782e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 484: f 3.49316e-11 trial_f 7.72232e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 485: f 3.49316e-11 trial_f 1.30609e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 486: f 3.49316e-11 trial_f 2.44396e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 487: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 488: f 3.49316e-11 trial_f 6.59273e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 489: f 3.49316e-11 trial_f 6.48251e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 490: f 3.49316e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 491: f 0.0077631 trial_f 0.0077631 accepted 1  lowest_f 2.57694e-11
# basinhopping step 492: f 0.0077631 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 493: f 0.0077631 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 494: f 7.83613e-11 trial_f 7.83613e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 495: f 7.83613e-11 trial_f 5.14016e+09 accepted 0  lowest_f 2.57694e-11
# basinhopping step 496: f 7.83613e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 497: f 7.83613e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 498: f 7.83613e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 499: f 8.51141e-06 trial_f 8.51141e-06 accepted 1  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.150000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 500: f 1.34141e-10 trial_f 1.34141e-10 accepted 1  lowest_f 2.57694e-11
# basinhopping step 501: f 1.34141e-10 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 502: f 2.62573e-11 trial_f 2.62573e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 503: f 2.62573e-11 trial_f 4.14591e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 504: f 2.62573e-11 trial_f 4.73017e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 505: f 2.62573e-11 trial_f 2.74152e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 506: f 2.62573e-11 trial_f 1.96886e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 507: f 2.62573e-11 trial_f 1.62937e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 508: f 2.62573e-11 trial_f 1.30612e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 509: f 2.62573e-11 trial_f 4.72987e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 510: f 2.62573e-11 trial_f 6.86165e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 511: f 2.62573e-11 trial_f 1.5288e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 512: f 2.62573e-11 trial_f 2.31679e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 513: f 2.62573e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 514: f 2.62573e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 515: f 2.62573e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 516: f 0.177482 trial_f 0.177482 accepted 1  lowest_f 2.57694e-11
# basinhopping step 517: f 2.57948e-11 trial_f 2.57948e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 518: f 2.57948e-11 trial_f 4.30742e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 519: f 2.57948e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 520: f 3.70027e-06 trial_f 3.70027e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 521: f 2.5783e-11 trial_f 2.5783e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 522: f 2.5783e-11 trial_f 1.03708e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 523: f 2.5783e-11 trial_f 2.93433e+12 accepted 0  lowest_f 2.57694e-11
# ...
# basinhopping step 573: f 0.047668 trial_f 4.73007e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 574: f 0.047668 trial_f 1.30611e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 575: f 0.047668 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 576: f 0.047668 trial_f 2.93379e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 577: f 0.047668 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 578: f 0.047668 trial_f 1.33478e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 579: f 0.047668 trial_f 2.37564e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 580: f 0.584053 trial_f 0.584053 accepted 1  lowest_f 2.57694e-11
# basinhopping step 581: f 0.584053 trial_f 6.53749e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 582: f 3.80367e-10 trial_f 3.80367e-10 accepted 1  lowest_f 2.57694e-11
# basinhopping step 583: f 0.0145147 trial_f 0.0145147 accepted 1  lowest_f 2.57694e-11
# basinhopping step 584: f 0.0145147 trial_f 3.66503e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 585: f 0.0145147 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 586: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 587: f 2.57694e-11 trial_f 4.73026e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 588: f 2.57694e-11 trial_f 2.93421e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 589: f 0.0628053 trial_f 0.0628053 accepted 1  lowest_f 2.57694e-11
# basinhopping step 590: f 0.0628053 trial_f 2.63294e+09 accepted 0  lowest_f 2.57694e-11
# basinhopping step 591: f 0.0628053 trial_f 2.02705e+11 accepted 0  lowest_f 2.57694e-11
# basinhopping step 592: f 2.5783e-11 trial_f 2.5783e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 593: f 2.5783e-11 trial_f 2.82202e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 594: f 2.5783e-11 trial_f 1.50744e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 595: f 2.5783e-11 trial_f 1.56668e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 596: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 597: f 2.5783e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 598: f 2.5783e-11 trial_f 1.53837e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 599: f 2.5783e-11 trial_f 1.5082e+12 accepted 0  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.170000 target 0.500000 new stepsize 0.28243 old stepsize 0.313811
# basinhopping step 600: f 2.5783e-11 trial_f 2.70259e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 601: f 2.5783e-11 trial_f 2.93328e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 602: f 0.278317 trial_f 0.278317 accepted 1  lowest_f 2.57694e-11
# basinhopping step 603: f 0.278317 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 604: f 3.09015e-11 trial_f 3.09015e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 605: f 1.60098e-08 trial_f 1.60098e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 606: f 1.60098e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 607: f 1.60098e-08 trial_f 7.33272e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 608: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 609: f 2.57694e-11 trial_f 4.47165e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 610: f 2.57694e-11 trial_f 3.76061e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 611: f 7.42501e-06 trial_f 7.42501e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 612: f 7.42501e-06 trial_f 2.83689e+16 accepted 0  lowest_f 2.57694e-11
# basinhopping step 613: f 7.42501e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 614: f 2.58292e-11 trial_f 2.58292e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 615: f 2.58292e-11 trial_f 1.46805e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 616: f 2.58292e-11 trial_f 2.78562e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 617: f 2.58292e-11 trial_f 1.49463e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 618: f 2.58292e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 619: f 1.24289e-08 trial_f 1.24289e-08 accepted 1  lowest_f 2.57694e-11
# basinhopping step 620: f 1.24289e-08 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 621: f 1.24289e-08 trial_f 1.78142e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 622: f 1.24289e-08 trial_f 1.80209e+15 accepted 0  lowest_f 2.57694e-11
# basinhopping step 623: f 1.24289e-08 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 624: f 2.58392e-11 trial_f 2.58392e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 625: f 2.58392e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 626: f 2.58392e-11 trial_f 4.7301e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 627: f 2.58392e-11 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 628: f 2.58392e-11 trial_f 1.08065 accepted 0  lowest_f 2.57694e-11
# basinhopping step 629: f 2.58392e-11 trial_f 1.11028e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 630: f 2.58392e-11 trial_f 1.56667e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 631: f 0.000526398 trial_f 0.000526398 accepted 1  lowest_f 2.57694e-11
# basinhopping step 632: f 0.000526398 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 633: f 0.000526398 trial_f 8.32214e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 634: f 0.000526398 trial_f 8.35619e+16 accepted 0  lowest_f 2.57694e-11
# basinhopping step 635: f 0.00608816 trial_f 0.00608816 accepted 1  lowest_f 2.57694e-11
# basinhopping step 636: f 0.00608816 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 637: f 0.00608816 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 638: f 0.00608816 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 639: f 1.69062e-05 trial_f 1.69062e-05 accepted 1  lowest_f 2.57694e-11
# basinhopping step 640: f 3.32768e-07 trial_f 3.32768e-07 accepted 1  lowest_f 2.57694e-11
# basinhopping step 641: f 1.95786e-05 trial_f 1.95786e-05 accepted 1  lowest_f 2.57694e-11
# basinhopping step 642: f 2.57999e-11 trial_f 2.57999e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 643: f 2.57999e-11 trial_f 2.54313e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 644: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 645: f 2.57694e-11 trial_f 222.771 accepted 0  lowest_f 2.57694e-11
# basinhopping step 646: f 2.57694e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 647: f 2.57694e-11 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 648: f 2.57694e-11 trial_f 5.72698e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 649: f 0.0541886 trial_f 0.0541886 accepted 1  lowest_f 2.57694e-11
# adaptive stepsize: acceptance rate 0.181538 target 0.500000 new stepsize 0.254187 old stepsize 0.28243
# basinhopping step 650: f 0.0541886 trial_f 156.349 accepted 0  lowest_f 2.57694e-11
# basinhopping step 651: f 0.0541886 trial_f 140.965 accepted 0  lowest_f 2.57694e-11
# basinhopping step 652: f 0.0541886 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 653: f 2.57694e-11 trial_f 2.57694e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 654: f 2.57694e-11 trial_f 1.4386e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 655: f 0.0290599 trial_f 0.0290599 accepted 1  lowest_f 2.57694e-11
# basinhopping step 656: f 0.0290599 trial_f 3.70183e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 657: f 0.0290599 trial_f 3.12905e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 658: f 0.00535205 trial_f 0.00535205 accepted 1  lowest_f 2.57694e-11
# basinhopping step 659: f 2.5805e-11 trial_f 2.5805e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 660: f 2.5805e-11 trial_f 1.24633e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 661: f 2.5805e-11 trial_f 1.37742e+10 accepted 0  lowest_f 2.57694e-11
# basinhopping step 662: f 0.0286632 trial_f 0.0286632 accepted 1  lowest_f 2.57694e-11
# basinhopping step 663: f 0.0286632 trial_f 3.096e+08 accepted 0  lowest_f 2.57694e-11
# basinhopping step 664: f 0.0286632 trial_f 2.26206e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 665: f 0.0286632 trial_f 2.59347e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 666: f 0.0286632 trial_f 2.93436e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 667: f 0.0286632 trial_f 9.69464e+11 accepted 0  lowest_f 2.57694e-11
# basinhopping step 668: f 0.0286632 trial_f 2.58816e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 669: f 0.0286632 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 670: f 0.0286632 trial_f 2.66651e+12 accepted 0  lowest_f 2.57694e-11
# basinhopping step 671: f 7.06469e-06 trial_f 7.06469e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 672: f 7.06469e-06 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 673: f 7.06469e-06 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 674: f 7.06469e-06 trial_f 0.398282 accepted 0  lowest_f 2.57694e-11
# basinhopping step 675: f 7.06469e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 676: f 7.06469e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 677: f 7.06469e-06 trial_f 1.83741e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 678: f 7.06469e-06 trial_f 8.35524e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 679: f 7.06469e-06 trial_f 8.35525e+17 accepted 0  lowest_f 2.57694e-11
# basinhopping step 680: f 7.06469e-06 trial_f 0.90291 accepted 0  lowest_f 2.57694e-11
# basinhopping step 681: f 0.00808287 trial_f 0.00808287 accepted 1  lowest_f 2.57694e-11
# basinhopping step 682: f 0.00808287 trial_f 0.621441 accepted 0  lowest_f 2.57694e-11
# basinhopping step 683: f 0.00808287 trial_f 0.477196 accepted 0  lowest_f 2.57694e-11
# basinhopping step 684: f 4.64412e-11 trial_f 4.64412e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 685: f 4.64412e-11 trial_f 1.88422e+16 accepted 0  lowest_f 2.57694e-11
# basinhopping step 686: f 6.85708e-06 trial_f 6.85708e-06 accepted 1  lowest_f 2.57694e-11
# basinhopping step 687: f 2.60385e-11 trial_f 2.60385e-11 accepted 1  lowest_f 2.57694e-11
# basinhopping step 688: f 2.60385e-11 trial_f 2.07168e+12 accepted 0  lowest_f 2.57694e-11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 65
#      56 x0 = np.array([1200, 30e-3, 800, 3e5])
#      58 # Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#      59 #result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#      60 #result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#    (...)
#      63 # Perform global optimization using basinhopping
#      64 # Basin Hopping Methods: Powell
# ---> 65 result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_basinhopping.py:727, in basinhopping(func, x0, niter, T, stepsize, minimizer_kwargs, take_step, accept_test, callback, interval, disp, niter_success, seed, target_accept_rate, stepwise_factor)
#     724 message = ["requested number of basinhopping iterations completed"
#     725            " successfully"]
#     726 for i in range(niter):
# --> 727     new_global_min = bh.one_cycle()
#     729     if callable(callback):
#     730         # should we pass a copy of x?
#     731         val = callback(bh.xtrial, bh.energy_trial, bh.accept)
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_basinhopping.py:162, in BasinHoppingRunner.one_cycle(self)
#     159 self.nstep += 1
#     160 new_global_min = False
# --> 162 accept, minres = self._monte_carlo_step()
#     164 if accept:
#     165     self.energy = minres.fun
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_basinhopping.py:111, in BasinHoppingRunner._monte_carlo_step(self)
#     108 x_after_step = self.step_taking(x_after_step)
#     110 # do a local minimization
# --> 111 minres = self.minimizer(x_after_step)
#     112 x_after_quench = minres.x
#     113 energy_after_quench = minres.fun
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_basinhopping.py:303, in MinimizerWrapper.__call__(self, x0)
#     301     return self.minimizer(x0, **self.kwargs)
#     302 else:
# --> 303     return self.minimizer(self.func, x0, **self.kwargs)
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_minimize.py:704, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
# --> 704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     705 elif meth == 'cg':
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_optimize.py:3491, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3489 direc1 = direc[i]
#    3490 fx2 = fval
# -> 3491 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3492                                      tol=xtol * 100,
#    3493                                      lower_bound=lower_bound,
#    3494                                      upper_bound=upper_bound,
#    3495                                      fval=fval)
#    3496 if (fx2 - fval) > delta:
#    3497     delta = fx2 - fval
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_optimize.py:3179, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3176     return _linesearch_powell(func, p, xi, fval=fval, tol=tol)
#    3177 elif not np.isneginf(bound[0]) and not np.isposinf(bound[1]):
#    3178     # we can use a bounded scalar minimization
# -> 3179     res = _minimize_scalar_bounded(myfunc, bound, xatol=tol / 100)
#    3180     xi = res.x * xi
#    3181     return squeeze(res.fun), p + xi, xi
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_optimize.py:2322, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2320 si = np.sign(rat) + (rat == 0)
#    2321 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2322 fu = func(x, *args)
#    2323 num += 1
#    2324 fmin_data = (num, x, fu)
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_optimize.py:3160, in _linesearch_powell.<locals>.myfunc(alpha)
#    3159 def myfunc(alpha):
# -> 3160     return func(p + alpha*xi)
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\scipy\optimize\_optimize.py:526, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     524 ncalls[0] += 1
#     525 # A copy of x is sent to the user function (gh13740)
# --> 526 fx = function(np.copy(x), *(wrapper_args + args))
#     527 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     528 # backwards-compatibility, also allow np.array([1.3]),
#     529 # np.array([[1.3]]) etc.
#     530 if not np.isscalar(fx):
#
# File D:\anaconda3\envs\myenv\Lib\site-packages\numpy\lib\function_base.py:962, in copy(a, order, subok)
#     873 @array_function_dispatch(_copy_dispatcher)
#     874 def copy(a, order='K', subok=False):
#     875     """
#     876     Return an array copy of the given object.
#     877
#    (...)
#     960
#     961     """
# --> 962     return array(a, order=order, subok=subok, copy=True)
#
# KeyboardInterrupt:

# %%
rho2, mu2, Power2, P2 = result.x[0], result.x[1], result.x[2], result.x[3]

M2 = Q2*rho2
H2 = P2/rho2/g
specific_speed_1 = N1*np.sqrt(Q1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(Q2)/(P2/(rho2*g))**(3/4)
print(f"Ns_1 = {specific_speed_1:.4f}, Ns_2 = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = Power1/ ( rho1 * N1**3 * D1**5)
power_coeff_2 = Power2/ ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff_1 = (P1*Q1)/Power1
pump_eff_2 = (P2*Q2)/Power2
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Power1/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Power1/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Efficiency = {pump_eff_1*100:.3f} %\n"
      f"Prototype's Electrical Power = {Power1/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Dynamic Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Kinematic Viscosity is {mu2*10**6/rho2:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Power2/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Power2/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Efficiency = {pump_eff_2*100:.3f} %\n"
      f"Model's Electrical Power = {Power2/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns_1 = 13.4047, Ns_2 = 13.5131, Matching = 99.19141026326864 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031771428571428565, Matching = 98.37628235294117 %
# Head Coefficient Prototype = 0.0014186931209146892, Model = 0.0014186931209144338, Matching = 99.999999999982 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8462, Matching = 100.0 %
# Power Coefficient Prototype = 0.00000078, Model = 0.00000078, Matching = 99.99999972453534 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.800 Bar
# Prototype's Pressure Head is 70.884 m HAN+H2O2
# Prototype's Pressure Head is 70.884 m Testing Fluid
# Prototype's Pressure Head is 110.125 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 590.886 W
# Prototype's Shaft Power = 1043.333 W
# Prototype's Shaft Torque = 0.712 N-m
# Prototype's Efficiency = 57.206 %
# Prototype's Electrical Power = 1227.451 W
#
#
# Model's Shaft Speed is 7000.000 RPM
# Model's Impeller Diameter is 50.000 mm
# Model's Mass Flow Rate is 0.222 Kg/s
# Model's Pressure Across Pump is 1.391 Bar
# Model's Pressure Head is 9.127 m HAN+H2O2
# Model's Pressure Head is 17.721 m Testing Fluid
# Model's Pressure Head is 14.180 m Water
# Model's Volumetric Flow Rate is 0.2780 L/s
# Model's Fluid's Dynamic Viscosity is 16.7387 mPa-s
# Model's Fluid's Kinematic Viscosity is 20.9192 mPa-s
# Model's Fluid's Density is 800.1618 kg/m^3
# Model's Hydraulic Power = 38.659 W
# Model's Shaft Power = 67.169 W
# Model's Shaft Torque = 0.092 N-m
# Model's Efficiency = 58.135 %
# Model's Electrical Power = 79.023 W
