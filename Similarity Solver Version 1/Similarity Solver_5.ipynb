# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.4e5
#rho2 = 1000; mu2 = 10e-3
D2 = 55e-3
g = 9.807  # Acceleration due to gravity in m/s^2

Q1 = M1/rho1

# Define lower and upper bounds for mu, rho, m_dot, pressure rise
lb = [2000, 20e-3, 1200, 0.3, 2.5e5]  # Lower bounds
ub = [10000, 40e-3, 1300, 0.85, 4e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    N2, mu2, rho2, M2, P2 = x
    
    # Specific speed equation residual
    F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( M1/rho1 / (N1 * D1**3)) - (M2/rho2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( P1/rho1 / (N1**2 * D1**2)) - ( P2/rho2 / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (M1/mu1 / D1) - (M2/mu2 / D2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( P1 * M1/rho1 / ( rho1 * N1**3 * D1**5) ) - ( P2 * M2/rho2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F1, F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1.0, 1.0e-3, 1.0e-3, 1, 1.0e3]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([8000, 30e-3, 1000, 0.4, 2e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 0.019125
# basinhopping step 1: f 0.118023 trial_f 0.118023 accepted 1  lowest_f 0.019125
# basinhopping step 2: f 0.228434 trial_f 0.228434 accepted 1  lowest_f 0.019125
# basinhopping step 3: f 0.303224 trial_f 0.303224 accepted 1  lowest_f 0.019125
# basinhopping step 4: f 0.117183 trial_f 0.117183 accepted 1  lowest_f 0.019125
# basinhopping step 5: f 0.0457943 trial_f 0.0457943 accepted 1  lowest_f 0.019125
# basinhopping step 6: f 0.0190102 trial_f 0.0190102 accepted 1  lowest_f 0.0190102
# found new global minimum on step 6 with function value 0.0190102
# basinhopping step 7: f 0.0220687 trial_f 0.0220687 accepted 1  lowest_f 0.0190102
# basinhopping step 8: f 0.115851 trial_f 0.115851 accepted 1  lowest_f 0.0190102
# basinhopping step 9: f 0.128218 trial_f 0.128218 accepted 1  lowest_f 0.0190102
# basinhopping step 10: f 1.6266e-13 trial_f 1.6266e-13 accepted 1  lowest_f 1.6266e-13
# found new global minimum on step 10 with function value 1.6266e-13
# basinhopping step 11: f 0.0369748 trial_f 0.0369748 accepted 1  lowest_f 1.6266e-13
# basinhopping step 12: f 0.0369748 trial_f 0.298444 accepted 0  lowest_f 1.6266e-13
# basinhopping step 13: f 0.127917 trial_f 0.127917 accepted 1  lowest_f 1.6266e-13
# basinhopping step 14: f 1.76498e-13 trial_f 1.76498e-13 accepted 1  lowest_f 1.6266e-13
# C:\Users\Krai\AppData\Local\Temp\ipykernel_21680\2005615068.py:23: RuntimeWarning: invalid value encountered in sqrt
#   F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
# basinhopping step 15: f 1.76498e-13 trial_f 0.304679 accepted 0  lowest_f 1.6266e-13
# basinhopping step 16: f 0.176977 trial_f 0.176977 accepted 1  lowest_f 1.6266e-13
# basinhopping step 17: f 0.0220687 trial_f 0.0220687 accepted 1  lowest_f 1.6266e-13
# basinhopping step 18: f 0.128363 trial_f 0.128363 accepted 1  lowest_f 1.6266e-13
# basinhopping step 19: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.6266e-13
# basinhopping step 20: f 0.0220598 trial_f 0.128398 accepted 0  lowest_f 1.6266e-13
# basinhopping step 21: f 0.0203767 trial_f 0.0203767 accepted 1  lowest_f 1.6266e-13
# basinhopping step 22: f 0.0203767 trial_f 0.298566 accepted 0  lowest_f 1.6266e-13
# basinhopping step 23: f 0.298454 trial_f 0.298454 accepted 1  lowest_f 1.6266e-13
# basinhopping step 24: f 0.0220672 trial_f 0.0220672 accepted 1  lowest_f 1.6266e-13
# basinhopping step 25: f 0.227418 trial_f 0.227418 accepted 1  lowest_f 1.6266e-13
# basinhopping step 26: f 0.00923274 trial_f 0.00923274 accepted 1  lowest_f 1.6266e-13
# basinhopping step 27: f 0.0220658 trial_f 0.0220658 accepted 1  lowest_f 1.6266e-13
# basinhopping step 28: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.6266e-13
# basinhopping step 29: f 0.0220597 trial_f 0.209049 accepted 0  lowest_f 1.6266e-13
# basinhopping step 30: f 0.0013443 trial_f 0.0013443 accepted 1  lowest_f 1.6266e-13
# basinhopping step 31: f 0.303174 trial_f 0.303174 accepted 1  lowest_f 1.6266e-13
# basinhopping step 32: f 0.0289279 trial_f 0.0289279 accepted 1  lowest_f 1.6266e-13
# basinhopping step 33: f 0.128236 trial_f 0.128236 accepted 1  lowest_f 1.6266e-13
# basinhopping step 34: f 1.30311e-14 trial_f 1.30311e-14 accepted 1  lowest_f 1.30311e-14
# found new global minimum on step 34 with function value 1.30311e-14
# basinhopping step 35: f 3.77283e-07 trial_f 3.77283e-07 accepted 1  lowest_f 1.30311e-14
# basinhopping step 36: f 3.49189e-07 trial_f 3.49189e-07 accepted 1  lowest_f 1.30311e-14
# basinhopping step 37: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.30311e-14
# basinhopping step 38: f 0.118263 trial_f 0.118263 accepted 1  lowest_f 1.30311e-14
# basinhopping step 39: f 0.0655726 trial_f 0.0655726 accepted 1  lowest_f 1.30311e-14
# basinhopping step 40: f 0.00196947 trial_f 0.00196947 accepted 1  lowest_f 1.30311e-14
# basinhopping step 41: f 0.00196947 trial_f 0.032207 accepted 0  lowest_f 1.30311e-14
# basinhopping step 42: f 0.00196947 trial_f 0.209969 accepted 0  lowest_f 1.30311e-14
# basinhopping step 43: f 0.304443 trial_f 0.304443 accepted 1  lowest_f 1.30311e-14
# basinhopping step 44: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.30311e-14
# basinhopping step 45: f 0.116025 trial_f 0.116025 accepted 1  lowest_f 1.30311e-14
# basinhopping step 46: f 0.0182229 trial_f 0.0182229 accepted 1  lowest_f 1.30311e-14
# basinhopping step 47: f 0.000240691 trial_f 0.000240691 accepted 1  lowest_f 1.30311e-14
# basinhopping step 48: f 1.74577e-13 trial_f 1.74577e-13 accepted 1  lowest_f 1.30311e-14
# basinhopping step 49: f 1.40261e-16 trial_f 1.40261e-16 accepted 1  lowest_f 1.40261e-16
# found new global minimum on step 49 with function value 1.40261e-16
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 50: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 51: f 0.12832 trial_f 0.12832 accepted 1  lowest_f 1.40261e-16
# basinhopping step 52: f 0.0489507 trial_f 0.0489507 accepted 1  lowest_f 1.40261e-16
# basinhopping step 53: f 4.67942e-07 trial_f 4.67942e-07 accepted 1  lowest_f 1.40261e-16
# basinhopping step 54: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 55: f 0.0220691 trial_f 0.114057 accepted 0  lowest_f 1.40261e-16
# basinhopping step 56: f 1.74364e-13 trial_f 1.74364e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 57: f 3.7101e-07 trial_f 3.7101e-07 accepted 1  lowest_f 1.40261e-16
# basinhopping step 58: f 0.00619188 trial_f 0.00619188 accepted 1  lowest_f 1.40261e-16
# basinhopping step 59: f 0.127951 trial_f 0.127951 accepted 1  lowest_f 1.40261e-16
# basinhopping step 60: f 0.128114 trial_f 0.128114 accepted 1  lowest_f 1.40261e-16
# basinhopping step 61: f 0.0522757 trial_f 0.0522757 accepted 1  lowest_f 1.40261e-16
# basinhopping step 62: f 0.0220678 trial_f 0.0220678 accepted 1  lowest_f 1.40261e-16
# basinhopping step 63: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 64: f 0.00812745 trial_f 0.00812745 accepted 1  lowest_f 1.40261e-16
# basinhopping step 65: f 9.34515e-05 trial_f 9.34515e-05 accepted 1  lowest_f 1.40261e-16
# basinhopping step 66: f 9.34515e-05 trial_f 0.0109264 accepted 0  lowest_f 1.40261e-16
# basinhopping step 67: f 0.298457 trial_f 0.298457 accepted 1  lowest_f 1.40261e-16
# basinhopping step 68: f 8.88625e-13 trial_f 8.88625e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 69: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 70: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 71: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 72: f 0.302503 trial_f 0.302503 accepted 1  lowest_f 1.40261e-16
# basinhopping step 73: f 1.28488e-15 trial_f 1.28488e-15 accepted 1  lowest_f 1.40261e-16
# basinhopping step 74: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 75: f 0.0220691 trial_f 0.229587 accepted 0  lowest_f 1.40261e-16
# basinhopping step 76: f 0.0574989 trial_f 0.0574989 accepted 1  lowest_f 1.40261e-16
# basinhopping step 77: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.40261e-16
# basinhopping step 78: f 0.117627 trial_f 0.117627 accepted 1  lowest_f 1.40261e-16
# basinhopping step 79: f 1.89661e-13 trial_f 1.89661e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 80: f 1.89661e-13 trial_f 0.202219 accepted 0  lowest_f 1.40261e-16
# basinhopping step 81: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 82: f 0.0173934 trial_f 0.0173934 accepted 1  lowest_f 1.40261e-16
# basinhopping step 83: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.40261e-16
# basinhopping step 84: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 85: f 2.28667e-15 trial_f 2.28667e-15 accepted 1  lowest_f 1.40261e-16
# basinhopping step 86: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.40261e-16
# basinhopping step 87: f 0.0220598 trial_f 0.113965 accepted 0  lowest_f 1.40261e-16
# basinhopping step 88: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 89: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 90: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 91: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 92: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 93: f 5.14975e-14 trial_f 5.14975e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 94: f 1.75868e-13 trial_f 1.75868e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 95: f 0.032861 trial_f 0.032861 accepted 1  lowest_f 1.40261e-16
# basinhopping step 96: f 0.0558287 trial_f 0.0558287 accepted 1  lowest_f 1.40261e-16
# basinhopping step 97: f 0.0220661 trial_f 0.0220661 accepted 1  lowest_f 1.40261e-16
# basinhopping step 98: f 0.0136231 trial_f 0.0136231 accepted 1  lowest_f 1.40261e-16
# basinhopping step 99: f 1.05547e-07 trial_f 1.05547e-07 accepted 1  lowest_f 1.40261e-16
# adaptive stepsize: acceptance rate 0.870000 target 0.500000 new stepsize 1.23457 old stepsize 1.11111
# basinhopping step 100: f 1.05547e-07 trial_f 0.0220644 accepted 0  lowest_f 1.40261e-16
# basinhopping step 101: f 0.128294 trial_f 0.128294 accepted 1  lowest_f 1.40261e-16
# basinhopping step 102: f 0.0139064 trial_f 0.0139064 accepted 1  lowest_f 1.40261e-16
# basinhopping step 103: f 0.0139064 trial_f 0.303384 accepted 0  lowest_f 1.40261e-16
# basinhopping step 104: f 2.08611e-13 trial_f 2.08611e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 105: f 0.129944 trial_f 0.129944 accepted 1  lowest_f 1.40261e-16
# basinhopping step 106: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 107: f 0.0327636 trial_f 0.0327636 accepted 1  lowest_f 1.40261e-16
# basinhopping step 108: f 9.55097e-06 trial_f 9.55097e-06 accepted 1  lowest_f 1.40261e-16
# basinhopping step 109: f 0.117796 trial_f 0.117796 accepted 1  lowest_f 1.40261e-16
# basinhopping step 110: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.40261e-16
# basinhopping step 111: f 1.76632e-13 trial_f 1.76632e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 112: f 0.126514 trial_f 0.126514 accepted 1  lowest_f 1.40261e-16
# basinhopping step 113: f 0.126514 trial_f 13.5055 accepted 0  lowest_f 1.40261e-16
# basinhopping step 114: f 0.298478 trial_f 0.298478 accepted 1  lowest_f 1.40261e-16
# basinhopping step 115: f 3.54659e-07 trial_f 3.54659e-07 accepted 1  lowest_f 1.40261e-16
# basinhopping step 116: f 1.4836e-14 trial_f 1.4836e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 117: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 118: f 1.74111e-13 trial_f 1.74111e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 119: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 120: f 0.30811 trial_f 0.30811 accepted 1  lowest_f 1.40261e-16
# basinhopping step 121: f 0.0220676 trial_f 0.0220676 accepted 1  lowest_f 1.40261e-16
# basinhopping step 122: f 0.303184 trial_f 0.303184 accepted 1  lowest_f 1.40261e-16
# basinhopping step 123: f 0.128241 trial_f 0.128241 accepted 1  lowest_f 1.40261e-16
# basinhopping step 124: f 0.0694855 trial_f 0.0694855 accepted 1  lowest_f 1.40261e-16
# basinhopping step 125: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.40261e-16
# basinhopping step 126: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 127: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 128: f 0.0220597 trial_f 0.303298 accepted 0  lowest_f 1.40261e-16
# basinhopping step 129: f 1.69315e-13 trial_f 1.69315e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 130: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 131: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 132: f 0.00359714 trial_f 0.00359714 accepted 1  lowest_f 1.40261e-16
# basinhopping step 133: f 0.0518197 trial_f 0.0518197 accepted 1  lowest_f 1.40261e-16
# basinhopping step 134: f 1.12956e-13 trial_f 1.12956e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 135: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 136: f 0.298566 trial_f 0.298566 accepted 1  lowest_f 1.40261e-16
# basinhopping step 137: f 0.0220672 trial_f 0.0220672 accepted 1  lowest_f 1.40261e-16
# basinhopping step 138: f 0.0110463 trial_f 0.0110463 accepted 1  lowest_f 1.40261e-16
# basinhopping step 139: f 1.07501e-14 trial_f 1.07501e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 140: f 0.0167868 trial_f 0.0167868 accepted 1  lowest_f 1.40261e-16
# basinhopping step 141: f 0.0220685 trial_f 0.0220685 accepted 1  lowest_f 1.40261e-16
# basinhopping step 142: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 143: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 144: f 0.0220597 trial_f 0.0986964 accepted 0  lowest_f 1.40261e-16
# basinhopping step 145: f 0.0644969 trial_f 0.0644969 accepted 1  lowest_f 1.40261e-16
# basinhopping step 146: f 0.0304962 trial_f 0.0304962 accepted 1  lowest_f 1.40261e-16
# basinhopping step 147: f 7.74886e-14 trial_f 7.74886e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 148: f 1.15198e-14 trial_f 1.15198e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 149: f 3.55148e-07 trial_f 3.55148e-07 accepted 1  lowest_f 1.40261e-16
# adaptive stepsize: acceptance rate 0.880000 target 0.500000 new stepsize 1.37174 old stepsize 1.23457
# basinhopping step 150: f 3.61646e-07 trial_f 3.61646e-07 accepted 1  lowest_f 1.40261e-16
# basinhopping step 151: f 2.73045e-14 trial_f 2.73045e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 152: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 153: f 0.0113325 trial_f 0.0113325 accepted 1  lowest_f 1.40261e-16
# basinhopping step 154: f 0.0109913 trial_f 0.0109913 accepted 1  lowest_f 1.40261e-16
# basinhopping step 155: f 4.34186e-14 trial_f 4.34186e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 156: f 1.13054e-14 trial_f 1.13054e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 157: f 1.13054e-14 trial_f 54.8164 accepted 0  lowest_f 1.40261e-16
# basinhopping step 158: f 0.031244 trial_f 0.031244 accepted 1  lowest_f 1.40261e-16
# basinhopping step 159: f 1.14748e-13 trial_f 1.14748e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 160: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 161: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 162: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 163: f 0.128229 trial_f 0.128229 accepted 1  lowest_f 1.40261e-16
# basinhopping step 164: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.40261e-16
# basinhopping step 165: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 166: f 0.0302966 trial_f 0.0302966 accepted 1  lowest_f 1.40261e-16
# basinhopping step 167: f 9.33441e-14 trial_f 9.33441e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 168: f 0.000954703 trial_f 0.000954703 accepted 1  lowest_f 1.40261e-16
# basinhopping step 169: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 170: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 171: f 0.0867354 trial_f 0.0867354 accepted 1  lowest_f 1.40261e-16
# basinhopping step 172: f 0.0867354 trial_f 38.4851 accepted 0  lowest_f 1.40261e-16
# basinhopping step 173: f 1.77475e-13 trial_f 1.77475e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 174: f 2.38794e-14 trial_f 2.38794e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 175: f 0.022292 trial_f 0.022292 accepted 1  lowest_f 1.40261e-16
# basinhopping step 176: f 1.02206e-10 trial_f 1.02206e-10 accepted 1  lowest_f 1.40261e-16
# basinhopping step 177: f 0.0220651 trial_f 0.0220651 accepted 1  lowest_f 1.40261e-16
# basinhopping step 178: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 179: f 0.0220597 trial_f 0.298559 accepted 0  lowest_f 1.40261e-16
# basinhopping step 180: f 1.61884e-13 trial_f 1.61884e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 181: f 0.00133161 trial_f 0.00133161 accepted 1  lowest_f 1.40261e-16
# basinhopping step 182: f 3.08121e-15 trial_f 3.08121e-15 accepted 1  lowest_f 1.40261e-16
# basinhopping step 183: f 1.37554e-14 trial_f 1.37554e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 184: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 185: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 186: f 0.116412 trial_f 0.116412 accepted 1  lowest_f 1.40261e-16
# basinhopping step 187: f 0.0220599 trial_f 0.0220599 accepted 1  lowest_f 1.40261e-16
# basinhopping step 188: f 1.80952e-13 trial_f 1.80952e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 189: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 190: f 0.0220691 trial_f 0.0296787 accepted 0  lowest_f 1.40261e-16
# basinhopping step 191: f 0.29846 trial_f 0.29846 accepted 1  lowest_f 1.40261e-16
# basinhopping step 192: f 0.0220672 trial_f 0.0220672 accepted 1  lowest_f 1.40261e-16
# basinhopping step 193: f 0.0220672 trial_f 0.298444 accepted 0  lowest_f 1.40261e-16
# basinhopping step 194: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 195: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 196: f 0.0646271 trial_f 0.0646271 accepted 1  lowest_f 1.40261e-16
# basinhopping step 197: f 0.000602944 trial_f 0.000602944 accepted 1  lowest_f 1.40261e-16
# basinhopping step 198: f 0.302941 trial_f 0.302941 accepted 1  lowest_f 1.40261e-16
# basinhopping step 199: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.40261e-16
# adaptive stepsize: acceptance rate 0.885000 target 0.500000 new stepsize 1.52416 old stepsize 1.37174
# basinhopping step 200: f 0.0220675 trial_f 0.303213 accepted 0  lowest_f 1.40261e-16
# basinhopping step 201: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 202: f 0.033661 trial_f 0.033661 accepted 1  lowest_f 1.40261e-16
# basinhopping step 203: f 0.302313 trial_f 0.302313 accepted 1  lowest_f 1.40261e-16
# basinhopping step 204: f 0.0220674 trial_f 0.0220674 accepted 1  lowest_f 1.40261e-16
# basinhopping step 205: f 1.82823e-13 trial_f 1.82823e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 206: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 207: f 1.66261e-13 trial_f 1.66261e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 208: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 209: f 0.0281803 trial_f 0.0281803 accepted 1  lowest_f 1.40261e-16
# basinhopping step 210: f 0.0104649 trial_f 0.0104649 accepted 1  lowest_f 1.40261e-16
# basinhopping step 211: f 1.14768e-05 trial_f 1.14768e-05 accepted 1  lowest_f 1.40261e-16
# basinhopping step 212: f 2.19256e-14 trial_f 2.19256e-14 accepted 1  lowest_f 1.40261e-16
# basinhopping step 213: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 214: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 215: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 216: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 217: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.40261e-16
# basinhopping step 218: f 0.0842926 trial_f 0.0842926 accepted 1  lowest_f 1.40261e-16
# basinhopping step 219: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.40261e-16
# basinhopping step 220: f 0.0220596 trial_f 68.9667 accepted 0  lowest_f 1.40261e-16
# basinhopping step 221: f 0.1163 trial_f 0.1163 accepted 1  lowest_f 1.40261e-16
# basinhopping step 222: f 0.0640783 trial_f 0.0640783 accepted 1  lowest_f 1.40261e-16
# basinhopping step 223: f 0.0220672 trial_f 0.0220672 accepted 1  lowest_f 1.40261e-16
# basinhopping step 224: f 0.119938 trial_f 0.119938 accepted 1  lowest_f 1.40261e-16
# basinhopping step 225: f 1.85517e-13 trial_f 1.85517e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 226: f 1.85517e-13 trial_f 0.149055 accepted 0  lowest_f 1.40261e-16
# basinhopping step 227: f 4.47109e-15 trial_f 4.47109e-15 accepted 1  lowest_f 1.40261e-16
# basinhopping step 228: f 3.68159e-15 trial_f 3.68159e-15 accepted 1  lowest_f 1.40261e-16
# basinhopping step 229: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.40261e-16
# basinhopping step 230: f 0.0220691 trial_f 0.128532 accepted 0  lowest_f 1.40261e-16
# basinhopping step 231: f 0.118353 trial_f 0.118353 accepted 1  lowest_f 1.40261e-16
# basinhopping step 232: f 1.75203e-13 trial_f 1.75203e-13 accepted 1  lowest_f 1.40261e-16
# basinhopping step 233: f 0.00827171 trial_f 0.00827171 accepted 1  lowest_f 1.40261e-16
# basinhopping step 234: f 0.129837 trial_f 0.129837 accepted 1  lowest_f 1.40261e-16
# basinhopping step 235: f 1.07312e-20 trial_f 1.07312e-20 accepted 1  lowest_f 1.07312e-20
# found new global minimum on step 235 with function value 1.07312e-20
# basinhopping step 236: f 0.229988 trial_f 0.229988 accepted 1  lowest_f 1.07312e-20
# basinhopping step 237: f 1.75285e-13 trial_f 1.75285e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 238: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 239: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 240: f 1.84339e-13 trial_f 1.84339e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 241: f 4.13979e-15 trial_f 4.13979e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 242: f 0.130343 trial_f 0.130343 accepted 1  lowest_f 1.07312e-20
# basinhopping step 243: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 244: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 245: f 1.74491e-13 trial_f 1.74491e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 246: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 247: f 0.0220691 trial_f 0.210102 accepted 0  lowest_f 1.07312e-20
# basinhopping step 248: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 249: f 0.298454 trial_f 0.298454 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.888000 target 0.500000 new stepsize 1.69351 old stepsize 1.52416
# basinhopping step 250: f 0.298446 trial_f 0.298446 accepted 1  lowest_f 1.07312e-20
# basinhopping step 251: f 3.63052e-07 trial_f 3.63052e-07 accepted 1  lowest_f 1.07312e-20
# basinhopping step 252: f 0.0472401 trial_f 0.0472401 accepted 1  lowest_f 1.07312e-20
# basinhopping step 253: f 0.0220669 trial_f 0.0220669 accepted 1  lowest_f 1.07312e-20
# basinhopping step 254: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 255: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 256: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 257: f 1.69097e-13 trial_f 1.69097e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 258: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 259: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 260: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 261: f 0.0220597 trial_f 0.303329 accepted 0  lowest_f 1.07312e-20
# basinhopping step 262: f 0.30318 trial_f 0.30318 accepted 1  lowest_f 1.07312e-20
# basinhopping step 263: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.07312e-20
# basinhopping step 264: f 0.0220675 trial_f 0.128251 accepted 0  lowest_f 1.07312e-20
# basinhopping step 265: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 266: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 267: f 1.69768e-13 trial_f 1.69768e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 268: f 8.07308e-15 trial_f 8.07308e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 269: f 9.36022e-14 trial_f 9.36022e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 270: f 0.303464 trial_f 0.303464 accepted 1  lowest_f 1.07312e-20
# basinhopping step 271: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.07312e-20
# basinhopping step 272: f 0.0220675 trial_f 0.11914 accepted 0  lowest_f 1.07312e-20
# basinhopping step 273: f 0.128101 trial_f 0.128101 accepted 1  lowest_f 1.07312e-20
# basinhopping step 274: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.07312e-20
# basinhopping step 275: f 0.104694 trial_f 0.104694 accepted 1  lowest_f 1.07312e-20
# basinhopping step 276: f 1.72784e-13 trial_f 1.72784e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 277: f 1.02014e-13 trial_f 1.02014e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 278: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 279: f 1.76285e-13 trial_f 1.76285e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 280: f 1.72369e-14 trial_f 1.72369e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 281: f 0.303488 trial_f 0.303488 accepted 1  lowest_f 1.07312e-20
# basinhopping step 282: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.07312e-20
# basinhopping step 283: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 284: f 0.0108571 trial_f 0.0108571 accepted 1  lowest_f 1.07312e-20
# basinhopping step 285: f 0.00147111 trial_f 0.00147111 accepted 1  lowest_f 1.07312e-20
# basinhopping step 286: f 0.130479 trial_f 0.130479 accepted 1  lowest_f 1.07312e-20
# basinhopping step 287: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 288: f 0.0220597 trial_f 0.305914 accepted 0  lowest_f 1.07312e-20
# basinhopping step 289: f 0.0583963 trial_f 0.0583963 accepted 1  lowest_f 1.07312e-20
# basinhopping step 290: f 0.0583963 trial_f 0.128251 accepted 0  lowest_f 1.07312e-20
# basinhopping step 291: f 0.0680355 trial_f 0.0680355 accepted 1  lowest_f 1.07312e-20
# basinhopping step 292: f 0.229736 trial_f 0.229736 accepted 1  lowest_f 1.07312e-20
# basinhopping step 293: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.07312e-20
# basinhopping step 294: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 295: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 296: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 297: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 298: f 0.30737 trial_f 0.30737 accepted 1  lowest_f 1.07312e-20
# basinhopping step 299: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.890000 target 0.500000 new stepsize 1.88168 old stepsize 1.69351
# basinhopping step 300: f 0.118235 trial_f 0.118235 accepted 1  lowest_f 1.07312e-20
# basinhopping step 301: f 1.78177e-13 trial_f 1.78177e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 302: f 0.00799549 trial_f 0.00799549 accepted 1  lowest_f 1.07312e-20
# basinhopping step 303: f 5.70513e-14 trial_f 5.70513e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 304: f 0.000684066 trial_f 0.000684066 accepted 1  lowest_f 1.07312e-20
# basinhopping step 305: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 306: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 307: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 308: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 309: f 0.129216 trial_f 0.129216 accepted 1  lowest_f 1.07312e-20
# basinhopping step 310: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 311: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 312: f 0.0220597 trial_f 0.30313 accepted 0  lowest_f 1.07312e-20
# basinhopping step 313: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 314: f 0.00129842 trial_f 0.00129842 accepted 1  lowest_f 1.07312e-20
# basinhopping step 315: f 0.118165 trial_f 0.118165 accepted 1  lowest_f 1.07312e-20
# basinhopping step 316: f 0.12837 trial_f 0.12837 accepted 1  lowest_f 1.07312e-20
# basinhopping step 317: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.07312e-20
# basinhopping step 318: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 319: f 0.129311 trial_f 0.129311 accepted 1  lowest_f 1.07312e-20
# basinhopping step 320: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 321: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 322: f 1.80206e-13 trial_f 1.80206e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 323: f 5.97879e-15 trial_f 5.97879e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 324: f 3.97048e-13 trial_f 3.97048e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 325: f 4.8767e-12 trial_f 4.8767e-12 accepted 1  lowest_f 1.07312e-20
# basinhopping step 326: f 0.022069 trial_f 0.022069 accepted 1  lowest_f 1.07312e-20
# basinhopping step 327: f 0.0349176 trial_f 0.0349176 accepted 1  lowest_f 1.07312e-20
# basinhopping step 328: f 0.00669867 trial_f 0.00669867 accepted 1  lowest_f 1.07312e-20
# basinhopping step 329: f 1.69161e-13 trial_f 1.69161e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 330: f 9.89612e-15 trial_f 9.89612e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 331: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 332: f 1.8416e-13 trial_f 1.8416e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 333: f 1.8416e-13 trial_f 0.0220691 accepted 0  lowest_f 1.07312e-20
# basinhopping step 334: f 1.8416e-13 trial_f 0.152353 accepted 0  lowest_f 1.07312e-20
# basinhopping step 335: f 1.48651e-14 trial_f 1.48651e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 336: f 9.97998e-15 trial_f 9.97998e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 337: f 9.49277e-14 trial_f 9.49277e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 338: f 9.49277e-14 trial_f 0.0220691 accepted 0  lowest_f 1.07312e-20
# basinhopping step 339: f 8.62971e-14 trial_f 8.62971e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 340: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 341: f 0.0487524 trial_f 0.0487524 accepted 1  lowest_f 1.07312e-20
# basinhopping step 342: f 1.75492e-13 trial_f 1.75492e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 343: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 344: f 0.0220691 trial_f 0.298577 accepted 0  lowest_f 1.07312e-20
# basinhopping step 345: f 0.116134 trial_f 0.116134 accepted 1  lowest_f 1.07312e-20
# basinhopping step 346: f 0.0220599 trial_f 0.0220599 accepted 1  lowest_f 1.07312e-20
# basinhopping step 347: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 348: f 0.0220597 trial_f 0.303289 accepted 0  lowest_f 1.07312e-20
# basinhopping step 349: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.888571 target 0.500000 new stepsize 2.09075 old stepsize 1.88168
# basinhopping step 350: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 351: f 1.82058e-13 trial_f 1.82058e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 352: f 1.10861e-14 trial_f 1.10861e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 353: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 354: f 1.84121e-13 trial_f 1.84121e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 355: f 1.12148e-13 trial_f 1.12148e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 356: f 1.01786e-13 trial_f 1.01786e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 357: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 358: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 359: f 1.80603e-13 trial_f 1.80603e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 360: f 0.0449433 trial_f 0.0449433 accepted 1  lowest_f 1.07312e-20
# basinhopping step 361: f 8.28832e-14 trial_f 8.28832e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 362: f 1.0612e-13 trial_f 1.0612e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 363: f 0.298482 trial_f 0.298482 accepted 1  lowest_f 1.07312e-20
# basinhopping step 364: f 0.0237314 trial_f 0.0237314 accepted 1  lowest_f 1.07312e-20
# basinhopping step 365: f 0.0220686 trial_f 0.0220686 accepted 1  lowest_f 1.07312e-20
# basinhopping step 366: f 0.190728 trial_f 0.190728 accepted 1  lowest_f 1.07312e-20
# basinhopping step 367: f 1.85867e-13 trial_f 1.85867e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 368: f 5.25339e-12 trial_f 5.25339e-12 accepted 1  lowest_f 1.07312e-20
# basinhopping step 369: f 1.08806e-13 trial_f 1.08806e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 370: f 1.28613e-14 trial_f 1.28613e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 371: f 1.20392e-13 trial_f 1.20392e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 372: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 373: f 1.60847e-13 trial_f 1.60847e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 374: f 1.01848e-14 trial_f 1.01848e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 375: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 376: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 377: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 378: f 0.129296 trial_f 0.129296 accepted 1  lowest_f 1.07312e-20
# basinhopping step 379: f 1.70397e-13 trial_f 1.70397e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 380: f 0.303495 trial_f 0.303495 accepted 1  lowest_f 1.07312e-20
# basinhopping step 381: f 0.0220675 trial_f 0.0220675 accepted 1  lowest_f 1.07312e-20
# basinhopping step 382: f 1.75635e-13 trial_f 1.75635e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 383: f 8.01931e-14 trial_f 8.01931e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 384: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 385: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 386: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 387: f 1.8746e-13 trial_f 1.8746e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 388: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 389: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 390: f 0.216652 trial_f 0.216652 accepted 1  lowest_f 1.07312e-20
# basinhopping step 391: f 0.298441 trial_f 0.298441 accepted 1  lowest_f 1.07312e-20
# basinhopping step 392: f 1.27765e-13 trial_f 1.27765e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 393: f 1.27765e-13 trial_f 0.298454 accepted 0  lowest_f 1.07312e-20
# basinhopping step 394: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 395: f 0.209658 trial_f 0.209658 accepted 1  lowest_f 1.07312e-20
# basinhopping step 396: f 1.81542e-13 trial_f 1.81542e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 397: f 1.81542e-13 trial_f 0.210092 accepted 0  lowest_f 1.07312e-20
# basinhopping step 398: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 399: f 0.000210618 trial_f 0.000210618 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.897500 target 0.500000 new stepsize 2.32306 old stepsize 2.09075
# basinhopping step 400: f 1.72041e-13 trial_f 1.72041e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 401: f 0.00895893 trial_f 0.00895893 accepted 1  lowest_f 1.07312e-20
# basinhopping step 402: f 0.00898427 trial_f 0.00898427 accepted 1  lowest_f 1.07312e-20
# basinhopping step 403: f 0.000874739 trial_f 0.000874739 accepted 1  lowest_f 1.07312e-20
# basinhopping step 404: f 0.00907338 trial_f 0.00907338 accepted 1  lowest_f 1.07312e-20
# basinhopping step 405: f 0.0220687 trial_f 0.0220687 accepted 1  lowest_f 1.07312e-20
# basinhopping step 406: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 407: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 408: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 409: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 410: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 411: f 0.0220597 trial_f 33.0041 accepted 0  lowest_f 1.07312e-20
# basinhopping step 412: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 413: f 2.97554e-13 trial_f 2.97554e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 414: f 0.0220686 trial_f 0.0220686 accepted 1  lowest_f 1.07312e-20
# basinhopping step 415: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 416: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 417: f 1.61271e-13 trial_f 1.61271e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 418: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 419: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 420: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 421: f 0.115453 trial_f 0.115453 accepted 1  lowest_f 1.07312e-20
# basinhopping step 422: f 0.0220599 trial_f 0.0220599 accepted 1  lowest_f 1.07312e-20
# basinhopping step 423: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 424: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 425: f 0.0108746 trial_f 0.0108746 accepted 1  lowest_f 1.07312e-20
# basinhopping step 426: f 9.28232e-14 trial_f 9.28232e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 427: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 428: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 429: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 430: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 431: f 0.0220597 trial_f 100.777 accepted 0  lowest_f 1.07312e-20
# basinhopping step 432: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 433: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 434: f 0.0220597 trial_f 0.1293 accepted 0  lowest_f 1.07312e-20
# basinhopping step 435: f 1.74861e-13 trial_f 1.74861e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 436: f 1.20637e-13 trial_f 1.20637e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 437: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 438: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 439: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 440: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 441: f 0.298557 trial_f 0.298557 accepted 1  lowest_f 1.07312e-20
# basinhopping step 442: f 1.2199e-13 trial_f 1.2199e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 443: f 8.95648e-14 trial_f 8.95648e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 444: f 9.5002e-14 trial_f 9.5002e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 445: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 446: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 447: f 1.95552e-13 trial_f 1.95552e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 448: f 1.42767e-14 trial_f 1.42767e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 449: f 0.130044 trial_f 0.130044 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.902222 target 0.500000 new stepsize 2.58117 old stepsize 2.32306
# basinhopping step 450: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 451: f 1.7878e-13 trial_f 1.7878e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 452: f 1.6238e-14 trial_f 1.6238e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 453: f 1.07087e-14 trial_f 1.07087e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 454: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 455: f 0.108455 trial_f 0.108455 accepted 1  lowest_f 1.07312e-20
# basinhopping step 456: f 0.12834 trial_f 0.12834 accepted 1  lowest_f 1.07312e-20
# basinhopping step 457: f 1.91352e-13 trial_f 1.91352e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 458: f 8.15861e-14 trial_f 8.15861e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 459: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 460: f 1.75417e-13 trial_f 1.75417e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 461: f 0.00919397 trial_f 0.00919397 accepted 1  lowest_f 1.07312e-20
# basinhopping step 462: f 0.0220688 trial_f 0.0220688 accepted 1  lowest_f 1.07312e-20
# basinhopping step 463: f 1.79893e-13 trial_f 1.79893e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 464: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 465: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 466: f 1.66712e-13 trial_f 1.66712e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 467: f 1.04533e-13 trial_f 1.04533e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 468: f 1.09003e-14 trial_f 1.09003e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 469: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 470: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 471: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 472: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 473: f 1.77963e-13 trial_f 1.77963e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 474: f 1.77963e-13 trial_f 0.0220691 accepted 0  lowest_f 1.07312e-20
# basinhopping step 475: f 1.38515e-13 trial_f 1.38515e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 476: f 8.68688e-15 trial_f 8.68688e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 477: f 4.1367e-15 trial_f 4.1367e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 478: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 479: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 480: f 1.81262e-13 trial_f 1.81262e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 481: f 1.04677e-13 trial_f 1.04677e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 482: f 1.09423e-13 trial_f 1.09423e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 483: f 3.02256e-14 trial_f 3.02256e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 484: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 485: f 1.77377e-13 trial_f 1.77377e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 486: f 0.00718172 trial_f 0.00718172 accepted 1  lowest_f 1.07312e-20
# basinhopping step 487: f 1.1456e-14 trial_f 1.1456e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 488: f 6.48209e-12 trial_f 6.48209e-12 accepted 1  lowest_f 1.07312e-20
# basinhopping step 489: f 0.0220686 trial_f 0.0220686 accepted 1  lowest_f 1.07312e-20
# basinhopping step 490: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 491: f 1.76395e-13 trial_f 1.76395e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 492: f 1.2815e-13 trial_f 1.2815e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 493: f 0.0298018 trial_f 0.0298018 accepted 1  lowest_f 1.07312e-20
# basinhopping step 494: f 1.40741e-14 trial_f 1.40741e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 495: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 496: f 0.128159 trial_f 0.128159 accepted 1  lowest_f 1.07312e-20
# basinhopping step 497: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.07312e-20
# basinhopping step 498: f 1.7658e-13 trial_f 1.7658e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 499: f 1.43598e-13 trial_f 1.43598e-13 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.910000 target 0.500000 new stepsize 2.86797 old stepsize 2.58117
# basinhopping step 500: f 0.167093 trial_f 0.167093 accepted 1  lowest_f 1.07312e-20
# basinhopping step 501: f 1.38651e-13 trial_f 1.38651e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 502: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 503: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 504: f 1.8837e-13 trial_f 1.8837e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 505: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 506: f 1.74652e-13 trial_f 1.74652e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 507: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 508: f 1.79088e-13 trial_f 1.79088e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 509: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 510: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 511: f 1.7376e-13 trial_f 1.7376e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 512: f 9.457e-14 trial_f 9.457e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 513: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 514: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 515: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 516: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 517: f 0.115794 trial_f 0.115794 accepted 1  lowest_f 1.07312e-20
# basinhopping step 518: f 0.1282 trial_f 0.1282 accepted 1  lowest_f 1.07312e-20
# basinhopping step 519: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.07312e-20
# basinhopping step 520: f 1.75511e-13 trial_f 1.75511e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 521: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 522: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 523: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 524: f 1.83726e-13 trial_f 1.83726e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 525: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 526: f 0.114904 trial_f 0.114904 accepted 1  lowest_f 1.07312e-20
# basinhopping step 527: f 0.12806 trial_f 0.12806 accepted 1  lowest_f 1.07312e-20
# basinhopping step 528: f 0.0220598 trial_f 0.0220598 accepted 1  lowest_f 1.07312e-20
# basinhopping step 529: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 530: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 531: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 532: f 3.60757e-07 trial_f 3.60757e-07 accepted 1  lowest_f 1.07312e-20
# basinhopping step 533: f 8.68816e-14 trial_f 8.68816e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 534: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 535: f 0.0464132 trial_f 0.0464132 accepted 1  lowest_f 1.07312e-20
# basinhopping step 536: f 0.208658 trial_f 0.208658 accepted 1  lowest_f 1.07312e-20
# ...
# basinhopping step 824: f 1.26253e-13 trial_f 1.26253e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 825: f 9.82292e-14 trial_f 9.82292e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 826: f 1.28398e-13 trial_f 1.28398e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 827: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 828: f 0.228024 trial_f 0.228024 accepted 1  lowest_f 1.07312e-20
# basinhopping step 829: f 0.00601405 trial_f 0.00601405 accepted 1  lowest_f 1.07312e-20
# basinhopping step 830: f 1.6738e-13 trial_f 1.6738e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 831: f 1.68522e-13 trial_f 1.68522e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 832: f 1.71131e-13 trial_f 1.71131e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 833: f 9.85743e-15 trial_f 9.85743e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 834: f 1.63024e-13 trial_f 1.63024e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 835: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 836: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 837: f 5.25229e-18 trial_f 5.25229e-18 accepted 1  lowest_f 1.07312e-20
# basinhopping step 838: f 1.93172e-13 trial_f 1.93172e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 839: f 9.22171e-16 trial_f 9.22171e-16 accepted 1  lowest_f 1.07312e-20
# basinhopping step 840: f 0.0220688 trial_f 0.0220688 accepted 1  lowest_f 1.07312e-20
# basinhopping step 841: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 842: f 2.00809e-13 trial_f 2.00809e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 843: f 1.4528e-13 trial_f 1.4528e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 844: f 4.44707e-15 trial_f 4.44707e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 845: f 1.59898e-13 trial_f 1.59898e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 846: f 8.6987e-14 trial_f 8.6987e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 847: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 848: f 1.8957e-13 trial_f 1.8957e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 849: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.940000 target 0.500000 new stepsize 5.99622 old stepsize 5.3966
# basinhopping step 850: f 2.00355e-13 trial_f 2.00355e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 851: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 852: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 853: f 1.98764e-13 trial_f 1.98764e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 854: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 855: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 856: f 0.11874 trial_f 0.11874 accepted 1  lowest_f 1.07312e-20
# basinhopping step 857: f 1.97684e-13 trial_f 1.97684e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 858: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 859: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 860: f 2.0156e-13 trial_f 2.0156e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 861: f 1.21034e-13 trial_f 1.21034e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 862: f 1.59345e-13 trial_f 1.59345e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 863: f 1.66568e-13 trial_f 1.66568e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 864: f 0.00756222 trial_f 0.00756222 accepted 1  lowest_f 1.07312e-20
# basinhopping step 865: f 1.78558e-13 trial_f 1.78558e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 866: f 1.60913e-13 trial_f 1.60913e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 867: f 0.207805 trial_f 0.207805 accepted 1  lowest_f 1.07312e-20
# basinhopping step 868: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.07312e-20
# basinhopping step 869: f 1.7508e-13 trial_f 1.7508e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 870: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 871: f 1.93035e-13 trial_f 1.93035e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 872: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 873: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 874: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 875: f 2.01272e-13 trial_f 2.01272e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 876: f 1.77366e-13 trial_f 1.77366e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 877: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 878: f 1.92881e-13 trial_f 1.92881e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 879: f 1.62947e-13 trial_f 1.62947e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 880: f 1.34232e-13 trial_f 1.34232e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 881: f 9.28695e-15 trial_f 9.28695e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 882: f 1.72614e-13 trial_f 1.72614e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 883: f 1.43601e-13 trial_f 1.43601e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 884: f 1.63046e-13 trial_f 1.63046e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 885: f 1.68354e-13 trial_f 1.68354e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 886: f 1.68354e-13 trial_f 0.0220691 accepted 0  lowest_f 1.07312e-20
# basinhopping step 887: f 0.247569 trial_f 0.247569 accepted 1  lowest_f 1.07312e-20
# basinhopping step 888: f 0.0220682 trial_f 0.0220682 accepted 1  lowest_f 1.07312e-20
# basinhopping step 889: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 890: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 891: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 892: f 1.87433e-13 trial_f 1.87433e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 893: f 1.17355e-13 trial_f 1.17355e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 894: f 0.0715713 trial_f 0.0715713 accepted 1  lowest_f 1.07312e-20
# basinhopping step 895: f 1.1792e-14 trial_f 1.1792e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 896: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 897: f 0.0574862 trial_f 0.0574862 accepted 1  lowest_f 1.07312e-20
# basinhopping step 898: f 0.0220676 trial_f 0.0220676 accepted 1  lowest_f 1.07312e-20
# basinhopping step 899: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.942222 target 0.500000 new stepsize 6.66246 old stepsize 5.99622
# basinhopping step 900: f 1.78421e-13 trial_f 1.78421e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 901: f 1.67563e-13 trial_f 1.67563e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 902: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 903: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 904: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 905: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 906: f 1.847e-13 trial_f 1.847e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 907: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 908: f 1.92982e-13 trial_f 1.92982e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 909: f 0.00326919 trial_f 0.00326919 accepted 1  lowest_f 1.07312e-20
# basinhopping step 910: f 0.022069 trial_f 0.022069 accepted 1  lowest_f 1.07312e-20
# basinhopping step 911: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 912: f 2.03322e-13 trial_f 2.03322e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 913: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 914: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 915: f 1.84354e-13 trial_f 1.84354e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 916: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 917: f 0.0220691 trial_f 0.108834 accepted 0  lowest_f 1.07312e-20
# basinhopping step 918: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 919: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 920: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 921: f 1.9872e-13 trial_f 1.9872e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 922: f 3.5446e-07 trial_f 3.5446e-07 accepted 1  lowest_f 1.07312e-20
# basinhopping step 923: f 1.56286e-13 trial_f 1.56286e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 924: f 1.8117e-13 trial_f 1.8117e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 925: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 926: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 927: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 928: f 1.82404e-13 trial_f 1.82404e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 929: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 930: f 1.9397e-13 trial_f 1.9397e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 931: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 932: f 1.85021e-13 trial_f 1.85021e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 933: f 1.81752e-13 trial_f 1.81752e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 934: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 935: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 936: f 1.93518e-13 trial_f 1.93518e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 937: f 3.03667e-15 trial_f 3.03667e-15 accepted 1  lowest_f 1.07312e-20
# basinhopping step 938: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 939: f 2.0024e-13 trial_f 2.0024e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 940: f 1.66329e-14 trial_f 1.66329e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 941: f 1.58083e-13 trial_f 1.58083e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 942: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 943: f 2.01175e-13 trial_f 2.01175e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 944: f 1.15896e-14 trial_f 1.15896e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 945: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 946: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 947: f 1.6844e-13 trial_f 1.6844e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 948: f 1.7955e-13 trial_f 1.7955e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 949: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.944211 target 0.500000 new stepsize 7.40274 old stepsize 6.66246
# basinhopping step 950: f 2.00665e-13 trial_f 2.00665e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 951: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 952: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 953: f 2.03249e-13 trial_f 2.03249e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 954: f 1.66796e-13 trial_f 1.66796e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 955: f 1.47801e-13 trial_f 1.47801e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 956: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 957: f 2.01929e-13 trial_f 2.01929e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 958: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 959: f 2.02476e-13 trial_f 2.02476e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 960: f 1.14048e-13 trial_f 1.14048e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 961: f 8.75612e-14 trial_f 8.75612e-14 accepted 1  lowest_f 1.07312e-20
# basinhopping step 962: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 963: f 1.79347e-13 trial_f 1.79347e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 964: f 1.79347e-13 trial_f 0.0220691 accepted 0  lowest_f 1.07312e-20
# basinhopping step 965: f 1.90669e-13 trial_f 1.90669e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 966: f 1.85142e-13 trial_f 1.85142e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 967: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 968: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 969: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 970: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 971: f 1.98869e-13 trial_f 1.98869e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 972: f 1.32435e-13 trial_f 1.32435e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 973: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 974: f 1.88472e-13 trial_f 1.88472e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 975: f 0.0110798 trial_f 0.0110798 accepted 1  lowest_f 1.07312e-20
# basinhopping step 976: f 1.02449e-12 trial_f 1.02449e-12 accepted 1  lowest_f 1.07312e-20
# basinhopping step 977: f 0.022069 trial_f 0.022069 accepted 1  lowest_f 1.07312e-20
# basinhopping step 978: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 979: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 980: f 2.01586e-13 trial_f 2.01586e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 981: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 982: f 0.128046 trial_f 0.128046 accepted 1  lowest_f 1.07312e-20
# basinhopping step 983: f 0.1813 trial_f 0.1813 accepted 1  lowest_f 1.07312e-20
# basinhopping step 984: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.07312e-20
# basinhopping step 985: f 1.92405e-13 trial_f 1.92405e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 986: f 0.21134 trial_f 0.21134 accepted 1  lowest_f 1.07312e-20
# basinhopping step 987: f 1.97629e-13 trial_f 1.97629e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 988: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 989: f 1.67877e-13 trial_f 1.67877e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 990: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 991: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 992: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 993: f 0.105788 trial_f 0.105788 accepted 1  lowest_f 1.07312e-20
# basinhopping step 994: f 0.0220596 trial_f 0.0220596 accepted 1  lowest_f 1.07312e-20
# basinhopping step 995: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 996: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# basinhopping step 997: f 2.03911e-13 trial_f 2.03911e-13 accepted 1  lowest_f 1.07312e-20
# basinhopping step 998: f 0.0220691 trial_f 0.0220691 accepted 1  lowest_f 1.07312e-20
# basinhopping step 999: f 0.0220597 trial_f 0.0220597 accepted 1  lowest_f 1.07312e-20
# adaptive stepsize: acceptance rate 0.946000 target 0.500000 new stepsize 8.22526 old stepsize 7.40274
# basinhopping step 1000: f 1.844e-13 trial_f 1.844e-13 accepted 1  lowest_f 1.07312e-20

# %%
N2, mu2, rho2, M2, P2 = result.x[0], result.x[1], result.x[2], result.x[3], result.x[4]
Q2 = M2/rho2
specific_speed_1 = N1*np.sqrt(M1/rho1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(M2/rho2)/(P2/(rho2*g))**(3/4)
print(f"Ns = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = P1 * M1 / rho1 / ( rho1 * N1**3 * D1**5)
power_coeff_2 = P2 * M2 / rho2 / ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff = 0.50
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Q1*P1/pump_eff/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Q1*P1/pump_eff/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Electrical Power = {Q1*P1/pump_eff/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Dynamic Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Kinematic Viscosity is {mu2*10**6/rho2:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Q2*P2/pump_eff/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Q2*P2/pump_eff/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Electrical Power = {Q2*P2/pump_eff/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns = 13.7895, Matching = 99.99999999934245 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031263792851757136, Matching = 99.99999999369727 %
# Head Coefficient Prototype = 0.001366148931251182, Model = 0.0013661489312966073, Matching = 99.99999999667494 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8461, Matching = 99.99999999370019 %
# Power Coefficient Prototype = 0.00000043, Model = 0.00000043, Matching = 99.99999999037225 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.400 Bar
# Prototype's Pressure Head is 68.259 m HAN+H2O2
# Prototype's Pressure Head is 68.259 m Testing Fluid
# Prototype's Pressure Head is 106.047 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 569.001 W
# Prototype's Shaft Power = 1149.497 W
# Prototype's Shaft Torque = 0.784 N-m
# Prototype's Electrical Power = 1352.349 W
#
#
# Model's Shaft Speed is 7220.513 RPM
# Model's Impeller Diameter is 55.000 mm
# Model's Mass Flow Rate is 0.488 Kg/s
# Model's Pressure Across Pump is 2.801 Bar
# Model's Pressure Head is 18.383 m HAN+H2O2
# Model's Pressure Head is 21.970 m Testing Fluid
# Model's Pressure Head is 28.561 m Water
# Model's Volumetric Flow Rate is 0.3756 L/s
# Model's Fluid's Dynamic Viscosity is 33.9424 mPa-s
# Model's Fluid's Kinematic Viscosity is 26.1096 mPa-s
# Model's Fluid's Density is 1299.9999 kg/m^3
# Model's Hydraulic Power = 105.196 W
# Model's Shaft Power = 212.518 W
# Model's Shaft Torque = 0.281 N-m
# Model's Electrical Power = 250.021 W
