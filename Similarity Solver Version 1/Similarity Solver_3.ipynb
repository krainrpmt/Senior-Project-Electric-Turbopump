# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.4e5
#rho2 = 1000; mu2 = 10e-3
N2 = 8000; D2 = 50e-3
g = 9.807  # Acceleration due to gravity in m/s^2

Q1 = M1/rho1

# Define lower and upper bounds for mu, rho, m_dot, pressure rise
lb = [1e-3, 800, 0.1, 1e5]  # Lower bounds
ub = [65e-3, 1400, 1.0, 3e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    mu2, rho2, M2, P2 = x
    
    # Specific speed equation residual
    F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( M1/rho1 / (N1 * D1**3)) - (M2/rho2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( P1/rho1 / (N1**2 * D1**2)) - ( P2/rho2 / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (M1/mu1 / D1) - (M2/mu2 / D2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( P1 * M1/rho1 / ( rho1 * N1**3 * D1**5) ) - ( P2 * M2/rho2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F1, F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1.0, 1.0e-3, 1.0e-3, 1, 1.0e3]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([30e-3, 1000, 0.4, 2e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 5.28255e-06
# basinhopping step 1: f 0.00213049 trial_f 0.00213049 accepted 1  lowest_f 5.28255e-06
# basinhopping step 2: f 0.0561058 trial_f 0.0561058 accepted 1  lowest_f 5.28255e-06
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 0.0561058 trial_f 6.11138e-07 accepted 0  lowest_f 5.28255e-06
# basinhopping step 4: f 3.02552e-17 trial_f 3.02552e-17 accepted 1  lowest_f 3.02552e-17
# found new global minimum on step 4 with function value 3.02552e-17
# basinhopping step 5: f 3.02552e-17 trial_f 5.10573 accepted 0  lowest_f 3.02552e-17
# basinhopping step 6: f 7.59084e-12 trial_f 7.59084e-12 accepted 1  lowest_f 3.02552e-17
# warning: basinhopping: local minimization failure
# basinhopping step 7: f 7.59084e-12 trial_f 2.18632e-06 accepted 0  lowest_f 3.02552e-17
# /var/folders/j3/dr9c4mcx23gcdm0215yvb0h00000gn/T/ipykernel_19640/2506717071.py:23: RuntimeWarning: invalid value encountered in sqrt
#   F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
# basinhopping step 8: f 7.59084e-12 trial_f 2.30878 accepted 0  lowest_f 3.02552e-17
# basinhopping step 9: f 7.54855e-12 trial_f 7.54855e-12 accepted 1  lowest_f 3.02552e-17
# basinhopping step 10: f 3.2311e-17 trial_f 3.2311e-17 accepted 1  lowest_f 3.02552e-17
# basinhopping step 11: f 3.2311e-17 trial_f 11.4391 accepted 0  lowest_f 3.02552e-17
# basinhopping step 12: f 0.0448528 trial_f 0.0448528 accepted 1  lowest_f 3.02552e-17
# basinhopping step 13: f 0.0334925 trial_f 0.0334925 accepted 1  lowest_f 3.02552e-17
# warning: basinhopping: local minimization failure
# basinhopping step 14: f 0.0334925 trial_f 6.07209e-07 accepted 0  lowest_f 3.02552e-17
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 0.0334925 trial_f 6.11031e-07 accepted 0  lowest_f 3.02552e-17
# basinhopping step 16: f 0.0334925 trial_f 2.62107 accepted 0  lowest_f 3.02552e-17
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 0.0334925 trial_f 6.06643e-07 accepted 0  lowest_f 3.02552e-17
# basinhopping step 18: f 0.0334925 trial_f 11.4368 accepted 0  lowest_f 3.02552e-17
# basinhopping step 19: f 1.06687e-12 trial_f 1.06687e-12 accepted 1  lowest_f 3.02552e-17
# basinhopping step 20: f 1.06687e-12 trial_f 11.5301 accepted 0  lowest_f 3.02552e-17
# basinhopping step 21: f 4.8734e-15 trial_f 4.8734e-15 accepted 1  lowest_f 3.02552e-17
# basinhopping step 22: f 4.8734e-15 trial_f 11.5297 accepted 0  lowest_f 3.02552e-17
# basinhopping step 23: f 2.95083e-17 trial_f 2.95083e-17 accepted 1  lowest_f 2.95083e-17
# found new global minimum on step 23 with function value 2.95083e-17
# basinhopping step 24: f 2.95083e-17 trial_f 1.61741 accepted 0  lowest_f 2.95083e-17
# basinhopping step 25: f 3.40446e-05 trial_f 3.40446e-05 accepted 1  lowest_f 2.95083e-17
# basinhopping step 26: f 3.79343e-14 trial_f 3.79343e-14 accepted 1  lowest_f 2.95083e-17
# basinhopping step 27: f 3.79343e-14 trial_f 0.480531 accepted 0  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 28: f 3.79343e-14 trial_f 4.80646e-07 accepted 0  lowest_f 2.95083e-17
# basinhopping step 29: f 3.79343e-14 trial_f 4.19712 accepted 0  lowest_f 2.95083e-17
# basinhopping step 30: f 3.79343e-14 trial_f 11.4135 accepted 0  lowest_f 2.95083e-17
# basinhopping step 31: f 3.79343e-14 trial_f 8.24793 accepted 0  lowest_f 2.95083e-17
# basinhopping step 32: f 3.79343e-14 trial_f 9.5123 accepted 0  lowest_f 2.95083e-17
# basinhopping step 33: f 3.79343e-14 trial_f 0.724537 accepted 0  lowest_f 2.95083e-17
# basinhopping step 34: f 3.79343e-14 trial_f 299207 accepted 0  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 3.79343e-14 trial_f 4.83841e-07 accepted 0  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 36: f 3.79343e-14 trial_f 4.77479e-07 accepted 0  lowest_f 2.95083e-17
# basinhopping step 37: f 3.79343e-14 trial_f 11.4505 accepted 0  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 3.79343e-14 trial_f 4.74632e-07 accepted 0  lowest_f 2.95083e-17
# basinhopping step 39: f 0.0101653 trial_f 0.0101653 accepted 1  lowest_f 2.95083e-17
# basinhopping step 40: f 2.24372e-12 trial_f 2.24372e-12 accepted 1  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 2.24372e-12 trial_f 2.65783e-07 accepted 0  lowest_f 2.95083e-17
# basinhopping step 42: f 8.99327e-13 trial_f 8.99327e-13 accepted 1  lowest_f 2.95083e-17
# basinhopping step 43: f 8.99327e-13 trial_f 11.5347 accepted 0  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 8.99327e-13 trial_f 1.66688e-05 accepted 0  lowest_f 2.95083e-17
# basinhopping step 45: f 8.99327e-13 trial_f 11.5333 accepted 0  lowest_f 2.95083e-17
# basinhopping step 46: f 0.320675 trial_f 0.320675 accepted 1  lowest_f 2.95083e-17
# basinhopping step 47: f 0.320675 trial_f 11.5059 accepted 0  lowest_f 2.95083e-17
# basinhopping step 48: f 0.320675 trial_f 11.4495 accepted 0  lowest_f 2.95083e-17
# warning: basinhopping: local minimization failure
# basinhopping step 49: f 0.320675 trial_f 6.07476e-07 accepted 0  lowest_f 2.95083e-17
# adaptive stepsize: acceptance rate 0.340000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 50: f 1.54967e-12 trial_f 1.54967e-12 accepted 1  lowest_f 2.95083e-17
# basinhopping step 51: f 0.17926 trial_f 0.17926 accepted 1  lowest_f 2.95083e-17
# basinhopping step 52: f 3.55132e-05 trial_f 3.55132e-05 accepted 1  lowest_f 2.95083e-17
# basinhopping step 53: f 3.55132e-05 trial_f 3.60967 accepted 0  lowest_f 2.95083e-17
# basinhopping step 54: f 2.27293e-12 trial_f 2.27293e-12 accepted 1  lowest_f 2.95083e-17
# basinhopping step 55: f 0.553013 trial_f 0.553013 accepted 1  lowest_f 2.95083e-17
# basinhopping step 56: f 3.63209e-05 trial_f 3.63209e-05 accepted 1  lowest_f 2.95083e-17
# basinhopping step 57: f 1.26849e-11 trial_f 1.26849e-11 accepted 1  lowest_f 2.95083e-17
# basinhopping step 58: f 0.0421531 trial_f 0.0421531 accepted 1  lowest_f 2.95083e-17
# basinhopping step 59: f 0.00486828 trial_f 0.00486828 accepted 1  lowest_f 2.95083e-17
# basinhopping step 60: f 5.18588e-19 trial_f 5.18588e-19 accepted 1  lowest_f 5.18588e-19
# found new global minimum on step 60 with function value 5.18588e-19
# basinhopping step 61: f 5.18588e-19 trial_f 9.46794 accepted 0  lowest_f 5.18588e-19
# basinhopping step 62: f 5.18588e-19 trial_f 2.26106 accepted 0  lowest_f 5.18588e-19
# basinhopping step 63: f 1.21732e-18 trial_f 1.21732e-18 accepted 1  lowest_f 5.18588e-19
# basinhopping step 64: f 1.21732e-18 trial_f 0.287184 accepted 0  lowest_f 5.18588e-19
# basinhopping step 65: f 1.21732e-18 trial_f 0.508621 accepted 0  lowest_f 5.18588e-19
# basinhopping step 66: f 1.21732e-18 trial_f 3.39652 accepted 0  lowest_f 5.18588e-19
# basinhopping step 67: f 1.21732e-18 trial_f 363413 accepted 0  lowest_f 5.18588e-19
# basinhopping step 68: f 1.21732e-18 trial_f 6.23261 accepted 0  lowest_f 5.18588e-19
# basinhopping step 69: f 0.0205724 trial_f 0.0205724 accepted 1  lowest_f 5.18588e-19
# basinhopping step 70: f 0.105448 trial_f 0.105448 accepted 1  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 0.105448 trial_f 6.07361e-07 accepted 0  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 72: f 0.105448 trial_f 6.19675e-07 accepted 0  lowest_f 5.18588e-19
# basinhopping step 73: f 2.47247e-12 trial_f 2.47247e-12 accepted 1  lowest_f 5.18588e-19
# basinhopping step 74: f 0.550874 trial_f 0.550874 accepted 1  lowest_f 5.18588e-19
# basinhopping step 75: f 0.344962 trial_f 0.344962 accepted 1  lowest_f 5.18588e-19
# basinhopping step 76: f 5.96549e-11 trial_f 5.96549e-11 accepted 1  lowest_f 5.18588e-19
# basinhopping step 77: f 2.51254e-14 trial_f 2.51254e-14 accepted 1  lowest_f 5.18588e-19
# basinhopping step 78: f 6.1632e-05 trial_f 6.1632e-05 accepted 1  lowest_f 5.18588e-19
# basinhopping step 79: f 1.41763e-12 trial_f 1.41763e-12 accepted 1  lowest_f 5.18588e-19
# basinhopping step 80: f 1.41763e-12 trial_f 425860 accepted 0  lowest_f 5.18588e-19
# basinhopping step 81: f 3.40438e-05 trial_f 3.40438e-05 accepted 1  lowest_f 5.18588e-19
# basinhopping step 82: f 1.17043e-18 trial_f 1.17043e-18 accepted 1  lowest_f 5.18588e-19
# basinhopping step 83: f 0.0476252 trial_f 0.0476252 accepted 1  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 84: f 0.0476252 trial_f 6.15432e-07 accepted 0  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 85: f 0.0476252 trial_f 6.07187e-07 accepted 0  lowest_f 5.18588e-19
# basinhopping step 86: f 0.0476252 trial_f 11.4439 accepted 0  lowest_f 5.18588e-19
# basinhopping step 87: f 0.211816 trial_f 0.211816 accepted 1  lowest_f 5.18588e-19
# basinhopping step 88: f 3.54346e-05 trial_f 3.54346e-05 accepted 1  lowest_f 5.18588e-19
# basinhopping step 89: f 3.54346e-05 trial_f 11.5242 accepted 0  lowest_f 5.18588e-19
# basinhopping step 90: f 2.96284e-11 trial_f 2.96284e-11 accepted 1  lowest_f 5.18588e-19
# basinhopping step 91: f 2.96284e-11 trial_f 2.26278 accepted 0  lowest_f 5.18588e-19
# basinhopping step 92: f 0.0600459 trial_f 0.0600459 accepted 1  lowest_f 5.18588e-19
# basinhopping step 93: f 0.0600459 trial_f 2.8629 accepted 0  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 94: f 0.0600459 trial_f 6.14761e-07 accepted 0  lowest_f 5.18588e-19
# basinhopping step 95: f 0.0600459 trial_f 10.8552 accepted 0  lowest_f 5.18588e-19
# basinhopping step 96: f 0.206625 trial_f 0.206625 accepted 1  lowest_f 5.18588e-19
# basinhopping step 97: f 0.206625 trial_f 5.05707 accepted 0  lowest_f 5.18588e-19
# basinhopping step 98: f 2.26294e-05 trial_f 2.26294e-05 accepted 1  lowest_f 5.18588e-19
# basinhopping step 99: f 2.26294e-05 trial_f 11.4263 accepted 0  lowest_f 5.18588e-19
# adaptive stepsize: acceptance rate 0.460000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# warning: basinhopping: local minimization failure
# basinhopping step 100: f 2.26294e-05 trial_f 4.35458e-07 accepted 0  lowest_f 5.18588e-19
# basinhopping step 101: f 2.26294e-05 trial_f 11.4614 accepted 0  lowest_f 5.18588e-19
# basinhopping step 102: f 2.26294e-05 trial_f 4.39987 accepted 0  lowest_f 5.18588e-19
# basinhopping step 103: f 2.26294e-05 trial_f 2.79674 accepted 0  lowest_f 5.18588e-19
# basinhopping step 104: f 2.26294e-05 trial_f 0.526595 accepted 0  lowest_f 5.18588e-19
# basinhopping step 105: f 1.29692 trial_f 1.29692 accepted 1  lowest_f 5.18588e-19
# basinhopping step 106: f 0.356535 trial_f 0.356535 accepted 1  lowest_f 5.18588e-19
# basinhopping step 107: f 1.39992e-07 trial_f 1.39992e-07 accepted 1  lowest_f 5.18588e-19
# basinhopping step 108: f 1.39992e-07 trial_f 11.5178 accepted 0  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 109: f 1.39992e-07 trial_f 6.45699e-07 accepted 0  lowest_f 5.18588e-19
# basinhopping step 110: f 1.39992e-07 trial_f 0.509189 accepted 0  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 111: f 1.39992e-07 trial_f 6.45447e-07 accepted 0  lowest_f 5.18588e-19
# warning: basinhopping: local minimization failure
# basinhopping step 112: f 1.39992e-07 trial_f 6.4164e-07 accepted 0  lowest_f 5.18588e-19
# basinhopping step 113: f 1.39992e-07 trial_f 11.506 accepted 0  lowest_f 5.18588e-19
# basinhopping step 114: f 1.39992e-07 trial_f 2.28432 accepted 0  lowest_f 5.18588e-19
# basinhopping step 115: f 3.61624e-12 trial_f 3.61624e-12 accepted 1  lowest_f 5.18588e-19
# basinhopping step 116: f 4.73373e-20 trial_f 4.73373e-20 accepted 1  lowest_f 4.73373e-20
# found new global minimum on step 116 with function value 4.73373e-20
# basinhopping step 117: f 1.21208e-18 trial_f 1.21208e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 118: f 1.22166e-18 trial_f 1.22166e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 119: f 1.25674e-05 trial_f 1.25674e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 120: f 1.25674e-05 trial_f 11.4799 accepted 0  lowest_f 4.73373e-20
# basinhopping step 121: f 6.97283e-15 trial_f 6.97283e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 122: f 1.39381e-10 trial_f 1.39381e-10 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 123: f 1.39381e-10 trial_f 1.78052e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 124: f 1.39381e-10 trial_f 5.63329 accepted 0  lowest_f 4.73373e-20
# basinhopping step 125: f 0.365747 trial_f 0.365747 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 126: f 0.365747 trial_f 6.11146e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 127: f 2.93117e-11 trial_f 2.93117e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 128: f 0.0013732 trial_f 0.0013732 accepted 1  lowest_f 4.73373e-20
# basinhopping step 129: f 1.03222e-12 trial_f 1.03222e-12 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 130: f 1.03222e-12 trial_f 5.93869e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 131: f 6.23724e-14 trial_f 6.23724e-14 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 132: f 6.23724e-14 trial_f 5.1715e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 133: f 6.23724e-14 trial_f 11.4599 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 134: f 6.23724e-14 trial_f 5.13707e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 135: f 6.23724e-14 trial_f 5.13595e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 136: f 6.23724e-14 trial_f 10.0199 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 137: f 6.23724e-14 trial_f 5.10396e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 138: f 6.23724e-14 trial_f 5.10281e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 139: f 6.23724e-14 trial_f 0.463903 accepted 0  lowest_f 4.73373e-20
# basinhopping step 140: f 6.23724e-14 trial_f 10.6627 accepted 0  lowest_f 4.73373e-20
# basinhopping step 141: f 5.41109e-12 trial_f 5.41109e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 142: f 2.28933 trial_f 2.28933 accepted 1  lowest_f 4.73373e-20
# basinhopping step 143: f 1.3502 trial_f 1.3502 accepted 1  lowest_f 4.73373e-20
# basinhopping step 144: f 1.3502 trial_f 11.4588 accepted 0  lowest_f 4.73373e-20
# basinhopping step 145: f 0.0138202 trial_f 0.0138202 accepted 1  lowest_f 4.73373e-20
# basinhopping step 146: f 2.02262e-15 trial_f 2.02262e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 147: f 2.02262e-15 trial_f 3.95824 accepted 0  lowest_f 4.73373e-20
# basinhopping step 148: f 2.89001e-12 trial_f 2.89001e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 149: f 2.89001e-12 trial_f 1.80056 accepted 0  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.446667 target 0.500000 new stepsize 0.729 old stepsize 0.81
# warning: basinhopping: local minimization failure
# basinhopping step 150: f 2.89001e-12 trial_f 1.48037e-05 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 151: f 2.89001e-12 trial_f 2.08094e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 152: f 2.89001e-12 trial_f 11.5275 accepted 0  lowest_f 4.73373e-20
# basinhopping step 153: f 2.89001e-12 trial_f 11.5072 accepted 0  lowest_f 4.73373e-20
# basinhopping step 154: f 2.52594e-05 trial_f 2.52594e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 155: f 2.52594e-05 trial_f 11.4362 accepted 0  lowest_f 4.73373e-20
# basinhopping step 156: f 2.52594e-05 trial_f 4.33386 accepted 0  lowest_f 4.73373e-20
# basinhopping step 157: f 2.52594e-05 trial_f 11.4402 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 158: f 2.52594e-05 trial_f 4.95614e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 159: f 2.52594e-05 trial_f 4.95442e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 160: f 2.52594e-05 trial_f 10.852 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 161: f 2.52594e-05 trial_f 4.89334e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 162: f 2.52594e-05 trial_f 4.85765e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 163: f 2.52594e-05 trial_f 4.86127e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 164: f 2.52594e-05 trial_f 0.657934 accepted 0  lowest_f 4.73373e-20
# basinhopping step 165: f 2.52594e-05 trial_f 1.34585 accepted 0  lowest_f 4.73373e-20
# basinhopping step 166: f 2.52594e-05 trial_f 0.999764 accepted 0  lowest_f 4.73373e-20
# basinhopping step 167: f 0.18662 trial_f 0.18662 accepted 1  lowest_f 4.73373e-20
# basinhopping step 168: f 2.07513e-12 trial_f 2.07513e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 169: f 2.07513e-12 trial_f 11.4547 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 170: f 2.07513e-12 trial_f 5.33027e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 171: f 2.07513e-12 trial_f 5.29129e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 172: f 2.07513e-12 trial_f 0.225582 accepted 0  lowest_f 4.73373e-20
# basinhopping step 173: f 2.07513e-12 trial_f 11.4463 accepted 0  lowest_f 4.73373e-20
# basinhopping step 174: f 0.0124528 trial_f 0.0124528 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 175: f 0.0124528 trial_f 6.15247e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 176: f 0.0124528 trial_f 6.18917e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 177: f 0.552977 trial_f 0.552977 accepted 1  lowest_f 4.73373e-20
# basinhopping step 178: f 0.437242 trial_f 0.437242 accepted 1  lowest_f 4.73373e-20
# basinhopping step 179: f 0.437242 trial_f 0.505139 accepted 0  lowest_f 4.73373e-20
# basinhopping step 180: f 4.58968e-13 trial_f 4.58968e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 181: f 0.107514 trial_f 0.107514 accepted 1  lowest_f 4.73373e-20
# basinhopping step 182: f 0.00490598 trial_f 0.00490598 accepted 1  lowest_f 4.73373e-20
# basinhopping step 183: f 0.00490598 trial_f 107876 accepted 0  lowest_f 4.73373e-20
# basinhopping step 184: f 6.45592e-17 trial_f 6.45592e-17 accepted 1  lowest_f 4.73373e-20
# basinhopping step 185: f 1.22849e-18 trial_f 1.22849e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 186: f 1.21511e-18 trial_f 1.21511e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 187: f 1.21511e-18 trial_f 11.534 accepted 0  lowest_f 4.73373e-20
# basinhopping step 188: f 1.21942e-18 trial_f 1.21942e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 189: f 1.21942e-18 trial_f 0.38397 accepted 0  lowest_f 4.73373e-20
# basinhopping step 190: f 1.23072e-18 trial_f 1.23072e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 191: f 1.21405e-18 trial_f 1.21405e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 192: f 1.21405e-18 trial_f 2.74867e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 193: f 1.21405e-18 trial_f 11.5259 accepted 0  lowest_f 4.73373e-20
# basinhopping step 194: f 1.21405e-18 trial_f 0.948948 accepted 0  lowest_f 4.73373e-20
# basinhopping step 195: f 1.21405e-18 trial_f 11.5306 accepted 0  lowest_f 4.73373e-20
# basinhopping step 196: f 1.21172e-18 trial_f 1.21172e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 197: f 1.22171e-18 trial_f 1.22171e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 198: f 1.22171e-18 trial_f 11.5258 accepted 0  lowest_f 4.73373e-20
# basinhopping step 199: f 1.22171e-18 trial_f 11.5182 accepted 0  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.420000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 200: f 1.2188e-18 trial_f 1.2188e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 201: f 1.21387e-18 trial_f 1.21387e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 202: f 9.93584e-07 trial_f 9.93584e-07 accepted 1  lowest_f 4.73373e-20
# basinhopping step 203: f 9.93584e-07 trial_f 1.16479 accepted 0  lowest_f 4.73373e-20
# basinhopping step 204: f 9.93584e-07 trial_f 0.550256 accepted 0  lowest_f 4.73373e-20
# basinhopping step 205: f 9.93584e-07 trial_f 0.285873 accepted 0  lowest_f 4.73373e-20
# basinhopping step 206: f 8.02243e-14 trial_f 8.02243e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 207: f 8.02243e-14 trial_f 0.305546 accepted 0  lowest_f 4.73373e-20
# basinhopping step 208: f 1.21576e-18 trial_f 1.21576e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 209: f 1.21353e-18 trial_f 1.21353e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 210: f 0.000963334 trial_f 0.000963334 accepted 1  lowest_f 4.73373e-20
# basinhopping step 211: f 2.27946e-12 trial_f 2.27946e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 212: f 1.69328e-05 trial_f 1.69328e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 213: f 1.69328e-05 trial_f 2.25181 accepted 0  lowest_f 4.73373e-20
# basinhopping step 214: f 0.00812525 trial_f 0.00812525 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 215: f 0.00812525 trial_f 1.24193e-05 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 216: f 0.00812525 trial_f 1.26693e-05 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 217: f 0.00812525 trial_f 1.24231e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 218: f 0.00812525 trial_f 0.793821 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 219: f 0.00812525 trial_f 1.26652e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 220: f 1.13006e-11 trial_f 1.13006e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 221: f 1.13006e-11 trial_f 2.94487 accepted 0  lowest_f 4.73373e-20
# basinhopping step 222: f 2.46188e-14 trial_f 2.46188e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 223: f 2.46188e-14 trial_f 5.87048 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 224: f 2.46188e-14 trial_f 2.34991e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 225: f 0.0864202 trial_f 0.0864202 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 226: f 0.0864202 trial_f 6.15177e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 227: f 0.0864202 trial_f 0.553321 accepted 0  lowest_f 4.73373e-20
# basinhopping step 228: f 1.74295e-12 trial_f 1.74295e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 229: f 1.74295e-12 trial_f 11.5225 accepted 0  lowest_f 4.73373e-20
# basinhopping step 230: f 8.2502e-14 trial_f 8.2502e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 231: f 1.22541e-18 trial_f 1.22541e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 232: f 1.22242e-18 trial_f 1.22242e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 233: f 0.273651 trial_f 0.273651 accepted 1  lowest_f 4.73373e-20
# basinhopping step 234: f 5.39566e-15 trial_f 5.39566e-15 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 235: f 5.39566e-15 trial_f 1.35116e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 236: f 0.0239909 trial_f 0.0239909 accepted 1  lowest_f 4.73373e-20
# basinhopping step 237: f 0.00663695 trial_f 0.00663695 accepted 1  lowest_f 4.73373e-20
# basinhopping step 238: f 0.00663695 trial_f 3.98819 accepted 0  lowest_f 4.73373e-20
# basinhopping step 239: f 0.00663695 trial_f 3.90289 accepted 0  lowest_f 4.73373e-20
# basinhopping step 240: f 0.00663695 trial_f 11.5305 accepted 0  lowest_f 4.73373e-20
# basinhopping step 241: f 0.00663695 trial_f 4.41123 accepted 0  lowest_f 4.73373e-20
# basinhopping step 242: f 0.00663695 trial_f 0.0888865 accepted 0  lowest_f 4.73373e-20
# basinhopping step 243: f 0.00663695 trial_f 11.4958 accepted 0  lowest_f 4.73373e-20
# basinhopping step 244: f 0.00663695 trial_f 533977 accepted 0  lowest_f 4.73373e-20
# basinhopping step 245: f 4.06628e-15 trial_f 4.06628e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 246: f 1.68599e-12 trial_f 1.68599e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 247: f 1.68599e-12 trial_f 3.6064 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 248: f 1.68599e-12 trial_f 1.31076e-05 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 249: f 1.68599e-12 trial_f 1.33731e-05 accepted 0  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.428000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 250: f 0.001608 trial_f 0.001608 accepted 1  lowest_f 4.73373e-20
# basinhopping step 251: f 0.001608 trial_f 2.74869e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 252: f 0.00942499 trial_f 0.00942499 accepted 1  lowest_f 4.73373e-20
# basinhopping step 253: f 0.00942499 trial_f 1.508 accepted 0  lowest_f 4.73373e-20
# basinhopping step 254: f 0.00942499 trial_f 5.74092 accepted 0  lowest_f 4.73373e-20
# basinhopping step 255: f 0.0383364 trial_f 0.0383364 accepted 1  lowest_f 4.73373e-20
# basinhopping step 256: f 0.0383364 trial_f 0.201376 accepted 0  lowest_f 4.73373e-20
# basinhopping step 257: f 0.0383364 trial_f 0.553242 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 258: f 0.0383364 trial_f 6.03691e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 259: f 2.52214e-12 trial_f 2.52214e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 260: f 2.52214e-12 trial_f 1.8569e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 261: f 1.86832e-19 trial_f 1.86832e-19 accepted 1  lowest_f 4.73373e-20
# basinhopping step 262: f 1.86832e-19 trial_f 3.69408 accepted 0  lowest_f 4.73373e-20
# basinhopping step 263: f 1.25014e-06 trial_f 1.25014e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 264: f 1.2427e-05 trial_f 1.2427e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 265: f 8.58489e-14 trial_f 8.58489e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 266: f 8.58489e-14 trial_f 2.09069 accepted 0  lowest_f 4.73373e-20
# basinhopping step 267: f 5.32623e-06 trial_f 5.32623e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 268: f 5.32623e-06 trial_f 1.95608 accepted 0  lowest_f 4.73373e-20
# basinhopping step 269: f 2.13713e-05 trial_f 2.13713e-05 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 270: f 2.13713e-05 trial_f 4.10478e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 271: f 2.13713e-05 trial_f 11.4129 accepted 0  lowest_f 4.73373e-20
# basinhopping step 272: f 2.13713e-05 trial_f 0.0318965 accepted 0  lowest_f 4.73373e-20
# basinhopping step 273: f 2.13713e-05 trial_f 0.676889 accepted 0  lowest_f 4.73373e-20
# basinhopping step 274: f 0.334785 trial_f 0.334785 accepted 1  lowest_f 4.73373e-20
# basinhopping step 275: f 6.34907e-05 trial_f 6.34907e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 276: f 0.000198827 trial_f 0.000198827 accepted 1  lowest_f 4.73373e-20
# basinhopping step 277: f 0.000406397 trial_f 0.000406397 accepted 1  lowest_f 4.73373e-20
# basinhopping step 278: f 0.000406397 trial_f 10.2688 accepted 0  lowest_f 4.73373e-20
# basinhopping step 279: f 0.000406397 trial_f 2.2173 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 280: f 0.000406397 trial_f 6.07375e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 281: f 2.26623e-12 trial_f 2.26623e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 282: f 2.26623e-12 trial_f 0.326547 accepted 0  lowest_f 4.73373e-20
# basinhopping step 283: f 2.26623e-12 trial_f 551074 accepted 0  lowest_f 4.73373e-20
# basinhopping step 284: f 1.80111 trial_f 1.80111 accepted 1  lowest_f 4.73373e-20
# basinhopping step 285: f 0.389567 trial_f 0.389567 accepted 1  lowest_f 4.73373e-20
# basinhopping step 286: f 0.391056 trial_f 0.391056 accepted 1  lowest_f 4.73373e-20
# basinhopping step 287: f 3.4788e-12 trial_f 3.4788e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 288: f 1.27053e-15 trial_f 1.27053e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 289: f 1.27053e-15 trial_f 11.5091 accepted 0  lowest_f 4.73373e-20
# basinhopping step 290: f 0.0779682 trial_f 0.0779682 accepted 1  lowest_f 4.73373e-20
# basinhopping step 291: f 9.55917e-05 trial_f 9.55917e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 292: f 0.508325 trial_f 0.508325 accepted 1  lowest_f 4.73373e-20
# basinhopping step 293: f 3.66706e-14 trial_f 3.66706e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 294: f 1.31875e-10 trial_f 1.31875e-10 accepted 1  lowest_f 4.73373e-20
# basinhopping step 295: f 1.31875e-10 trial_f 6.82516 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 296: f 1.31875e-10 trial_f 5.40078e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 297: f 1.31875e-10 trial_f 5.47412e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 298: f 1.31875e-10 trial_f 5.40439e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 299: f 0.0145471 trial_f 0.0145471 accepted 1  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.443333 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 300: f 9.60287e-05 trial_f 9.60287e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 301: f 9.60287e-05 trial_f 0.442385 accepted 0  lowest_f 4.73373e-20
# basinhopping step 302: f 9.60287e-05 trial_f 0.509306 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 303: f 9.60287e-05 trial_f 1.47314e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 304: f 7.44153e-13 trial_f 7.44153e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 305: f 3.40438e-05 trial_f 3.40438e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 306: f 1.59829e-05 trial_f 1.59829e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 307: f 1.59829e-05 trial_f 0.482736 accepted 0  lowest_f 4.73373e-20
# basinhopping step 308: f 0.417344 trial_f 0.417344 accepted 1  lowest_f 4.73373e-20
# basinhopping step 309: f 0.0126492 trial_f 0.0126492 accepted 1  lowest_f 4.73373e-20
# basinhopping step 310: f 0.0184393 trial_f 0.0184393 accepted 1  lowest_f 4.73373e-20
# basinhopping step 311: f 0.148418 trial_f 0.148418 accepted 1  lowest_f 4.73373e-20
# basinhopping step 312: f 0.000200256 trial_f 0.000200256 accepted 1  lowest_f 4.73373e-20
# basinhopping step 313: f 0.000200256 trial_f 0.152431 accepted 0  lowest_f 4.73373e-20
# basinhopping step 314: f 1.4826e-11 trial_f 1.4826e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 315: f 1.4826e-11 trial_f 9.4297 accepted 0  lowest_f 4.73373e-20
# basinhopping step 316: f 1.4826e-11 trial_f 3.74481 accepted 0  lowest_f 4.73373e-20
# basinhopping step 317: f 1.4826e-11 trial_f 10.9455 accepted 0  lowest_f 4.73373e-20
# basinhopping step 318: f 6.34149e-06 trial_f 6.34149e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 319: f 6.34149e-06 trial_f 0.50811 accepted 0  lowest_f 4.73373e-20
# basinhopping step 320: f 6.34149e-06 trial_f 0.553027 accepted 0  lowest_f 4.73373e-20
# basinhopping step 321: f 1.6474e-14 trial_f 1.6474e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 322: f 1.6474e-14 trial_f 2.74871e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 323: f 1.29002e-11 trial_f 1.29002e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 324: f 0.00548296 trial_f 0.00548296 accepted 1  lowest_f 4.73373e-20
# basinhopping step 325: f 0.00548296 trial_f 6.62949 accepted 0  lowest_f 4.73373e-20
# basinhopping step 326: f 0.00548296 trial_f 3.02688 accepted 0  lowest_f 4.73373e-20
# basinhopping step 327: f 0.00548296 trial_f 3.74148 accepted 0  lowest_f 4.73373e-20
# basinhopping step 328: f 0.00548296 trial_f 11.4914 accepted 0  lowest_f 4.73373e-20
# basinhopping step 329: f 9.79183e-05 trial_f 9.79183e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 330: f 0.345813 trial_f 0.345813 accepted 1  lowest_f 4.73373e-20
# basinhopping step 331: f 3.61467e-05 trial_f 3.61467e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 332: f 3.61467e-05 trial_f 1.95656 accepted 0  lowest_f 4.73373e-20
# basinhopping step 333: f 1.98494e-11 trial_f 1.98494e-11 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 334: f 1.98494e-11 trial_f 1.37822e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 335: f 0.0620339 trial_f 0.0620339 accepted 1  lowest_f 4.73373e-20
# basinhopping step 336: f 0.00488214 trial_f 0.00488214 accepted 1  lowest_f 4.73373e-20
# basinhopping step 337: f 0.00488214 trial_f 5.1309 accepted 0  lowest_f 4.73373e-20
# basinhopping step 338: f 1.68281e-05 trial_f 1.68281e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 339: f 3.40444e-05 trial_f 3.40444e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 340: f 1.13108e-11 trial_f 1.13108e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 341: f 1.13108e-11 trial_f 1.99852 accepted 0  lowest_f 4.73373e-20
# basinhopping step 342: f 1.13108e-11 trial_f 9.01167 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 343: f 1.13108e-11 trial_f 1.71811e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 344: f 0.122554 trial_f 0.122554 accepted 1  lowest_f 4.73373e-20
# basinhopping step 345: f 2.37966e-12 trial_f 2.37966e-12 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 346: f 2.37966e-12 trial_f 2.6745e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 347: f 2.37966e-12 trial_f 2.69387e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 348: f 2.37966e-12 trial_f 2.67483e-07 accepted 0  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 349: f 2.37966e-12 trial_f 2.66094e-07 accepted 0  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.451429 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 350: f 2.37966e-12 trial_f 2.94749 accepted 0  lowest_f 4.73373e-20
# basinhopping step 351: f 2.37966e-12 trial_f 0.45064 accepted 0  lowest_f 4.73373e-20
# basinhopping step 352: f 0.0353459 trial_f 0.0353459 accepted 1  lowest_f 4.73373e-20
# basinhopping step 353: f 0.0022178 trial_f 0.0022178 accepted 1  lowest_f 4.73373e-20
# basinhopping step 354: f 0.110825 trial_f 0.110825 accepted 1  lowest_f 4.73373e-20
# basinhopping step 355: f 5.52164e-05 trial_f 5.52164e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 356: f 5.52164e-05 trial_f 0.600386 accepted 0  lowest_f 4.73373e-20
# basinhopping step 357: f 0.114265 trial_f 0.114265 accepted 1  lowest_f 4.73373e-20
# basinhopping step 358: f 0.0048616 trial_f 0.0048616 accepted 1  lowest_f 4.73373e-20
# basinhopping step 359: f 6.96982e-18 trial_f 6.96982e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 360: f 0.0115157 trial_f 0.0115157 accepted 1  lowest_f 4.73373e-20
# basinhopping step 361: f 0.0115157 trial_f 2.09799 accepted 0  lowest_f 4.73373e-20
# basinhopping step 362: f 0.15593 trial_f 0.15593 accepted 1  lowest_f 4.73373e-20
# basinhopping step 363: f 3.54776e-05 trial_f 3.54776e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 364: f 0.0520774 trial_f 0.0520774 accepted 1  lowest_f 4.73373e-20
# basinhopping step 365: f 0.246246 trial_f 0.246246 accepted 1  lowest_f 4.73373e-20
# basinhopping step 366: f 0.122885 trial_f 0.122885 accepted 1  lowest_f 4.73373e-20
# basinhopping step 367: f 0.122885 trial_f 2.7487e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 368: f 0.122885 trial_f 2.31259e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 369: f 4.92739e-06 trial_f 4.92739e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 370: f 0.00333744 trial_f 0.00333744 accepted 1  lowest_f 4.73373e-20
# basinhopping step 371: f 0.00416337 trial_f 0.00416337 accepted 1  lowest_f 4.73373e-20
# basinhopping step 372: f 0.00416337 trial_f 1.36434 accepted 0  lowest_f 4.73373e-20
# basinhopping step 373: f 2.08239e-13 trial_f 2.08239e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 374: f 2.08239e-13 trial_f 2.7487e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 375: f 0.197178 trial_f 0.197178 accepted 1  lowest_f 4.73373e-20
# basinhopping step 376: f 3.56229e-05 trial_f 3.56229e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 377: f 8.2433e-17 trial_f 8.2433e-17 accepted 1  lowest_f 4.73373e-20
# basinhopping step 378: f 8.2433e-17 trial_f 2.20338 accepted 0  lowest_f 4.73373e-20
# basinhopping step 379: f 8.2433e-17 trial_f 6.37046 accepted 0  lowest_f 4.73373e-20
# basinhopping step 380: f 1.33335e-05 trial_f 1.33335e-05 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 381: f 1.33335e-05 trial_f 2.12845e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 382: f 1.33335e-05 trial_f 0.127057 accepted 0  lowest_f 4.73373e-20
# basinhopping step 383: f 1.33335e-05 trial_f 5.29715 accepted 0  lowest_f 4.73373e-20
# basinhopping step 384: f 1.33335e-05 trial_f 0.299952 accepted 0  lowest_f 4.73373e-20
# basinhopping step 385: f 0.0269763 trial_f 0.0269763 accepted 1  lowest_f 4.73373e-20
# basinhopping step 386: f 0.00418943 trial_f 0.00418943 accepted 1  lowest_f 4.73373e-20
# basinhopping step 387: f 0.00418943 trial_f 4.91171 accepted 0  lowest_f 4.73373e-20
# basinhopping step 388: f 0.000112521 trial_f 0.000112521 accepted 1  lowest_f 4.73373e-20
# basinhopping step 389: f 0.342295 trial_f 0.342295 accepted 1  lowest_f 4.73373e-20
# basinhopping step 390: f 3.46738e-14 trial_f 3.46738e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 391: f 0.480836 trial_f 0.480836 accepted 1  lowest_f 4.73373e-20
# basinhopping step 392: f 0.689272 trial_f 0.689272 accepted 1  lowest_f 4.73373e-20
# basinhopping step 393: f 1.70594e-14 trial_f 1.70594e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 394: f 3.40437e-05 trial_f 3.40437e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 395: f 3.40437e-05 trial_f 0.032836 accepted 0  lowest_f 4.73373e-20
# basinhopping step 396: f 2.74352e-07 trial_f 2.74352e-07 accepted 1  lowest_f 4.73373e-20
# basinhopping step 397: f 3.79748e-13 trial_f 3.79748e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 398: f 2.13605e-16 trial_f 2.13605e-16 accepted 1  lowest_f 4.73373e-20
# basinhopping step 399: f 0.0661841 trial_f 0.0661841 accepted 1  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.480000 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 400: f 0.247785 trial_f 0.247785 accepted 1  lowest_f 4.73373e-20
# basinhopping step 401: f 0.247785 trial_f 5.22884 accepted 0  lowest_f 4.73373e-20
# basinhopping step 402: f 0.369725 trial_f 0.369725 accepted 1  lowest_f 4.73373e-20
# basinhopping step 403: f 3.62972e-05 trial_f 3.62972e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 404: f 3.13861e-10 trial_f 3.13861e-10 accepted 1  lowest_f 4.73373e-20
# basinhopping step 405: f 0.553261 trial_f 0.553261 accepted 1  lowest_f 4.73373e-20
# basinhopping step 406: f 3.63208e-05 trial_f 3.63208e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 407: f 4.7835e-14 trial_f 4.7835e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 408: f 1.99385e-11 trial_f 1.99385e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 409: f 1.99385e-11 trial_f 0.552615 accepted 0  lowest_f 4.73373e-20
# basinhopping step 410: f 0.0638466 trial_f 0.0638466 accepted 1  lowest_f 4.73373e-20
# basinhopping step 411: f 0.210973 trial_f 0.210973 accepted 1  lowest_f 4.73373e-20
# basinhopping step 412: f 0.00501747 trial_f 0.00501747 accepted 1  lowest_f 4.73373e-20
# basinhopping step 413: f 0.00824487 trial_f 0.00824487 accepted 1  lowest_f 4.73373e-20
# basinhopping step 414: f 2.30686e-13 trial_f 2.30686e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 415: f 5.03038e-13 trial_f 5.03038e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 416: f 5.03038e-13 trial_f 1.98203e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 417: f 0.20268 trial_f 0.20268 accepted 1  lowest_f 4.73373e-20
# basinhopping step 418: f 0.00488816 trial_f 0.00488816 accepted 1  lowest_f 4.73373e-20
# basinhopping step 419: f 0.00488816 trial_f 1.96174 accepted 0  lowest_f 4.73373e-20
# basinhopping step 420: f 0.00488816 trial_f 6.35899 accepted 0  lowest_f 4.73373e-20
# basinhopping step 421: f 0.000140484 trial_f 0.000140484 accepted 1  lowest_f 4.73373e-20
# basinhopping step 422: f 0.0103792 trial_f 0.0103792 accepted 1  lowest_f 4.73373e-20
# basinhopping step 423: f 0.00017245 trial_f 0.00017245 accepted 1  lowest_f 4.73373e-20
# basinhopping step 424: f 2.55687e-05 trial_f 2.55687e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 425: f 2.55687e-05 trial_f 4.22734 accepted 0  lowest_f 4.73373e-20
# basinhopping step 426: f 8.28788e-16 trial_f 8.28788e-16 accepted 1  lowest_f 4.73373e-20
# basinhopping step 427: f 3.64964e-12 trial_f 3.64964e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 428: f 4.74624e-20 trial_f 4.74624e-20 accepted 1  lowest_f 4.73373e-20
# basinhopping step 429: f 8.17715e-05 trial_f 8.17715e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 430: f 1.057e-11 trial_f 1.057e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 431: f 2.15046e-14 trial_f 2.15046e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 432: f 2.15046e-14 trial_f 0.0985505 accepted 0  lowest_f 4.73373e-20
# basinhopping step 433: f 0.553031 trial_f 0.553031 accepted 1  lowest_f 4.73373e-20
# basinhopping step 434: f 1.89853e-05 trial_f 1.89853e-05 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 435: f 1.89853e-05 trial_f 3.53862e-07 accepted 0  lowest_f 4.73373e-20
# basinhopping step 436: f 0.0130114 trial_f 0.0130114 accepted 1  lowest_f 4.73373e-20
# basinhopping step 437: f 0.173488 trial_f 0.173488 accepted 1  lowest_f 4.73373e-20
# basinhopping step 438: f 0.00490614 trial_f 0.00490614 accepted 1  lowest_f 4.73373e-20
# basinhopping step 439: f 8.71175e-06 trial_f 8.71175e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 440: f 8.71175e-06 trial_f 2.93769 accepted 0  lowest_f 4.73373e-20
# basinhopping step 441: f 8.71175e-06 trial_f 1.6689e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 442: f 5.21414e-13 trial_f 5.21414e-13 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 443: f 5.21414e-13 trial_f 1.59949e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 444: f 0.0159892 trial_f 0.0159892 accepted 1  lowest_f 4.73373e-20
# basinhopping step 445: f 0.0159892 trial_f 1.19382 accepted 0  lowest_f 4.73373e-20
# basinhopping step 446: f 0.268881 trial_f 0.268881 accepted 1  lowest_f 4.73373e-20
# basinhopping step 447: f 3.58268e-05 trial_f 3.58268e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 448: f 5.30929e-06 trial_f 5.30929e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 449: f 0.0199816 trial_f 0.0199816 accepted 1  lowest_f 4.73373e-20
# adaptive stepsize: acceptance rate 0.511111 target 0.500000 new stepsize 0.478297 old stepsize 0.430467
# basinhopping step 450: f 1.07505e-15 trial_f 1.07505e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 451: f 0.00474817 trial_f 0.00474817 accepted 1  lowest_f 4.73373e-20
# basinhopping step 452: f 1.34444e-13 trial_f 1.34444e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 453: f 1.34444e-13 trial_f 1.77058 accepted 0  lowest_f 4.73373e-20
# basinhopping step 454: f 1.34444e-13 trial_f 4.9092 accepted 0  lowest_f 4.73373e-20
# basinhopping step 455: f 1.34444e-13 trial_f 2.74867e+06 accepted 0  lowest_f 4.73373e-20
# basinhopping step 456: f 3.74416e-13 trial_f 3.74416e-13 accepted 1  lowest_f 4.73373e-20
# basinhopping step 457: f 0.000174508 trial_f 0.000174508 accepted 1  lowest_f 4.73373e-20
# basinhopping step 458: f 1.52652e-05 trial_f 1.52652e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 459: f 0.390787 trial_f 0.390787 accepted 1  lowest_f 4.73373e-20
# basinhopping step 460: f 2.94939e-12 trial_f 2.94939e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 461: f 7.14285e-12 trial_f 7.14285e-12 accepted 1  lowest_f 4.73373e-20
# basinhopping step 462: f 0.00456464 trial_f 0.00456464 accepted 1  lowest_f 4.73373e-20
# basinhopping step 463: f 9.9013e-16 trial_f 9.9013e-16 accepted 1  lowest_f 4.73373e-20
# basinhopping step 464: f 0.231285 trial_f 0.231285 accepted 1  lowest_f 4.73373e-20
# basinhopping step 465: f 0.0888851 trial_f 0.0888851 accepted 1  lowest_f 4.73373e-20
# basinhopping step 466: f 3.20771e-05 trial_f 3.20771e-05 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 467: f 3.20771e-05 trial_f 1.33294e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 468: f 3.20771e-05 trial_f 168304 accepted 0  lowest_f 4.73373e-20
# basinhopping step 469: f 5.78253e-05 trial_f 5.78253e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 470: f 0.000796859 trial_f 0.000796859 accepted 1  lowest_f 4.73373e-20
# basinhopping step 471: f 0.0278796 trial_f 0.0278796 accepted 1  lowest_f 4.73373e-20
# basinhopping step 472: f 0.0278796 trial_f 1.38625 accepted 0  lowest_f 4.73373e-20
# basinhopping step 473: f 0.000212491 trial_f 0.000212491 accepted 1  lowest_f 4.73373e-20
# basinhopping step 474: f 0.000212491 trial_f 272766 accepted 0  lowest_f 4.73373e-20
# basinhopping step 475: f 0.000212491 trial_f 5.68765 accepted 0  lowest_f 4.73373e-20
# basinhopping step 476: f 1.81361e-05 trial_f 1.81361e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 477: f 2.76726e-11 trial_f 2.76726e-11 accepted 1  lowest_f 4.73373e-20
# basinhopping step 478: f 1.1121e-05 trial_f 1.1121e-05 accepted 1  lowest_f 4.73373e-20
# basinhopping step 479: f 1.1121e-05 trial_f 84185.3 accepted 0  lowest_f 4.73373e-20
# basinhopping step 480: f 1.1121e-05 trial_f 0.351062 accepted 0  lowest_f 4.73373e-20
# basinhopping step 481: f 0.00170579 trial_f 0.00170579 accepted 1  lowest_f 4.73373e-20
# basinhopping step 482: f 7.36646e-15 trial_f 7.36646e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 483: f 0.0154658 trial_f 0.0154658 accepted 1  lowest_f 4.73373e-20
# basinhopping step 484: f 5.99211e-15 trial_f 5.99211e-15 accepted 1  lowest_f 4.73373e-20
# basinhopping step 485: f 0.211975 trial_f 0.211975 accepted 1  lowest_f 4.73373e-20
# basinhopping step 486: f 0.211975 trial_f 5.32175 accepted 0  lowest_f 4.73373e-20
# basinhopping step 487: f 2.15902e-06 trial_f 2.15902e-06 accepted 1  lowest_f 4.73373e-20
# basinhopping step 488: f 8.25269e-14 trial_f 8.25269e-14 accepted 1  lowest_f 4.73373e-20
# basinhopping step 489: f 8.25269e-14 trial_f 0.289186 accepted 0  lowest_f 4.73373e-20
# basinhopping step 490: f 1.22212e-18 trial_f 1.22212e-18 accepted 1  lowest_f 4.73373e-20
# basinhopping step 491: f 5.77814e-12 trial_f 5.77814e-12 accepted 1  lowest_f 4.73373e-20
# warning: basinhopping: local minimization failure
# basinhopping step 492: f 5.77814e-12 trial_f 1.81011e-05 accepted 0  lowest_f 4.73373e-20
# basinhopping step 493: f 0.00880012 trial_f 0.00880012 accepted 1  lowest_f 4.73373e-20
# basinhopping step 494: f 0.00880012 trial_f 152456 accepted 0  lowest_f 4.73373e-20
# basinhopping step 495: f 0.00881111 trial_f 0.00881111 accepted 1  lowest_f 4.73373e-20
# ...
# basinhopping step 832: f 0.0250029 trial_f 1.99649 accepted 0  lowest_f 3.96747e-25
# basinhopping step 833: f 0.0250029 trial_f 5.56926 accepted 0  lowest_f 3.96747e-25
# basinhopping step 834: f 0.0250029 trial_f 11.5348 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 835: f 0.0250029 trial_f 1.23412e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 836: f 0.0250029 trial_f 2.26423 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 837: f 0.0250029 trial_f 1.2182e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 838: f 0.000114751 trial_f 0.000114751 accepted 1  lowest_f 3.96747e-25
# basinhopping step 839: f 1.41246e-12 trial_f 1.41246e-12 accepted 1  lowest_f 3.96747e-25
# basinhopping step 840: f 0.0302294 trial_f 0.0302294 accepted 1  lowest_f 3.96747e-25
# basinhopping step 841: f 0.00486134 trial_f 0.00486134 accepted 1  lowest_f 3.96747e-25
# basinhopping step 842: f 0.00486134 trial_f 0.22329 accepted 0  lowest_f 3.96747e-25
# basinhopping step 843: f 6.62847e-18 trial_f 6.62847e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 844: f 6.62847e-18 trial_f 1.82359 accepted 0  lowest_f 3.96747e-25
# basinhopping step 845: f 6.62847e-18 trial_f 11.53 accepted 0  lowest_f 3.96747e-25
# basinhopping step 846: f 6.05573e-06 trial_f 6.05573e-06 accepted 1  lowest_f 3.96747e-25
# basinhopping step 847: f 6.05573e-06 trial_f 1.73886 accepted 0  lowest_f 3.96747e-25
# basinhopping step 848: f 6.05573e-06 trial_f 5.70042 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 849: f 6.05573e-06 trial_f 1.3227e-05 accepted 0  lowest_f 3.96747e-25
# adaptive stepsize: acceptance rate 0.504706 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 850: f 6.05573e-06 trial_f 2.26069 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 851: f 6.05573e-06 trial_f 1.32267e-05 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 852: f 6.05573e-06 trial_f 1.34033e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 853: f 3.25915e-10 trial_f 3.25915e-10 accepted 1  lowest_f 3.96747e-25
# basinhopping step 854: f 0.0149989 trial_f 0.0149989 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 855: f 0.0149989 trial_f 1.25757e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 856: f 3.4781e-16 trial_f 3.4781e-16 accepted 1  lowest_f 3.96747e-25
# basinhopping step 857: f 3.4781e-16 trial_f 11.5143 accepted 0  lowest_f 3.96747e-25
# basinhopping step 858: f 3.4781e-16 trial_f 2.2801 accepted 0  lowest_f 3.96747e-25
# basinhopping step 859: f 4.99194e-12 trial_f 4.99194e-12 accepted 1  lowest_f 3.96747e-25
# basinhopping step 860: f 4.99194e-12 trial_f 11.4511 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 861: f 4.99194e-12 trial_f 3.01662e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 862: f 4.99194e-12 trial_f 11.5322 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 863: f 4.99194e-12 trial_f 3.08146e-05 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 864: f 4.99194e-12 trial_f 3.02966e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 865: f 4.99194e-12 trial_f 11.5322 accepted 0  lowest_f 3.96747e-25
# basinhopping step 866: f 4.99194e-12 trial_f 0.133372 accepted 0  lowest_f 3.96747e-25
# basinhopping step 867: f 4.99194e-12 trial_f 2.27822 accepted 0  lowest_f 3.96747e-25
# basinhopping step 868: f 4.99194e-12 trial_f 2.25164 accepted 0  lowest_f 3.96747e-25
# basinhopping step 869: f 0.0674847 trial_f 0.0674847 accepted 1  lowest_f 3.96747e-25
# basinhopping step 870: f 0.0674847 trial_f 11.5201 accepted 0  lowest_f 3.96747e-25
# basinhopping step 871: f 0.0674847 trial_f 0.306169 accepted 0  lowest_f 3.96747e-25
# basinhopping step 872: f 0.00488484 trial_f 0.00488484 accepted 1  lowest_f 3.96747e-25
# basinhopping step 873: f 3.52789e-17 trial_f 3.52789e-17 accepted 1  lowest_f 3.96747e-25
# basinhopping step 874: f 0.0359572 trial_f 0.0359572 accepted 1  lowest_f 3.96747e-25
# basinhopping step 875: f 9.18611e-14 trial_f 9.18611e-14 accepted 1  lowest_f 3.96747e-25
# basinhopping step 876: f 9.18611e-14 trial_f 2.1616 accepted 0  lowest_f 3.96747e-25
# basinhopping step 877: f 1.2674e-14 trial_f 1.2674e-14 accepted 1  lowest_f 3.96747e-25
# basinhopping step 878: f 1.2674e-14 trial_f 2.27785 accepted 0  lowest_f 3.96747e-25
# basinhopping step 879: f 1.2674e-14 trial_f 2.271 accepted 0  lowest_f 3.96747e-25
# basinhopping step 880: f 1.21494e-18 trial_f 1.21494e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 881: f 1.20755e-18 trial_f 1.20755e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 882: f 1.20755e-18 trial_f 11.3789 accepted 0  lowest_f 3.96747e-25
# basinhopping step 883: f 1.23967e-18 trial_f 1.23967e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 884: f 1.21876e-18 trial_f 1.21876e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 885: f 1.21876e-18 trial_f 0.257653 accepted 0  lowest_f 3.96747e-25
# basinhopping step 886: f 1.21876e-18 trial_f 1.69252 accepted 0  lowest_f 3.96747e-25
# basinhopping step 887: f 1.21876e-18 trial_f 1.71561 accepted 0  lowest_f 3.96747e-25
# basinhopping step 888: f 1.21261e-18 trial_f 1.21261e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 889: f 1.22271e-18 trial_f 1.22271e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 890: f 1.22271e-18 trial_f 11.5297 accepted 0  lowest_f 3.96747e-25
# basinhopping step 891: f 0.461767 trial_f 0.461767 accepted 1  lowest_f 3.96747e-25
# basinhopping step 892: f 3.63208e-05 trial_f 3.63208e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 893: f 3.63208e-05 trial_f 11.5285 accepted 0  lowest_f 3.96747e-25
# basinhopping step 894: f 3.63208e-05 trial_f 4.38269 accepted 0  lowest_f 3.96747e-25
# basinhopping step 895: f 3.63208e-05 trial_f 2.07606 accepted 0  lowest_f 3.96747e-25
# basinhopping step 896: f 2.99124e-16 trial_f 2.99124e-16 accepted 1  lowest_f 3.96747e-25
# basinhopping step 897: f 1.21952e-18 trial_f 1.21952e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 898: f 1.2088e-18 trial_f 1.2088e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 899: f 1.2088e-18 trial_f 5.89903 accepted 0  lowest_f 3.96747e-25
# adaptive stepsize: acceptance rate 0.500000 target 0.500000 new stepsize 1 old stepsize 1.11111
# basinhopping step 900: f 1.21772e-18 trial_f 1.21772e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 901: f 0.625625 trial_f 0.625625 accepted 1  lowest_f 3.96747e-25
# basinhopping step 902: f 0.625625 trial_f 11.4306 accepted 0  lowest_f 3.96747e-25
# basinhopping step 903: f 1.48785e-12 trial_f 1.48785e-12 accepted 1  lowest_f 3.96747e-25
# basinhopping step 904: f 1.48785e-12 trial_f 9.02686 accepted 0  lowest_f 3.96747e-25
# basinhopping step 905: f 1.48785e-12 trial_f 2.22284 accepted 0  lowest_f 3.96747e-25
# basinhopping step 906: f 0.0153282 trial_f 0.0153282 accepted 1  lowest_f 3.96747e-25
# basinhopping step 907: f 5.5761e-13 trial_f 5.5761e-13 accepted 1  lowest_f 3.96747e-25
# basinhopping step 908: f 3.60176e-12 trial_f 3.60176e-12 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 909: f 3.60176e-12 trial_f 1.42359e-07 accepted 0  lowest_f 3.96747e-25
# basinhopping step 910: f 3.60176e-12 trial_f 5.1341 accepted 0  lowest_f 3.96747e-25
# basinhopping step 911: f 0.431898 trial_f 0.431898 accepted 1  lowest_f 3.96747e-25
# basinhopping step 912: f 0.431898 trial_f 3.20517 accepted 0  lowest_f 3.96747e-25
# basinhopping step 913: f 0.431898 trial_f 10.1735 accepted 0  lowest_f 3.96747e-25
# basinhopping step 914: f 0.431898 trial_f 11.481 accepted 0  lowest_f 3.96747e-25
# basinhopping step 915: f 4.8804e-05 trial_f 4.8804e-05 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 916: f 4.8804e-05 trial_f 1.36946e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 917: f 4.8804e-05 trial_f 11.5265 accepted 0  lowest_f 3.96747e-25
# basinhopping step 918: f 4.69475e-10 trial_f 4.69475e-10 accepted 1  lowest_f 3.96747e-25
# basinhopping step 919: f 4.69475e-10 trial_f 1.95579 accepted 0  lowest_f 3.96747e-25
# basinhopping step 920: f 3.63654e-12 trial_f 3.63654e-12 accepted 1  lowest_f 3.96747e-25
# basinhopping step 921: f 4.11233e-08 trial_f 4.11233e-08 accepted 1  lowest_f 3.96747e-25
# basinhopping step 922: f 5.8571e-11 trial_f 5.8571e-11 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 923: f 5.8571e-11 trial_f 3.66679e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 924: f 5.8571e-11 trial_f 2.21364 accepted 0  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 925: f 5.8571e-11 trial_f 3.70166e-05 accepted 0  lowest_f 3.96747e-25
# basinhopping step 926: f 1.82062e-05 trial_f 1.82062e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 927: f 2.97729e-21 trial_f 2.97729e-21 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 928: f 2.97729e-21 trial_f 6.05769e-07 accepted 0  lowest_f 3.96747e-25
# basinhopping step 929: f 2.84191e-12 trial_f 2.84191e-12 accepted 1  lowest_f 3.96747e-25
# basinhopping step 930: f 0.0505843 trial_f 0.0505843 accepted 1  lowest_f 3.96747e-25
# basinhopping step 931: f 2.282e-12 trial_f 2.282e-12 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 932: f 2.282e-12 trial_f 2.897e-07 accepted 0  lowest_f 3.96747e-25
# basinhopping step 933: f 2.282e-12 trial_f 0.244518 accepted 0  lowest_f 3.96747e-25
# basinhopping step 934: f 0.523513 trial_f 0.523513 accepted 1  lowest_f 3.96747e-25
# basinhopping step 935: f 3.63208e-05 trial_f 3.63208e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 936: f 2.83551e-16 trial_f 2.83551e-16 accepted 1  lowest_f 3.96747e-25
# basinhopping step 937: f 2.83551e-16 trial_f 11.5109 accepted 0  lowest_f 3.96747e-25
# basinhopping step 938: f 1.23607e-18 trial_f 1.23607e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 939: f 1.23607e-18 trial_f 0.497172 accepted 0  lowest_f 3.96747e-25
# basinhopping step 940: f 1.2113e-18 trial_f 1.2113e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 941: f 1.80444e-12 trial_f 1.80444e-12 accepted 1  lowest_f 3.96747e-25
# basinhopping step 942: f 3.46367e-17 trial_f 3.46367e-17 accepted 1  lowest_f 3.96747e-25
# basinhopping step 943: f 1.22225e-18 trial_f 1.22225e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 944: f 1.22225e-18 trial_f 11.5003 accepted 0  lowest_f 3.96747e-25
# basinhopping step 945: f 1.22225e-18 trial_f 5.74946 accepted 0  lowest_f 3.96747e-25
# basinhopping step 946: f 1.22225e-18 trial_f 0.438253 accepted 0  lowest_f 3.96747e-25
# basinhopping step 947: f 1.22225e-18 trial_f 4.47901 accepted 0  lowest_f 3.96747e-25
# basinhopping step 948: f 0.0228818 trial_f 0.0228818 accepted 1  lowest_f 3.96747e-25
# basinhopping step 949: f 0.0228818 trial_f 11.4834 accepted 0  lowest_f 3.96747e-25
# adaptive stepsize: acceptance rate 0.501053 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 950: f 3.40438e-05 trial_f 3.40438e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 951: f 3.40438e-05 trial_f 11.4702 accepted 0  lowest_f 3.96747e-25
# basinhopping step 952: f 3.40438e-05 trial_f 3.18964 accepted 0  lowest_f 3.96747e-25
# basinhopping step 953: f 1.1711e-18 trial_f 1.1711e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 954: f 1.66288e-07 trial_f 1.66288e-07 accepted 1  lowest_f 3.96747e-25
# basinhopping step 955: f 1.66288e-07 trial_f 2.1281 accepted 0  lowest_f 3.96747e-25
# basinhopping step 956: f 3.40438e-05 trial_f 3.40438e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 957: f 3.40438e-05 trial_f 2.26337 accepted 0  lowest_f 3.96747e-25
# basinhopping step 958: f 1.1482e-18 trial_f 1.1482e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 959: f 1.20629e-18 trial_f 1.20629e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 960: f 0.0020054 trial_f 0.0020054 accepted 1  lowest_f 3.96747e-25
# basinhopping step 961: f 0.0020054 trial_f 11.5089 accepted 0  lowest_f 3.96747e-25
# basinhopping step 962: f 0.0020054 trial_f 0.309265 accepted 0  lowest_f 3.96747e-25
# basinhopping step 963: f 7.92809e-14 trial_f 7.92809e-14 accepted 1  lowest_f 3.96747e-25
# basinhopping step 964: f 0.414916 trial_f 0.414916 accepted 1  lowest_f 3.96747e-25
# basinhopping step 965: f 3.63209e-05 trial_f 3.63209e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 966: f 3.63209e-05 trial_f 2.18533 accepted 0  lowest_f 3.96747e-25
# basinhopping step 967: f 3.63209e-05 trial_f 2.29117 accepted 0  lowest_f 3.96747e-25
# basinhopping step 968: f 3.63209e-05 trial_f 11.5158 accepted 0  lowest_f 3.96747e-25
# basinhopping step 969: f 3.63209e-05 trial_f 0.700724 accepted 0  lowest_f 3.96747e-25
# basinhopping step 970: f 2.96556e-16 trial_f 2.96556e-16 accepted 1  lowest_f 3.96747e-25
# basinhopping step 971: f 0.0126773 trial_f 0.0126773 accepted 1  lowest_f 3.96747e-25
# basinhopping step 972: f 3.40438e-05 trial_f 3.40438e-05 accepted 1  lowest_f 3.96747e-25
# basinhopping step 973: f 3.40438e-05 trial_f 2.29809 accepted 0  lowest_f 3.96747e-25
# basinhopping step 974: f 3.40438e-05 trial_f 11.533 accepted 0  lowest_f 3.96747e-25
# basinhopping step 975: f 3.40438e-05 trial_f 11.5306 accepted 0  lowest_f 3.96747e-25
# basinhopping step 976: f 3.40438e-05 trial_f 2.27448 accepted 0  lowest_f 3.96747e-25
# basinhopping step 977: f 1.17798e-18 trial_f 1.17798e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 978: f 1.17798e-18 trial_f 7.90556 accepted 0  lowest_f 3.96747e-25
# basinhopping step 979: f 1.17798e-18 trial_f 11.4702 accepted 0  lowest_f 3.96747e-25
# basinhopping step 980: f 1.23529e-18 trial_f 1.23529e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 981: f 0.000607434 trial_f 0.000607434 accepted 1  lowest_f 3.96747e-25
# basinhopping step 982: f 0.000607434 trial_f 2.27358 accepted 0  lowest_f 3.96747e-25
# basinhopping step 983: f 6.67112e-14 trial_f 6.67112e-14 accepted 1  lowest_f 3.96747e-25
# basinhopping step 984: f 0.0310324 trial_f 0.0310324 accepted 1  lowest_f 3.96747e-25
# basinhopping step 985: f 0.00486206 trial_f 0.00486206 accepted 1  lowest_f 3.96747e-25
# basinhopping step 986: f 5.08619e-18 trial_f 5.08619e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 987: f 5.08619e-18 trial_f 11.5338 accepted 0  lowest_f 3.96747e-25
# basinhopping step 988: f 1.23824e-18 trial_f 1.23824e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 989: f 1.23824e-18 trial_f 0.286544 accepted 0  lowest_f 3.96747e-25
# basinhopping step 990: f 1.22611e-18 trial_f 1.22611e-18 accepted 1  lowest_f 3.96747e-25
# basinhopping step 991: f 1.22611e-18 trial_f 11.5303 accepted 0  lowest_f 3.96747e-25
# basinhopping step 992: f 0.000896049 trial_f 0.000896049 accepted 1  lowest_f 3.96747e-25
# warning: basinhopping: local minimization failure
# basinhopping step 993: f 0.000896049 trial_f 6.15567e-07 accepted 0  lowest_f 3.96747e-25
# basinhopping step 994: f 0.000896049 trial_f 11.5029 accepted 0  lowest_f 3.96747e-25
# basinhopping step 995: f 6.22336e-16 trial_f 6.22336e-16 accepted 1  lowest_f 3.96747e-25
# basinhopping step 996: f 0.00133401 trial_f 0.00133401 accepted 1  lowest_f 3.96747e-25
# basinhopping step 997: f 0.00133401 trial_f 11.5036 accepted 0  lowest_f 3.96747e-25
# basinhopping step 998: f 0.00133401 trial_f 11.4292 accepted 0  lowest_f 3.96747e-25
# basinhopping step 999: f 0.00133401 trial_f 11.5114 accepted 0  lowest_f 3.96747e-25
# adaptive stepsize: acceptance rate 0.501000 target 0.500000 new stepsize 1.23457 old stepsize 1.11111
# warning: basinhopping: local minimization failure
# basinhopping step 1000: f 0.00133401 trial_f 6.07345e-07 accepted 0  lowest_f 3.96747e-25

# %%
mu2, rho2, M2, P2 = result.x[0], result.x[1], result.x[2], result.x[3]
Q2 = M2/rho2
specific_speed_1 = N1*np.sqrt(M1/rho1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(M2/rho2)/(P2/(rho2*g))**(3/4)
print(f"Ns = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = P1 * M1 / rho1 / ( rho1 * N1**3 * D1**5)
power_coeff_2 = P2 * M2 / rho2 / ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff = 0.50
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Q1*P1/pump_eff/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Q1*P1/pump_eff/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Electrical Power = {Q1*P1/pump_eff/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Dynamic Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Kinematic Viscosity is {mu2*10**6/rho2:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Q2*P2/pump_eff/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Q2*P2/pump_eff/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Electrical Power = {Q2*P2/pump_eff/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns = 13.7895, Matching = 99.99999999999953 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031263792849777833, Matching = 99.99999999997175 %
# Head Coefficient Prototype = 0.001366148931251182, Model = 0.0013661489312509333, Matching = 99.9999999999818 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8462, Matching = 99.99999999997154 %
# Power Coefficient Prototype = 0.00000043, Model = 0.00000043, Matching = 99.99999999995353 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.400 Bar
# Prototype's Pressure Head is 68.259 m HAN+H2O2
# Prototype's Pressure Head is 68.259 m Testing Fluid
# Prototype's Pressure Head is 106.047 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 569.001 W
# Prototype's Shaft Power = 1149.497 W
# Prototype's Shaft Torque = 0.784 N-m
# Prototype's Electrical Power = 1352.349 W
#
#
# Model's Shaft Speed is 8000.000 RPM
# Model's Impeller Diameter is 50.000 mm
# Model's Mass Flow Rate is 0.333 Kg/s
# Model's Pressure Across Pump is 2.326 Bar
# Model's Pressure Head is 15.269 m HAN+H2O2
# Model's Pressure Head is 22.289 m Testing Fluid
# Model's Pressure Head is 23.723 m Water
# Model's Volumetric Flow Rate is 0.3126 L/s
# Model's Fluid's Dynamic Viscosity is 25.4458 mPa-s
# Model's Fluid's Kinematic Viscosity is 23.9076 mPa-s
# Model's Fluid's Density is 1064.3401 kg/m^3
# Model's Hydraulic Power = 72.734 W
# Model's Shaft Power = 146.938 W
# Model's Shaft Torque = 0.175 N-m
# Model's Electrical Power = 172.869 W
