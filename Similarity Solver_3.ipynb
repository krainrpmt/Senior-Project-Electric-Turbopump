# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
rho1 = 1573.2; mu1 = 65e-3; N1 = 18000; D1 = 50e-3; M1 = 0.85; P1 = 10.4e5
#rho2 = 1000; mu2 = 10e-3
N2 = 2900; D2 = 80e-3
g = 9.807  # Acceleration due to gravity in m/s^2

Q1 = M1/rho1

# Define lower and upper bounds
lb = [1e-3, 500, 0.1, 0.5e5]  # Lower bounds
ub = [100e-3, 1500, 1.0, 4e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    mu2, rho2, M2, P2 = x
    
    # Specific speed equation residual
    F1 = (N1 * np.sqrt(M1/rho1) / (g * P1/(rho1*g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (g * P2/(rho2*g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = (M1/rho1 / (N1 * D1**3)) - (M2/rho2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = (g * P1/(rho1*g) / (N1**2 * D1**2)) - (g * P2/(rho2*g) / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (M1 / mu1 / D1) - (M2 / mu2 / D2)
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F1, F2, F3, F4]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1.0, 1.0e-3, 1.0e-3, 1]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([30e-3, 1000, 0.4, 2e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 0.000336767
# basinhopping step 1: f 2.7243e-11 trial_f 2.7243e-11 accepted 1  lowest_f 2.7243e-11
# found new global minimum on step 1 with function value 2.7243e-11
# basinhopping step 2: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.7243e-11
# basinhopping step 3: f 9.0511e-07 trial_f 9.0511e-07 accepted 1  lowest_f 2.7243e-11
# basinhopping step 4: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.7243e-11
# basinhopping step 5: f 0.0733347 trial_f 0.161976 accepted 0  lowest_f 2.7243e-11
# basinhopping step 6: f 0.00426742 trial_f 0.00426742 accepted 1  lowest_f 2.7243e-11
# basinhopping step 7: f 0.0475656 trial_f 0.0475656 accepted 1  lowest_f 2.7243e-11
# basinhopping step 8: f 0.0136447 trial_f 0.0136447 accepted 1  lowest_f 2.7243e-11
# basinhopping step 9: f 0.0136447 trial_f 906.717 accepted 0  lowest_f 2.7243e-11
# basinhopping step 10: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.7243e-11
# basinhopping step 11: f 1.43926e-15 trial_f 1.43926e-15 accepted 1  lowest_f 1.43926e-15
# found new global minimum on step 11 with function value 1.43926e-15
# basinhopping step 12: f 1.43926e-15 trial_f 0.788504 accepted 0  lowest_f 1.43926e-15
# basinhopping step 13: f 1.43926e-15 trial_f 0.108567 accepted 0  lowest_f 1.43926e-15
# basinhopping step 14: f 0.0119477 trial_f 0.0119477 accepted 1  lowest_f 1.43926e-15
# basinhopping step 15: f 0.0119477 trial_f 3543.32 accepted 0  lowest_f 1.43926e-15
# basinhopping step 16: f 0.0119477 trial_f 0.28309 accepted 0  lowest_f 1.43926e-15
# basinhopping step 17: f 0.0119477 trial_f 581.862 accepted 0  lowest_f 1.43926e-15
# basinhopping step 18: f 0.038483 trial_f 0.038483 accepted 1  lowest_f 1.43926e-15
# basinhopping step 19: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.43926e-15
# basinhopping step 20: f 0.188816 trial_f 14798.6 accepted 0  lowest_f 1.43926e-15
# basinhopping step 21: f 0.0303239 trial_f 0.0303239 accepted 1  lowest_f 1.43926e-15
# basinhopping step 22: f 0.166159 trial_f 0.166159 accepted 1  lowest_f 1.43926e-15
# basinhopping step 23: f 1.16765e-15 trial_f 1.16765e-15 accepted 1  lowest_f 1.16765e-15
# found new global minimum on step 23 with function value 1.16765e-15
# basinhopping step 24: f 1.16765e-15 trial_f 5612.01 accepted 0  lowest_f 1.16765e-15
# basinhopping step 25: f 1.16765e-15 trial_f 13220.1 accepted 0  lowest_f 1.16765e-15
# basinhopping step 26: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.16765e-15
# basinhopping step 27: f 0.0733347 trial_f 30412.9 accepted 0  lowest_f 1.16765e-15
# basinhopping step 28: f 0.553592 trial_f 0.553592 accepted 1  lowest_f 1.16765e-15
# basinhopping step 29: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.16765e-15
# basinhopping step 30: f 1.00324e-11 trial_f 1.00324e-11 accepted 1  lowest_f 1.16765e-15
# basinhopping step 31: f 1.00324e-11 trial_f 568.803 accepted 0  lowest_f 1.16765e-15
# basinhopping step 32: f 0.0588527 trial_f 0.0588527 accepted 1  lowest_f 1.16765e-15
# basinhopping step 33: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.16765e-15
# basinhopping step 34: f 0.0183509 trial_f 0.0183509 accepted 1  lowest_f 1.16765e-15
# basinhopping step 35: f 0.289128 trial_f 0.289128 accepted 1  lowest_f 1.16765e-15
# /Users/krai/Development/Programming/myenv/lib/python3.12/site-packages/scipy/optimize/_basinhopping.py:302: OptimizeWarning: Initial guess is not within the specified bounds
#   return self.minimizer(self.func, x0, **self.kwargs)
# /var/folders/j3/dr9c4mcx23gcdm0215yvb0h00000gn/T/ipykernel_46426/3904918122.py:23: RuntimeWarning: invalid value encountered in sqrt
#   F1 = (N1 * np.sqrt(M1/rho1) / (g * P1/(rho1*g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (g * P2/(rho2*g))**(3/4))
# basinhopping step 36: f 8.38845e-18 trial_f 8.38845e-18 accepted 1  lowest_f 8.38845e-18
# found new global minimum on step 36 with function value 8.38845e-18
# basinhopping step 37: f 8.38845e-18 trial_f 0.0733347 accepted 0  lowest_f 8.38845e-18
# basinhopping step 38: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 39: f 0.188948 trial_f 0.188948 accepted 1  lowest_f 8.38845e-18
# basinhopping step 40: f 0.188948 trial_f 3690.71 accepted 0  lowest_f 8.38845e-18
# basinhopping step 41: f 3.78809e-12 trial_f 3.78809e-12 accepted 1  lowest_f 8.38845e-18
# basinhopping step 42: f 9.75406e-08 trial_f 9.75406e-08 accepted 1  lowest_f 8.38845e-18
# basinhopping step 43: f 9.75406e-08 trial_f 0.188816 accepted 0  lowest_f 8.38845e-18
# basinhopping step 44: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 45: f 0.0766901 trial_f 0.0766901 accepted 1  lowest_f 8.38845e-18
# basinhopping step 46: f 0.0766901 trial_f 887312 accepted 0  lowest_f 8.38845e-18
# basinhopping step 47: f 0.188009 trial_f 0.188009 accepted 1  lowest_f 8.38845e-18
# basinhopping step 48: f 0.188009 trial_f 15394.2 accepted 0  lowest_f 8.38845e-18
# basinhopping step 49: f 0.189603 trial_f 0.189603 accepted 1  lowest_f 8.38845e-18
# adaptive stepsize: acceptance rate 0.640000 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 50: f 0.189603 trial_f 0.332906 accepted 0  lowest_f 8.38845e-18
# basinhopping step 51: f 0.181504 trial_f 0.181504 accepted 1  lowest_f 8.38845e-18
# basinhopping step 52: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 53: f 0.0733347 trial_f 5665.46 accepted 0  lowest_f 8.38845e-18
# basinhopping step 54: f 0.000251146 trial_f 0.000251146 accepted 1  lowest_f 8.38845e-18
# basinhopping step 55: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 56: f 0.0733347 trial_f 887345 accepted 0  lowest_f 8.38845e-18
# basinhopping step 57: f 2.93655e-14 trial_f 2.93655e-14 accepted 1  lowest_f 8.38845e-18
# basinhopping step 58: f 2.93655e-14 trial_f 0.14555 accepted 0  lowest_f 8.38845e-18
# basinhopping step 59: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 8.38845e-18
# basinhopping step 60: f 0.188816 trial_f 12521.8 accepted 0  lowest_f 8.38845e-18
# basinhopping step 61: f 1.38917e-15 trial_f 1.38917e-15 accepted 1  lowest_f 8.38845e-18
# basinhopping step 62: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 63: f 0.0733347 trial_f 15635.4 accepted 0  lowest_f 8.38845e-18
# basinhopping step 64: f 0.141104 trial_f 0.141104 accepted 1  lowest_f 8.38845e-18
# basinhopping step 65: f 2.91002e-12 trial_f 2.91002e-12 accepted 1  lowest_f 8.38845e-18
# basinhopping step 66: f 2.91002e-12 trial_f 4050.17 accepted 0  lowest_f 8.38845e-18
# basinhopping step 67: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 68: f 5.75005e-16 trial_f 5.75005e-16 accepted 1  lowest_f 8.38845e-18
# basinhopping step 69: f 5.75005e-16 trial_f 887330 accepted 0  lowest_f 8.38845e-18
# basinhopping step 70: f 5.75005e-16 trial_f 8020.37 accepted 0  lowest_f 8.38845e-18
# basinhopping step 71: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 72: f 0.188013 trial_f 0.188013 accepted 1  lowest_f 8.38845e-18
# basinhopping step 73: f 0.0149283 trial_f 0.0149283 accepted 1  lowest_f 8.38845e-18
# basinhopping step 74: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 8.38845e-18
# basinhopping step 75: f 0.188816 trial_f 6391.2 accepted 0  lowest_f 8.38845e-18
# basinhopping step 76: f 0.188816 trial_f 14222.7 accepted 0  lowest_f 8.38845e-18
# basinhopping step 77: f 0.188816 trial_f 3113.12 accepted 0  lowest_f 8.38845e-18
# basinhopping step 78: f 0.0201322 trial_f 0.0201322 accepted 1  lowest_f 8.38845e-18
# basinhopping step 79: f 0.138811 trial_f 0.138811 accepted 1  lowest_f 8.38845e-18
# basinhopping step 80: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 81: f 1.17109e-07 trial_f 1.17109e-07 accepted 1  lowest_f 8.38845e-18
# basinhopping step 82: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 83: f 0.0733347 trial_f 5924.86 accepted 0  lowest_f 8.38845e-18
# basinhopping step 84: f 0.0733347 trial_f 10465.2 accepted 0  lowest_f 8.38845e-18
# basinhopping step 85: f 0.0733347 trial_f 12657.5 accepted 0  lowest_f 8.38845e-18
# basinhopping step 86: f 0.0733347 trial_f 6031.54 accepted 0  lowest_f 8.38845e-18
# basinhopping step 87: f 0.0733347 trial_f 0.773117 accepted 0  lowest_f 8.38845e-18
# basinhopping step 88: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 89: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 90: f 0.188008 trial_f 0.188008 accepted 1  lowest_f 8.38845e-18
# basinhopping step 91: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 92: f 0.426912 trial_f 0.426912 accepted 1  lowest_f 8.38845e-18
# basinhopping step 93: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 94: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 8.38845e-18
# basinhopping step 95: f 0.189517 trial_f 0.189517 accepted 1  lowest_f 8.38845e-18
# basinhopping step 96: f 0.18921 trial_f 0.18921 accepted 1  lowest_f 8.38845e-18
# basinhopping step 97: f 0.0432714 trial_f 0.0432714 accepted 1  lowest_f 8.38845e-18
# basinhopping step 98: f 0.0432714 trial_f 0.188816 accepted 0  lowest_f 8.38845e-18
# basinhopping step 99: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# adaptive stepsize: acceptance rate 0.640000 target 0.500000 new stepsize 1.23457 old stepsize 1.11111
# basinhopping step 100: f 0.00261317 trial_f 0.00261317 accepted 1  lowest_f 8.38845e-18
# basinhopping step 101: f 0.00261317 trial_f 0.0733347 accepted 0  lowest_f 8.38845e-18
# basinhopping step 102: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 103: f 0.136841 trial_f 0.136841 accepted 1  lowest_f 8.38845e-18
# basinhopping step 104: f 3.97928e-13 trial_f 3.97928e-13 accepted 1  lowest_f 8.38845e-18
# basinhopping step 105: f 0.00148805 trial_f 0.00148805 accepted 1  lowest_f 8.38845e-18
# basinhopping step 106: f 0.105124 trial_f 0.105124 accepted 1  lowest_f 8.38845e-18
# basinhopping step 107: f 0.105124 trial_f 14491.5 accepted 0  lowest_f 8.38845e-18
# basinhopping step 108: f 0.105124 trial_f 15390.6 accepted 0  lowest_f 8.38845e-18
# basinhopping step 109: f 0.104246 trial_f 0.104246 accepted 1  lowest_f 8.38845e-18
# basinhopping step 110: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 111: f 0.0733347 trial_f 2571.81 accepted 0  lowest_f 8.38845e-18
# basinhopping step 112: f 0.0733347 trial_f 12214.7 accepted 0  lowest_f 8.38845e-18
# basinhopping step 113: f 0.104492 trial_f 0.104492 accepted 1  lowest_f 8.38845e-18
# basinhopping step 114: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 8.38845e-18
# basinhopping step 115: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 116: f 0.0733347 trial_f 12540.4 accepted 0  lowest_f 8.38845e-18
# basinhopping step 117: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 118: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 8.38845e-18
# basinhopping step 119: f 0.0733347 trial_f 12204 accepted 0  lowest_f 8.38845e-18
# basinhopping step 120: f 0.0441178 trial_f 0.0441178 accepted 1  lowest_f 8.38845e-18
# basinhopping step 121: f 0.00946795 trial_f 0.00946795 accepted 1  lowest_f 8.38845e-18
# basinhopping step 122: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 123: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 124: f 0.0322178 trial_f 0.0322178 accepted 1  lowest_f 8.38845e-18
# basinhopping step 125: f 0.0135884 trial_f 0.0135884 accepted 1  lowest_f 8.38845e-18
# basinhopping step 126: f 0.0135884 trial_f 0.0733347 accepted 0  lowest_f 8.38845e-18
# basinhopping step 127: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 8.38845e-18
# basinhopping step 128: f 2.06921e-19 trial_f 2.06921e-19 accepted 1  lowest_f 2.06921e-19
# found new global minimum on step 128 with function value 2.06921e-19
# basinhopping step 129: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 130: f 7.18862e-11 trial_f 7.18862e-11 accepted 1  lowest_f 2.06921e-19
# basinhopping step 131: f 0.298141 trial_f 0.298141 accepted 1  lowest_f 2.06921e-19
# basinhopping step 132: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 133: f 0.188816 trial_f 18626.7 accepted 0  lowest_f 2.06921e-19
# basinhopping step 134: f 2.18182e-15 trial_f 2.18182e-15 accepted 1  lowest_f 2.06921e-19
# basinhopping step 135: f 2.18182e-15 trial_f 125857 accepted 0  lowest_f 2.06921e-19
# basinhopping step 136: f 0.0767957 trial_f 0.0767957 accepted 1  lowest_f 2.06921e-19
# basinhopping step 137: f 3.08704e-14 trial_f 3.08704e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 138: f 3.08704e-14 trial_f 100.306 accepted 0  lowest_f 2.06921e-19
# basinhopping step 139: f 0.0435368 trial_f 0.0435368 accepted 1  lowest_f 2.06921e-19
# basinhopping step 140: f 0.0435368 trial_f 0.0733347 accepted 0  lowest_f 2.06921e-19
# basinhopping step 141: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 2.06921e-19
# basinhopping step 142: f 4.00683e-17 trial_f 4.00683e-17 accepted 1  lowest_f 2.06921e-19
# basinhopping step 143: f 4.00683e-17 trial_f 0.240982 accepted 0  lowest_f 2.06921e-19
# basinhopping step 144: f 5.40261e-05 trial_f 5.40261e-05 accepted 1  lowest_f 2.06921e-19
# basinhopping step 145: f 5.40261e-05 trial_f 0.0733347 accepted 0  lowest_f 2.06921e-19
# basinhopping step 146: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 147: f 0.189191 trial_f 0.189191 accepted 1  lowest_f 2.06921e-19
# basinhopping step 148: f 3.99343e-12 trial_f 3.99343e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 149: f 0.100885 trial_f 0.100885 accepted 1  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.660000 target 0.500000 new stepsize 1.37174 old stepsize 1.23457
# basinhopping step 150: f 0.188923 trial_f 0.188923 accepted 1  lowest_f 2.06921e-19
# basinhopping step 151: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 2.06921e-19
# basinhopping step 152: f 0.188011 trial_f 9699.02 accepted 0  lowest_f 2.06921e-19
# basinhopping step 153: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 154: f 0.188013 trial_f 0.188013 accepted 1  lowest_f 2.06921e-19
# basinhopping step 155: f 0.188007 trial_f 0.188007 accepted 1  lowest_f 2.06921e-19
# basinhopping step 156: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 157: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 158: f 0.0733347 trial_f 0.117157 accepted 0  lowest_f 2.06921e-19
# basinhopping step 159: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 160: f 0.0733347 trial_f 3294.17 accepted 0  lowest_f 2.06921e-19
# basinhopping step 161: f 2.13465e-17 trial_f 2.13465e-17 accepted 1  lowest_f 2.06921e-19
# basinhopping step 162: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 163: f 1.06106e-15 trial_f 1.06106e-15 accepted 1  lowest_f 2.06921e-19
# basinhopping step 164: f 1.06106e-15 trial_f 0.296164 accepted 0  lowest_f 2.06921e-19
# basinhopping step 165: f 1.39381e-14 trial_f 1.39381e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 166: f 1.39381e-14 trial_f 12545.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 167: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 168: f 0.0733347 trial_f 7226.16 accepted 0  lowest_f 2.06921e-19
# basinhopping step 169: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 170: f 0.0733347 trial_f 7024.38 accepted 0  lowest_f 2.06921e-19
# basinhopping step 171: f 0.0733347 trial_f 111514 accepted 0  lowest_f 2.06921e-19
# basinhopping step 172: f 0.0733347 trial_f 12722.1 accepted 0  lowest_f 2.06921e-19
# basinhopping step 173: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 174: f 0.0733347 trial_f 18613.2 accepted 0  lowest_f 2.06921e-19
# basinhopping step 175: f 0.0733347 trial_f 2195.39 accepted 0  lowest_f 2.06921e-19
# basinhopping step 176: f 0.0383031 trial_f 0.0383031 accepted 1  lowest_f 2.06921e-19
# basinhopping step 177: f 0.0241098 trial_f 0.0241098 accepted 1  lowest_f 2.06921e-19
# basinhopping step 178: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 179: f 0.115611 trial_f 0.115611 accepted 1  lowest_f 2.06921e-19
# basinhopping step 180: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 181: f 2.48041e-13 trial_f 2.48041e-13 accepted 1  lowest_f 2.06921e-19
# basinhopping step 182: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 183: f 0.188816 trial_f 887330 accepted 0  lowest_f 2.06921e-19
# basinhopping step 184: f 0.0400182 trial_f 0.0400182 accepted 1  lowest_f 2.06921e-19
# basinhopping step 185: f 0.00752482 trial_f 0.00752482 accepted 1  lowest_f 2.06921e-19
# basinhopping step 186: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 187: f 0.0934757 trial_f 0.0934757 accepted 1  lowest_f 2.06921e-19
# basinhopping step 188: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 189: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 190: f 0.0733347 trial_f 0.188882 accepted 0  lowest_f 2.06921e-19
# basinhopping step 191: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 192: f 1.1362e-11 trial_f 1.1362e-11 accepted 1  lowest_f 2.06921e-19
# basinhopping step 193: f 1.81851e-14 trial_f 1.81851e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 194: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 195: f 0.0629734 trial_f 0.0629734 accepted 1  lowest_f 2.06921e-19
# basinhopping step 196: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 197: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 198: f 0.104453 trial_f 0.104453 accepted 1  lowest_f 2.06921e-19
# basinhopping step 199: f 0.104453 trial_f 18607 accepted 0  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.675000 target 0.500000 new stepsize 1.52416 old stepsize 1.37174
# basinhopping step 200: f 0.00276853 trial_f 0.00276853 accepted 1  lowest_f 2.06921e-19
# basinhopping step 201: f 0.127433 trial_f 0.127433 accepted 1  lowest_f 2.06921e-19
# basinhopping step 202: f 0.127433 trial_f 6715.35 accepted 0  lowest_f 2.06921e-19
# basinhopping step 203: f 0.127433 trial_f 18616 accepted 0  lowest_f 2.06921e-19
# basinhopping step 204: f 3.35456e-19 trial_f 3.35456e-19 accepted 1  lowest_f 2.06921e-19
# basinhopping step 205: f 3.35456e-19 trial_f 255551 accepted 0  lowest_f 2.06921e-19
# basinhopping step 206: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 207: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 208: f 0.0733347 trial_f 18624.1 accepted 0  lowest_f 2.06921e-19
# basinhopping step 209: f 0.0733347 trial_f 18613.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 210: f 0.597469 trial_f 0.597469 accepted 1  lowest_f 2.06921e-19
# basinhopping step 211: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 212: f 0.189603 trial_f 0.189603 accepted 1  lowest_f 2.06921e-19
# basinhopping step 213: f 6.74759e-13 trial_f 6.74759e-13 accepted 1  lowest_f 2.06921e-19
# basinhopping step 214: f 1.86232e-14 trial_f 1.86232e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 215: f 1.86232e-14 trial_f 0.188816 accepted 0  lowest_f 2.06921e-19
# basinhopping step 216: f 2.13105e-14 trial_f 2.13105e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 217: f 0.0550234 trial_f 0.0550234 accepted 1  lowest_f 2.06921e-19
# basinhopping step 218: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 219: f 4.67716e-18 trial_f 4.67716e-18 accepted 1  lowest_f 2.06921e-19
# basinhopping step 220: f 0.0447149 trial_f 0.0447149 accepted 1  lowest_f 2.06921e-19
# basinhopping step 221: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 222: f 0.189066 trial_f 0.189066 accepted 1  lowest_f 2.06921e-19
# basinhopping step 223: f 0.189066 trial_f 5262.65 accepted 0  lowest_f 2.06921e-19
# basinhopping step 224: f 0.189066 trial_f 7954.72 accepted 0  lowest_f 2.06921e-19
# basinhopping step 225: f 0.186166 trial_f 0.186166 accepted 1  lowest_f 2.06921e-19
# basinhopping step 226: f 0.186166 trial_f 7174.04 accepted 0  lowest_f 2.06921e-19
# basinhopping step 227: f 4.85457e-14 trial_f 4.85457e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 228: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 229: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 230: f 0.0733347 trial_f 18626.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 231: f 0.0733347 trial_f 0.189086 accepted 0  lowest_f 2.06921e-19
# basinhopping step 232: f 0.0733347 trial_f 12252.5 accepted 0  lowest_f 2.06921e-19
# basinhopping step 233: f 0.188016 trial_f 0.188016 accepted 1  lowest_f 2.06921e-19
# basinhopping step 234: f 0.188016 trial_f 4196.46 accepted 0  lowest_f 2.06921e-19
# basinhopping step 235: f 0.188016 trial_f 10877.8 accepted 0  lowest_f 2.06921e-19
# basinhopping step 236: f 0.188016 trial_f 18624.2 accepted 0  lowest_f 2.06921e-19
# basinhopping step 237: f 0.188016 trial_f 18633.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 238: f 3.72377e-12 trial_f 3.72377e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 239: f 3.72377e-12 trial_f 0.0733347 accepted 0  lowest_f 2.06921e-19
# basinhopping step 240: f 3.72377e-12 trial_f 6053.76 accepted 0  lowest_f 2.06921e-19
# basinhopping step 241: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 242: f 8.4545e-19 trial_f 8.4545e-19 accepted 1  lowest_f 2.06921e-19
# basinhopping step 243: f 8.4545e-19 trial_f 672068 accepted 0  lowest_f 2.06921e-19
# basinhopping step 244: f 0.209326 trial_f 0.209326 accepted 1  lowest_f 2.06921e-19
# basinhopping step 245: f 0.0604905 trial_f 0.0604905 accepted 1  lowest_f 2.06921e-19
# basinhopping step 246: f 0.208796 trial_f 0.208796 accepted 1  lowest_f 2.06921e-19
# basinhopping step 247: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 248: f 0.189086 trial_f 0.189086 accepted 1  lowest_f 2.06921e-19
# basinhopping step 249: f 0.189086 trial_f 4979.25 accepted 0  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.660000 target 0.500000 new stepsize 1.69351 old stepsize 1.52416
# basinhopping step 250: f 0.190228 trial_f 0.190228 accepted 1  lowest_f 2.06921e-19
# basinhopping step 251: f 0.0314324 trial_f 0.0314324 accepted 1  lowest_f 2.06921e-19
# basinhopping step 252: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 253: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 254: f 0.0733347 trial_f 18620 accepted 0  lowest_f 2.06921e-19
# basinhopping step 255: f 4.59493e-14 trial_f 4.59493e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 256: f 4.59493e-14 trial_f 7256.47 accepted 0  lowest_f 2.06921e-19
# basinhopping step 257: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 258: f 1.16954e-07 trial_f 1.16954e-07 accepted 1  lowest_f 2.06921e-19
# basinhopping step 259: f 1.16954e-07 trial_f 5041.39 accepted 0  lowest_f 2.06921e-19
# basinhopping step 260: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 261: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 262: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 263: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 264: f 0.188018 trial_f 0.188018 accepted 1  lowest_f 2.06921e-19
# basinhopping step 265: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 266: f 0.189262 trial_f 0.189262 accepted 1  lowest_f 2.06921e-19
# basinhopping step 267: f 0.187694 trial_f 0.187694 accepted 1  lowest_f 2.06921e-19
# basinhopping step 268: f 0.188 trial_f 0.188 accepted 1  lowest_f 2.06921e-19
# basinhopping step 269: f 0.188 trial_f 887327 accepted 0  lowest_f 2.06921e-19
# basinhopping step 270: f 0.188 trial_f 18622.1 accepted 0  lowest_f 2.06921e-19
# basinhopping step 271: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 272: f 1.86661e-16 trial_f 1.86661e-16 accepted 1  lowest_f 2.06921e-19
# basinhopping step 273: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 274: f 0.00459604 trial_f 0.00459604 accepted 1  lowest_f 2.06921e-19
# basinhopping step 275: f 0.00483816 trial_f 0.00483816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 276: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 277: f 5.35651e-14 trial_f 5.35651e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 278: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 279: f 0.188959 trial_f 0.188959 accepted 1  lowest_f 2.06921e-19
# basinhopping step 280: f 7.24405e-13 trial_f 7.24405e-13 accepted 1  lowest_f 2.06921e-19
# basinhopping step 281: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 282: f 0.188816 trial_f 15795.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 283: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 284: f 0.109142 trial_f 0.109142 accepted 1  lowest_f 2.06921e-19
# basinhopping step 285: f 0.188961 trial_f 0.188961 accepted 1  lowest_f 2.06921e-19
# basinhopping step 286: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 287: f 4.03058e-11 trial_f 4.03058e-11 accepted 1  lowest_f 2.06921e-19
# basinhopping step 288: f 4.03058e-11 trial_f 0.0733347 accepted 0  lowest_f 2.06921e-19
# basinhopping step 289: f 4.03058e-11 trial_f 0.0733347 accepted 0  lowest_f 2.06921e-19
# basinhopping step 290: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 291: f 0.0733347 trial_f 18612.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 292: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 293: f 8.75598e-12 trial_f 8.75598e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 294: f 1.90294e-14 trial_f 1.90294e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 295: f 1.90294e-14 trial_f 5728.1 accepted 0  lowest_f 2.06921e-19
# basinhopping step 296: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 297: f 3.47317e-12 trial_f 3.47317e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 298: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 299: f 1.53216e-13 trial_f 1.53216e-13 accepted 1  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.683333 target 0.500000 new stepsize 1.88168 old stepsize 1.69351
# basinhopping step 300: f 3.69593e-14 trial_f 3.69593e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 301: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 302: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 303: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 2.06921e-19
# basinhopping step 304: f 0.0733347 trial_f 112.782 accepted 0  lowest_f 2.06921e-19
# basinhopping step 305: f 0.0733347 trial_f 18604.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 306: f 2.77481e-14 trial_f 2.77481e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 307: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 308: f 0.0733347 trial_f 18612.5 accepted 0  lowest_f 2.06921e-19
# basinhopping step 309: f 1.58607e-05 trial_f 1.58607e-05 accepted 1  lowest_f 2.06921e-19
# basinhopping step 310: f 3.08298e-11 trial_f 3.08298e-11 accepted 1  lowest_f 2.06921e-19
# basinhopping step 311: f 3.08298e-11 trial_f 0.0733347 accepted 0  lowest_f 2.06921e-19
# basinhopping step 312: f 0.0729494 trial_f 0.0729494 accepted 1  lowest_f 2.06921e-19
# basinhopping step 313: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 314: f 0.188816 trial_f 7211.42 accepted 0  lowest_f 2.06921e-19
# basinhopping step 315: f 1.54852e-13 trial_f 1.54852e-13 accepted 1  lowest_f 2.06921e-19
# basinhopping step 316: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 317: f 0.00522981 trial_f 0.00522981 accepted 1  lowest_f 2.06921e-19
# basinhopping step 318: f 0.00522981 trial_f 14571 accepted 0  lowest_f 2.06921e-19
# basinhopping step 319: f 0.00522981 trial_f 9388.54 accepted 0  lowest_f 2.06921e-19
# basinhopping step 320: f 1.37379e-14 trial_f 1.37379e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 321: f 1.37379e-14 trial_f 14535.4 accepted 0  lowest_f 2.06921e-19
# basinhopping step 322: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 323: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 324: f 0.0733347 trial_f 83916.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 325: f 0.0733347 trial_f 887331 accepted 0  lowest_f 2.06921e-19
# basinhopping step 326: f 0.0733347 trial_f 4277.73 accepted 0  lowest_f 2.06921e-19
# basinhopping step 327: f 0.0733347 trial_f 18621.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 328: f 0.0733347 trial_f 2217.49 accepted 0  lowest_f 2.06921e-19
# basinhopping step 329: f 0.113719 trial_f 0.113719 accepted 1  lowest_f 2.06921e-19
# basinhopping step 330: f 1.42095e-15 trial_f 1.42095e-15 accepted 1  lowest_f 2.06921e-19
# basinhopping step 331: f 1.42095e-15 trial_f 269333 accepted 0  lowest_f 2.06921e-19
# basinhopping step 332: f 1.42095e-15 trial_f 17039.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 333: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 334: f 0.188816 trial_f 14332 accepted 0  lowest_f 2.06921e-19
# basinhopping step 335: f 0.0403371 trial_f 0.0403371 accepted 1  lowest_f 2.06921e-19
# basinhopping step 336: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 337: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 338: f 0.00153321 trial_f 0.00153321 accepted 1  lowest_f 2.06921e-19
# basinhopping step 339: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 340: f 0.0733347 trial_f 18622.2 accepted 0  lowest_f 2.06921e-19
# basinhopping step 341: f 0.0733347 trial_f 18624 accepted 0  lowest_f 2.06921e-19
# basinhopping step 342: f 4.86201e-12 trial_f 4.86201e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 343: f 4.86201e-12 trial_f 0.641072 accepted 0  lowest_f 2.06921e-19
# basinhopping step 344: f 1.69214e-10 trial_f 1.69214e-10 accepted 1  lowest_f 2.06921e-19
# basinhopping step 345: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 346: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 347: f 1.04731e-07 trial_f 1.04731e-07 accepted 1  lowest_f 2.06921e-19
# basinhopping step 348: f 1.04731e-07 trial_f 18613.5 accepted 0  lowest_f 2.06921e-19
# basinhopping step 349: f 1.04731e-07 trial_f 0.188816 accepted 0  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.665714 target 0.500000 new stepsize 2.09075 old stepsize 1.88168
# basinhopping step 350: f 1.04731e-07 trial_f 0.188816 accepted 0  lowest_f 2.06921e-19
# basinhopping step 351: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 352: f 0.0733347 trial_f 10742.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 353: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 354: f 0.0733347 trial_f 18619.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 355: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 356: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 357: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 358: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 359: f 0.0170605 trial_f 0.0170605 accepted 1  lowest_f 2.06921e-19
# basinhopping step 360: f 2.9347e-14 trial_f 2.9347e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 361: f 2.9347e-14 trial_f 14301.1 accepted 0  lowest_f 2.06921e-19
# basinhopping step 362: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 363: f 2.75731e-14 trial_f 2.75731e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 364: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 365: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 366: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 367: f 0.189035 trial_f 0.189035 accepted 1  lowest_f 2.06921e-19
# basinhopping step 368: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 369: f 2.94886e-14 trial_f 2.94886e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 370: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 371: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 372: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 373: f 0.0733347 trial_f 0.188005 accepted 0  lowest_f 2.06921e-19
# basinhopping step 374: f 0.187927 trial_f 0.187927 accepted 1  lowest_f 2.06921e-19
# basinhopping step 375: f 0.0337308 trial_f 0.0337308 accepted 1  lowest_f 2.06921e-19
# basinhopping step 376: f 0.0337308 trial_f 16831.7 accepted 0  lowest_f 2.06921e-19
# basinhopping step 377: f 0.0337308 trial_f 15101.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 378: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 379: f 0.00195822 trial_f 0.00195822 accepted 1  lowest_f 2.06921e-19
# basinhopping step 380: f 0.00195822 trial_f 17850.4 accepted 0  lowest_f 2.06921e-19
# basinhopping step 381: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 382: f 0.188005 trial_f 0.188005 accepted 1  lowest_f 2.06921e-19
# basinhopping step 383: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 384: f 0.188009 trial_f 0.188009 accepted 1  lowest_f 2.06921e-19
# basinhopping step 385: f 0.18802 trial_f 0.18802 accepted 1  lowest_f 2.06921e-19
# basinhopping step 386: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 387: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 388: f 0.188003 trial_f 0.188003 accepted 1  lowest_f 2.06921e-19
# basinhopping step 389: f 0.181462 trial_f 0.181462 accepted 1  lowest_f 2.06921e-19
# basinhopping step 390: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 391: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 392: f 0.189261 trial_f 0.189261 accepted 1  lowest_f 2.06921e-19
# basinhopping step 393: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 394: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 395: f 2.00671e-12 trial_f 2.00671e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 396: f 0.0237621 trial_f 0.0237621 accepted 1  lowest_f 2.06921e-19
# basinhopping step 397: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 398: f 2.27139e-14 trial_f 2.27139e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 399: f 2.27139e-14 trial_f 12980.7 accepted 0  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.685000 target 0.500000 new stepsize 2.32306 old stepsize 2.09075
# basinhopping step 400: f 2.27139e-14 trial_f 0.188816 accepted 0  lowest_f 2.06921e-19
# basinhopping step 401: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 402: f 0.0733347 trial_f 17185.8 accepted 0  lowest_f 2.06921e-19
# basinhopping step 403: f 0.0733347 trial_f 18587.4 accepted 0  lowest_f 2.06921e-19
# basinhopping step 404: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 405: f 0.0465307 trial_f 0.0465307 accepted 1  lowest_f 2.06921e-19
# basinhopping step 406: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 407: f 0.188969 trial_f 0.188969 accepted 1  lowest_f 2.06921e-19
# basinhopping step 408: f 0.00433535 trial_f 0.00433535 accepted 1  lowest_f 2.06921e-19
# basinhopping step 409: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 410: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 411: f 0.0733347 trial_f 3182.31 accepted 0  lowest_f 2.06921e-19
# basinhopping step 412: f 0.0733347 trial_f 10129.2 accepted 0  lowest_f 2.06921e-19
# basinhopping step 413: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 414: f 0.188816 trial_f 18610.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 415: f 0.188005 trial_f 0.188005 accepted 1  lowest_f 2.06921e-19
# basinhopping step 416: f 0.0877781 trial_f 0.0877781 accepted 1  lowest_f 2.06921e-19
# basinhopping step 417: f 0.0877781 trial_f 11734 accepted 0  lowest_f 2.06921e-19
# basinhopping step 418: f 0.531912 trial_f 0.531912 accepted 1  lowest_f 2.06921e-19
# basinhopping step 419: f 0.531912 trial_f 18582.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 420: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 421: f 0.188012 trial_f 0.188012 accepted 1  lowest_f 2.06921e-19
# basinhopping step 422: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 423: f 2.36153e-13 trial_f 2.36153e-13 accepted 1  lowest_f 2.06921e-19
# basinhopping step 424: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 425: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 426: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 427: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 428: f 0.0733347 trial_f 0.188011 accepted 0  lowest_f 2.06921e-19
# basinhopping step 429: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 430: f 4.08997e-16 trial_f 4.08997e-16 accepted 1  lowest_f 2.06921e-19
# basinhopping step 431: f 4.08997e-16 trial_f 6357.75 accepted 0  lowest_f 2.06921e-19
# basinhopping step 432: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 433: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 434: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 435: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 436: f 0.0733347 trial_f 16764.4 accepted 0  lowest_f 2.06921e-19
# basinhopping step 437: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 438: f 0.140633 trial_f 0.140633 accepted 1  lowest_f 2.06921e-19
# basinhopping step 439: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 440: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 441: f 0.0733347 trial_f 14777.8 accepted 0  lowest_f 2.06921e-19
# basinhopping step 442: f 0.18888 trial_f 0.18888 accepted 1  lowest_f 2.06921e-19
# basinhopping step 443: f 0.187125 trial_f 0.187125 accepted 1  lowest_f 2.06921e-19
# basinhopping step 444: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 2.06921e-19
# basinhopping step 445: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 446: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 447: f 0.0733347 trial_f 18591.5 accepted 0  lowest_f 2.06921e-19
# basinhopping step 448: f 0.0733347 trial_f 18627.4 accepted 0  lowest_f 2.06921e-19
# basinhopping step 449: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.688889 target 0.500000 new stepsize 2.58117 old stepsize 2.32306
# basinhopping step 450: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 451: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 452: f 0.00082628 trial_f 0.00082628 accepted 1  lowest_f 2.06921e-19
# basinhopping step 453: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 454: f 0.0733347 trial_f 18225.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 455: f 0.0733347 trial_f 18611.5 accepted 0  lowest_f 2.06921e-19
# basinhopping step 456: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 457: f 4.85038e-12 trial_f 4.85038e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 458: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 459: f 3.2206e-10 trial_f 3.2206e-10 accepted 1  lowest_f 2.06921e-19
# basinhopping step 460: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 461: f 0.0733347 trial_f 12200.2 accepted 0  lowest_f 2.06921e-19
# basinhopping step 462: f 2.66651e-14 trial_f 2.66651e-14 accepted 1  lowest_f 2.06921e-19
# basinhopping step 463: f 2.66651e-14 trial_f 0.0904067 accepted 0  lowest_f 2.06921e-19
# basinhopping step 464: f 2.66651e-14 trial_f 5144.81 accepted 0  lowest_f 2.06921e-19
# basinhopping step 465: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 466: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 467: f 0.0733347 trial_f 16425.1 accepted 0  lowest_f 2.06921e-19
# basinhopping step 468: f 0.0733347 trial_f 7240.32 accepted 0  lowest_f 2.06921e-19
# basinhopping step 469: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 470: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 471: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 472: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 473: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 474: f 0.0733347 trial_f 17381.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 475: f 5.2505e-11 trial_f 5.2505e-11 accepted 1  lowest_f 2.06921e-19
# basinhopping step 476: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 477: f 0.0733347 trial_f 18632.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 478: f 0.0733347 trial_f 18617.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 479: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 480: f 0.123224 trial_f 0.123224 accepted 1  lowest_f 2.06921e-19
# basinhopping step 481: f 4.61472e-18 trial_f 4.61472e-18 accepted 1  lowest_f 2.06921e-19
# basinhopping step 482: f 4.61472e-18 trial_f 18532.8 accepted 0  lowest_f 2.06921e-19
# basinhopping step 483: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 484: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 485: f 0.320645 trial_f 0.320645 accepted 1  lowest_f 2.06921e-19
# basinhopping step 486: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 487: f 0.188015 trial_f 0.188015 accepted 1  lowest_f 2.06921e-19
# basinhopping step 488: f 0.189265 trial_f 0.189265 accepted 1  lowest_f 2.06921e-19
# basinhopping step 489: f 0.0055951 trial_f 0.0055951 accepted 1  lowest_f 2.06921e-19
# basinhopping step 490: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 491: f 1.88578e-11 trial_f 1.88578e-11 accepted 1  lowest_f 2.06921e-19
# basinhopping step 492: f 4.48756e-10 trial_f 4.48756e-10 accepted 1  lowest_f 2.06921e-19
# basinhopping step 493: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 494: f 0.187999 trial_f 0.187999 accepted 1  lowest_f 2.06921e-19
# basinhopping step 495: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 496: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 497: f 0.189552 trial_f 0.189552 accepted 1  lowest_f 2.06921e-19
# basinhopping step 498: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 499: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# adaptive stepsize: acceptance rate 0.698000 target 0.500000 new stepsize 2.86797 old stepsize 2.58117
# basinhopping step 500: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 501: f 0.0733347 trial_f 18585.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 502: f 1.55847e-12 trial_f 1.55847e-12 accepted 1  lowest_f 2.06921e-19
# basinhopping step 503: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 504: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 505: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 506: f 0.0733347 trial_f 18622.7 accepted 0  lowest_f 2.06921e-19
# basinhopping step 507: f 0.0733347 trial_f 0.188832 accepted 0  lowest_f 2.06921e-19
# basinhopping step 508: f 0.0733347 trial_f 11115.5 accepted 0  lowest_f 2.06921e-19
# basinhopping step 509: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 510: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 511: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 512: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 513: f 0.0733347 trial_f 18603.3 accepted 0  lowest_f 2.06921e-19
# basinhopping step 514: f 1.26484e-06 trial_f 1.26484e-06 accepted 1  lowest_f 2.06921e-19
# basinhopping step 515: f 1.26484e-06 trial_f 0.188816 accepted 0  lowest_f 2.06921e-19
# basinhopping step 516: f 0.187957 trial_f 0.187957 accepted 1  lowest_f 2.06921e-19
# basinhopping step 517: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 2.06921e-19
# basinhopping step 518: f 0.188011 trial_f 18405.8 accepted 0  lowest_f 2.06921e-19
# basinhopping step 519: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 520: f 6.09013e-10 trial_f 6.09013e-10 accepted 1  lowest_f 2.06921e-19
# basinhopping step 521: f 6.09013e-10 trial_f 7806.22 accepted 0  lowest_f 2.06921e-19
# basinhopping step 522: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 523: f 0.00737064 trial_f 0.00737064 accepted 1  lowest_f 2.06921e-19
# basinhopping step 524: f 0.00737064 trial_f 18617.6 accepted 0  lowest_f 2.06921e-19
# basinhopping step 525: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 526: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 527: f 0.0733347 trial_f 18582.7 accepted 0  lowest_f 2.06921e-19
# basinhopping step 528: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 529: f 0.0733347 trial_f 18619.4 accepted 0  lowest_f 2.06921e-19
# basinhopping step 530: f 0.153379 trial_f 0.153379 accepted 1  lowest_f 2.06921e-19
# basinhopping step 531: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 532: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 533: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 534: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 535: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 536: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# basinhopping step 537: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 2.06921e-19
# basinhopping step 538: f 0.188816 trial_f 18630 accepted 0  lowest_f 2.06921e-19
# basinhopping step 539: f 0.188816 trial_f 17017.9 accepted 0  lowest_f 2.06921e-19
# basinhopping step 540: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 2.06921e-19
# ...
# basinhopping step 818: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 819: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 1.45551e-19
# basinhopping step 820: f 0.0733347 trial_f 18619.3 accepted 0  lowest_f 1.45551e-19
# basinhopping step 821: f 0.188028 trial_f 0.188028 accepted 1  lowest_f 1.45551e-19
# basinhopping step 822: f 4.72882e-12 trial_f 4.72882e-12 accepted 1  lowest_f 1.45551e-19
# basinhopping step 823: f 0.188817 trial_f 0.188817 accepted 1  lowest_f 1.45551e-19
# basinhopping step 824: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 825: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 826: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 827: f 0.12406 trial_f 0.12406 accepted 1  lowest_f 1.45551e-19
# basinhopping step 828: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 829: f 0.190228 trial_f 0.190228 accepted 1  lowest_f 1.45551e-19
# basinhopping step 830: f 0.188022 trial_f 0.188022 accepted 1  lowest_f 1.45551e-19
# basinhopping step 831: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 832: f 6.59147e-12 trial_f 6.59147e-12 accepted 1  lowest_f 1.45551e-19
# basinhopping step 833: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 834: f 0.000427869 trial_f 0.000427869 accepted 1  lowest_f 1.45551e-19
# basinhopping step 835: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 836: f 0.0733347 trial_f 18633.6 accepted 0  lowest_f 1.45551e-19
# basinhopping step 837: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 838: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 839: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 840: f 2.28617e-13 trial_f 2.28617e-13 accepted 1  lowest_f 1.45551e-19
# basinhopping step 841: f 0.188845 trial_f 0.188845 accepted 1  lowest_f 1.45551e-19
# basinhopping step 842: f 0.188845 trial_f 18601.2 accepted 0  lowest_f 1.45551e-19
# basinhopping step 843: f 5.05934e-17 trial_f 5.05934e-17 accepted 1  lowest_f 1.45551e-19
# basinhopping step 844: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 845: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 846: f 0.188881 trial_f 0.188881 accepted 1  lowest_f 1.45551e-19
# basinhopping step 847: f 0.190228 trial_f 0.190228 accepted 1  lowest_f 1.45551e-19
# basinhopping step 848: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 849: f 0.0733347 trial_f 18633.7 accepted 0  lowest_f 1.45551e-19
# adaptive stepsize: acceptance rate 0.710588 target 0.500000 new stepsize 5.99622 old stepsize 5.3966
# basinhopping step 850: f 0.188018 trial_f 0.188018 accepted 1  lowest_f 1.45551e-19
# basinhopping step 851: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 852: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 853: f 0.0733347 trial_f 18633.4 accepted 0  lowest_f 1.45551e-19
# basinhopping step 854: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 855: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 856: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 857: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 858: f 1.25736e-17 trial_f 1.25736e-17 accepted 1  lowest_f 1.45551e-19
# basinhopping step 859: f 1.25736e-17 trial_f 0.0733347 accepted 0  lowest_f 1.45551e-19
# basinhopping step 860: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 861: f 0.188014 trial_f 0.188014 accepted 1  lowest_f 1.45551e-19
# basinhopping step 862: f 0.188014 trial_f 18589.7 accepted 0  lowest_f 1.45551e-19
# basinhopping step 863: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 864: f 0.188009 trial_f 0.188009 accepted 1  lowest_f 1.45551e-19
# basinhopping step 865: f 0.188009 trial_f 18565 accepted 0  lowest_f 1.45551e-19
# basinhopping step 866: f 0.188011 trial_f 0.188011 accepted 1  lowest_f 1.45551e-19
# basinhopping step 867: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 868: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 1.45551e-19
# basinhopping step 869: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 870: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 871: f 0.0733347 trial_f 0.188009 accepted 0  lowest_f 1.45551e-19
# basinhopping step 872: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 873: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 874: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 875: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 876: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 877: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 878: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 879: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 880: f 0.187998 trial_f 0.187998 accepted 1  lowest_f 1.45551e-19
# basinhopping step 881: f 0.188039 trial_f 0.188039 accepted 1  lowest_f 1.45551e-19
# basinhopping step 882: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 883: f 0.188013 trial_f 0.188013 accepted 1  lowest_f 1.45551e-19
# basinhopping step 884: f 0.190225 trial_f 0.190225 accepted 1  lowest_f 1.45551e-19
# basinhopping step 885: f 0.190224 trial_f 0.190224 accepted 1  lowest_f 1.45551e-19
# basinhopping step 886: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 887: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 888: f 1.59103e-17 trial_f 1.59103e-17 accepted 1  lowest_f 1.45551e-19
# basinhopping step 889: f 1.59103e-17 trial_f 0.188816 accepted 0  lowest_f 1.45551e-19
# basinhopping step 890: f 3.1733e-10 trial_f 3.1733e-10 accepted 1  lowest_f 1.45551e-19
# basinhopping step 891: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 892: f 0.188007 trial_f 0.188007 accepted 1  lowest_f 1.45551e-19
# basinhopping step 893: f 0.189265 trial_f 0.189265 accepted 1  lowest_f 1.45551e-19
# basinhopping step 894: f 0.189265 trial_f 18618.3 accepted 0  lowest_f 1.45551e-19
# basinhopping step 895: f 0.188019 trial_f 0.188019 accepted 1  lowest_f 1.45551e-19
# basinhopping step 896: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 897: f 0.0733347 trial_f 18627.9 accepted 0  lowest_f 1.45551e-19
# basinhopping step 898: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 899: f 0.188882 trial_f 0.188882 accepted 1  lowest_f 1.45551e-19
# adaptive stepsize: acceptance rate 0.716667 target 0.500000 new stepsize 6.66246 old stepsize 5.99622
# basinhopping step 900: f 0.188882 trial_f 17943.8 accepted 0  lowest_f 1.45551e-19
# basinhopping step 901: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 902: f 0.189072 trial_f 0.189072 accepted 1  lowest_f 1.45551e-19
# basinhopping step 903: f 7.62073e-13 trial_f 7.62073e-13 accepted 1  lowest_f 1.45551e-19
# basinhopping step 904: f 0.120664 trial_f 0.120664 accepted 1  lowest_f 1.45551e-19
# basinhopping step 905: f 0.001936 trial_f 0.001936 accepted 1  lowest_f 1.45551e-19
# basinhopping step 906: f 0.001936 trial_f 2980.81 accepted 0  lowest_f 1.45551e-19
# basinhopping step 907: f 0.001936 trial_f 18529.2 accepted 0  lowest_f 1.45551e-19
# basinhopping step 908: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 909: f 0.188009 trial_f 0.188009 accepted 1  lowest_f 1.45551e-19
# basinhopping step 910: f 0.188001 trial_f 0.188001 accepted 1  lowest_f 1.45551e-19
# basinhopping step 911: f 0.188001 trial_f 10628.4 accepted 0  lowest_f 1.45551e-19
# basinhopping step 912: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 913: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 914: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 915: f 0.0733347 trial_f 15943.1 accepted 0  lowest_f 1.45551e-19
# basinhopping step 916: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 917: f 0.188014 trial_f 0.188014 accepted 1  lowest_f 1.45551e-19
# basinhopping step 918: f 0.190224 trial_f 0.190224 accepted 1  lowest_f 1.45551e-19
# basinhopping step 919: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 920: f 0.0733347 trial_f 18573.4 accepted 0  lowest_f 1.45551e-19
# basinhopping step 921: f 0.188006 trial_f 0.188006 accepted 1  lowest_f 1.45551e-19
# basinhopping step 922: f 0.18801 trial_f 0.18801 accepted 1  lowest_f 1.45551e-19
# basinhopping step 923: f 0.18801 trial_f 11036.7 accepted 0  lowest_f 1.45551e-19
# basinhopping step 924: f 0.0347743 trial_f 0.0347743 accepted 1  lowest_f 1.45551e-19
# basinhopping step 925: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 926: f 0.188838 trial_f 0.188838 accepted 1  lowest_f 1.45551e-19
# basinhopping step 927: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 928: f 0.188838 trial_f 0.188838 accepted 1  lowest_f 1.45551e-19
# basinhopping step 929: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 930: f 0.188013 trial_f 0.188013 accepted 1  lowest_f 1.45551e-19
# basinhopping step 931: f 0.188041 trial_f 0.188041 accepted 1  lowest_f 1.45551e-19
# basinhopping step 932: f 0.190227 trial_f 0.190227 accepted 1  lowest_f 1.45551e-19
# basinhopping step 933: f 0.190227 trial_f 18566 accepted 0  lowest_f 1.45551e-19
# basinhopping step 934: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 935: f 0.190228 trial_f 0.190228 accepted 1  lowest_f 1.45551e-19
# basinhopping step 936: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 937: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 938: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 939: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 940: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 941: f 0.188816 trial_f 18572.9 accepted 0  lowest_f 1.45551e-19
# basinhopping step 942: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 943: f 0.0733347 trial_f 18622.7 accepted 0  lowest_f 1.45551e-19
# basinhopping step 944: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 945: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 946: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 947: f 0.188881 trial_f 0.188881 accepted 1  lowest_f 1.45551e-19
# basinhopping step 948: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 949: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 1.45551e-19
# adaptive stepsize: acceptance rate 0.720000 target 0.500000 new stepsize 7.40274 old stepsize 6.66246
# basinhopping step 950: f 0.0733347 trial_f 0.188001 accepted 0  lowest_f 1.45551e-19
# basinhopping step 951: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 952: f 0.0733347 trial_f 0.188838 accepted 0  lowest_f 1.45551e-19
# basinhopping step 953: f 0.188021 trial_f 0.188021 accepted 1  lowest_f 1.45551e-19
# basinhopping step 954: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 955: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 956: f 0.188013 trial_f 0.188013 accepted 1  lowest_f 1.45551e-19
# basinhopping step 957: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 958: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 959: f 0.188839 trial_f 0.188839 accepted 1  lowest_f 1.45551e-19
# basinhopping step 960: f 0.188005 trial_f 0.188005 accepted 1  lowest_f 1.45551e-19
# basinhopping step 961: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 962: f 0.0733347 trial_f 9849.5 accepted 0  lowest_f 1.45551e-19
# basinhopping step 963: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 964: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 965: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 966: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 967: f 0.0733347 trial_f 0.190227 accepted 0  lowest_f 1.45551e-19
# basinhopping step 968: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 1.45551e-19
# basinhopping step 969: f 0.0733347 trial_f 0.188004 accepted 0  lowest_f 1.45551e-19
# basinhopping step 970: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 971: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 972: f 0.188004 trial_f 0.188004 accepted 1  lowest_f 1.45551e-19
# basinhopping step 973: f 0.190226 trial_f 0.190226 accepted 1  lowest_f 1.45551e-19
# basinhopping step 974: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 975: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 976: f 0.0733347 trial_f 0.190229 accepted 0  lowest_f 1.45551e-19
# basinhopping step 977: f 0.188005 trial_f 0.188005 accepted 1  lowest_f 1.45551e-19
# basinhopping step 978: f 0.190217 trial_f 0.190217 accepted 1  lowest_f 1.45551e-19
# basinhopping step 979: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 980: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 981: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 982: f 0.000881463 trial_f 0.000881463 accepted 1  lowest_f 1.45551e-19
# basinhopping step 983: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 984: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 985: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 986: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 987: f 0.0733347 trial_f 18597.3 accepted 0  lowest_f 1.45551e-19
# basinhopping step 988: f 0.0733347 trial_f 0.188816 accepted 0  lowest_f 1.45551e-19
# basinhopping step 989: f 0.188008 trial_f 0.188008 accepted 1  lowest_f 1.45551e-19
# basinhopping step 990: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 991: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 992: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# basinhopping step 993: f 0.190214 trial_f 0.190214 accepted 1  lowest_f 1.45551e-19
# basinhopping step 994: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 995: f 0.188008 trial_f 0.188008 accepted 1  lowest_f 1.45551e-19
# basinhopping step 996: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 997: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 998: f 0.0733347 trial_f 0.0733347 accepted 1  lowest_f 1.45551e-19
# basinhopping step 999: f 0.188816 trial_f 0.188816 accepted 1  lowest_f 1.45551e-19
# adaptive stepsize: acceptance rate 0.725000 target 0.500000 new stepsize 8.22526 old stepsize 7.40274
# basinhopping step 1000: f 0.190227 trial_f 0.190227 accepted 1  lowest_f 1.45551e-19

# %%
mu2, rho2, M2, P2 = result.x[0], result.x[1], result.x[2], result.x[3]
Q2 = M2/rho2
specific_speed_1 = N1*np.sqrt(M1/rho1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(M2/rho2)/(P2/(rho2*g))**(3/4)
print(f"Ns = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_2-Reysnold_2)/Reysnold_1*100} %")

pump_eff = 0.33
motor_eff = 0.60
mechanical_eff = 0.99

print(f"\nModel's Shaft Speed is {N2:.2f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.2f} mm\n"
      f"Model's Mass Flow Rate is {M2:.2f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.2f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.2f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.2f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.2f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2} W\n"
      f"Model's Shaft Power = {Q2*P2/pump_eff/mechanical_eff} W\n"
      f"Model's Shaft Torque = {Q2*P2/pump_eff/mechanical_eff/(N2*2*math.pi/60)} N-m\n"
      f"Model's Electrical Power = {Q2*P2/pump_eff/mechanical_eff/motor_eff} W\n")
# Out:
# Ns = 17.7850, Matching = 99.99999999710029 %
# Flow Coefficient Prototype = 0.00024013334463372592, Model = 0.00024013334465862888, Matching = 99.99999998962953 %
# Head Coefficient Prototype = 0.0008161394719577614, Model = 0.0008161394720457408, Matching = 99.99999998922004 %
# Reynolds Number Prototype = 1089138.4615, Model = 1089138.4614, Matching = 100.0 %
#
# Model's Shaft Speed is 2900.00 RPM
# Model's Impeller Diameter is 80.00 mm
# Model's Mass Flow Rate is 0.53 Kg/s
# Model's Pressure Across Pump is 0.66 Bar
# Model's Pressure Head is 4.27 m HAN+H2O2
# Model's Pressure Head is 4.48 m Testing Fluid
# Model's Pressure Head is 6.72 m Water
# Model's Volumetric Flow Rate is 0.3565 L/s
# Model's Fluid's Viscosity is 25.5615 mPa-s
# Model's Fluid's Density is 1499.9994 kg/m^3
# Model's Hydraulic Power = 23.493724443069233 W
# Model's Shaft Power = 71.91222663933037 W
# Model's Shaft Torque = 0.23679695872539527 N-m
# Model's Electrical Power = 119.85371106555063 W
