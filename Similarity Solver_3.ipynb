# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.4e5
#rho2 = 1000; mu2 = 10e-3
N2 = 5000; D2 = 60e-3
g = 9.807  # Acceleration due to gravity in m/s^2

Q1 = M1/rho1

# Define lower and upper bounds for mu, rho, m_dot, pressure rise
lb = [1e-3, 800, 0.1, 0.5e5]  # Lower bounds
ub = [65e-3, 1200, 1.0, 3e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    mu2, rho2, M2, P2 = x
    
    # Specific speed equation residual
    F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( M1/rho1 / (N1 * D1**3)) - (M2/rho2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( P1/rho1 / (N1**2 * D1**2)) - ( P2/rho2 / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (M1/mu1 / D1) - (M2/mu2 / D2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( P1 * M1/rho1 / ( rho1 * N1**3 * D1**5) ) - ( P2 * M2/rho2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F1, F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1.0, 1.0e-3, 1.0e-3, 1, 1.0e3]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([30e-3, 1000, 0.4, 2e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 1.3675e-05
# basinhopping step 1: f 0.0749638 trial_f 0.0749638 accepted 1  lowest_f 1.3675e-05
# basinhopping step 2: f 0.00697217 trial_f 0.00697217 accepted 1  lowest_f 1.3675e-05
# basinhopping step 3: f 1.87034e-15 trial_f 1.87034e-15 accepted 1  lowest_f 1.87034e-15
# found new global minimum on step 3 with function value 1.87034e-15
# basinhopping step 4: f 3.12473e-13 trial_f 3.12473e-13 accepted 1  lowest_f 1.87034e-15
# basinhopping step 5: f 3.12481e-13 trial_f 3.12481e-13 accepted 1  lowest_f 1.87034e-15
# basinhopping step 6: f 3.12481e-13 trial_f 1.61332 accepted 0  lowest_f 1.87034e-15
# basinhopping step 7: f 3.12481e-13 trial_f 1.61281 accepted 0  lowest_f 1.87034e-15
# basinhopping step 8: f 0.0561658 trial_f 0.0561658 accepted 1  lowest_f 1.87034e-15
# basinhopping step 9: f 0.0561658 trial_f 15.7215 accepted 0  lowest_f 1.87034e-15
# basinhopping step 10: f 0.000212246 trial_f 0.000212246 accepted 1  lowest_f 1.87034e-15
# basinhopping step 11: f 0.224877 trial_f 0.224877 accepted 1  lowest_f 1.87034e-15
# basinhopping step 12: f 1.54244e-05 trial_f 1.54244e-05 accepted 1  lowest_f 1.87034e-15
# basinhopping step 13: f 4.76544e-13 trial_f 4.76544e-13 accepted 1  lowest_f 1.87034e-15
# basinhopping step 14: f 4.76544e-13 trial_f 10.7078 accepted 0  lowest_f 1.87034e-15
# basinhopping step 15: f 0.474424 trial_f 0.474424 accepted 1  lowest_f 1.87034e-15
# basinhopping step 16: f 0.00708427 trial_f 0.00708427 accepted 1  lowest_f 1.87034e-15
# basinhopping step 17: f 0.0399994 trial_f 0.0399994 accepted 1  lowest_f 1.87034e-15
# basinhopping step 18: f 1.45359e-05 trial_f 1.45359e-05 accepted 1  lowest_f 1.87034e-15
# basinhopping step 19: f 4.52302e-13 trial_f 4.52302e-13 accepted 1  lowest_f 1.87034e-15
# basinhopping step 20: f 4.52302e-13 trial_f 83355.3 accepted 0  lowest_f 1.87034e-15
# basinhopping step 21: f 4.52302e-13 trial_f 3.14428 accepted 0  lowest_f 1.87034e-15
# basinhopping step 22: f 3.12575e-13 trial_f 3.12575e-13 accepted 1  lowest_f 1.87034e-15
# basinhopping step 23: f 3.12575e-13 trial_f 1.79028e+06 accepted 0  lowest_f 1.87034e-15
# basinhopping step 24: f 0.0124132 trial_f 0.0124132 accepted 1  lowest_f 1.87034e-15
# basinhopping step 25: f 0.170724 trial_f 0.170724 accepted 1  lowest_f 1.87034e-15
# basinhopping step 26: f 0.170724 trial_f 1.60655 accepted 0  lowest_f 1.87034e-15
# basinhopping step 27: f 5.18694e-18 trial_f 5.18694e-18 accepted 1  lowest_f 5.18694e-18
# found new global minimum on step 27 with function value 5.18694e-18
# basinhopping step 28: f 0.215341 trial_f 0.215341 accepted 1  lowest_f 5.18694e-18
# basinhopping step 29: f 3.31683e-14 trial_f 3.31683e-14 accepted 1  lowest_f 5.18694e-18
# basinhopping step 30: f 1.34827e-14 trial_f 1.34827e-14 accepted 1  lowest_f 5.18694e-18
# C:\Users\Krai\AppData\Local\Temp\ipykernel_34536\1617256422.py:23: RuntimeWarning: invalid value encountered in sqrt
#   F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
# basinhopping step 31: f 0.358437 trial_f 0.358437 accepted 1  lowest_f 5.18694e-18
# basinhopping step 32: f 6.11509e-19 trial_f 6.11509e-19 accepted 1  lowest_f 6.11509e-19
# found new global minimum on step 32 with function value 6.11509e-19
# basinhopping step 33: f 6.11509e-19 trial_f 12.8903 accepted 0  lowest_f 6.11509e-19
# basinhopping step 34: f 6.11509e-19 trial_f 0.0873077 accepted 0  lowest_f 6.11509e-19
# basinhopping step 35: f 3.12538e-13 trial_f 3.12538e-13 accepted 1  lowest_f 6.11509e-19
# basinhopping step 36: f 0.386211 trial_f 0.386211 accepted 1  lowest_f 6.11509e-19
# basinhopping step 37: f 1.7243e-05 trial_f 1.7243e-05 accepted 1  lowest_f 6.11509e-19
# basinhopping step 38: f 1.7243e-05 trial_f 0.850327 accepted 0  lowest_f 6.11509e-19
# basinhopping step 39: f 0.0095961 trial_f 0.0095961 accepted 1  lowest_f 6.11509e-19
# basinhopping step 40: f 0.0095961 trial_f 0.0576334 accepted 0  lowest_f 6.11509e-19
# basinhopping step 41: f 0.38059 trial_f 0.38059 accepted 1  lowest_f 6.11509e-19
# basinhopping step 42: f 0.38059 trial_f 1.79029e+06 accepted 0  lowest_f 6.11509e-19
# basinhopping step 43: f 0.38059 trial_f 1.60616 accepted 0  lowest_f 6.11509e-19
# basinhopping step 44: f 0.38059 trial_f 1.60465 accepted 0  lowest_f 6.11509e-19
# basinhopping step 45: f 0.000166568 trial_f 0.000166568 accepted 1  lowest_f 6.11509e-19
# basinhopping step 46: f 0.0332716 trial_f 0.0332716 accepted 1  lowest_f 6.11509e-19
# basinhopping step 47: f 0.0332716 trial_f 1.0463 accepted 0  lowest_f 6.11509e-19
# basinhopping step 48: f 5.93524e-19 trial_f 5.93524e-19 accepted 1  lowest_f 5.93524e-19
# found new global minimum on step 48 with function value 5.93524e-19
# basinhopping step 49: f 3.12599e-13 trial_f 3.12599e-13 accepted 1  lowest_f 5.93524e-19
# adaptive stepsize: acceptance rate 0.660000 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 50: f 3.12599e-13 trial_f 1.60289 accepted 0  lowest_f 5.93524e-19
# basinhopping step 51: f 3.12538e-13 trial_f 3.12538e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 52: f 3.12777e-13 trial_f 3.12777e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 53: f 3.12777e-13 trial_f 22.6855 accepted 0  lowest_f 5.93524e-19
# basinhopping step 54: f 0.0961534 trial_f 0.0961534 accepted 1  lowest_f 5.93524e-19
# basinhopping step 55: f 1.45513e-05 trial_f 1.45513e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 56: f 4.5238e-13 trial_f 4.5238e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 57: f 2.47721e-12 trial_f 2.47721e-12 accepted 1  lowest_f 5.93524e-19
# basinhopping step 58: f 2.47721e-12 trial_f 0.578189 accepted 0  lowest_f 5.93524e-19
# basinhopping step 59: f 2.47721e-12 trial_f 10.7518 accepted 0  lowest_f 5.93524e-19
# basinhopping step 60: f 1.47098e-13 trial_f 1.47098e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 61: f 1.47098e-13 trial_f 1.62372 accepted 0  lowest_f 5.93524e-19
# basinhopping step 62: f 1.47098e-13 trial_f 1.60236 accepted 0  lowest_f 5.93524e-19
# basinhopping step 63: f 0.0122749 trial_f 0.0122749 accepted 1  lowest_f 5.93524e-19
# basinhopping step 64: f 0.0122749 trial_f 1.33042 accepted 0  lowest_f 5.93524e-19
# basinhopping step 65: f 0.544857 trial_f 0.544857 accepted 1  lowest_f 5.93524e-19
# basinhopping step 66: f 0.544857 trial_f 7.39765 accepted 0  lowest_f 5.93524e-19
# basinhopping step 67: f 6.06652e-19 trial_f 6.06652e-19 accepted 1  lowest_f 5.93524e-19
# basinhopping step 68: f 6.06652e-19 trial_f 5.97302 accepted 0  lowest_f 5.93524e-19
# basinhopping step 69: f 0.300814 trial_f 0.300814 accepted 1  lowest_f 5.93524e-19
# basinhopping step 70: f 0.300814 trial_f 1.61344 accepted 0  lowest_f 5.93524e-19
# basinhopping step 71: f 0.300814 trial_f 0.417644 accepted 0  lowest_f 5.93524e-19
# basinhopping step 72: f 0.0193802 trial_f 0.0193802 accepted 1  lowest_f 5.93524e-19
# basinhopping step 73: f 0.0193802 trial_f 1.61987 accepted 0  lowest_f 5.93524e-19
# basinhopping step 74: f 0.0193802 trial_f 1.5202 accepted 0  lowest_f 5.93524e-19
# basinhopping step 75: f 0.3498 trial_f 0.3498 accepted 1  lowest_f 5.93524e-19
# basinhopping step 76: f 1.68238e-05 trial_f 1.68238e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 77: f 0.333445 trial_f 0.333445 accepted 1  lowest_f 5.93524e-19
# basinhopping step 78: f 1.66742e-05 trial_f 1.66742e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 79: f 2.94345e-13 trial_f 2.94345e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 80: f 3.12474e-13 trial_f 3.12474e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 81: f 3.12474e-13 trial_f 0.49987 accepted 0  lowest_f 5.93524e-19
# basinhopping step 82: f 1.61159 trial_f 1.61159 accepted 1  lowest_f 5.93524e-19
# basinhopping step 83: f 1.41687 trial_f 1.41687 accepted 1  lowest_f 5.93524e-19
# basinhopping step 84: f 1.41687 trial_f 17.6325 accepted 0  lowest_f 5.93524e-19
# basinhopping step 85: f 0.654374 trial_f 0.654374 accepted 1  lowest_f 5.93524e-19
# basinhopping step 86: f 6.01982e-19 trial_f 6.01982e-19 accepted 1  lowest_f 5.93524e-19
# basinhopping step 87: f 6.01982e-19 trial_f 5.18915 accepted 0  lowest_f 5.93524e-19
# basinhopping step 88: f 3.12586e-13 trial_f 3.12586e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 89: f 3.12586e-13 trial_f 0.730016 accepted 0  lowest_f 5.93524e-19
# basinhopping step 90: f 3.16616e-12 trial_f 3.16616e-12 accepted 1  lowest_f 5.93524e-19
# basinhopping step 91: f 3.16616e-12 trial_f 1.13564 accepted 0  lowest_f 5.93524e-19
# basinhopping step 92: f 3.16616e-12 trial_f 1.41171 accepted 0  lowest_f 5.93524e-19
# basinhopping step 93: f 4.56609e-15 trial_f 4.56609e-15 accepted 1  lowest_f 5.93524e-19
# basinhopping step 94: f 3.12767e-13 trial_f 3.12767e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 95: f 3.12767e-13 trial_f 0.690929 accepted 0  lowest_f 5.93524e-19
# basinhopping step 96: f 3.1278e-13 trial_f 3.1278e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 97: f 0.204449 trial_f 0.204449 accepted 1  lowest_f 5.93524e-19
# basinhopping step 98: f 0.204449 trial_f 0.801473 accepted 0  lowest_f 5.93524e-19
# basinhopping step 99: f 0.114227 trial_f 0.114227 accepted 1  lowest_f 5.93524e-19
# adaptive stepsize: acceptance rate 0.620000 target 0.500000 new stepsize 1.23457 old stepsize 1.11111
# basinhopping step 100: f 0.114227 trial_f 22.7679 accepted 0  lowest_f 5.93524e-19
# basinhopping step 101: f 1.45557e-05 trial_f 1.45557e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 102: f 0.000968454 trial_f 0.000968454 accepted 1  lowest_f 5.93524e-19
# basinhopping step 103: f 0.000968454 trial_f 1.60675 accepted 0  lowest_f 5.93524e-19
# basinhopping step 104: f 2.52643e-15 trial_f 2.52643e-15 accepted 1  lowest_f 5.93524e-19
# basinhopping step 105: f 2.52643e-15 trial_f 22.3551 accepted 0  lowest_f 5.93524e-19
# basinhopping step 106: f 0.803963 trial_f 0.803963 accepted 1  lowest_f 5.93524e-19
# basinhopping step 107: f 6.08096e-19 trial_f 6.08096e-19 accepted 1  lowest_f 5.93524e-19
# basinhopping step 108: f 0.230978 trial_f 0.230978 accepted 1  lowest_f 5.93524e-19
# basinhopping step 109: f 1.55248e-05 trial_f 1.55248e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 110: f 2.79193e-13 trial_f 2.79193e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 111: f 2.79193e-13 trial_f 10.7616 accepted 0  lowest_f 5.93524e-19
# basinhopping step 112: f 3.12806e-13 trial_f 3.12806e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 113: f 0.638977 trial_f 0.638977 accepted 1  lowest_f 5.93524e-19
# basinhopping step 114: f 6.01815e-19 trial_f 6.01815e-19 accepted 1  lowest_f 5.93524e-19
# basinhopping step 115: f 0.301326 trial_f 0.301326 accepted 1  lowest_f 5.93524e-19
# basinhopping step 116: f 3.99615e-14 trial_f 3.99615e-14 accepted 1  lowest_f 5.93524e-19
# basinhopping step 117: f 3.12624e-13 trial_f 3.12624e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 118: f 3.12624e-13 trial_f 0.691244 accepted 0  lowest_f 5.93524e-19
# basinhopping step 119: f 3.12624e-13 trial_f 0.865756 accepted 0  lowest_f 5.93524e-19
# basinhopping step 120: f 0.0169213 trial_f 0.0169213 accepted 1  lowest_f 5.93524e-19
# basinhopping step 121: f 0.144835 trial_f 0.144835 accepted 1  lowest_f 5.93524e-19
# basinhopping step 122: f 0.144835 trial_f 1.19672 accepted 0  lowest_f 5.93524e-19
# basinhopping step 123: f 0.0198818 trial_f 0.0198818 accepted 1  lowest_f 5.93524e-19
# basinhopping step 124: f 1.45293e-05 trial_f 1.45293e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 125: f 4.51886e-13 trial_f 4.51886e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 126: f 4.51886e-13 trial_f 0.528753 accepted 0  lowest_f 5.93524e-19
# basinhopping step 127: f 3.12695e-13 trial_f 3.12695e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 128: f 3.12695e-13 trial_f 8.78389 accepted 0  lowest_f 5.93524e-19
# basinhopping step 129: f 3.12695e-13 trial_f 0.356858 accepted 0  lowest_f 5.93524e-19
# basinhopping step 130: f 0.286564 trial_f 0.286564 accepted 1  lowest_f 5.93524e-19
# basinhopping step 131: f 0.286564 trial_f 21.8221 accepted 0  lowest_f 5.93524e-19
# basinhopping step 132: f 0.286564 trial_f 1.60524 accepted 0  lowest_f 5.93524e-19
# basinhopping step 133: f 0.0141092 trial_f 0.0141092 accepted 1  lowest_f 5.93524e-19
# warning: basinhopping: local minimization failure
# basinhopping step 134: f 0.0141092 trial_f 5.37819e-16 accepted 0  lowest_f 5.93524e-19
# basinhopping step 135: f 0.0141092 trial_f 15.3374 accepted 0  lowest_f 5.93524e-19
# warning: basinhopping: local minimization failure
# basinhopping step 136: f 0.0141092 trial_f 4.24648e-16 accepted 0  lowest_f 5.93524e-19
# warning: basinhopping: local minimization failure
# basinhopping step 137: f 0.0141092 trial_f 4.17932e-16 accepted 0  lowest_f 5.93524e-19
# basinhopping step 138: f 0.0141092 trial_f 0.472163 accepted 0  lowest_f 5.93524e-19
# warning: basinhopping: local minimization failure
# basinhopping step 139: f 0.0141092 trial_f 4.21568e-16 accepted 0  lowest_f 5.93524e-19
# basinhopping step 140: f 0.0141092 trial_f 4.81948 accepted 0  lowest_f 5.93524e-19
# basinhopping step 141: f 0.0141092 trial_f 0.259964 accepted 0  lowest_f 5.93524e-19
# basinhopping step 142: f 4.04589e-16 trial_f 4.04589e-16 accepted 1  lowest_f 5.93524e-19
# basinhopping step 143: f 4.04589e-16 trial_f 0.501215 accepted 0  lowest_f 5.93524e-19
# basinhopping step 144: f 0.350957 trial_f 0.350957 accepted 1  lowest_f 5.93524e-19
# basinhopping step 145: f 0.350957 trial_f 0.686855 accepted 0  lowest_f 5.93524e-19
# basinhopping step 146: f 2.03504e-05 trial_f 2.03504e-05 accepted 1  lowest_f 5.93524e-19
# basinhopping step 147: f 0.0281176 trial_f 0.0281176 accepted 1  lowest_f 5.93524e-19
# basinhopping step 148: f 0.0528836 trial_f 0.0528836 accepted 1  lowest_f 5.93524e-19
# basinhopping step 149: f 0.0528836 trial_f 0.771112 accepted 0  lowest_f 5.93524e-19
# adaptive stepsize: acceptance rate 0.593333 target 0.500000 new stepsize 1.37174 old stepsize 1.23457
# basinhopping step 150: f 0.0528836 trial_f 1.60598 accepted 0  lowest_f 5.93524e-19
# basinhopping step 151: f 0.0528836 trial_f 1.41703 accepted 0  lowest_f 5.93524e-19
# basinhopping step 152: f 0.0528836 trial_f 24.4753 accepted 0  lowest_f 5.93524e-19
# basinhopping step 153: f 0.454109 trial_f 0.454109 accepted 1  lowest_f 5.93524e-19
# basinhopping step 154: f 0.323428 trial_f 0.323428 accepted 1  lowest_f 5.93524e-19
# basinhopping step 155: f 6.10301e-19 trial_f 6.10301e-19 accepted 1  lowest_f 5.93524e-19
# basinhopping step 156: f 6.10301e-19 trial_f 0.450679 accepted 0  lowest_f 5.93524e-19
# basinhopping step 157: f 6.10301e-19 trial_f 1.1954 accepted 0  lowest_f 5.93524e-19
# basinhopping step 158: f 6.10301e-19 trial_f 16.536 accepted 0  lowest_f 5.93524e-19
# basinhopping step 159: f 3.12567e-13 trial_f 3.12567e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 160: f 3.1254e-13 trial_f 3.1254e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 161: f 3.12831e-13 trial_f 3.12831e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 162: f 3.12656e-13 trial_f 3.12656e-13 accepted 1  lowest_f 5.93524e-19
# basinhopping step 163: f 0.0271781 trial_f 0.0271781 accepted 1  lowest_f 5.93524e-19
# basinhopping step 164: f 6.13165e-22 trial_f 6.13165e-22 accepted 1  lowest_f 6.13165e-22
# found new global minimum on step 164 with function value 6.13165e-22
# basinhopping step 165: f 3.12764e-13 trial_f 3.12764e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 166: f 0.198087 trial_f 0.198087 accepted 1  lowest_f 6.13165e-22
# basinhopping step 167: f 0.198087 trial_f 10.361 accepted 0  lowest_f 6.13165e-22
# basinhopping step 168: f 0.198087 trial_f 1.60736 accepted 0  lowest_f 6.13165e-22
# basinhopping step 169: f 3.94057e-16 trial_f 3.94057e-16 accepted 1  lowest_f 6.13165e-22
# basinhopping step 170: f 0.472655 trial_f 0.472655 accepted 1  lowest_f 6.13165e-22
# basinhopping step 171: f 0.472655 trial_f 10.1552 accepted 0  lowest_f 6.13165e-22
# basinhopping step 172: f 0.472655 trial_f 1.33042 accepted 0  lowest_f 6.13165e-22
# basinhopping step 173: f 0.472655 trial_f 1.11104 accepted 0  lowest_f 6.13165e-22
# basinhopping step 174: f 0.258661 trial_f 0.258661 accepted 1  lowest_f 6.13165e-22
# basinhopping step 175: f 1.5662e-16 trial_f 1.5662e-16 accepted 1  lowest_f 6.13165e-22
# basinhopping step 176: f 3.12855e-13 trial_f 3.12855e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 177: f 4.69414e-06 trial_f 4.69414e-06 accepted 1  lowest_f 6.13165e-22
# basinhopping step 178: f 2.4451e-16 trial_f 2.4451e-16 accepted 1  lowest_f 6.13165e-22
# basinhopping step 179: f 2.4451e-16 trial_f 0.600343 accepted 0  lowest_f 6.13165e-22
# basinhopping step 180: f 3.12797e-13 trial_f 3.12797e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 181: f 3.12818e-13 trial_f 3.12818e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 182: f 0.661198 trial_f 0.661198 accepted 1  lowest_f 6.13165e-22
# basinhopping step 183: f 6.01941e-19 trial_f 6.01941e-19 accepted 1  lowest_f 6.13165e-22
# basinhopping step 184: f 3.12675e-13 trial_f 3.12675e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 185: f 3.12589e-13 trial_f 3.12589e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 186: f 6.28481e-12 trial_f 6.28481e-12 accepted 1  lowest_f 6.13165e-22
# basinhopping step 187: f 6.28481e-12 trial_f 16.0621 accepted 0  lowest_f 6.13165e-22
# basinhopping step 188: f 6.28481e-12 trial_f 20.3783 accepted 0  lowest_f 6.13165e-22
# basinhopping step 189: f 1.12927e-16 trial_f 1.12927e-16 accepted 1  lowest_f 6.13165e-22
# basinhopping step 190: f 1.12927e-16 trial_f 0.308012 accepted 0  lowest_f 6.13165e-22
# basinhopping step 191: f 1.12927e-16 trial_f 0.26221 accepted 0  lowest_f 6.13165e-22
# basinhopping step 192: f 0.0325536 trial_f 0.0325536 accepted 1  lowest_f 6.13165e-22
# basinhopping step 193: f 1.42665e-11 trial_f 1.42665e-11 accepted 1  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 194: f 1.42665e-11 trial_f 3.81421e-06 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 195: f 1.42665e-11 trial_f 3.81529e-06 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 196: f 1.42665e-11 trial_f 3.74119e-06 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 197: f 1.42665e-11 trial_f 3.86589e-06 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 198: f 1.42665e-11 trial_f 3.81506e-06 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 199: f 1.42665e-11 trial_f 3.7902e-06 accepted 0  lowest_f 6.13165e-22
# adaptive stepsize: acceptance rate 0.585000 target 0.500000 new stepsize 1.52416 old stepsize 1.37174
# warning: basinhopping: local minimization failure
# basinhopping step 200: f 1.42665e-11 trial_f 3.8164e-06 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 201: f 1.42665e-11 trial_f 3.91791e-06 accepted 0  lowest_f 6.13165e-22
# basinhopping step 202: f 1.42665e-11 trial_f 23.3819 accepted 0  lowest_f 6.13165e-22
# warning: basinhopping: local minimization failure
# basinhopping step 203: f 1.42665e-11 trial_f 3.86526e-06 accepted 0  lowest_f 6.13165e-22
# basinhopping step 204: f 1.42665e-11 trial_f 11.8949 accepted 0  lowest_f 6.13165e-22
# basinhopping step 205: f 1.42665e-11 trial_f 1.60592 accepted 0  lowest_f 6.13165e-22
# basinhopping step 206: f 1.42665e-11 trial_f 1.33042 accepted 0  lowest_f 6.13165e-22
# basinhopping step 207: f 0.0450135 trial_f 0.0450135 accepted 1  lowest_f 6.13165e-22
# basinhopping step 208: f 1.45373e-05 trial_f 1.45373e-05 accepted 1  lowest_f 6.13165e-22
# basinhopping step 209: f 4.52373e-13 trial_f 4.52373e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 210: f 4.52373e-13 trial_f 1.41445 accepted 0  lowest_f 6.13165e-22
# basinhopping step 211: f 4.52373e-13 trial_f 1.61071 accepted 0  lowest_f 6.13165e-22
# basinhopping step 212: f 4.52373e-13 trial_f 1.41293 accepted 0  lowest_f 6.13165e-22
# basinhopping step 213: f 4.52373e-13 trial_f 0.324872 accepted 0  lowest_f 6.13165e-22
# basinhopping step 214: f 0.0583257 trial_f 0.0583257 accepted 1  lowest_f 6.13165e-22
# basinhopping step 215: f 0.0583257 trial_f 1.41731 accepted 0  lowest_f 6.13165e-22
# basinhopping step 216: f 7.70507e-20 trial_f 7.70507e-20 accepted 1  lowest_f 6.13165e-22
# basinhopping step 217: f 7.70507e-20 trial_f 0.338397 accepted 0  lowest_f 6.13165e-22
# basinhopping step 218: f 7.70507e-20 trial_f 1.39978 accepted 0  lowest_f 6.13165e-22
# basinhopping step 219: f 7.70507e-20 trial_f 1.04069 accepted 0  lowest_f 6.13165e-22
# basinhopping step 220: f 3.12701e-13 trial_f 3.12701e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 221: f 3.12626e-13 trial_f 3.12626e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 222: f 0.303581 trial_f 0.303581 accepted 1  lowest_f 6.13165e-22
# basinhopping step 223: f 0.303581 trial_f 1.33042 accepted 0  lowest_f 6.13165e-22
# basinhopping step 224: f 1.64204e-05 trial_f 1.64204e-05 accepted 1  lowest_f 6.13165e-22
# basinhopping step 225: f 1.64204e-05 trial_f 1.55626 accepted 0  lowest_f 6.13165e-22
# basinhopping step 226: f 0.0904058 trial_f 0.0904058 accepted 1  lowest_f 6.13165e-22
# basinhopping step 227: f 0.0904058 trial_f 17.3435 accepted 0  lowest_f 6.13165e-22
# basinhopping step 228: f 5.24315e-14 trial_f 5.24315e-14 accepted 1  lowest_f 6.13165e-22
# basinhopping step 229: f 3.12714e-13 trial_f 3.12714e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 230: f 3.12757e-13 trial_f 3.12757e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 231: f 3.12757e-13 trial_f 4.03362 accepted 0  lowest_f 6.13165e-22
# basinhopping step 232: f 3.12757e-13 trial_f 1.29766 accepted 0  lowest_f 6.13165e-22
# basinhopping step 233: f 0.380402 trial_f 0.380402 accepted 1  lowest_f 6.13165e-22
# basinhopping step 234: f 0.380402 trial_f 1.7903e+06 accepted 0  lowest_f 6.13165e-22
# basinhopping step 235: f 1.71645e-05 trial_f 1.71645e-05 accepted 1  lowest_f 6.13165e-22
# basinhopping step 236: f 3.02163e-13 trial_f 3.02163e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 237: f 0.150808 trial_f 0.150808 accepted 1  lowest_f 6.13165e-22
# basinhopping step 238: f 0.150808 trial_f 1.60808 accepted 0  lowest_f 6.13165e-22
# basinhopping step 239: f 0.150808 trial_f 0.317051 accepted 0  lowest_f 6.13165e-22
# basinhopping step 240: f 0.150808 trial_f 1.61011 accepted 0  lowest_f 6.13165e-22
# basinhopping step 241: f 0.473616 trial_f 0.473616 accepted 1  lowest_f 6.13165e-22
# basinhopping step 242: f 0.00707505 trial_f 0.00707505 accepted 1  lowest_f 6.13165e-22
# basinhopping step 243: f 2.98921e-13 trial_f 2.98921e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 244: f 3.12688e-13 trial_f 3.12688e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 245: f 3.12642e-13 trial_f 3.12642e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 246: f 3.12642e-13 trial_f 1.6059 accepted 0  lowest_f 6.13165e-22
# basinhopping step 247: f 3.12642e-13 trial_f 24.1944 accepted 0  lowest_f 6.13165e-22
# basinhopping step 248: f 3.12753e-13 trial_f 3.12753e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 249: f 3.12733e-13 trial_f 3.12733e-13 accepted 1  lowest_f 6.13165e-22
# adaptive stepsize: acceptance rate 0.564000 target 0.500000 new stepsize 1.69351 old stepsize 1.52416
# basinhopping step 250: f 3.12733e-13 trial_f 1.26818 accepted 0  lowest_f 6.13165e-22
# basinhopping step 251: f 3.12798e-13 trial_f 3.12798e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 252: f 3.12713e-13 trial_f 3.12713e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 253: f 3.12581e-13 trial_f 3.12581e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 254: f 3.1238e-13 trial_f 3.1238e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 255: f 3.12664e-13 trial_f 3.12664e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 256: f 3.12664e-13 trial_f 1.41143 accepted 0  lowest_f 6.13165e-22
# basinhopping step 257: f 3.12381e-13 trial_f 3.12381e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 258: f 3.12381e-13 trial_f 0.547069 accepted 0  lowest_f 6.13165e-22
# basinhopping step 259: f 3.12381e-13 trial_f 12.2423 accepted 0  lowest_f 6.13165e-22
# basinhopping step 260: f 3.12381e-13 trial_f 1.60834 accepted 0  lowest_f 6.13165e-22
# basinhopping step 261: f 0.0209177 trial_f 0.0209177 accepted 1  lowest_f 6.13165e-22
# basinhopping step 262: f 0.0209177 trial_f 1.40769 accepted 0  lowest_f 6.13165e-22
# basinhopping step 263: f 2.97635e-15 trial_f 2.97635e-15 accepted 1  lowest_f 6.13165e-22
# basinhopping step 264: f 3.1258e-13 trial_f 3.1258e-13 accepted 1  lowest_f 6.13165e-22
# basinhopping step 265: f 3.1258e-13 trial_f 14.888 accepted 0  lowest_f 6.13165e-22
# basinhopping step 266: f 0.00699118 trial_f 0.00699118 accepted 1  lowest_f 6.13165e-22
# basinhopping step 267: f 0.00699118 trial_f 1.84917 accepted 0  lowest_f 6.13165e-22
# basinhopping step 268: f 0.00699118 trial_f 17.7291 accepted 0  lowest_f 6.13165e-22
# basinhopping step 269: f 7.13872e-25 trial_f 7.13872e-25 accepted 1  lowest_f 7.13872e-25
# found new global minimum on step 269 with function value 7.13872e-25
# basinhopping step 270: f 3.12801e-13 trial_f 3.12801e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 271: f 3.12822e-13 trial_f 3.12822e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 272: f 6.71668e-13 trial_f 6.71668e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 273: f 6.20107e-13 trial_f 6.20107e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 274: f 0.337448 trial_f 0.337448 accepted 1  lowest_f 7.13872e-25
# basinhopping step 275: f 1.67195e-05 trial_f 1.67195e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 276: f 2.95243e-13 trial_f 2.95243e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 277: f 3.12672e-13 trial_f 3.12672e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 278: f 3.12672e-13 trial_f 1.33042 accepted 0  lowest_f 7.13872e-25
# basinhopping step 279: f 3.12672e-13 trial_f 6.00628 accepted 0  lowest_f 7.13872e-25
# basinhopping step 280: f 3.12672e-13 trial_f 1.41753 accepted 0  lowest_f 7.13872e-25
# basinhopping step 281: f 3.12672e-13 trial_f 1.41748 accepted 0  lowest_f 7.13872e-25
# basinhopping step 282: f 3.12841e-13 trial_f 3.12841e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 283: f 0.13618 trial_f 0.13618 accepted 1  lowest_f 7.13872e-25
# basinhopping step 284: f 0.0910278 trial_f 0.0910278 accepted 1  lowest_f 7.13872e-25
# basinhopping step 285: f 0.259803 trial_f 0.259803 accepted 1  lowest_f 7.13872e-25
# basinhopping step 286: f 1.57965e-05 trial_f 1.57965e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 287: f 2.8129e-13 trial_f 2.8129e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 288: f 3.1278e-13 trial_f 3.1278e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 289: f 3.1278e-13 trial_f 23.2063 accepted 0  lowest_f 7.13872e-25
# basinhopping step 290: f 0.247583 trial_f 0.247583 accepted 1  lowest_f 7.13872e-25
# basinhopping step 291: f 4.03702e-16 trial_f 4.03702e-16 accepted 1  lowest_f 7.13872e-25
# basinhopping step 292: f 0.028314 trial_f 0.028314 accepted 1  lowest_f 7.13872e-25
# basinhopping step 293: f 0.028314 trial_f 19.436 accepted 0  lowest_f 7.13872e-25
# basinhopping step 294: f 0.028314 trial_f 343641 accepted 0  lowest_f 7.13872e-25
# basinhopping step 295: f 0.00663697 trial_f 0.00663697 accepted 1  lowest_f 7.13872e-25
# basinhopping step 296: f 0.00663697 trial_f 1.61275 accepted 0  lowest_f 7.13872e-25
# warning: basinhopping: local minimization failure
# basinhopping step 297: f 0.00663697 trial_f 2.52513e-06 accepted 0  lowest_f 7.13872e-25
# warning: basinhopping: local minimization failure
# basinhopping step 298: f 0.00663697 trial_f 2.52561e-06 accepted 0  lowest_f 7.13872e-25
# warning: basinhopping: local minimization failure
# basinhopping step 299: f 0.00663697 trial_f 2.56289e-06 accepted 0  lowest_f 7.13872e-25
# adaptive stepsize: acceptance rate 0.570000 target 0.500000 new stepsize 1.88168 old stepsize 1.69351
# basinhopping step 300: f 0.134878 trial_f 0.134878 accepted 1  lowest_f 7.13872e-25
# basinhopping step 301: f 1.48085e-05 trial_f 1.48085e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 302: f 4.60196e-13 trial_f 4.60196e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 303: f 4.60196e-13 trial_f 1.60943 accepted 0  lowest_f 7.13872e-25
# basinhopping step 304: f 4.60196e-13 trial_f 1.41708 accepted 0  lowest_f 7.13872e-25
# basinhopping step 305: f 1.54842 trial_f 1.54842 accepted 1  lowest_f 7.13872e-25
# basinhopping step 306: f 0.00751708 trial_f 0.00751708 accepted 1  lowest_f 7.13872e-25
# basinhopping step 307: f 1.49218e-16 trial_f 1.49218e-16 accepted 1  lowest_f 7.13872e-25
# basinhopping step 308: f 1.49218e-16 trial_f 1.41724 accepted 0  lowest_f 7.13872e-25
# basinhopping step 309: f 1.49218e-16 trial_f 1.41808 accepted 0  lowest_f 7.13872e-25
# basinhopping step 310: f 3.12507e-13 trial_f 3.12507e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 311: f 3.12507e-13 trial_f 1.12516 accepted 0  lowest_f 7.13872e-25
# basinhopping step 312: f 3.12756e-13 trial_f 3.12756e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 313: f 3.06305e-14 trial_f 3.06305e-14 accepted 1  lowest_f 7.13872e-25
# basinhopping step 314: f 0.0282978 trial_f 0.0282978 accepted 1  lowest_f 7.13872e-25
# basinhopping step 315: f 0.0282978 trial_f 1.03558 accepted 0  lowest_f 7.13872e-25
# basinhopping step 316: f 0.0282978 trial_f 20.1579 accepted 0  lowest_f 7.13872e-25
# basinhopping step 317: f 1.45322e-05 trial_f 1.45322e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 318: f 0.0258153 trial_f 0.0258153 accepted 1  lowest_f 7.13872e-25
# basinhopping step 319: f 1.45308e-05 trial_f 1.45308e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 320: f 4.51988e-13 trial_f 4.51988e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 321: f 3.12719e-13 trial_f 3.12719e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 322: f 3.12719e-13 trial_f 1.41723 accepted 0  lowest_f 7.13872e-25
# basinhopping step 323: f 3.12719e-13 trial_f 1.65439 accepted 0  lowest_f 7.13872e-25
# basinhopping step 324: f 3.12872e-13 trial_f 3.12872e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 325: f 3.12731e-13 trial_f 3.12731e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 326: f 3.12539e-13 trial_f 3.12539e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 327: f 3.12428e-13 trial_f 3.12428e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 328: f 3.12363e-13 trial_f 3.12363e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 329: f 3.12363e-13 trial_f 14.0757 accepted 0  lowest_f 7.13872e-25
# basinhopping step 330: f 3.12363e-13 trial_f 1.33042 accepted 0  lowest_f 7.13872e-25
# basinhopping step 331: f 3.12637e-13 trial_f 3.12637e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 332: f 3.12637e-13 trial_f 0.476946 accepted 0  lowest_f 7.13872e-25
# basinhopping step 333: f 3.12515e-13 trial_f 3.12515e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 334: f 3.12371e-13 trial_f 3.12371e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 335: f 3.12371e-13 trial_f 0.050523 accepted 0  lowest_f 7.13872e-25
# basinhopping step 336: f 3.1292e-13 trial_f 3.1292e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 337: f 3.1292e-13 trial_f 1.93495 accepted 0  lowest_f 7.13872e-25
# basinhopping step 338: f 3.12472e-13 trial_f 3.12472e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 339: f 3.12917e-13 trial_f 3.12917e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 340: f 3.12917e-13 trial_f 1.60512 accepted 0  lowest_f 7.13872e-25
# basinhopping step 341: f 3.12509e-13 trial_f 3.12509e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 342: f 3.12619e-13 trial_f 3.12619e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 343: f 3.12619e-13 trial_f 1.61336 accepted 0  lowest_f 7.13872e-25
# basinhopping step 344: f 3.12619e-13 trial_f 0.561655 accepted 0  lowest_f 7.13872e-25
# basinhopping step 345: f 3.12619e-13 trial_f 0.940629 accepted 0  lowest_f 7.13872e-25
# basinhopping step 346: f 3.12743e-13 trial_f 3.12743e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 347: f 1.9705e-13 trial_f 1.9705e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 348: f 1.9705e-13 trial_f 1.6055 accepted 0  lowest_f 7.13872e-25
# basinhopping step 349: f 0.0594565 trial_f 0.0594565 accepted 1  lowest_f 7.13872e-25
# adaptive stepsize: acceptance rate 0.577143 target 0.500000 new stepsize 2.09075 old stepsize 1.88168
# basinhopping step 350: f 1.43992e-13 trial_f 1.43992e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 351: f 1.43992e-13 trial_f 1.41731 accepted 0  lowest_f 7.13872e-25
# basinhopping step 352: f 3.12925e-13 trial_f 3.12925e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 353: f 3.12476e-13 trial_f 3.12476e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 354: f 3.12644e-13 trial_f 3.12644e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 355: f 3.12644e-13 trial_f 0.688962 accepted 0  lowest_f 7.13872e-25
# basinhopping step 356: f 3.12644e-13 trial_f 1.62463 accepted 0  lowest_f 7.13872e-25
# basinhopping step 357: f 3.12644e-13 trial_f 12.5978 accepted 0  lowest_f 7.13872e-25
# basinhopping step 358: f 0.0874249 trial_f 0.0874249 accepted 1  lowest_f 7.13872e-25
# basinhopping step 359: f 0.0874249 trial_f 0.473763 accepted 0  lowest_f 7.13872e-25
# basinhopping step 360: f 1.45469e-05 trial_f 1.45469e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 361: f 4.51877e-13 trial_f 4.51877e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 362: f 4.51877e-13 trial_f 0.786876 accepted 0  lowest_f 7.13872e-25
# basinhopping step 363: f 3.12737e-13 trial_f 3.12737e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 364: f 3.12684e-13 trial_f 3.12684e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 365: f 3.12444e-13 trial_f 3.12444e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 366: f 0.208451 trial_f 0.208451 accepted 1  lowest_f 7.13872e-25
# basinhopping step 367: f 7.99506e-23 trial_f 7.99506e-23 accepted 1  lowest_f 7.13872e-25
# basinhopping step 368: f 3.12762e-13 trial_f 3.12762e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 369: f 3.12943e-13 trial_f 3.12943e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 370: f 3.12621e-13 trial_f 3.12621e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 371: f 0.601266 trial_f 0.601266 accepted 1  lowest_f 7.13872e-25
# basinhopping step 372: f 6.02741e-19 trial_f 6.02741e-19 accepted 1  lowest_f 7.13872e-25
# basinhopping step 373: f 6.02741e-19 trial_f 1.41712 accepted 0  lowest_f 7.13872e-25
# basinhopping step 374: f 4.6336e-11 trial_f 4.6336e-11 accepted 1  lowest_f 7.13872e-25
# basinhopping step 375: f 7.34831e-16 trial_f 7.34831e-16 accepted 1  lowest_f 7.13872e-25
# basinhopping step 376: f 7.34831e-16 trial_f 1.33042 accepted 0  lowest_f 7.13872e-25
# basinhopping step 377: f 7.34831e-16 trial_f 1.60758 accepted 0  lowest_f 7.13872e-25
# basinhopping step 378: f 1.41704 trial_f 1.41704 accepted 1  lowest_f 7.13872e-25
# basinhopping step 379: f 1.67722e-13 trial_f 1.67722e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 380: f 1.67722e-13 trial_f 1.41724 accepted 0  lowest_f 7.13872e-25
# basinhopping step 381: f 1.67722e-13 trial_f 1.60473 accepted 0  lowest_f 7.13872e-25
# basinhopping step 382: f 1.67722e-13 trial_f 1.41728 accepted 0  lowest_f 7.13872e-25
# basinhopping step 383: f 0.18441 trial_f 0.18441 accepted 1  lowest_f 7.13872e-25
# basinhopping step 384: f 0.18441 trial_f 1.41711 accepted 0  lowest_f 7.13872e-25
# basinhopping step 385: f 0.18441 trial_f 1.41731 accepted 0  lowest_f 7.13872e-25
# basinhopping step 386: f 1.49129e-05 trial_f 1.49129e-05 accepted 1  lowest_f 7.13872e-25
# basinhopping step 387: f 4.6183e-13 trial_f 4.6183e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 388: f 4.6183e-13 trial_f 1.60466 accepted 0  lowest_f 7.13872e-25
# basinhopping step 389: f 4.6183e-13 trial_f 1.60556 accepted 0  lowest_f 7.13872e-25
# basinhopping step 390: f 4.6183e-13 trial_f 1.41729 accepted 0  lowest_f 7.13872e-25
# basinhopping step 391: f 0.34976 trial_f 0.34976 accepted 1  lowest_f 7.13872e-25
# basinhopping step 392: f 0.00518959 trial_f 0.00518959 accepted 1  lowest_f 7.13872e-25
# basinhopping step 393: f 4.05978e-17 trial_f 4.05978e-17 accepted 1  lowest_f 7.13872e-25
# basinhopping step 394: f 3.12322e-13 trial_f 3.12322e-13 accepted 1  lowest_f 7.13872e-25
# basinhopping step 395: f 0.0103556 trial_f 0.0103556 accepted 1  lowest_f 7.13872e-25
# basinhopping step 396: f 0.0103556 trial_f 0.940647 accepted 0  lowest_f 7.13872e-25
# basinhopping step 397: f 3.62564e-30 trial_f 3.62564e-30 accepted 1  lowest_f 3.62564e-30
# found new global minimum on step 397 with function value 3.62564e-30
# basinhopping step 398: f 0.0467966 trial_f 0.0467966 accepted 1  lowest_f 3.62564e-30
# basinhopping step 399: f 0.0467966 trial_f 16.3287 accepted 0  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.582500 target 0.500000 new stepsize 2.32306 old stepsize 2.09075
# basinhopping step 400: f 0.0467966 trial_f 1.60552 accepted 0  lowest_f 3.62564e-30
# basinhopping step 401: f 0.0467966 trial_f 0.453766 accepted 0  lowest_f 3.62564e-30
# basinhopping step 402: f 0.0467966 trial_f 13.7263 accepted 0  lowest_f 3.62564e-30
# basinhopping step 403: f 1.63628e-13 trial_f 1.63628e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 404: f 1.63628e-13 trial_f 1.41748 accepted 0  lowest_f 3.62564e-30
# basinhopping step 405: f 1.63628e-13 trial_f 1.60434 accepted 0  lowest_f 3.62564e-30
# basinhopping step 406: f 1.63628e-13 trial_f 1.27506 accepted 0  lowest_f 3.62564e-30
# basinhopping step 407: f 3.12922e-13 trial_f 3.12922e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 408: f 3.12922e-13 trial_f 1.7903e+06 accepted 0  lowest_f 3.62564e-30
# basinhopping step 409: f 3.12922e-13 trial_f 0.41948 accepted 0  lowest_f 3.62564e-30
# basinhopping step 410: f 3.12841e-13 trial_f 3.12841e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 411: f 0.0849409 trial_f 0.0849409 accepted 1  lowest_f 3.62564e-30
# basinhopping step 412: f 0.0849409 trial_f 9.23576 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 413: f 0.0849409 trial_f 2.35834e-14 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 414: f 0.0849409 trial_f 2.82676e-14 accepted 0  lowest_f 3.62564e-30
# basinhopping step 415: f 0.0849409 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 416: f 0.0849409 trial_f 0.584419 accepted 0  lowest_f 3.62564e-30
# basinhopping step 417: f 0.0849409 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 418: f 0.0849409 trial_f 2.04839e-14 accepted 0  lowest_f 3.62564e-30
# basinhopping step 419: f 0.0849409 trial_f 1.41715 accepted 0  lowest_f 3.62564e-30
# basinhopping step 420: f 0.0849409 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 421: f 0.0849409 trial_f 2.19247e-14 accepted 0  lowest_f 3.62564e-30
# basinhopping step 422: f 0.0148391 trial_f 0.0148391 accepted 1  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 423: f 0.0148391 trial_f 2.8086e-17 accepted 0  lowest_f 3.62564e-30
# basinhopping step 424: f 0.0148391 trial_f 15.4288 accepted 0  lowest_f 3.62564e-30
# basinhopping step 425: f 0.0148391 trial_f 1.41749 accepted 0  lowest_f 3.62564e-30
# basinhopping step 426: f 0.0148391 trial_f 0.568564 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 427: f 0.0148391 trial_f 3.31587e-17 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 428: f 0.0148391 trial_f 1.42112e-16 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 429: f 0.0148391 trial_f 2.36379e-17 accepted 0  lowest_f 3.62564e-30
# basinhopping step 430: f 0.0240007 trial_f 0.0240007 accepted 1  lowest_f 3.62564e-30
# basinhopping step 431: f 1.29577e-14 trial_f 1.29577e-14 accepted 1  lowest_f 3.62564e-30
# basinhopping step 432: f 3.12374e-13 trial_f 3.12374e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 433: f 3.12374e-13 trial_f 260636 accepted 0  lowest_f 3.62564e-30
# basinhopping step 434: f 3.12751e-13 trial_f 3.12751e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 435: f 0.0127145 trial_f 0.0127145 accepted 1  lowest_f 3.62564e-30
# basinhopping step 436: f 1.66229e-13 trial_f 1.66229e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 437: f 2.26772e-13 trial_f 2.26772e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 438: f 2.26772e-13 trial_f 89228.3 accepted 0  lowest_f 3.62564e-30
# basinhopping step 439: f 3.1227e-13 trial_f 3.1227e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 440: f 3.1227e-13 trial_f 0.0628097 accepted 0  lowest_f 3.62564e-30
# basinhopping step 441: f 0.0496864 trial_f 0.0496864 accepted 1  lowest_f 3.62564e-30
# basinhopping step 442: f 1.55534e-13 trial_f 1.55534e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 443: f 1.55534e-13 trial_f 22.7452 accepted 0  lowest_f 3.62564e-30
# basinhopping step 444: f 3.1298e-13 trial_f 3.1298e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 445: f 3.12567e-13 trial_f 3.12567e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 446: f 3.128e-13 trial_f 3.128e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 447: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 448: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 449: f 1.33042 trial_f 14.8941 accepted 0  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.562222 target 0.500000 new stepsize 2.58117 old stepsize 2.32306
# basinhopping step 450: f 1.41729 trial_f 1.41729 accepted 1  lowest_f 3.62564e-30
# basinhopping step 451: f 1.41729 trial_f 20.4227 accepted 0  lowest_f 3.62564e-30
# basinhopping step 452: f 5.96623e-19 trial_f 5.96623e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 453: f 3.12495e-13 trial_f 3.12495e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 454: f 3.12307e-13 trial_f 3.12307e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 455: f 0.0524044 trial_f 0.0524044 accepted 1  lowest_f 3.62564e-30
# basinhopping step 456: f 0.0524044 trial_f 1.41742 accepted 0  lowest_f 3.62564e-30
# basinhopping step 457: f 1.51148e-13 trial_f 1.51148e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 458: f 3.12835e-13 trial_f 3.12835e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 459: f 5.125e-12 trial_f 5.125e-12 accepted 1  lowest_f 3.62564e-30
# basinhopping step 460: f 5.125e-12 trial_f 0.456621 accepted 0  lowest_f 3.62564e-30
# basinhopping step 461: f 5.125e-12 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 462: f 5.125e-12 trial_f 8.06667e-06 accepted 0  lowest_f 3.62564e-30
# basinhopping step 463: f 5.125e-12 trial_f 22.1654 accepted 0  lowest_f 3.62564e-30
# basinhopping step 464: f 0.199678 trial_f 0.199678 accepted 1  lowest_f 3.62564e-30
# basinhopping step 465: f 2.52066e-16 trial_f 2.52066e-16 accepted 1  lowest_f 3.62564e-30
# basinhopping step 466: f 2.52066e-16 trial_f 1.41732 accepted 0  lowest_f 3.62564e-30
# basinhopping step 467: f 3.12223e-13 trial_f 3.12223e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 468: f 3.12223e-13 trial_f 1.41707 accepted 0  lowest_f 3.62564e-30
# basinhopping step 469: f 3.12609e-13 trial_f 3.12609e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 470: f 3.12585e-13 trial_f 3.12585e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 471: f 3.12912e-13 trial_f 3.12912e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 472: f 3.12912e-13 trial_f 0.415992 accepted 0  lowest_f 3.62564e-30
# basinhopping step 473: f 3.12442e-13 trial_f 3.12442e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 474: f 3.12315e-13 trial_f 3.12315e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 475: f 3.12537e-13 trial_f 3.12537e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 476: f 3.13004e-13 trial_f 3.13004e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 477: f 3.13033e-13 trial_f 3.13033e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 478: f 3.13033e-13 trial_f 1.60548 accepted 0  lowest_f 3.62564e-30
# basinhopping step 479: f 3.12436e-13 trial_f 3.12436e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 480: f 3.12866e-13 trial_f 3.12866e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 481: f 0.533867 trial_f 0.533867 accepted 1  lowest_f 3.62564e-30
# basinhopping step 482: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 483: f 1.41568 trial_f 1.41568 accepted 1  lowest_f 3.62564e-30
# basinhopping step 484: f 5.97369e-19 trial_f 5.97369e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 485: f 5.97369e-19 trial_f 1.60466 accepted 0  lowest_f 3.62564e-30
# basinhopping step 486: f 5.97369e-19 trial_f 0.0812902 accepted 0  lowest_f 3.62564e-30
# basinhopping step 487: f 5.97369e-19 trial_f 1.6172 accepted 0  lowest_f 3.62564e-30
# basinhopping step 488: f 5.97369e-19 trial_f 19.1726 accepted 0  lowest_f 3.62564e-30
# basinhopping step 489: f 5.97369e-19 trial_f 1.41728 accepted 0  lowest_f 3.62564e-30
# basinhopping step 490: f 5.97369e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 491: f 5.97369e-19 trial_f 0.224875 accepted 0  lowest_f 3.62564e-30
# basinhopping step 492: f 3.1285e-13 trial_f 3.1285e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 493: f 3.12754e-13 trial_f 3.12754e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 494: f 0.413647 trial_f 0.413647 accepted 1  lowest_f 3.62564e-30
# basinhopping step 495: f 6.12292e-19 trial_f 6.12292e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 496: f 3.12323e-13 trial_f 3.12323e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 497: f 3.12566e-13 trial_f 3.12566e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 498: f 3.12489e-13 trial_f 3.12489e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 499: f 0.011071 trial_f 0.011071 accepted 1  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.572000 target 0.500000 new stepsize 2.86797 old stepsize 2.58117
# basinhopping step 500: f 1.46493e-16 trial_f 1.46493e-16 accepted 1  lowest_f 3.62564e-30
# basinhopping step 501: f 1.46493e-16 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 502: f 3.1299e-13 trial_f 3.1299e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 503: f 3.12294e-13 trial_f 3.12294e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 504: f 3.12294e-13 trial_f 1.60384 accepted 0  lowest_f 3.62564e-30
# basinhopping step 505: f 3.12829e-13 trial_f 3.12829e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 506: f 3.12226e-13 trial_f 3.12226e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 507: f 3.12871e-13 trial_f 3.12871e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 508: f 3.12871e-13 trial_f 1.41743 accepted 0  lowest_f 3.62564e-30
# basinhopping step 509: f 3.12871e-13 trial_f 1.41718 accepted 0  lowest_f 3.62564e-30
# basinhopping step 510: f 3.12571e-13 trial_f 3.12571e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 511: f 0.0245968 trial_f 0.0245968 accepted 1  lowest_f 3.62564e-30
# basinhopping step 512: f 3.78632e-14 trial_f 3.78632e-14 accepted 1  lowest_f 3.62564e-30
# basinhopping step 513: f 3.78632e-14 trial_f 1.60373 accepted 0  lowest_f 3.62564e-30
# basinhopping step 514: f 0.0861895 trial_f 0.0861895 accepted 1  lowest_f 3.62564e-30
# basinhopping step 515: f 0.0861895 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 516: f 2.4045e-12 trial_f 2.4045e-12 accepted 1  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 517: f 2.4045e-12 trial_f 8.32201e-06 accepted 0  lowest_f 3.62564e-30
# ...
# basinhopping step 825: f 3.12295e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 826: f 3.12529e-13 trial_f 3.12529e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 827: f 3.12236e-13 trial_f 3.12236e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 828: f 3.12236e-13 trial_f 1.41723 accepted 0  lowest_f 3.62564e-30
# basinhopping step 829: f 3.12236e-13 trial_f 2.08192 accepted 0  lowest_f 3.62564e-30
# basinhopping step 830: f 3.12236e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 831: f 3.12065e-13 trial_f 3.12065e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 832: f 3.13503e-13 trial_f 3.13503e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 833: f 3.13217e-13 trial_f 3.13217e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 834: f 3.13217e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 835: f 3.12403e-13 trial_f 3.12403e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 836: f 3.12403e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 837: f 3.1295e-13 trial_f 3.1295e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 838: f 0.0119667 trial_f 0.0119667 accepted 1  lowest_f 3.62564e-30
# basinhopping step 839: f 3.43827e-19 trial_f 3.43827e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 840: f 3.43827e-19 trial_f 1.41729 accepted 0  lowest_f 3.62564e-30
# basinhopping step 841: f 3.43827e-19 trial_f 1.41718 accepted 0  lowest_f 3.62564e-30
# basinhopping step 842: f 3.12644e-13 trial_f 3.12644e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 843: f 3.12644e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 844: f 3.12249e-13 trial_f 3.12249e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 845: f 3.13136e-13 trial_f 3.13136e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 846: f 3.13136e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 847: f 3.13393e-13 trial_f 3.13393e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 848: f 3.13393e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 849: f 3.12962e-13 trial_f 3.12962e-13 accepted 1  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.541176 target 0.500000 new stepsize 5.99622 old stepsize 5.3966
# basinhopping step 850: f 3.12244e-13 trial_f 3.12244e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 851: f 3.12244e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 852: f 3.12244e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 853: f 3.12671e-13 trial_f 3.12671e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 854: f 3.12671e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 855: f 3.12585e-13 trial_f 3.12585e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 856: f 3.1314e-13 trial_f 3.1314e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 857: f 3.1314e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 858: f 3.1314e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 859: f 3.12188e-13 trial_f 3.12188e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 860: f 3.1214e-13 trial_f 3.1214e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 861: f 3.13536e-13 trial_f 3.13536e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 862: f 3.13536e-13 trial_f 1.35766 accepted 0  lowest_f 3.62564e-30
# basinhopping step 863: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 864: f 5.94706e-19 trial_f 5.94706e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 865: f 5.94706e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 866: f 5.94706e-19 trial_f 1.6031 accepted 0  lowest_f 3.62564e-30
# basinhopping step 867: f 3.11995e-13 trial_f 3.11995e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 868: f 3.11816e-13 trial_f 3.11816e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 869: f 3.13439e-13 trial_f 3.13439e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 870: f 3.1188e-13 trial_f 3.1188e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 871: f 3.1188e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 872: f 3.13478e-13 trial_f 3.13478e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 873: f 3.13478e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 874: f 3.13478e-13 trial_f 1.41926 accepted 0  lowest_f 3.62564e-30
# basinhopping step 875: f 0.0961519 trial_f 0.0961519 accepted 1  lowest_f 3.62564e-30
# basinhopping step 876: f 0.0961519 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 877: f 5.08788e-14 trial_f 5.08788e-14 accepted 1  lowest_f 3.62564e-30
# basinhopping step 878: f 5.08788e-14 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 879: f 3.13259e-13 trial_f 3.13259e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 880: f 5.23664e-10 trial_f 5.23664e-10 accepted 1  lowest_f 3.62564e-30
# basinhopping step 881: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 882: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 883: f 5.92526e-19 trial_f 5.92526e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 884: f 5.92526e-19 trial_f 1.41741 accepted 0  lowest_f 3.62564e-30
# basinhopping step 885: f 5.92526e-19 trial_f 1.60339 accepted 0  lowest_f 3.62564e-30
# basinhopping step 886: f 5.92526e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 887: f 5.92526e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 888: f 5.92526e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 889: f 5.92526e-19 trial_f 0.52794 accepted 0  lowest_f 3.62564e-30
# basinhopping step 890: f 3.12631e-13 trial_f 3.12631e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 891: f 3.12631e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 892: f 3.12933e-13 trial_f 3.12933e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 893: f 3.12933e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 894: f 3.12952e-13 trial_f 3.12952e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 895: f 3.12952e-13 trial_f 0.425628 accepted 0  lowest_f 3.62564e-30
# basinhopping step 896: f 3.12952e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 897: f 3.12952e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 898: f 3.1271e-13 trial_f 3.1271e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 899: f 3.1271e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.538889 target 0.500000 new stepsize 6.66246 old stepsize 5.99622
# basinhopping step 900: f 3.1271e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 901: f 3.12661e-13 trial_f 3.12661e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 902: f 3.12661e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 903: f 0.0300401 trial_f 0.0300401 accepted 1  lowest_f 3.62564e-30
# basinhopping step 904: f 5.90479e-14 trial_f 5.90479e-14 accepted 1  lowest_f 3.62564e-30
# basinhopping step 905: f 5.90479e-14 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 906: f 5.90479e-14 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 907: f 5.90479e-14 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 908: f 5.90479e-14 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 909: f 5.90479e-14 trial_f 1.60221 accepted 0  lowest_f 3.62564e-30
# basinhopping step 910: f 5.90479e-14 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 911: f 3.12416e-13 trial_f 3.12416e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 912: f 3.12416e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 913: f 3.12937e-13 trial_f 3.12937e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 914: f 3.13546e-13 trial_f 3.13546e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 915: f 3.12897e-13 trial_f 3.12897e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 916: f 3.12032e-13 trial_f 3.12032e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 917: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 918: f 5.95826e-19 trial_f 5.95826e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 919: f 3.11643e-13 trial_f 3.11643e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 920: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 921: f 5.95575e-19 trial_f 5.95575e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 922: f 5.95575e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 923: f 0.053164 trial_f 0.053164 accepted 1  lowest_f 3.62564e-30
# basinhopping step 924: f 0.053164 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 925: f 1.45354e-05 trial_f 1.45354e-05 accepted 1  lowest_f 3.62564e-30
# basinhopping step 926: f 4.51069e-13 trial_f 4.51069e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 927: f 3.11861e-13 trial_f 3.11861e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 928: f 3.12337e-13 trial_f 3.12337e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 929: f 3.12337e-13 trial_f 1.41495 accepted 0  lowest_f 3.62564e-30
# basinhopping step 930: f 3.12949e-13 trial_f 3.12949e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 931: f 3.13158e-13 trial_f 3.13158e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 932: f 3.13158e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 933: f 3.12052e-13 trial_f 3.12052e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 934: f 3.12052e-13 trial_f 1.4174 accepted 0  lowest_f 3.62564e-30
# basinhopping step 935: f 3.12052e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 936: f 3.12052e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 937: f 3.12052e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 938: f 3.13159e-13 trial_f 3.13159e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 939: f 3.13159e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 940: f 3.12069e-13 trial_f 3.12069e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 941: f 3.12253e-13 trial_f 3.12253e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 942: f 3.12253e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 943: f 3.1165e-13 trial_f 3.1165e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 944: f 0.811343 trial_f 0.811343 accepted 1  lowest_f 3.62564e-30
# basinhopping step 945: f 0.811343 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 946: f 0.436067 trial_f 0.436067 accepted 1  lowest_f 3.62564e-30
# basinhopping step 947: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 948: f 1.41717 trial_f 1.41717 accepted 1  lowest_f 3.62564e-30
# basinhopping step 949: f 5.92064e-19 trial_f 5.92064e-19 accepted 1  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.542105 target 0.500000 new stepsize 7.40274 old stepsize 6.66246
# basinhopping step 950: f 1.90398e-10 trial_f 1.90398e-10 accepted 1  lowest_f 3.62564e-30
# basinhopping step 951: f 5.63445e-13 trial_f 5.63445e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 952: f 3.1176e-13 trial_f 3.1176e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 953: f 3.11579e-13 trial_f 3.11579e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 954: f 3.13515e-13 trial_f 3.13515e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 955: f 3.12753e-13 trial_f 3.12753e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 956: f 3.12285e-13 trial_f 3.12285e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 957: f 3.12513e-13 trial_f 3.12513e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 958: f 3.12513e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 959: f 3.12513e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 960: f 3.13625e-13 trial_f 3.13625e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 961: f 3.13625e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 962: f 0.744422 trial_f 0.744422 accepted 1  lowest_f 3.62564e-30
# basinhopping step 963: f 0.744422 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 964: f 6.0155e-19 trial_f 6.0155e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 965: f 3.11621e-13 trial_f 3.11621e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 966: f 3.11621e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 967: f 3.11621e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 968: f 3.11621e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 969: f 3.11621e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 970: f 3.1378e-13 trial_f 3.1378e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 971: f 3.12969e-13 trial_f 3.12969e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 972: f 3.1219e-13 trial_f 3.1219e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 973: f 3.1326e-13 trial_f 3.1326e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 974: f 3.11528e-13 trial_f 3.11528e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 975: f 3.11528e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 976: f 3.12873e-13 trial_f 3.12873e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 977: f 3.12873e-13 trial_f 1.41738 accepted 0  lowest_f 3.62564e-30
# basinhopping step 978: f 3.11853e-13 trial_f 3.11853e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 979: f 5.80639e-11 trial_f 5.80639e-11 accepted 1  lowest_f 3.62564e-30
# basinhopping step 980: f 1.21809e-05 trial_f 1.21809e-05 accepted 1  lowest_f 3.62564e-30
# basinhopping step 981: f 1.21809e-05 trial_f 1.4173 accepted 0  lowest_f 3.62564e-30
# basinhopping step 982: f 3.02614e-13 trial_f 3.02614e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 983: f 3.02614e-13 trial_f 2.42192 accepted 0  lowest_f 3.62564e-30
# basinhopping step 984: f 3.02614e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 985: f 1.41738 trial_f 1.41738 accepted 1  lowest_f 3.62564e-30
# basinhopping step 986: f 1.99695e-12 trial_f 1.99695e-12 accepted 1  lowest_f 3.62564e-30
# basinhopping step 987: f 1.33042 trial_f 1.33042 accepted 1  lowest_f 3.62564e-30
# basinhopping step 988: f 5.94169e-19 trial_f 5.94169e-19 accepted 1  lowest_f 3.62564e-30
# basinhopping step 989: f 5.94169e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 990: f 5.94169e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 991: f 5.94169e-19 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 992: f 5.94169e-19 trial_f 1.41737 accepted 0  lowest_f 3.62564e-30
# basinhopping step 993: f 5.94169e-19 trial_f 1.41855 accepted 0  lowest_f 3.62564e-30
# basinhopping step 994: f 3.12389e-13 trial_f 3.12389e-13 accepted 1  lowest_f 3.62564e-30
# basinhopping step 995: f 3.12389e-13 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# basinhopping step 996: f 3.65343e-11 trial_f 3.65343e-11 accepted 1  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 997: f 3.65343e-11 trial_f 7.93688e-06 accepted 0  lowest_f 3.62564e-30
# basinhopping step 998: f 3.65343e-11 trial_f 1.33042 accepted 0  lowest_f 3.62564e-30
# warning: basinhopping: local minimization failure
# basinhopping step 999: f 3.65343e-11 trial_f 7.90071e-06 accepted 0  lowest_f 3.62564e-30
# adaptive stepsize: acceptance rate 0.543000 target 0.500000 new stepsize 8.22526 old stepsize 7.40274
# warning: basinhopping: local minimization failure
# basinhopping step 1000: f 3.65343e-11 trial_f 8.0646e-06 accepted 0  lowest_f 3.62564e-30

# %%
mu2, rho2, M2, P2 = result.x[0], result.x[1], result.x[2], result.x[3]
Q2 = M2/rho2
specific_speed_1 = N1*np.sqrt(M1/rho1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(M2/rho2)/(P2/(rho2*g))**(3/4)
print(f"Ns = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = P1 * M1 / rho1 / ( rho1 * N1**3 * D1**5)
power_coeff_2 = P2 * M2 / rho2 / ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff = 0.33
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Q1*P1/pump_eff/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Q1*P1/pump_eff/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Electrical Power = {Q1*P1/pump_eff/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Q2*P2/pump_eff/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Q2*P2/pump_eff/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Electrical Power = {Q2*P2/pump_eff/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns = 13.7895, Matching = 99.99999999999999 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031263792849786686, Matching = 99.99999999999993 %
# Head Coefficient Prototype = 0.001366148931251182, Model = 0.0013661489312511825, Matching = 99.99999999999997 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8462, Matching = 99.99999999999993 %
# Power Coefficient Prototype = 0.00000043, Model = 0.00000043, Matching = 99.99999999999994 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.400 Bar
# Prototype's Pressure Head is 68.259 m HAN+H2O2
# Prototype's Pressure Head is 68.259 m Testing Fluid
# Prototype's Pressure Head is 106.047 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 569.001 W
# Prototype's Shaft Power = 1741.662 W
# Prototype's Shaft Torque = 1.188 N-m
# Prototype's Electrical Power = 2049.014 W
#
#
# Model's Shaft Speed is 5000.000 RPM
# Model's Impeller Diameter is 60.000 mm
# Model's Mass Flow Rate is 0.399 Kg/s
# Model's Pressure Across Pump is 1.454 Bar
# Model's Pressure Head is 9.543 m HAN+H2O2
# Model's Pressure Head is 12.537 m Testing Fluid
# Model's Pressure Head is 14.827 m Water
# Model's Volumetric Flow Rate is 0.3376 L/s
# Model's Fluid's Viscosity is 25.4458 mPa-s
# Model's Fluid's Density is 1182.6001 kg/m^3
# Model's Hydraulic Power = 49.096 W
# Model's Shaft Power = 150.278 W
# Model's Shaft Torque = 0.287 N-m
# Model's Electrical Power = 176.797 W
