# %%
import numpy as np
import scipy as sp
import math
# Define known parameters
rho1 = 1553.6; mu1 = 65e-3; N1 = 14000; D1 = 50e-3; M1 = 0.85; P1 = 10.4e5
#rho2 = 1000; mu2 = 10e-3
N2 = 8000; D2 = 50e-3
g = 9.807  # Acceleration due to gravity in m/s^2

Q1 = M1/rho1

# Define lower and upper bounds for mu, rho, m_dot, pressure rise
lb = [1e-3, 900, 0.1, 1e5]  # Lower bounds
ub = [65e-3, 1000, 1.0, 3e5]  # Upper bounds
bounds = [(low, high) for low, high in zip(lb, ub)]
#np.random.seed(100)

# Define the objective function (sum of squared residuals)
def pump_equations(x):
    mu2, rho2, M2, P2 = x
    
    # Specific speed equation residual
    F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
    
    # Flow coefficient equation residual
    F2 = ( M1/rho1 / (N1 * D1**3)) - (M2/rho2 / (N2 * D2**3))
    
    # Head coefficient equation residual
    F3 = ( P1/rho1 / (N1**2 * D1**2)) - ( P2/rho2 / (N2**2 * D2**2))
    
    # Reynolds number equation residual
    F4 = (M1/mu1 / D1) - (M2/mu2 / D2)
    
    # Power Coefficient (based on hydraulic power)
    F5 = ( P1 * M1/rho1 / ( rho1 * N1**3 * D1**5) ) - ( P2 * M2/rho2 / ( rho2 * N2**3 * D2**5) )
    
    # Sum of squared residuals
    #return F1**2 + F2**2 + F3**2 + F4**2
    return [F1, F2, F3, F4, F5]

# Normalization function for better scaling
def normalize_residuals(residuals):
    # Scale each residual by a factor that brings them into a similar range
    scales = [1.0, 1.0e-3, 1.0e-3, 1, 1.0e3]  # Example scales, adjust as needed
    return [residuals[i] / scales[i] for i in range(len(residuals))]

# Objective function for minimization (sum of squares of normalized residuals)
def objective_function(x):
    residuals = pump_equations(x)
    normalized_residuals = normalize_residuals(residuals)
    return sum([r**2 for r in normalized_residuals])


# Initial guesses for unknowns
x0 = np.array([30e-3, 1000, 0.4, 2e5])

# Perform optimization using 'SLSQP' (Sequential Least Squares Programming)
#result = sp.optimize.minimize(objective_function, x0, bounds=bounds, method='trust-constr', options={'disp': True, 'maxiter': 10000, 'xtol': 1e-16, 'gtol': 1e-16})
#result = sp.optimize.differential_evolution(objective_function, bounds, disp = True, popsize=300, tol = 1e-16, maxiter = 1000)
#result = sp.optimize.root(pump_equations, x0, method='trust-constr', bounds=bounds, options={'xtol': 1e-10, 'maxiter': 2000})

# Perform global optimization using basinhopping
# Basin Hopping Methods: Powell
result = sp.optimize.basinhopping(objective_function,x0=x0,minimizer_kwargs={"method": "Powell", "bounds": bounds},niter=1000,T=0.5,stepsize=1,disp=True)
# Out:
# basinhopping step 0: f 0.0659752
# basinhopping step 1: f 0.0659752 trial_f 1.85249 accepted 0  lowest_f 0.0659752
# basinhopping step 2: f 0.0813993 trial_f 0.0813993 accepted 1  lowest_f 0.0659752
# basinhopping step 3: f 0.00149179 trial_f 0.00149179 accepted 1  lowest_f 0.00149179
# found new global minimum on step 3 with function value 0.00149179
# basinhopping step 4: f 0.0064993 trial_f 0.0064993 accepted 1  lowest_f 0.00149179
# basinhopping step 5: f 0.0064993 trial_f 3.04106 accepted 0  lowest_f 0.00149179
# basinhopping step 6: f 0.0064993 trial_f 0.3334 accepted 0  lowest_f 0.00149179
# basinhopping step 7: f 0.156202 trial_f 0.156202 accepted 1  lowest_f 0.00149179
# basinhopping step 8: f 0.00592625 trial_f 0.00592625 accepted 1  lowest_f 0.00149179
# basinhopping step 9: f 0.00373929 trial_f 0.00373929 accepted 1  lowest_f 0.00149179
# basinhopping step 10: f 0.00373929 trial_f 14.3695 accepted 0  lowest_f 0.00149179
# basinhopping step 11: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.00149179
# basinhopping step 12: f 0.123652 trial_f 0.123652 accepted 1  lowest_f 0.00149179
# basinhopping step 13: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 0.00149179
# basinhopping step 14: f 0.00373874 trial_f 1.18365 accepted 0  lowest_f 0.00149179
# basinhopping step 15: f 0.00373874 trial_f 2.40607 accepted 0  lowest_f 0.00149179
# basinhopping step 16: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.00149179
# basinhopping step 17: f 0.00373931 trial_f 0.0350312 accepted 0  lowest_f 0.00149179
# basinhopping step 18: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.00149179
# basinhopping step 19: f 0.000195984 trial_f 0.000195984 accepted 1  lowest_f 0.000195984
# found new global minimum on step 19 with function value 0.000195984
# basinhopping step 20: f 0.0473323 trial_f 0.0473323 accepted 1  lowest_f 0.000195984
# basinhopping step 21: f 0.0473323 trial_f 14.37 accepted 0  lowest_f 0.000195984
# basinhopping step 22: f 0.0473323 trial_f 14.3706 accepted 0  lowest_f 0.000195984
# basinhopping step 23: f 0.0473323 trial_f 8.76508 accepted 0  lowest_f 0.000195984
# basinhopping step 24: f 0.0473323 trial_f 14.3508 accepted 0  lowest_f 0.000195984
# basinhopping step 25: f 0.0473323 trial_f 6.01414 accepted 0  lowest_f 0.000195984
# basinhopping step 26: f 0.433122 trial_f 0.433122 accepted 1  lowest_f 0.000195984
# basinhopping step 27: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 0.000195984
# basinhopping step 28: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.000195984
# basinhopping step 29: f 0.00373931 trial_f 12.3999 accepted 0  lowest_f 0.000195984
# basinhopping step 30: f 0.600566 trial_f 0.600566 accepted 1  lowest_f 0.000195984
# basinhopping step 31: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 0.000195984
# basinhopping step 32: f 0.00373874 trial_f 0.229458 accepted 0  lowest_f 0.000195984
# basinhopping step 33: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.000195984
# basinhopping step 34: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.000195984
# basinhopping step 35: f 0.00945194 trial_f 0.00945194 accepted 1  lowest_f 0.000195984
# basinhopping step 36: f 0.0037047 trial_f 0.0037047 accepted 1  lowest_f 0.000195984
# basinhopping step 37: f 0.0037047 trial_f 6.16336 accepted 0  lowest_f 0.000195984
# basinhopping step 38: f 0.0037047 trial_f 0.0644639 accepted 0  lowest_f 0.000195984
# basinhopping step 39: f 0.179938 trial_f 0.179938 accepted 1  lowest_f 0.000195984
# C:\Users\Krai\AppData\Local\Temp\ipykernel_49388\1053404582.py:23: RuntimeWarning: invalid value encountered in sqrt
#   F1 = (N1 * np.sqrt(M1/rho1) / (P1/(rho1 * g))**(3/4)) - (N2 * np.sqrt(M2/rho2) / (P2/(rho2 * g))**(3/4))
# basinhopping step 40: f 0.179938 trial_f 14.3871 accepted 0  lowest_f 0.000195984
# basinhopping step 41: f 0.279004 trial_f 0.279004 accepted 1  lowest_f 0.000195984
# basinhopping step 42: f 0.263643 trial_f 0.263643 accepted 1  lowest_f 0.000195984
# basinhopping step 43: f 0.0037147 trial_f 0.0037147 accepted 1  lowest_f 0.000195984
# basinhopping step 44: f 0.0037147 trial_f 14.3875 accepted 0  lowest_f 0.000195984
# basinhopping step 45: f 0.0037147 trial_f 0.119321 accepted 0  lowest_f 0.000195984
# basinhopping step 46: f 0.0037147 trial_f 14.3559 accepted 0  lowest_f 0.000195984
# basinhopping step 47: f 0.00373928 trial_f 0.00373928 accepted 1  lowest_f 0.000195984
# basinhopping step 48: f 0.00373928 trial_f 3.65028 accepted 0  lowest_f 0.000195984
# basinhopping step 49: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.000195984
# adaptive stepsize: acceptance rate 0.560000 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 50: f 0.00373931 trial_f 2.38809 accepted 0  lowest_f 0.000195984
# basinhopping step 51: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 0.000195984
# basinhopping step 52: f 0.00373931 trial_f 3.07719 accepted 0  lowest_f 0.000195984
# basinhopping step 53: f 0.00373931 trial_f 0.510152 accepted 0  lowest_f 0.000195984
# basinhopping step 54: f 0.00373931 trial_f 14.3739 accepted 0  lowest_f 0.000195984
# basinhopping step 55: f 0.00373931 trial_f 0.885943 accepted 0  lowest_f 0.000195984
# basinhopping step 56: f 0.00373931 trial_f 1.40463 accepted 0  lowest_f 0.000195984
# basinhopping step 57: f 0.107118 trial_f 0.107118 accepted 1  lowest_f 0.000195984
# basinhopping step 58: f 0.107118 trial_f 2.74873e+06 accepted 0  lowest_f 0.000195984
# basinhopping step 59: f 2.68586e-12 trial_f 2.68586e-12 accepted 1  lowest_f 2.68586e-12
# found new global minimum on step 59 with function value 2.68586e-12
# basinhopping step 60: f 2.68586e-12 trial_f 2.38145 accepted 0  lowest_f 2.68586e-12
# basinhopping step 61: f 0.00373878 trial_f 0.00373878 accepted 1  lowest_f 2.68586e-12
# basinhopping step 62: f 0.00373878 trial_f 1.57925 accepted 0  lowest_f 2.68586e-12
# basinhopping step 63: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 64: f 0.00373931 trial_f 14.3873 accepted 0  lowest_f 2.68586e-12
# basinhopping step 65: f 0.00373931 trial_f 2.09271 accepted 0  lowest_f 2.68586e-12
# basinhopping step 66: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 67: f 0.00373931 trial_f 2.38754 accepted 0  lowest_f 2.68586e-12
# basinhopping step 68: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 69: f 0.00373931 trial_f 0.351436 accepted 0  lowest_f 2.68586e-12
# basinhopping step 70: f 0.00373931 trial_f 2.40806 accepted 0  lowest_f 2.68586e-12
# basinhopping step 71: f 0.00373931 trial_f 3.50553 accepted 0  lowest_f 2.68586e-12
# basinhopping step 72: f 0.00373931 trial_f 14.3873 accepted 0  lowest_f 2.68586e-12
# basinhopping step 73: f 0.00373931 trial_f 1.49064 accepted 0  lowest_f 2.68586e-12
# basinhopping step 74: f 0.00373931 trial_f 14.3705 accepted 0  lowest_f 2.68586e-12
# basinhopping step 75: f 0.358923 trial_f 0.358923 accepted 1  lowest_f 2.68586e-12
# basinhopping step 76: f 0.00367184 trial_f 0.00367184 accepted 1  lowest_f 2.68586e-12
# basinhopping step 77: f 0.00367184 trial_f 0.510708 accepted 0  lowest_f 2.68586e-12
# basinhopping step 78: f 0.00367184 trial_f 2.01255 accepted 0  lowest_f 2.68586e-12
# basinhopping step 79: f 0.102429 trial_f 0.102429 accepted 1  lowest_f 2.68586e-12
# basinhopping step 80: f 0.102429 trial_f 14.3687 accepted 0  lowest_f 2.68586e-12
# basinhopping step 81: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.68586e-12
# basinhopping step 82: f 0.0687537 trial_f 0.0687537 accepted 1  lowest_f 2.68586e-12
# basinhopping step 83: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.68586e-12
# basinhopping step 84: f 0.00373874 trial_f 2.3683 accepted 0  lowest_f 2.68586e-12
# basinhopping step 85: f 0.00373874 trial_f 0.235888 accepted 0  lowest_f 2.68586e-12
# basinhopping step 86: f 0.00373874 trial_f 12.018 accepted 0  lowest_f 2.68586e-12
# basinhopping step 87: f 0.00373874 trial_f 2.0054 accepted 0  lowest_f 2.68586e-12
# basinhopping step 88: f 0.00373874 trial_f 2.38097 accepted 0  lowest_f 2.68586e-12
# basinhopping step 89: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 90: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 91: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 92: f 0.00373931 trial_f 1.40013 accepted 0  lowest_f 2.68586e-12
# basinhopping step 93: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 94: f 0.00373931 trial_f 2.40671 accepted 0  lowest_f 2.68586e-12
# basinhopping step 95: f 0.00373931 trial_f 4.22347 accepted 0  lowest_f 2.68586e-12
# basinhopping step 96: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 97: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 98: f 0.281603 trial_f 0.281603 accepted 1  lowest_f 2.68586e-12
# basinhopping step 99: f 0.281603 trial_f 14.233 accepted 0  lowest_f 2.68586e-12
# adaptive stepsize: acceptance rate 0.480000 target 0.500000 new stepsize 1 old stepsize 1.11111
# basinhopping step 100: f 0.281603 trial_f 14.323 accepted 0  lowest_f 2.68586e-12
# basinhopping step 101: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.68586e-12
# basinhopping step 102: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 103: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 104: f 0.00373931 trial_f 14.3034 accepted 0  lowest_f 2.68586e-12
# basinhopping step 105: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 106: f 0.00373931 trial_f 0.338592 accepted 0  lowest_f 2.68586e-12
# basinhopping step 107: f 0.00373931 trial_f 0.61795 accepted 0  lowest_f 2.68586e-12
# basinhopping step 108: f 0.0271203 trial_f 0.0271203 accepted 1  lowest_f 2.68586e-12
# basinhopping step 109: f 0.32362 trial_f 0.32362 accepted 1  lowest_f 2.68586e-12
# basinhopping step 110: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.68586e-12
# basinhopping step 111: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 112: f 0.00373931 trial_f 2.36172 accepted 0  lowest_f 2.68586e-12
# basinhopping step 113: f 0.0394159 trial_f 0.0394159 accepted 1  lowest_f 2.68586e-12
# basinhopping step 114: f 0.00370485 trial_f 0.00370485 accepted 1  lowest_f 2.68586e-12
# basinhopping step 115: f 0.0124383 trial_f 0.0124383 accepted 1  lowest_f 2.68586e-12
# basinhopping step 116: f 0.00370528 trial_f 0.00370528 accepted 1  lowest_f 2.68586e-12
# basinhopping step 117: f 0.00370528 trial_f 2.33703 accepted 0  lowest_f 2.68586e-12
# basinhopping step 118: f 0.00370528 trial_f 2.37303 accepted 0  lowest_f 2.68586e-12
# basinhopping step 119: f 0.00952596 trial_f 0.00952596 accepted 1  lowest_f 2.68586e-12
# basinhopping step 120: f 0.00388414 trial_f 0.00388414 accepted 1  lowest_f 2.68586e-12
# basinhopping step 121: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 122: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 123: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 124: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.68586e-12
# basinhopping step 125: f 0.00373931 trial_f 0.23337 accepted 0  lowest_f 2.68586e-12
# basinhopping step 126: f 0.0555804 trial_f 0.0555804 accepted 1  lowest_f 2.68586e-12
# basinhopping step 127: f 0.00370779 trial_f 0.00370779 accepted 1  lowest_f 2.68586e-12
# basinhopping step 128: f 0.00370779 trial_f 11.0733 accepted 0  lowest_f 2.68586e-12
# basinhopping step 129: f 2.48439e-14 trial_f 2.48439e-14 accepted 1  lowest_f 2.48439e-14
# found new global minimum on step 129 with function value 2.48439e-14
# basinhopping step 130: f 2.48439e-14 trial_f 14.3915 accepted 0  lowest_f 2.48439e-14
# basinhopping step 131: f 2.48439e-14 trial_f 14.3619 accepted 0  lowest_f 2.48439e-14
# basinhopping step 132: f 2.48439e-14 trial_f 4.01208 accepted 0  lowest_f 2.48439e-14
# basinhopping step 133: f 0.00373878 trial_f 0.00373878 accepted 1  lowest_f 2.48439e-14
# basinhopping step 134: f 0.00373878 trial_f 14.3911 accepted 0  lowest_f 2.48439e-14
# basinhopping step 135: f 0.00373878 trial_f 1.69925 accepted 0  lowest_f 2.48439e-14
# basinhopping step 136: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 137: f 0.00373931 trial_f 2.37445 accepted 0  lowest_f 2.48439e-14
# basinhopping step 138: f 0.000469821 trial_f 0.000469821 accepted 1  lowest_f 2.48439e-14
# basinhopping step 139: f 0.000469821 trial_f 14.3883 accepted 0  lowest_f 2.48439e-14
# basinhopping step 140: f 0.000469821 trial_f 2.38666 accepted 0  lowest_f 2.48439e-14
# basinhopping step 141: f 0.000469821 trial_f 0.508341 accepted 0  lowest_f 2.48439e-14
# basinhopping step 142: f 0.000469821 trial_f 2.37436 accepted 0  lowest_f 2.48439e-14
# basinhopping step 143: f 0.000469821 trial_f 1.6777 accepted 0  lowest_f 2.48439e-14
# basinhopping step 144: f 0.000469821 trial_f 2.74875e+06 accepted 0  lowest_f 2.48439e-14
# basinhopping step 145: f 0.000469821 trial_f 14.3763 accepted 0  lowest_f 2.48439e-14
# basinhopping step 146: f 0.003739 trial_f 0.003739 accepted 1  lowest_f 2.48439e-14
# basinhopping step 147: f 0.0357193 trial_f 0.0357193 accepted 1  lowest_f 2.48439e-14
# basinhopping step 148: f 0.00370466 trial_f 0.00370466 accepted 1  lowest_f 2.48439e-14
# basinhopping step 149: f 0.411303 trial_f 0.411303 accepted 1  lowest_f 2.48439e-14
# adaptive stepsize: acceptance rate 0.506667 target 0.500000 new stepsize 1.11111 old stepsize 1
# basinhopping step 150: f 0.227431 trial_f 0.227431 accepted 1  lowest_f 2.48439e-14
# basinhopping step 151: f 5.19663e-13 trial_f 5.19663e-13 accepted 1  lowest_f 2.48439e-14
# basinhopping step 152: f 0.264015 trial_f 0.264015 accepted 1  lowest_f 2.48439e-14
# basinhopping step 153: f 0.108897 trial_f 0.108897 accepted 1  lowest_f 2.48439e-14
# basinhopping step 154: f 0.108897 trial_f 14.3644 accepted 0  lowest_f 2.48439e-14
# basinhopping step 155: f 0.108897 trial_f 121180 accepted 0  lowest_f 2.48439e-14
# basinhopping step 156: f 0.108897 trial_f 6.75868 accepted 0  lowest_f 2.48439e-14
# basinhopping step 157: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.48439e-14
# basinhopping step 158: f 0.112059 trial_f 0.112059 accepted 1  lowest_f 2.48439e-14
# basinhopping step 159: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.48439e-14
# basinhopping step 160: f 0.00373874 trial_f 3.37566 accepted 0  lowest_f 2.48439e-14
# basinhopping step 161: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 162: f 0.0910846 trial_f 0.0910846 accepted 1  lowest_f 2.48439e-14
# basinhopping step 163: f 0.0910846 trial_f 14.3656 accepted 0  lowest_f 2.48439e-14
# basinhopping step 164: f 0.0910846 trial_f 14.3328 accepted 0  lowest_f 2.48439e-14
# basinhopping step 165: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 2.48439e-14
# basinhopping step 166: f 0.00946699 trial_f 0.00946699 accepted 1  lowest_f 2.48439e-14
# basinhopping step 167: f 0.00946699 trial_f 14.3711 accepted 0  lowest_f 2.48439e-14
# basinhopping step 168: f 0.00444481 trial_f 0.00444481 accepted 1  lowest_f 2.48439e-14
# basinhopping step 169: f 0.00444481 trial_f 12.8993 accepted 0  lowest_f 2.48439e-14
# basinhopping step 170: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 171: f 0.00373931 trial_f 0.395068 accepted 0  lowest_f 2.48439e-14
# basinhopping step 172: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 173: f 0.00373931 trial_f 14.3798 accepted 0  lowest_f 2.48439e-14
# basinhopping step 174: f 0.00373931 trial_f 0.510708 accepted 0  lowest_f 2.48439e-14
# basinhopping step 175: f 0.00373931 trial_f 14.3869 accepted 0  lowest_f 2.48439e-14
# basinhopping step 176: f 0.00373931 trial_f 14.387 accepted 0  lowest_f 2.48439e-14
# basinhopping step 177: f 0.314923 trial_f 0.314923 accepted 1  lowest_f 2.48439e-14
# basinhopping step 178: f 0.00370013 trial_f 0.00370013 accepted 1  lowest_f 2.48439e-14
# basinhopping step 179: f 0.00373928 trial_f 0.00373928 accepted 1  lowest_f 2.48439e-14
# basinhopping step 180: f 0.00373928 trial_f 0.0890391 accepted 0  lowest_f 2.48439e-14
# basinhopping step 181: f 0.00373928 trial_f 14.3878 accepted 0  lowest_f 2.48439e-14
# basinhopping step 182: f 0.00373928 trial_f 14.3048 accepted 0  lowest_f 2.48439e-14
# basinhopping step 183: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 184: f 0.00373931 trial_f 2.27837 accepted 0  lowest_f 2.48439e-14
# basinhopping step 185: f 0.00373931 trial_f 2.35999 accepted 0  lowest_f 2.48439e-14
# basinhopping step 186: f 0.0109782 trial_f 0.0109782 accepted 1  lowest_f 2.48439e-14
# basinhopping step 187: f 0.0037047 trial_f 0.0037047 accepted 1  lowest_f 2.48439e-14
# basinhopping step 188: f 0.0037047 trial_f 14.3872 accepted 0  lowest_f 2.48439e-14
# basinhopping step 189: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 190: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 191: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 192: f 0.00373931 trial_f 14.375 accepted 0  lowest_f 2.48439e-14
# basinhopping step 193: f 0.242181 trial_f 0.242181 accepted 1  lowest_f 2.48439e-14
# basinhopping step 194: f 0.00371037 trial_f 0.00371037 accepted 1  lowest_f 2.48439e-14
# basinhopping step 195: f 0.00373928 trial_f 0.00373928 accepted 1  lowest_f 2.48439e-14
# basinhopping step 196: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 197: f 0.00373931 trial_f 2.34531 accepted 0  lowest_f 2.48439e-14
# basinhopping step 198: f 0.00373931 trial_f 2.32377 accepted 0  lowest_f 2.48439e-14
# basinhopping step 199: f 0.00373931 trial_f 14.3053 accepted 0  lowest_f 2.48439e-14
# adaptive stepsize: acceptance rate 0.515000 target 0.500000 new stepsize 1.23457 old stepsize 1.11111
# basinhopping step 200: f 0.00373931 trial_f 1.11244e+06 accepted 0  lowest_f 2.48439e-14
# basinhopping step 201: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 202: f 0.00373931 trial_f 2.39176 accepted 0  lowest_f 2.48439e-14
# basinhopping step 203: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 204: f 0.00373931 trial_f 2.03014 accepted 0  lowest_f 2.48439e-14
# basinhopping step 205: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 206: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 2.48439e-14
# basinhopping step 207: f 0.00373931 trial_f 892842 accepted 0  lowest_f 2.48439e-14
# basinhopping step 208: f 1.99974e-15 trial_f 1.99974e-15 accepted 1  lowest_f 1.99974e-15
# found new global minimum on step 208 with function value 1.99974e-15
# basinhopping step 209: f 1.99974e-15 trial_f 9.49736 accepted 0  lowest_f 1.99974e-15
# basinhopping step 210: f 0.00373873 trial_f 0.00373873 accepted 1  lowest_f 1.99974e-15
# basinhopping step 211: f 0.00373873 trial_f 1.65398 accepted 0  lowest_f 1.99974e-15
# basinhopping step 212: f 0.00373873 trial_f 14.3061 accepted 0  lowest_f 1.99974e-15
# basinhopping step 213: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 214: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 215: f 0.00373931 trial_f 14.3871 accepted 0  lowest_f 1.99974e-15
# basinhopping step 216: f 0.00373931 trial_f 14.3059 accepted 0  lowest_f 1.99974e-15
# basinhopping step 217: f 0.00373931 trial_f 2.41417 accepted 0  lowest_f 1.99974e-15
# basinhopping step 218: f 0.00373931 trial_f 0.634328 accepted 0  lowest_f 1.99974e-15
# basinhopping step 219: f 0.00373931 trial_f 1.19217 accepted 0  lowest_f 1.99974e-15
# basinhopping step 220: f 0.00373931 trial_f 0.384766 accepted 0  lowest_f 1.99974e-15
# basinhopping step 221: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 222: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 223: f 0.00373931 trial_f 1.92808 accepted 0  lowest_f 1.99974e-15
# basinhopping step 224: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 225: f 0.00373931 trial_f 0.229713 accepted 0  lowest_f 1.99974e-15
# basinhopping step 226: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 227: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 228: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 229: f 0.00373931 trial_f 2.28036 accepted 0  lowest_f 1.99974e-15
# basinhopping step 230: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 231: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 232: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 233: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 234: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 235: f 0.00373931 trial_f 2.36909 accepted 0  lowest_f 1.99974e-15
# basinhopping step 236: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 237: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 238: f 0.00373931 trial_f 14.3869 accepted 0  lowest_f 1.99974e-15
# basinhopping step 239: f 0.00373931 trial_f 14.3048 accepted 0  lowest_f 1.99974e-15
# basinhopping step 240: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 241: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 242: f 0.00373931 trial_f 2.39327 accepted 0  lowest_f 1.99974e-15
# basinhopping step 243: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 244: f 0.00373931 trial_f 0.25109 accepted 0  lowest_f 1.99974e-15
# basinhopping step 245: f 0.00373931 trial_f 14.3877 accepted 0  lowest_f 1.99974e-15
# basinhopping step 246: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 247: f 0.509236 trial_f 0.509236 accepted 1  lowest_f 1.99974e-15
# basinhopping step 248: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 249: f 0.00373874 trial_f 2.22915 accepted 0  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.520000 target 0.500000 new stepsize 1.37174 old stepsize 1.23457
# basinhopping step 250: f 0.618145 trial_f 0.618145 accepted 1  lowest_f 1.99974e-15
# basinhopping step 251: f 0.618145 trial_f 14.3587 accepted 0  lowest_f 1.99974e-15
# basinhopping step 252: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 253: f 0.00373874 trial_f 2.05534 accepted 0  lowest_f 1.99974e-15
# basinhopping step 254: f 0.0260295 trial_f 0.0260295 accepted 1  lowest_f 1.99974e-15
# basinhopping step 255: f 0.00631229 trial_f 0.00631229 accepted 1  lowest_f 1.99974e-15
# basinhopping step 256: f 0.00631229 trial_f 2.34435 accepted 0  lowest_f 1.99974e-15
# basinhopping step 257: f 0.00631229 trial_f 0.508344 accepted 0  lowest_f 1.99974e-15
# basinhopping step 258: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 259: f 0.00463096 trial_f 0.00463096 accepted 1  lowest_f 1.99974e-15
# basinhopping step 260: f 0.0065872 trial_f 0.0065872 accepted 1  lowest_f 1.99974e-15
# basinhopping step 261: f 0.0065872 trial_f 14.3029 accepted 0  lowest_f 1.99974e-15
# basinhopping step 262: f 0.00373932 trial_f 0.00373932 accepted 1  lowest_f 1.99974e-15
# basinhopping step 263: f 0.00373932 trial_f 14.3077 accepted 0  lowest_f 1.99974e-15
# basinhopping step 264: f 0.00373932 trial_f 14.3877 accepted 0  lowest_f 1.99974e-15
# basinhopping step 265: f 0.00373932 trial_f 14.3783 accepted 0  lowest_f 1.99974e-15
# basinhopping step 266: f 0.00373932 trial_f 2.41264 accepted 0  lowest_f 1.99974e-15
# basinhopping step 267: f 0.0792738 trial_f 0.0792738 accepted 1  lowest_f 1.99974e-15
# basinhopping step 268: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 269: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 270: f 0.00373931 trial_f 106579 accepted 0  lowest_f 1.99974e-15
# basinhopping step 271: f 0.00373931 trial_f 2.74867e+06 accepted 0  lowest_f 1.99974e-15
# basinhopping step 272: f 0.00373931 trial_f 1.43861 accepted 0  lowest_f 1.99974e-15
# basinhopping step 273: f 0.00373931 trial_f 14.3513 accepted 0  lowest_f 1.99974e-15
# basinhopping step 274: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 275: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 276: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 277: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 278: f 0.00373931 trial_f 14.3874 accepted 0  lowest_f 1.99974e-15
# basinhopping step 279: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 280: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 281: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 282: f 0.00373931 trial_f 0.212964 accepted 0  lowest_f 1.99974e-15
# basinhopping step 283: f 0.00373931 trial_f 2.39795 accepted 0  lowest_f 1.99974e-15
# basinhopping step 284: f 0.00373931 trial_f 14.3877 accepted 0  lowest_f 1.99974e-15
# basinhopping step 285: f 0.00373931 trial_f 14.3065 accepted 0  lowest_f 1.99974e-15
# basinhopping step 286: f 0.0789031 trial_f 0.0789031 accepted 1  lowest_f 1.99974e-15
# basinhopping step 287: f 0.0438623 trial_f 0.0438623 accepted 1  lowest_f 1.99974e-15
# basinhopping step 288: f 0.00699559 trial_f 0.00699559 accepted 1  lowest_f 1.99974e-15
# basinhopping step 289: f 0.00699559 trial_f 14.3856 accepted 0  lowest_f 1.99974e-15
# basinhopping step 290: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 291: f 0.348859 trial_f 0.348859 accepted 1  lowest_f 1.99974e-15
# basinhopping step 292: f 0.348859 trial_f 13.5309 accepted 0  lowest_f 1.99974e-15
# basinhopping step 293: f 0.229712 trial_f 0.229712 accepted 1  lowest_f 1.99974e-15
# basinhopping step 294: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 295: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 296: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 297: f 0.00373931 trial_f 0.903819 accepted 0  lowest_f 1.99974e-15
# basinhopping step 298: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 299: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.530000 target 0.500000 new stepsize 1.52416 old stepsize 1.37174
# basinhopping step 300: f 0.00373931 trial_f 14.3525 accepted 0  lowest_f 1.99974e-15
# basinhopping step 301: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 302: f 0.00373931 trial_f 14.3082 accepted 0  lowest_f 1.99974e-15
# basinhopping step 303: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 304: f 0.00373931 trial_f 14.3817 accepted 0  lowest_f 1.99974e-15
# basinhopping step 305: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 306: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 307: f 0.00373931 trial_f 0.355921 accepted 0  lowest_f 1.99974e-15
# basinhopping step 308: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 309: f 0.00373931 trial_f 14.3732 accepted 0  lowest_f 1.99974e-15
# basinhopping step 310: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 311: f 0.00373931 trial_f 14.3384 accepted 0  lowest_f 1.99974e-15
# basinhopping step 312: f 0.00373931 trial_f 14.309 accepted 0  lowest_f 1.99974e-15
# basinhopping step 313: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 314: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 315: f 0.0346692 trial_f 0.0346692 accepted 1  lowest_f 1.99974e-15
# basinhopping step 316: f 0.00370466 trial_f 0.00370466 accepted 1  lowest_f 1.99974e-15
# basinhopping step 317: f 0.00370466 trial_f 2.35522 accepted 0  lowest_f 1.99974e-15
# basinhopping step 318: f 0.00370466 trial_f 2.39657 accepted 0  lowest_f 1.99974e-15
# basinhopping step 319: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 320: f 0.00373931 trial_f 2.40438 accepted 0  lowest_f 1.99974e-15
# basinhopping step 321: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 322: f 0.00373931 trial_f 14.309 accepted 0  lowest_f 1.99974e-15
# basinhopping step 323: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 324: f 7.38206e-15 trial_f 7.38206e-15 accepted 1  lowest_f 1.99974e-15
# basinhopping step 325: f 0.00373871 trial_f 0.00373871 accepted 1  lowest_f 1.99974e-15
# basinhopping step 326: f 0.0111166 trial_f 0.0111166 accepted 1  lowest_f 1.99974e-15
# basinhopping step 327: f 0.00599011 trial_f 0.00599011 accepted 1  lowest_f 1.99974e-15
# basinhopping step 328: f 0.00599011 trial_f 2.28244 accepted 0  lowest_f 1.99974e-15
# basinhopping step 329: f 0.00599011 trial_f 14.3872 accepted 0  lowest_f 1.99974e-15
# basinhopping step 330: f 0.00197007 trial_f 0.00197007 accepted 1  lowest_f 1.99974e-15
# basinhopping step 331: f 0.00197007 trial_f 0.143137 accepted 0  lowest_f 1.99974e-15
# basinhopping step 332: f 0.00197007 trial_f 8.61046 accepted 0  lowest_f 1.99974e-15
# basinhopping step 333: f 0.00197007 trial_f 14.3912 accepted 0  lowest_f 1.99974e-15
# basinhopping step 334: f 0.003714 trial_f 0.003714 accepted 1  lowest_f 1.99974e-15
# basinhopping step 335: f 0.003714 trial_f 14.3083 accepted 0  lowest_f 1.99974e-15
# basinhopping step 336: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 337: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 338: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 339: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 340: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 341: f 0.00373931 trial_f 14.305 accepted 0  lowest_f 1.99974e-15
# basinhopping step 342: f 0.0383082 trial_f 0.0383082 accepted 1  lowest_f 1.99974e-15
# basinhopping step 343: f 0.0383082 trial_f 14.3334 accepted 0  lowest_f 1.99974e-15
# basinhopping step 344: f 0.0383082 trial_f 14.3802 accepted 0  lowest_f 1.99974e-15
# basinhopping step 345: f 0.0383082 trial_f 14.3802 accepted 0  lowest_f 1.99974e-15
# basinhopping step 346: f 0.0383082 trial_f 2.3504 accepted 0  lowest_f 1.99974e-15
# basinhopping step 347: f 0.0383082 trial_f 14.3244 accepted 0  lowest_f 1.99974e-15
# basinhopping step 348: f 0.00370465 trial_f 0.00370465 accepted 1  lowest_f 1.99974e-15
# basinhopping step 349: f 0.000247822 trial_f 0.000247822 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.531429 target 0.500000 new stepsize 1.69351 old stepsize 1.52416
# basinhopping step 350: f 1.49459e-11 trial_f 1.49459e-11 accepted 1  lowest_f 1.99974e-15
# basinhopping step 351: f 1.49459e-11 trial_f 0.00370503 accepted 0  lowest_f 1.99974e-15
# basinhopping step 352: f 0.0451468 trial_f 0.0451468 accepted 1  lowest_f 1.99974e-15
# basinhopping step 353: f 0.0451468 trial_f 14.2123 accepted 0  lowest_f 1.99974e-15
# basinhopping step 354: f 0.0561442 trial_f 0.0561442 accepted 1  lowest_f 1.99974e-15
# basinhopping step 355: f 0.00727112 trial_f 0.00727112 accepted 1  lowest_f 1.99974e-15
# basinhopping step 356: f 0.00727112 trial_f 2.41529 accepted 0  lowest_f 1.99974e-15
# basinhopping step 357: f 0.00727112 trial_f 1.6335 accepted 0  lowest_f 1.99974e-15
# basinhopping step 358: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 359: f 0.00373931 trial_f 2.40806 accepted 0  lowest_f 1.99974e-15
# basinhopping step 360: f 0.0318591 trial_f 0.0318591 accepted 1  lowest_f 1.99974e-15
# basinhopping step 361: f 0.0318591 trial_f 2.20048 accepted 0  lowest_f 1.99974e-15
# basinhopping step 362: f 0.0318591 trial_f 0.229736 accepted 0  lowest_f 1.99974e-15
# basinhopping step 363: f 0.00370465 trial_f 0.00370465 accepted 1  lowest_f 1.99974e-15
# basinhopping step 364: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 365: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 366: f 0.0159076 trial_f 0.0159076 accepted 1  lowest_f 1.99974e-15
# basinhopping step 367: f 0.0064287 trial_f 0.0064287 accepted 1  lowest_f 1.99974e-15
# basinhopping step 368: f 0.246703 trial_f 0.246703 accepted 1  lowest_f 1.99974e-15
# basinhopping step 369: f 0.246703 trial_f 14.3496 accepted 0  lowest_f 1.99974e-15
# basinhopping step 370: f 0.246703 trial_f 14.3499 accepted 0  lowest_f 1.99974e-15
# basinhopping step 371: f 0.129265 trial_f 0.129265 accepted 1  lowest_f 1.99974e-15
# basinhopping step 372: f 0.129265 trial_f 14.3862 accepted 0  lowest_f 1.99974e-15
# basinhopping step 373: f 0.129265 trial_f 9.93757 accepted 0  lowest_f 1.99974e-15
# basinhopping step 374: f 0.129265 trial_f 6.10297 accepted 0  lowest_f 1.99974e-15
# basinhopping step 375: f 0.229752 trial_f 0.229752 accepted 1  lowest_f 1.99974e-15
# basinhopping step 376: f 0.229752 trial_f 14.352 accepted 0  lowest_f 1.99974e-15
# basinhopping step 377: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 378: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 379: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 380: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 381: f 0.00373931 trial_f 14.3092 accepted 0  lowest_f 1.99974e-15
# basinhopping step 382: f 0.00373931 trial_f 14.3695 accepted 0  lowest_f 1.99974e-15
# basinhopping step 383: f 0.00373931 trial_f 1.87206 accepted 0  lowest_f 1.99974e-15
# basinhopping step 384: f 0.00373931 trial_f 14.3531 accepted 0  lowest_f 1.99974e-15
# basinhopping step 385: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 386: f 0.00373931 trial_f 0.2984 accepted 0  lowest_f 1.99974e-15
# basinhopping step 387: f 0.00373931 trial_f 14.3122 accepted 0  lowest_f 1.99974e-15
# basinhopping step 388: f 0.00373931 trial_f 14.3056 accepted 0  lowest_f 1.99974e-15
# basinhopping step 389: f 0.00373931 trial_f 0.507528 accepted 0  lowest_f 1.99974e-15
# basinhopping step 390: f 0.00373931 trial_f 14.3051 accepted 0  lowest_f 1.99974e-15
# basinhopping step 391: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 392: f 0.00373931 trial_f 14.3093 accepted 0  lowest_f 1.99974e-15
# basinhopping step 393: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 394: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 395: f 0.00373931 trial_f 0.103774 accepted 0  lowest_f 1.99974e-15
# basinhopping step 396: f 0.00373931 trial_f 14.3071 accepted 0  lowest_f 1.99974e-15
# basinhopping step 397: f 0.0765226 trial_f 0.0765226 accepted 1  lowest_f 1.99974e-15
# basinhopping step 398: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 399: f 0.00896113 trial_f 0.00896113 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.527500 target 0.500000 new stepsize 1.88168 old stepsize 1.69351
# basinhopping step 400: f 0.00443091 trial_f 0.00443091 accepted 1  lowest_f 1.99974e-15
# basinhopping step 401: f 0.00443091 trial_f 2.40325 accepted 0  lowest_f 1.99974e-15
# basinhopping step 402: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 403: f 0.18428 trial_f 0.18428 accepted 1  lowest_f 1.99974e-15
# basinhopping step 404: f 0.18428 trial_f 2.35404 accepted 0  lowest_f 1.99974e-15
# basinhopping step 405: f 0.508233 trial_f 0.508233 accepted 1  lowest_f 1.99974e-15
# basinhopping step 406: f 0.230533 trial_f 0.230533 accepted 1  lowest_f 1.99974e-15
# basinhopping step 407: f 0.230533 trial_f 13.9708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 408: f 0.230533 trial_f 13.0106 accepted 0  lowest_f 1.99974e-15
# basinhopping step 409: f 0.230533 trial_f 0.509305 accepted 0  lowest_f 1.99974e-15
# basinhopping step 410: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 411: f 0.00373874 trial_f 14.3919 accepted 0  lowest_f 1.99974e-15
# basinhopping step 412: f 0.00373874 trial_f 2.40956 accepted 0  lowest_f 1.99974e-15
# basinhopping step 413: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 414: f 0.00373931 trial_f 14.3048 accepted 0  lowest_f 1.99974e-15
# basinhopping step 415: f 0.000673097 trial_f 0.000673097 accepted 1  lowest_f 1.99974e-15
# basinhopping step 416: f 0.00373859 trial_f 0.00373859 accepted 1  lowest_f 1.99974e-15
# basinhopping step 417: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 418: f 0.00373931 trial_f 14.3145 accepted 0  lowest_f 1.99974e-15
# basinhopping step 419: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 420: f 0.142426 trial_f 0.142426 accepted 1  lowest_f 1.99974e-15
# basinhopping step 421: f 0.00592619 trial_f 0.00592619 accepted 1  lowest_f 1.99974e-15
# basinhopping step 422: f 0.00373929 trial_f 0.00373929 accepted 1  lowest_f 1.99974e-15
# basinhopping step 423: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 424: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 425: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 426: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 427: f 0.00373931 trial_f 14.3071 accepted 0  lowest_f 1.99974e-15
# basinhopping step 428: f 0.00373931 trial_f 14.3098 accepted 0  lowest_f 1.99974e-15
# basinhopping step 429: f 0.00373931 trial_f 2.74872e+06 accepted 0  lowest_f 1.99974e-15
# basinhopping step 430: f 0.00373931 trial_f 14.3731 accepted 0  lowest_f 1.99974e-15
# basinhopping step 431: f 0.0185967 trial_f 0.0185967 accepted 1  lowest_f 1.99974e-15
# basinhopping step 432: f 0.0185967 trial_f 0.229717 accepted 0  lowest_f 1.99974e-15
# basinhopping step 433: f 0.229717 trial_f 0.229717 accepted 1  lowest_f 1.99974e-15
# basinhopping step 434: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 435: f 0.00373874 trial_f 14.309 accepted 0  lowest_f 1.99974e-15
# basinhopping step 436: f 0.22971 trial_f 0.22971 accepted 1  lowest_f 1.99974e-15
# basinhopping step 437: f 0.22971 trial_f 14.3489 accepted 0  lowest_f 1.99974e-15
# basinhopping step 438: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 439: f 0.00373874 trial_f 14.3112 accepted 0  lowest_f 1.99974e-15
# basinhopping step 440: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 441: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 442: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 443: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 444: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 445: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 446: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 447: f 0.00373931 trial_f 14.3106 accepted 0  lowest_f 1.99974e-15
# basinhopping step 448: f 0.00373931 trial_f 2.31259 accepted 0  lowest_f 1.99974e-15
# basinhopping step 449: f 0.0131863 trial_f 0.0131863 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.537778 target 0.500000 new stepsize 2.09075 old stepsize 1.88168
# basinhopping step 450: f 0.00585145 trial_f 0.00585145 accepted 1  lowest_f 1.99974e-15
# basinhopping step 451: f 0.00585145 trial_f 14.3515 accepted 0  lowest_f 1.99974e-15
# basinhopping step 452: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 453: f 0.00373931 trial_f 2.18437 accepted 0  lowest_f 1.99974e-15
# basinhopping step 454: f 0.00373931 trial_f 14.3106 accepted 0  lowest_f 1.99974e-15
# basinhopping step 455: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 456: f 0.22971 trial_f 0.22971 accepted 1  lowest_f 1.99974e-15
# basinhopping step 457: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 458: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 459: f 0.229709 trial_f 14.3481 accepted 0  lowest_f 1.99974e-15
# basinhopping step 460: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 461: f 0.229677 trial_f 14.1156 accepted 0  lowest_f 1.99974e-15
# basinhopping step 462: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 463: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 464: f 0.00373931 trial_f 1.8167 accepted 0  lowest_f 1.99974e-15
# basinhopping step 465: f 0.00373931 trial_f 2.47754 accepted 0  lowest_f 1.99974e-15
# basinhopping step 466: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 467: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 468: f 0.229678 trial_f 88011.7 accepted 0  lowest_f 1.99974e-15
# basinhopping step 469: f 0.229678 trial_f 0.510918 accepted 0  lowest_f 1.99974e-15
# basinhopping step 470: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 471: f 0.0186982 trial_f 0.0186982 accepted 1  lowest_f 1.99974e-15
# basinhopping step 472: f 0.0186982 trial_f 0.142749 accepted 0  lowest_f 1.99974e-15
# basinhopping step 473: f 0.0186982 trial_f 2.37151 accepted 0  lowest_f 1.99974e-15
# basinhopping step 474: f 0.0186982 trial_f 2.41568 accepted 0  lowest_f 1.99974e-15
# basinhopping step 475: f 0.00565 trial_f 0.00565 accepted 1  lowest_f 1.99974e-15
# basinhopping step 476: f 0.00565 trial_f 1.92977 accepted 0  lowest_f 1.99974e-15
# basinhopping step 477: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 478: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 479: f 0.00373931 trial_f 2.38009 accepted 0  lowest_f 1.99974e-15
# basinhopping step 480: f 0.22971 trial_f 0.22971 accepted 1  lowest_f 1.99974e-15
# basinhopping step 481: f 0.22971 trial_f 14.2681 accepted 0  lowest_f 1.99974e-15
# basinhopping step 482: f 0.0250444 trial_f 0.0250444 accepted 1  lowest_f 1.99974e-15
# basinhopping step 483: f 0.00373894 trial_f 0.00373894 accepted 1  lowest_f 1.99974e-15
# basinhopping step 484: f 0.268247 trial_f 0.268247 accepted 1  lowest_f 1.99974e-15
# basinhopping step 485: f 0.268247 trial_f 8.15754 accepted 0  lowest_f 1.99974e-15
# basinhopping step 486: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 487: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 488: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 489: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 490: f 0.00373931 trial_f 0.710002 accepted 0  lowest_f 1.99974e-15
# basinhopping step 491: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 492: f 0.00373931 trial_f 156090 accepted 0  lowest_f 1.99974e-15
# basinhopping step 493: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 494: f 0.00373931 trial_f 2.34948 accepted 0  lowest_f 1.99974e-15
# basinhopping step 495: f 0.102085 trial_f 0.102085 accepted 1  lowest_f 1.99974e-15
# basinhopping step 496: f 0.017403 trial_f 0.017403 accepted 1  lowest_f 1.99974e-15
# basinhopping step 497: f 0.179401 trial_f 0.179401 accepted 1  lowest_f 1.99974e-15
# basinhopping step 498: f 0.179401 trial_f 11.1464 accepted 0  lowest_f 1.99974e-15
# basinhopping step 499: f 0.00648288 trial_f 0.00648288 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.544000 target 0.500000 new stepsize 2.32306 old stepsize 2.09075
# basinhopping step 500: f 0.00648288 trial_f 14.3083 accepted 0  lowest_f 1.99974e-15
# basinhopping step 501: f 0.00648288 trial_f 1.9189 accepted 0  lowest_f 1.99974e-15
# basinhopping step 502: f 0.00648288 trial_f 2.40177 accepted 0  lowest_f 1.99974e-15
# basinhopping step 503: f 0.00648288 trial_f 14.3446 accepted 0  lowest_f 1.99974e-15
# basinhopping step 504: f 0.00388365 trial_f 0.00388365 accepted 1  lowest_f 1.99974e-15
# basinhopping step 505: f 0.00388365 trial_f 14.308 accepted 0  lowest_f 1.99974e-15
# basinhopping step 506: f 0.00388365 trial_f 0.229711 accepted 0  lowest_f 1.99974e-15
# basinhopping step 507: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 508: f 0.00373931 trial_f 0.289754 accepted 0  lowest_f 1.99974e-15
# basinhopping step 509: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 510: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 511: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 512: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 513: f 0.00373931 trial_f 14.3162 accepted 0  lowest_f 1.99974e-15
# basinhopping step 514: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 515: f 0.00373931 trial_f 14.3078 accepted 0  lowest_f 1.99974e-15
# basinhopping step 516: f 0.00373931 trial_f 14.3752 accepted 0  lowest_f 1.99974e-15
# basinhopping step 517: f 0.00373931 trial_f 14.3072 accepted 0  lowest_f 1.99974e-15
# basinhopping step 518: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 519: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 520: f 0.00373874 trial_f 2.24533 accepted 0  lowest_f 1.99974e-15
# basinhopping step 521: f 0.00373874 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 522: f 0.000660583 trial_f 0.000660583 accepted 1  lowest_f 1.99974e-15
# basinhopping step 523: f 0.000660583 trial_f 14.3565 accepted 0  lowest_f 1.99974e-15
# basinhopping step 524: f 0.000660583 trial_f 14.2921 accepted 0  lowest_f 1.99974e-15
# basinhopping step 525: f 0.229727 trial_f 0.229727 accepted 1  lowest_f 1.99974e-15
# basinhopping step 526: f 0.00608878 trial_f 0.00608878 accepted 1  lowest_f 1.99974e-15
# basinhopping step 527: f 0.00608878 trial_f 14.2525 accepted 0  lowest_f 1.99974e-15
# basinhopping step 528: f 0.00638366 trial_f 0.00638366 accepted 1  lowest_f 1.99974e-15
# basinhopping step 529: f 0.298629 trial_f 0.298629 accepted 1  lowest_f 1.99974e-15
# basinhopping step 530: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 531: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 532: f 0.229709 trial_f 14.355 accepted 0  lowest_f 1.99974e-15
# basinhopping step 533: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 534: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 535: f 0.29419 trial_f 0.29419 accepted 1  lowest_f 1.99974e-15
# basinhopping step 536: f 0.29419 trial_f 14.3914 accepted 0  lowest_f 1.99974e-15
# basinhopping step 537: f 0.0037018 trial_f 0.0037018 accepted 1  lowest_f 1.99974e-15
# basinhopping step 538: f 0.0037018 trial_f 14.3627 accepted 0  lowest_f 1.99974e-15
# basinhopping step 539: f 0.00373928 trial_f 0.00373928 accepted 1  lowest_f 1.99974e-15
# basinhopping step 540: f 0.00373928 trial_f 4.40042 accepted 0  lowest_f 1.99974e-15
# ...
# basinhopping step 821: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 822: f 0.00373931 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 823: f 0.109704 trial_f 0.109704 accepted 1  lowest_f 1.99974e-15
# basinhopping step 824: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 825: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 826: f 0.00373931 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 827: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 828: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 829: f 0.00982387 trial_f 0.00982387 accepted 1  lowest_f 1.99974e-15
# basinhopping step 830: f 0.00385229 trial_f 0.00385229 accepted 1  lowest_f 1.99974e-15
# basinhopping step 831: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 832: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 833: f 0.229708 trial_f 2.20552 accepted 0  lowest_f 1.99974e-15
# basinhopping step 834: f 0.229708 trial_f 5.43633 accepted 0  lowest_f 1.99974e-15
# basinhopping step 835: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 836: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 837: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 838: f 0.00373874 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 839: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 840: f 0.00373931 trial_f 5.0125 accepted 0  lowest_f 1.99974e-15
# basinhopping step 841: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 842: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 843: f 0.229677 trial_f 14.3492 accepted 0  lowest_f 1.99974e-15
# basinhopping step 844: f 0.229677 trial_f 14.3476 accepted 0  lowest_f 1.99974e-15
# basinhopping step 845: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 846: f 0.00373874 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 847: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 848: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 849: f 0.00373931 trial_f 14.2006 accepted 0  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.591765 target 0.500000 new stepsize 4.85694 old stepsize 4.37124
# basinhopping step 850: f 0.00373931 trial_f 14.2023 accepted 0  lowest_f 1.99974e-15
# basinhopping step 851: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 852: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 853: f 0.00373931 trial_f 14.3118 accepted 0  lowest_f 1.99974e-15
# basinhopping step 854: f 0.00373931 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 855: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 856: f 0.229678 trial_f 0.229678 accepted 1  lowest_f 1.99974e-15
# basinhopping step 857: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 858: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 859: f 0.00373874 trial_f 2.20144 accepted 0  lowest_f 1.99974e-15
# basinhopping step 860: f 0.00373874 trial_f 14.1415 accepted 0  lowest_f 1.99974e-15
# basinhopping step 861: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 862: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 863: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 864: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 865: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 866: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 867: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 868: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 869: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 870: f 0.00373931 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 871: f 0.00373931 trial_f 3.54966 accepted 0  lowest_f 1.99974e-15
# basinhopping step 872: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 873: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 874: f 0.00373931 trial_f 0.229707 accepted 0  lowest_f 1.99974e-15
# basinhopping step 875: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 876: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 877: f 0.00373931 trial_f 2.31598 accepted 0  lowest_f 1.99974e-15
# basinhopping step 878: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 879: f 0.00373931 trial_f 3.52836 accepted 0  lowest_f 1.99974e-15
# basinhopping step 880: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 881: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 882: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 883: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 884: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 885: f 0.00373874 trial_f 0.229707 accepted 0  lowest_f 1.99974e-15
# basinhopping step 886: f 0.00373874 trial_f 14.3239 accepted 0  lowest_f 1.99974e-15
# basinhopping step 887: f 0.00373874 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 888: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 889: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 890: f 0.00373874 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 891: f 0.00373874 trial_f 14.392 accepted 0  lowest_f 1.99974e-15
# basinhopping step 892: f 0.00373874 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 893: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 894: f 0.229711 trial_f 0.229711 accepted 1  lowest_f 1.99974e-15
# basinhopping step 895: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 896: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 897: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 898: f 0.00373874 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 899: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.595556 target 0.500000 new stepsize 5.3966 old stepsize 4.85694
# basinhopping step 900: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 901: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 902: f 0.00373874 trial_f 0.266789 accepted 0  lowest_f 1.99974e-15
# basinhopping step 903: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 904: f 0.229709 trial_f 2.94129 accepted 0  lowest_f 1.99974e-15
# basinhopping step 905: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 906: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 907: f 0.00373874 trial_f 0.229707 accepted 0  lowest_f 1.99974e-15
# basinhopping step 908: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 909: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 910: f 0.00373931 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 911: f 0.00373931 trial_f 13.9808 accepted 0  lowest_f 1.99974e-15
# basinhopping step 912: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 913: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 914: f 0.229708 trial_f 14.3634 accepted 0  lowest_f 1.99974e-15
# basinhopping step 915: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 916: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 917: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 918: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 919: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 920: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 921: f 0.229706 trial_f 0.229706 accepted 1  lowest_f 1.99974e-15
# basinhopping step 922: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 923: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 924: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 925: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 926: f 0.00373874 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 927: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 928: f 0.00373931 trial_f 13.9702 accepted 0  lowest_f 1.99974e-15
# basinhopping step 929: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 930: f 0.229709 trial_f 13.9885 accepted 0  lowest_f 1.99974e-15
# basinhopping step 931: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 932: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 933: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 934: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 935: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 936: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 937: f 0.00373931 trial_f 14.3762 accepted 0  lowest_f 1.99974e-15
# basinhopping step 938: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 939: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 940: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 941: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 942: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 943: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 944: f 0.229677 trial_f 14.3559 accepted 0  lowest_f 1.99974e-15
# basinhopping step 945: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 946: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 947: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 948: f 0.00373931 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 949: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.604211 target 0.500000 new stepsize 5.99622 old stepsize 5.3966
# basinhopping step 950: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 951: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 952: f 3.38907e-12 trial_f 3.38907e-12 accepted 1  lowest_f 1.99974e-15
# basinhopping step 953: f 0.22972 trial_f 0.22972 accepted 1  lowest_f 1.99974e-15
# basinhopping step 954: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 955: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 956: f 1.36007 trial_f 1.36007 accepted 1  lowest_f 1.99974e-15
# basinhopping step 957: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 958: f 0.00373874 trial_f 14.3775 accepted 0  lowest_f 1.99974e-15
# basinhopping step 959: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 960: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 961: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 962: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 963: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 964: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 965: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 966: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 967: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 968: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 969: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 970: f 0.00373874 trial_f 1.08793 accepted 0  lowest_f 1.99974e-15
# basinhopping step 971: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 972: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 973: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 974: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 975: f 0.00373931 trial_f 0.229709 accepted 0  lowest_f 1.99974e-15
# basinhopping step 976: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 977: f 0.00373931 trial_f 0.229708 accepted 0  lowest_f 1.99974e-15
# basinhopping step 978: f 0.229708 trial_f 0.229708 accepted 1  lowest_f 1.99974e-15
# basinhopping step 979: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 980: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 981: f 3.25047e-15 trial_f 3.25047e-15 accepted 1  lowest_f 1.99974e-15
# basinhopping step 982: f 0.00373878 trial_f 0.00373878 accepted 1  lowest_f 1.99974e-15
# basinhopping step 983: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 984: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 985: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 986: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 987: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 988: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 989: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15
# basinhopping step 990: f 0.229707 trial_f 0.229707 accepted 1  lowest_f 1.99974e-15
# basinhopping step 991: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 992: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 993: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 994: f 0.229677 trial_f 0.229677 accepted 1  lowest_f 1.99974e-15
# basinhopping step 995: f 0.229677 trial_f 14.3558 accepted 0  lowest_f 1.99974e-15
# basinhopping step 996: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# basinhopping step 997: f 0.00373874 trial_f 14.3883 accepted 0  lowest_f 1.99974e-15
# basinhopping step 998: f 0.229709 trial_f 0.229709 accepted 1  lowest_f 1.99974e-15
# basinhopping step 999: f 0.00373874 trial_f 0.00373874 accepted 1  lowest_f 1.99974e-15
# adaptive stepsize: acceptance rate 0.618000 target 0.500000 new stepsize 6.66246 old stepsize 5.99622
# basinhopping step 1000: f 0.00373931 trial_f 0.00373931 accepted 1  lowest_f 1.99974e-15

# %%
mu2, rho2, M2, P2 = result.x[0], result.x[1], result.x[2], result.x[3]
Q2 = M2/rho2
specific_speed_1 = N1*np.sqrt(M1/rho1)/(P1/(rho1*g))**(3/4)
specific_speed_2 = N2*np.sqrt(M2/rho2)/(P2/(rho2*g))**(3/4)
print(f"Ns = {specific_speed_2:.4f}, Matching = {100-abs(specific_speed_1-specific_speed_2)/specific_speed_1*100} %")

flow_coeff_1 = Q1/N1/D1**3
flow_coeff_2 = Q2/N2/D2**3
print(f"Flow Coefficient Prototype = {flow_coeff_1}, Model = {flow_coeff_2}, Matching = {100-abs(flow_coeff_1-flow_coeff_2)/flow_coeff_1*100} %")

head_coeff_1 = g*P1/(rho1*g)/N1**2/D1**2
head_coeff_2 = g*P2/(rho2*g)/N2**2/D2**2
print(f"Head Coefficient Prototype = {head_coeff_1}, Model = {head_coeff_2}, Matching = {100-abs(head_coeff_1-head_coeff_2)/head_coeff_1*100} %")

Reysnold_1 = rho1*N1*D1**2/mu1
Reysnold_2 = rho2*N2*D2**2/mu2
print(f"Reynolds Number Prototype = {Reysnold_1:.4f}, Model = {Reysnold_2:.4f}, Matching = {100-abs(Reysnold_1-Reysnold_2)/Reysnold_1*100} %")

power_coeff_1 = P1 * M1 / rho1 / ( rho1 * N1**3 * D1**5)
power_coeff_2 = P2 * M2 / rho2 / ( rho2 * N2**3 * D2**5)
print(f"Power Coefficient Prototype = {power_coeff_1:.8f}, Model = {power_coeff_2:.8f}, Matching = {100-abs(power_coeff_1-power_coeff_2)/power_coeff_1*100} %")

pump_eff = 0.50
motor_eff = 0.85
mechanical_eff = 0.99

print(f"\nPrototype's Shaft Speed is {N1:.3f} RPM\n"
      f"Prototype's Impeller Diameter is {D1*1e3:.3f} mm\n"
      f"Prototype's Mass Flow Rate is {M1:.3f} Kg/s\n"
      f"Prototype's Pressure Across Pump is {P1/1e5:.3f} Bar\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Prototype's Pressure Head is {P1/rho1/9.807:.3f} m Testing Fluid\n"
      f"Prototype's Pressure Head is {P1/1000/9.807:.3f} m Water\n"
      f"Prototype's Volumetric Flow Rate is {Q1*1000:.4f} L/s\n"
      f"Prototype's Fluid's Viscosity is {mu1*1000:.4f} mPa-s\n"
      f"Prototype's Fluid's Density is {rho1:.4f} kg/m^3\n"
      f"Prototype's Hydraulic Power = {Q1*P1:.3f} W\n"
      f"Prototype's Shaft Power = {Q1*P1/pump_eff/mechanical_eff:.3f} W\n"
      f"Prototype's Shaft Torque = {Q1*P1/pump_eff/mechanical_eff/(N1*2*math.pi/60):.3f} N-m\n"
      f"Prototype's Electrical Power = {Q1*P1/pump_eff/mechanical_eff/motor_eff:.3f} W\n")

print(f"\nModel's Shaft Speed is {N2:.3f} RPM\n"
      f"Model's Impeller Diameter is {D2*1e3:.3f} mm\n"
      f"Model's Mass Flow Rate is {M2:.3f} Kg/s\n"
      f"Model's Pressure Across Pump is {P2/1e5:.3f} Bar\n"
      f"Model's Pressure Head is {P2/rho1/9.807:.3f} m HAN+H2O2\n"
      f"Model's Pressure Head is {P2/rho2/9.807:.3f} m Testing Fluid\n"
      f"Model's Pressure Head is {P2/1000/9.807:.3f} m Water\n"
      f"Model's Volumetric Flow Rate is {Q2*1000:.4f} L/s\n"
      f"Model's Fluid's Viscosity is {mu2*1000:.4f} mPa-s\n"
      f"Model's Fluid's Density is {rho2:.4f} kg/m^3\n"
      f"Model's Hydraulic Power = {Q2*P2:.3f} W\n"
      f"Model's Shaft Power = {Q2*P2/pump_eff/mechanical_eff:.3f} W\n"
      f"Model's Shaft Torque = {Q2*P2/pump_eff/mechanical_eff/(N2*2*math.pi/60):.3f} N-m\n"
      f"Model's Electrical Power = {Q2*P2/pump_eff/mechanical_eff/motor_eff:.3f} W\n")
# Out:
# Ns = 13.7895, Matching = 99.99999996858477 %
# Flow Coefficient Prototype = 0.00031263792849786664, Model = 0.00031263794309814135, Matching = 99.9999953299733 %
# Head Coefficient Prototype = 0.001366148931251182, Model = 0.001366148973211956, Matching = 99.9999969285359 %
# Reynolds Number Prototype = 836553.8462, Model = 836553.8071, Matching = 99.99999532895454 %
# Power Coefficient Prototype = 0.00000043, Model = 0.00000043, Matching = 99.99999225850901 %
#
# Prototype's Shaft Speed is 14000.000 RPM
# Prototype's Impeller Diameter is 50.000 mm
# Prototype's Mass Flow Rate is 0.850 Kg/s
# Prototype's Pressure Across Pump is 10.400 Bar
# Prototype's Pressure Head is 68.259 m HAN+H2O2
# Prototype's Pressure Head is 68.259 m Testing Fluid
# Prototype's Pressure Head is 106.047 m Water
# Prototype's Volumetric Flow Rate is 0.5471 L/s
# Prototype's Fluid's Viscosity is 65.0000 mPa-s
# Prototype's Fluid's Density is 1553.6000 kg/m^3
# Prototype's Hydraulic Power = 569.001 W
# Prototype's Shaft Power = 1149.497 W
# Prototype's Shaft Torque = 0.784 N-m
# Prototype's Electrical Power = 1352.349 W
#
#
# Model's Shaft Speed is 8000.000 RPM
# Model's Impeller Diameter is 50.000 mm
# Model's Mass Flow Rate is 0.311 Kg/s
# Model's Pressure Across Pump is 2.172 Bar
# Model's Pressure Head is 14.259 m HAN+H2O2
# Model's Pressure Head is 22.289 m Testing Fluid
# Model's Pressure Head is 22.152 m Water
# Model's Volumetric Flow Rate is 0.3126 L/s
# Model's Fluid's Viscosity is 23.7615 mPa-s
# Model's Fluid's Density is 993.8870 kg/m^3
# Model's Hydraulic Power = 67.920 W
# Model's Shaft Power = 137.212 W
# Model's Shaft Torque = 0.164 N-m
# Model's Electrical Power = 161.426 W
